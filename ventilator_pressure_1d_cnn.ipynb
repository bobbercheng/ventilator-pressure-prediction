# %% [markdown]
# <a href="https://colab.research.google.com/github/bobbercheng/ventilator-pressure-prediction/blob/master/ventilator_pressure_1d_cnn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-1b3f9324-3af1-4d88-85d1-e715b078cb7f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1b3f9324-3af1-4d88-85d1-e715b078cb7f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# User uploaded file "kaggle.json" with length 62 bytes

# %%
# !pip install pandas==1.3.2

# %%
# !pip install kaggle
# !mkdir /root/.kaggle
# !cp kaggle.json /root/.kaggle
# !kaggle competitions download -c ventilator-pressure-prediction
# !mkdir -p /kaggle/input/ventilator-pressure-prediction
# !unzip '*.zip' -d /kaggle/input/ventilator-pressure-prediction
# !ls /kaggle/input/ventilator-pressure-prediction
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.7/dist-packages (1.5.12)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from kaggle) (2021.5.30)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.23.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from kaggle) (4.62.3)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.24.3)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.7/dist-packages (from kaggle) (5.0.2)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.15.0)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.7/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (3.0.4)
# mkdir: cannot create directory ‘/root/.kaggle’: File exists
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /root/.kaggle/kaggle.json'
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.5.12 / client 1.5.4)
# sample_submission.csv.zip: Skipping, found more recently modified local copy (use --force to force download)
# train.csv.zip: Skipping, found more recently modified local copy (use --force to force download)
# test.csv.zip: Skipping, found more recently modified local copy (use --force to force download)
# Archive:  train.csv.zip
# replace /kaggle/input/ventilator-pressure-prediction/train.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: N
#
# Archive:  sample_submission.csv.zip
#
# Archive:  test.csv.zip
#
# 3 archives were successfully processed.
# sample_submission.csv  test.csv  train.csv

# %%
import numpy as np
import pandas as pd

# import optuna

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.callbacks import LearningRateScheduler, ReduceLROnPlateau
from tensorflow.keras.optimizers.schedules import ExponentialDecay

from sklearn.metrics import mean_absolute_error as mae
from sklearn.preprocessing import RobustScaler, normalize
from sklearn.model_selection import train_test_split, GroupKFold, KFold

from IPython.display import display

# %%
DEBUG = False

train = pd.read_csv('/kaggle/input/ventilator-pressure-prediction/train.csv')
test = pd.read_csv('/kaggle/input/ventilator-pressure-prediction/test.csv')
submission = pd.read_csv('/kaggle/input/ventilator-pressure-prediction/sample_submission.csv')

if DEBUG:
    train = train[:80*1000]

# %%
def add_feats(train):
    # # rewritten calculation of lag features from this notebook: https://www.kaggle.com/patrick0302/add-lag-u-in-as-new-feat
# # some of ideas from this notebook: https://www.kaggle.com/mst8823/google-brain-lightgbm-baseline
    # train[["15_out_mean"]] = train.groupby('breath_id')['u_out'].rolling(window=15,min_periods=1).agg({"15_out_mean":"mean"}).reset_index(level=0,drop=True)
    train['last_value_u_in'] = train.groupby('breath_id')['u_in'].transform('last')
    train['u_in_lag1'] = train.groupby('breath_id')['u_in'].shift(1)
    train['u_out_lag1'] = train.groupby('breath_id')['u_out'].shift(1)
    train['u_in_lag_back1'] = train.groupby('breath_id')['u_in'].shift(-1)
    train['u_out_lag_back1'] = train.groupby('breath_id')['u_out'].shift(-1)
    train['u_in_lag2'] = train.groupby('breath_id')['u_in'].shift(2)
    train['u_out_lag2'] = train.groupby('breath_id')['u_out'].shift(2)
    train['u_in_lag3'] = train.groupby('breath_id')['u_in'].shift(3)
    train['u_out_lag3'] = train.groupby('breath_id')['u_out'].shift(3)
    train['u_in_lag_back2'] = train.groupby('breath_id')['u_in'].shift(-2)
    train['u_out_lag_back2'] = train.groupby('breath_id')['u_out'].shift(-2)
    train['u_in_lag_back3'] = train.groupby('breath_id')['u_in'].shift(-3)
    train['u_out_lag_back3'] = train.groupby('breath_id')['u_out'].shift(-3)
    train['u_in_lag_back10'] = train.groupby('breath_id')['u_in'].shift(-10)
    train['u_out_lag_back10'] = train.groupby('breath_id')['u_out'].shift(-10)

    train['u_in_first'] = train.groupby('breath_id')['u_in'].first()
    train['u_out_first'] = train.groupby('breath_id')['u_out'].first()

    ## time since last step
    train['time_step_diff'] = train.groupby('breath_id')['time_step'].diff().fillna(0)
    ### rolling window ts feats
    train['ewm_u_in_mean'] = train.groupby('breath_id')['u_in'].ewm(halflife=9).mean().reset_index(level=0,drop=True)
    train['ewm_u_in_std'] = train.groupby('breath_id')['u_in'].ewm(halflife=10).std().reset_index(level=0,drop=True) ## could add covar?
    train['ewm_u_in_corr'] = train.groupby('breath_id')['u_in'].ewm(halflife=15).corr().reset_index(level=0,drop=True) # self umin corr
    # train['ewm_u_in_corr'] = train.groupby('breath_id')['u_in'].ewm(halflife=6).corr(train.groupby('breath_id')["u_out"]).reset_index(level=0,drop=True) # corr with u_out # error
    ## rolling window of 15 periods
    train[["15_in_sum","15_in_min","15_in_max","15_in_mean","15_out_std"]] = train.groupby('breath_id')['u_in'].rolling(window=15,min_periods=1).agg({"15_in_sum":"sum","15_in_min":"min","15_in_max":"max","15_in_mean":"mean","15_in_std":"std"}).reset_index(level=0,drop=True)
#     train[["45_in_sum","45_in_min","45_in_max","45_in_mean","45_out_std"]] = train.groupby('breath_id')['u_in'].rolling(window=45,min_periods=1).agg({"45_in_sum":"sum","45_in_min":"min","45_in_max":"max","45_in_mean":"mean","45_in_std":"std"}).reset_index(level=0,drop=True)
    train[["45_in_sum","45_in_min","45_in_max","45_in_mean","45_out_std"]] = train.groupby('breath_id')['u_in'].rolling(window=45,min_periods=1).agg({"45_in_sum":"sum","45_in_min":"min","45_in_max":"max","45_in_mean":"mean","45_in_std":"std"}).reset_index(level=0,drop=True)

    train[["15_out_mean"]] = train.groupby('breath_id')['u_out'].rolling(window=15,min_periods=1).agg({"15_out_mean":"mean"}).reset_index(level=0,drop=True)

    print(train.shape[0])
    display(train)
    train = train.fillna(0) # ORIG

    # max, min, mean value of u_in and u_out for each breath
    train['breath_id__u_in__max'] = train.groupby(['breath_id'])['u_in'].transform('max')
    train['breath_id__u_out__max'] = train.groupby(['breath_id'])['u_out'].transform('max')

    train['breath_id__u_out__mean'] =train.groupby(['breath_id'])['u_out'].mean()
    train['breath_id__u_in__mean'] =train.groupby(['breath_id'])['u_in'].mean()

    train['breath_id__u_in__min'] = train.groupby(['breath_id'])['u_in'].transform('min')
    train['breath_id__u_out__min'] = train.groupby(['breath_id'])['u_out'].transform('min')

    train['u_in_first'] = train.groupby(['breath_id'])['u_in'].transform('first')
    train['u_in_last'] = train.groupby(['breath_id'])['u_in'].transform('last')

    train['R_div_C'] = train["R"].div(train["C"])

    # difference between consequitive values
    train['R__C'] = train["R"].astype(str) + '__' + train["C"].astype(str)
    train['u_in_diff1'] = train['u_in'] - train['u_in_lag1']
    train['u_out_diff1'] = train['u_out'] - train['u_out_lag1']
    train['u_in_diff2'] = train['u_in'] - train['u_in_lag2']
    train['u_out_diff2'] = train['u_out'] - train['u_out_lag2']
    train['u_in_diff3'] = train['u_in'] - train['u_in_lag3']
    train['u_out_diff3'] = train['u_out'] - train['u_out_lag3']
    ## diff between last 2 steps
    train['u_in_diff_1_2'] = train['u_in_lag1'] - train['u_in_lag2']
    train['u_out_diff_1_2'] = train['u_out_lag1'] - train['u_out_lag2']
    train['u_in_lagback_diff_1_2'] = train['u_in_lag_back1'] - train['u_in_lag_back2']
    train['u_out_lagback_diff_1_2'] = train['u_out_lag_back1'] - train['u_out_lag_back2']

    train['u_in_lagback_diff1'] = train['u_in'] - train['u_in_lag_back1']
    train['u_out_lagback_diff1'] = train['u_out'] - train['u_out_lag_back1']
    train['u_in_lagback_diff2'] = train['u_in'] - train['u_in_lag_back2']
    train['u_out_lagback_diff2'] = train['u_out'] - train['u_out_lag_back2']

    # from here: https://www.kaggle.com/yasufuminakama/ventilator-pressure-lstm-starter
    train.loc[train['time_step'] == 0, 'u_in_diff'] = 0
    train.loc[train['time_step'] == 0, 'u_out_diff'] = 0

    # difference between the current value of u_in and the max value within the breath
    train['breath_id__u_in__diffmax'] = train.groupby(['breath_id'])['u_in'].transform('max') - train['u_in']
    train['breath_id__u_in__diffmean'] = train.groupby(['breath_id'])['u_in'].transform('mean') - train['u_in']

    print("before OHE")
    display(train)

    # OHE
    train = train.merge(pd.get_dummies(train['R'], prefix='R'), left_index=True, right_index=True).drop(['R'], axis=1)
    train = train.merge(pd.get_dummies(train['C'], prefix='C'), left_index=True, right_index=True).drop(['C'], axis=1)
    train = train.merge(pd.get_dummies(train['R__C'], prefix='R__C'), left_index=True, right_index=True).drop(['R__C'], axis=1)

    # https://www.kaggle.com/c/ventilator-pressure-prediction/discussion/273974
    train['u_in_cumsum'] = train.groupby(['breath_id'])['u_in'].cumsum()
    train['time_step_cumsum'] = train.groupby(['breath_id'])['time_step'].cumsum()

    # feature by u in or out (ideally - make 2 sep columns for each state) # dan
    train['u_in_partition_out_sum'] = train.groupby(['breath_id',"u_out"])['u_in'].transform("sum")

    train = train.fillna(0) # add for consistency with how test is done - dan

    return train

train = add_feats(train)
test = add_feats(test)
# Out:
# 6036000
#               id  breath_id   R  ...  45_in_mean  45_out_std  15_out_mean
# 0              1          1  20  ...    0.083334         NaN          0.0
# 1              2          1  20  ...    9.233188   12.939847          0.0
# 2              3          1  20  ...   13.658551   11.936136          0.0
# 3              4          1  20  ...   15.946119   10.766279          0.0
# 4              5          1  20  ...   17.828065   10.229525          0.0
# ...          ...        ...  ..  ...         ...         ...          ...
# 6035995  6035996     125749  50  ...    3.132079    4.277354          1.0
# 6035996  6035997     125749  50  ...    3.165156    4.258295          1.0
# 6035997  6035998     125749  50  ...    2.890898    3.936430          1.0
# 6035998  6035999     125749  50  ...    2.607671    3.557961          1.0
# 6035999  6036000     125749  50  ...    2.361694    3.221585          1.0
#
# [6036000 rows x 40 columns]
# before OHE
#               id  ...  breath_id__u_in__diffmean
# 0              1  ...                  10.062673
# 1              2  ...                  -8.237035
# 2              3  ...                 -12.363271
# 3              4  ...                 -12.662816
# 4              5  ...                 -15.209844
# ...          ...  ...                        ...
# 6035995  6035996  ...                   3.421689
# 6035996  6035997  ...                   3.422905
# 6035997  6035998  ...                   3.352424
# 6035998  6035999  ...                   3.638739
# 6035999  6036000  ...                   3.428663
#
# [6036000 rows x 67 columns]
# 4024000
#               id  breath_id   R  ...  45_in_mean  45_out_std  15_out_mean
# 0              1          0   5  ...    0.000000         NaN          0.0
# 1              2          0   5  ...    3.757523    5.313940          0.0
# 2              3          0   5  ...    7.388907    7.326652          0.0
# 3              4          0   5  ...   10.849333    9.147936          0.0
# 4              5          0   5  ...   13.943657   10.518450          0.0
# ...          ...        ...  ..  ...         ...         ...          ...
# 4023995  4023996     125748  20  ...    2.794529    2.152980          1.0
# 4023996  4023997     125748  20  ...    2.905101    2.133884          1.0
# 4023997  4023998     125748  20  ...    3.015755    2.108773          1.0
# 4023998  4023999     125748  20  ...    3.126481    2.077404          1.0
# 4023999  4024000     125748  20  ...    3.237267    2.039469          1.0
#
# [4024000 rows x 39 columns]
# before OHE
#               id  ...  breath_id__u_in__diffmean
# 0              1  ...                   9.327338
# 1              2  ...                   1.812292
# 2              3  ...                  -5.324338
# 3              4  ...                 -11.903272
# 4              5  ...                 -16.993619
# ...          ...  ...                        ...
# 4023995  4023996  ...                  -2.288270
# 4023996  4023997  ...                  -2.292733
# 4023997  4023998  ...                  -2.296492
# 4023998  4023999  ...                  -2.299672
# 4023999  4024000  ...                  -2.302397
#
# [4024000 rows x 66 columns]

# %%
train.head()
# Out:
#    id  breath_id  ...  time_step_cumsum  u_in_partition_out_sum
# 0   1          1  ...          0.000000              663.594727
# 1   2          1  ...          0.033652              663.594727
# 2   3          1  ...          0.101167              663.594727
# 3   4          1  ...          0.202709              663.594727
# 4   5          1  ...          0.338464              663.594727
#
# [5 rows x 82 columns]

# %%
train.shape
# Out:
# (6036000, 82)

# %%
targets = train[['pressure']].to_numpy().reshape(-1, 80)
u_outs = train[['u_out']].to_numpy().reshape(-1, 80)
train.drop(['pressure', 'id', 'breath_id'], axis=1, inplace=True)
test = test.drop(['id', 'breath_id'], axis=1)

# %%
RS = RobustScaler()
train = RS.fit_transform(train)
test = RS.transform(test)

# %%
train = train.reshape(-1, 80, train.shape[-1])
test = test.reshape(-1, 80, train.shape[-1])

# %%
def GBVPP_loss(y_true, y_pred, cols = 80):
    u_out = y_true[:, cols: ]
    y = y_true[:, :cols ]

    w = 1 - u_out
    mae = w * tf.abs(y - y_pred)
    return tf.reduce_sum(mae, axis=-1) / tf.reduce_sum(w, axis=-1)

# %%
EPOCH = 300
BATCH_SIZE = 1024
NUM_FOLDS = 10

# detect and init the TPU
tpu = tf.distribute.cluster_resolver.TPUClusterResolver.connect()

# instantiate a distribution strategy
tpu_strategy = tf.distribute.experimental.TPUStrategy(tpu)

with tpu_strategy.scope():
    kf = KFold(n_splits=NUM_FOLDS, shuffle=True, random_state=2021)
    test_preds = []
    for fold, (train_idx, test_idx) in enumerate(kf.split(train, targets)):
        print('-'*15, '>', f'Fold {fold+1}', '<', '-'*15)
        X_train, X_valid = train[train_idx], train[test_idx]
        y_train, y_valid = targets[train_idx], targets[test_idx]
        u_out_train, u_out_valid = u_outs[train_idx], u_outs[test_idx] 
        
        model = keras.models.Sequential([
            keras.layers.Input(shape=train.shape[-2:]),
            keras.layers.Conv1D(filters=1024, kernel_size=3, activation='relu'),
            keras.layers.BatchNormalization(),
            keras.layers.Conv1D(filters=512, kernel_size=3, activation='relu'),
            keras.layers.BatchNormalization(),
            keras.layers.Conv1D(filters=256, kernel_size=3, activation='relu'),
            keras.layers.BatchNormalization(),
            keras.layers.Conv1D(filters=128, kernel_size=3, activation='relu'),
            keras.layers.BatchNormalization(),
            keras.layers.Flatten(),
            keras.layers.Dense(512, activation='selu', kernel_initializer='lecun_normal'),
            keras.layers.BatchNormalization(),
            keras.layers.Dense(256, activation='selu', kernel_initializer='lecun_normal'),
            keras.layers.BatchNormalization(),
            keras.layers.Dense(80)
        ])
        model.compile(optimizer='adam', loss=GBVPP_loss)

        lr = ReduceLROnPlateau(monitor="val_loss", factor=0.75, patience=10, verbose=1)
        es = EarlyStopping(monitor="val_loss", patience=50, verbose=1, mode="min", restore_best_weights=True)
        checkpoint_filepath = f"folds{fold}.hdf5"
        sv = keras.callbacks.ModelCheckpoint(
            checkpoint_filepath, monitor='val_loss', verbose=1, save_best_only=True,
            save_weights_only=False, mode='auto', save_freq='epoch',
            options=None)

        history = model.fit(X_train,
                            np.append(y_train, u_out_train, axis =1),
                            validation_data=(X_valid, np.append(y_valid, u_out_valid, axis =1)), 
                            epochs=EPOCH, 
                            batch_size=1024, 
                            callbacks=[lr,es,sv])
    
        test_preds.append(model.predict(test).squeeze().reshape(-1, 1).squeeze())
# Out:
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Initializing the TPU system: grpc://10.10.239.50:8470
# INFO:tensorflow:Initializing the TPU system: grpc://10.10.239.50:8470
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Finished initializing TPU system.
# WARNING:absl:`tf.distribute.experimental.TPUStrategy` is deprecated, please use  the non experimental symbol `tf.distribute.TPUStrategy` instead.
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:2, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:2, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:3, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:3, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:4, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:4, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:5, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:5, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:6, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:6, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:7, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:7, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)
# Streaming output truncated to the last 5000 lines.
# Epoch 147/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6305 - val_loss: 0.4425
#
# Epoch 00147: val_loss did not improve from 0.40979
# Epoch 148/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6133 - val_loss: 0.4365
#
# Epoch 00148: val_loss did not improve from 0.40979
# Epoch 149/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.5946 - val_loss: 0.4710
#
# Epoch 00149: val_loss did not improve from 0.40979
# Epoch 150/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6426 - val_loss: 0.4344
#
# Epoch 00150: val_loss did not improve from 0.40979
# Epoch 151/300
# 67/67 [==============================] - 2s 29ms/step - loss: 0.5967 - val_loss: 0.4435
#
# Epoch 00151: val_loss did not improve from 0.40979
# Epoch 152/300
# 67/67 [==============================] - 2s 29ms/step - loss: 0.6232 - val_loss: 0.4419
#
# Epoch 00152: ReduceLROnPlateau reducing learning rate to 0.00010011290578404441.
#
# Epoch 00152: val_loss did not improve from 0.40979
# Epoch 153/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6114 - val_loss: 0.4500
#
# Epoch 00153: val_loss did not improve from 0.40979
# Epoch 154/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6123 - val_loss: 0.4611
#
# Epoch 00154: val_loss did not improve from 0.40979
# Epoch 155/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6184 - val_loss: 0.4284
#
# Epoch 00155: val_loss did not improve from 0.40979
# Epoch 156/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6035 - val_loss: 0.4392
#
# Epoch 00156: val_loss did not improve from 0.40979
# Epoch 157/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6025 - val_loss: 0.4280
#
# Epoch 00157: val_loss did not improve from 0.40979
# Epoch 158/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6000 - val_loss: 0.4525
#
# Epoch 00158: val_loss did not improve from 0.40979
# Epoch 159/300
# 67/67 [==============================] - 2s 29ms/step - loss: 0.6050 - val_loss: 0.4142
#
# Epoch 00159: val_loss did not improve from 0.40979
# Epoch 160/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6285 - val_loss: 0.4269
#
# Epoch 00160: val_loss did not improve from 0.40979
# Epoch 161/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6115 - val_loss: 0.4356
#
# Epoch 00161: val_loss did not improve from 0.40979
# Epoch 162/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6175 - val_loss: 0.4442
#
# Epoch 00162: ReduceLROnPlateau reducing learning rate to 7.508467933803331e-05.
#
# Epoch 00162: val_loss did not improve from 0.40979
# Epoch 163/300
# 67/67 [==============================] - 2s 29ms/step - loss: 0.6050 - val_loss: 0.4498
#
# Epoch 00163: val_loss did not improve from 0.40979
# Epoch 164/300
# 67/67 [==============================] - 2s 29ms/step - loss: 0.6024 - val_loss: 0.4553
#
# Epoch 00164: val_loss did not improve from 0.40979
# Epoch 165/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6205 - val_loss: 0.4672
#
# Epoch 00165: val_loss did not improve from 0.40979
# Epoch 166/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.5795 - val_loss: 0.4662
#
# Epoch 00166: val_loss did not improve from 0.40979
# Epoch 167/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6073 - val_loss: 0.4815
#
# Epoch 00167: val_loss did not improve from 0.40979
# Epoch 168/300
# 67/67 [==============================] - 2s 29ms/step - loss: 0.6072 - val_loss: 0.4809
#
# Epoch 00168: val_loss did not improve from 0.40979
# Epoch 169/300
# 67/67 [==============================] - 2s 29ms/step - loss: 0.6147 - val_loss: 0.4801
#
# Epoch 00169: val_loss did not improve from 0.40979
# Epoch 170/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6144 - val_loss: 0.4662
#
# Epoch 00170: val_loss did not improve from 0.40979
# Epoch 171/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.5991 - val_loss: 0.4704
#
# Epoch 00171: val_loss did not improve from 0.40979
# Epoch 172/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6147 - val_loss: 0.4710
#
# Epoch 00172: ReduceLROnPlateau reducing learning rate to 5.6313510867767036e-05.
#
# Epoch 00172: val_loss did not improve from 0.40979
# Epoch 173/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6040 - val_loss: 0.4984
#
# Epoch 00173: val_loss did not improve from 0.40979
# Epoch 174/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6165 - val_loss: 0.4709
#
# Epoch 00174: val_loss did not improve from 0.40979
# Epoch 175/300
# 67/67 [==============================] - 2s 29ms/step - loss: 0.6027 - val_loss: 0.4838
#
# Epoch 00175: val_loss did not improve from 0.40979
# Epoch 176/300
# 67/67 [==============================] - 2s 36ms/step - loss: 0.6002 - val_loss: 0.4273
#
# Epoch 00176: val_loss did not improve from 0.40979
# Epoch 177/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.5914 - val_loss: 0.4229
#
# Epoch 00177: val_loss did not improve from 0.40979
# Epoch 178/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6133 - val_loss: 0.4341
#
# Epoch 00178: val_loss did not improve from 0.40979
# Epoch 179/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6352 - val_loss: 0.4455
#
# Epoch 00179: val_loss did not improve from 0.40979
# Epoch 180/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6122 - val_loss: 0.4523
#
# Epoch 00180: val_loss did not improve from 0.40979
# Epoch 181/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.5833 - val_loss: 0.4535
#
# Epoch 00181: val_loss did not improve from 0.40979
# Epoch 182/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6033 - val_loss: 0.4755
#
# Epoch 00182: ReduceLROnPlateau reducing learning rate to 4.223513315082528e-05.
# Restoring model weights from the end of the best epoch.
#
# Epoch 00182: val_loss did not improve from 0.40979
# Epoch 00182: early stopping
# --------------- > Fold 7 < ---------------
# Epoch 1/300
# 67/67 [==============================] - 26s 214ms/step - loss: 16.4391 - val_loss: 14.3744
#
# Epoch 00001: val_loss improved from inf to 14.37436, saving model to folds6.hdf5
# Epoch 2/300
# 67/67 [==============================] - 2s 30ms/step - loss: 13.2061 - val_loss: 8.7508
#
# Epoch 00002: val_loss improved from 14.37436 to 8.75079, saving model to folds6.hdf5
# Epoch 3/300
# 67/67 [==============================] - 2s 30ms/step - loss: 5.7975 - val_loss: 6.9493
#
# Epoch 00003: val_loss improved from 8.75079 to 6.94927, saving model to folds6.hdf5
# Epoch 4/300
# 67/67 [==============================] - 2s 30ms/step - loss: 1.6884 - val_loss: 4.1215
#
# Epoch 00004: val_loss improved from 6.94927 to 4.12151, saving model to folds6.hdf5
# Epoch 5/300
# 67/67 [==============================] - 2s 30ms/step - loss: 1.3257 - val_loss: 1.5758
#
# Epoch 00005: val_loss improved from 4.12151 to 1.57575, saving model to folds6.hdf5
# Epoch 6/300
# 67/67 [==============================] - 2s 29ms/step - loss: 1.2560 - val_loss: 1.2587
#
# Epoch 00006: val_loss improved from 1.57575 to 1.25868, saving model to folds6.hdf5
# Epoch 7/300
# 67/67 [==============================] - 2s 30ms/step - loss: 1.1596 - val_loss: 1.4086
#
# Epoch 00007: val_loss did not improve from 1.25868
# Epoch 8/300
# 67/67 [==============================] - 2s 30ms/step - loss: 1.0965 - val_loss: 0.9552
#
# Epoch 00008: val_loss improved from 1.25868 to 0.95521, saving model to folds6.hdf5
# Epoch 9/300
# 67/67 [==============================] - 2s 30ms/step - loss: 1.0731 - val_loss: 0.9732
#
# Epoch 00009: val_loss did not improve from 0.95521
# Epoch 10/300
# 67/67 [==============================] - 2s 30ms/step - loss: 1.0758 - val_loss: 1.0637
#
# Epoch 00010: val_loss did not improve from 0.95521
# Epoch 11/300
# 67/67 [==============================] - 2s 30ms/step - loss: 1.0360 - val_loss: 0.8724
#
# Epoch 00011: val_loss improved from 0.95521 to 0.87242, saving model to folds6.hdf5
# Epoch 12/300
# 67/67 [==============================] - 2s 30ms/step - loss: 1.0256 - val_loss: 0.9415
#
# Epoch 00012: val_loss did not improve from 0.87242
# Epoch 13/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.9920 - val_loss: 0.8256
#
# Epoch 00013: val_loss improved from 0.87242 to 0.82557, saving model to folds6.hdf5
# Epoch 14/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.9537 - val_loss: 0.7881
#
# Epoch 00014: val_loss improved from 0.82557 to 0.78808, saving model to folds6.hdf5
# Epoch 15/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.9604 - val_loss: 0.7966
#
# Epoch 00015: val_loss did not improve from 0.78808
# Epoch 16/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.9373 - val_loss: 0.8105
#
# Epoch 00016: val_loss did not improve from 0.78808
# Epoch 17/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.9084 - val_loss: 0.7112
#
# Epoch 00017: val_loss improved from 0.78808 to 0.71115, saving model to folds6.hdf5
# Epoch 18/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.9148 - val_loss: 0.8712
#
# Epoch 00018: val_loss did not improve from 0.71115
# Epoch 19/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.9140 - val_loss: 0.6821
#
# Epoch 00019: val_loss improved from 0.71115 to 0.68214, saving model to folds6.hdf5
# Epoch 20/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.8844 - val_loss: 0.6660
#
# Epoch 00020: val_loss improved from 0.68214 to 0.66596, saving model to folds6.hdf5
# Epoch 21/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.8857 - val_loss: 0.7194
#
# Epoch 00021: val_loss did not improve from 0.66596
# Epoch 22/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.8878 - val_loss: 0.6780
#
# Epoch 00022: val_loss did not improve from 0.66596
# Epoch 23/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.8791 - val_loss: 0.7570
#
# Epoch 00023: val_loss did not improve from 0.66596
# Epoch 24/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.8571 - val_loss: 0.8004
#
# Epoch 00024: val_loss did not improve from 0.66596
# Epoch 25/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.8425 - val_loss: 0.6608
#
# Epoch 00025: val_loss improved from 0.66596 to 0.66078, saving model to folds6.hdf5
# Epoch 26/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.8635 - val_loss: 0.7393
#
# Epoch 00026: val_loss did not improve from 0.66078
# Epoch 27/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.8566 - val_loss: 0.6353
#
# Epoch 00027: val_loss improved from 0.66078 to 0.63533, saving model to folds6.hdf5
# Epoch 28/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.8208 - val_loss: 0.6367
#
# Epoch 00028: val_loss did not improve from 0.63533
# Epoch 29/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.8222 - val_loss: 0.6862
#
# Epoch 00029: val_loss did not improve from 0.63533
# Epoch 30/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.8184 - val_loss: 0.6621
#
# Epoch 00030: val_loss did not improve from 0.63533
# Epoch 31/300
# 67/67 [==============================] - 2s 31ms/step - loss: 0.8051 - val_loss: 0.7990
#
# Epoch 00031: val_loss did not improve from 0.63533
# Epoch 32/300
# 67/67 [==============================] - 2s 31ms/step - loss: 0.8296 - val_loss: 0.7020
#
# Epoch 00032: val_loss did not improve from 0.63533
# Epoch 33/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.8038 - val_loss: 0.6337
#
# Epoch 00033: val_loss improved from 0.63533 to 0.63368, saving model to folds6.hdf5
# Epoch 34/300
# 67/67 [==============================] - 2s 35ms/step - loss: 0.7952 - val_loss: 0.6628
#
# Epoch 00034: val_loss did not improve from 0.63368
# Epoch 35/300
# 67/67 [==============================] - 2s 29ms/step - loss: 0.8062 - val_loss: 0.7551
#
# Epoch 00035: val_loss did not improve from 0.63368
# Epoch 36/300
# 67/67 [==============================] - 2s 29ms/step - loss: 0.7851 - val_loss: 0.5521
#
# Epoch 00036: val_loss improved from 0.63368 to 0.55209, saving model to folds6.hdf5
# Epoch 37/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.7831 - val_loss: 0.6424
#
# Epoch 00037: val_loss did not improve from 0.55209
# Epoch 38/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.7866 - val_loss: 0.5646
#
# Epoch 00038: val_loss did not improve from 0.55209
# Epoch 39/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.7717 - val_loss: 0.6103
#
# Epoch 00039: val_loss did not improve from 0.55209
# Epoch 40/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.7794 - val_loss: 0.6130
#
# Epoch 00040: val_loss did not improve from 0.55209
# Epoch 41/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.7522 - val_loss: 0.6060
#
# Epoch 00041: val_loss did not improve from 0.55209
# Epoch 42/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.7724 - val_loss: 0.6236
#
# Epoch 00042: val_loss did not improve from 0.55209
# Epoch 43/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.7740 - val_loss: 0.5941
#
# Epoch 00043: val_loss did not improve from 0.55209
# Epoch 44/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.7568 - val_loss: 0.5523
#
# Epoch 00044: val_loss did not improve from 0.55209
# Epoch 45/300
# 67/67 [==============================] - 2s 29ms/step - loss: 0.7905 - val_loss: 0.5353
#
# Epoch 00045: val_loss improved from 0.55209 to 0.53526, saving model to folds6.hdf5
# Epoch 46/300
# 67/67 [==============================] - 2s 29ms/step - loss: 0.7437 - val_loss: 0.5430
#
# Epoch 00046: val_loss did not improve from 0.53526
# Epoch 47/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.7550 - val_loss: 0.6880
#
# Epoch 00047: val_loss did not improve from 0.53526
# Epoch 48/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.7512 - val_loss: 0.5430
#
# Epoch 00048: val_loss did not improve from 0.53526
# Epoch 49/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.7600 - val_loss: 0.5926
#
# Epoch 00049: val_loss did not improve from 0.53526
# Epoch 50/300
# 67/67 [==============================] - 2s 29ms/step - loss: 0.7518 - val_loss: 0.5399
#
# Epoch 00050: val_loss did not improve from 0.53526
# Epoch 51/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.7417 - val_loss: 0.6680
#
# Epoch 00051: val_loss did not improve from 0.53526
# Epoch 52/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.7536 - val_loss: 0.5215
#
# Epoch 00052: val_loss improved from 0.53526 to 0.52154, saving model to folds6.hdf5
# Epoch 53/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.7337 - val_loss: 0.5925
#
# Epoch 00053: val_loss did not improve from 0.52154
# Epoch 54/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.7515 - val_loss: 0.5542
#
# Epoch 00054: val_loss did not improve from 0.52154
# Epoch 55/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.7299 - val_loss: 0.5833
#
# Epoch 00055: val_loss did not improve from 0.52154
# Epoch 56/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.7528 - val_loss: 0.5377
#
# Epoch 00056: val_loss did not improve from 0.52154
# Epoch 57/300
# 67/67 [==============================] - 2s 29ms/step - loss: 0.7570 - val_loss: 0.5581
#
# Epoch 00057: val_loss did not improve from 0.52154
# Epoch 58/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.7064 - val_loss: 0.6485
#
# Epoch 00058: val_loss did not improve from 0.52154
# Epoch 59/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.7340 - val_loss: 0.6147
#
# Epoch 00059: val_loss did not improve from 0.52154
# Epoch 60/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.7366 - val_loss: 0.5882
#
# Epoch 00060: val_loss did not improve from 0.52154
# Epoch 61/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.7445 - val_loss: 0.5461
#
# Epoch 00061: val_loss did not improve from 0.52154
# Epoch 62/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.7207 - val_loss: 0.5214
#
# Epoch 00062: val_loss improved from 0.52154 to 0.52139, saving model to folds6.hdf5
# Epoch 63/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.7128 - val_loss: 0.5483
#
# Epoch 00063: val_loss did not improve from 0.52139
# Epoch 64/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.7244 - val_loss: 0.5060
#
# Epoch 00064: val_loss improved from 0.52139 to 0.50598, saving model to folds6.hdf5
# Epoch 65/300
# 67/67 [==============================] - 2s 29ms/step - loss: 0.7104 - val_loss: 0.6114
#
# Epoch 00065: val_loss did not improve from 0.50598
# Epoch 66/300
# 67/67 [==============================] - 2s 29ms/step - loss: 0.7291 - val_loss: 0.5449
#
# Epoch 00066: val_loss did not improve from 0.50598
# Epoch 67/300
# 67/67 [==============================] - 2s 29ms/step - loss: 0.7318 - val_loss: 0.5078
#
# Epoch 00067: val_loss did not improve from 0.50598
# Epoch 68/300
# 67/67 [==============================] - 2s 29ms/step - loss: 0.7211 - val_loss: 0.5687
#
# Epoch 00068: val_loss did not improve from 0.50598
# Epoch 69/300
# 67/67 [==============================] - 2s 29ms/step - loss: 0.7119 - val_loss: 0.5163
#
# Epoch 00069: val_loss did not improve from 0.50598
# Epoch 70/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.7350 - val_loss: 0.5091
#
# Epoch 00070: val_loss did not improve from 0.50598
# Epoch 71/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6936 - val_loss: 0.4977
#
# Epoch 00071: val_loss improved from 0.50598 to 0.49769, saving model to folds6.hdf5
# Epoch 72/300
# 67/67 [==============================] - 2s 36ms/step - loss: 0.7135 - val_loss: 0.5008
#
# Epoch 00072: val_loss did not improve from 0.49769
# Epoch 73/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.7162 - val_loss: 0.5695
#
# Epoch 00073: val_loss did not improve from 0.49769
# Epoch 74/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.7442 - val_loss: 0.5995
#
# Epoch 00074: val_loss did not improve from 0.49769
# Epoch 75/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.7146 - val_loss: 0.5176
#
# Epoch 00075: val_loss did not improve from 0.49769
# Epoch 76/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.7068 - val_loss: 0.5238
#
# Epoch 00076: val_loss did not improve from 0.49769
# Epoch 77/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.7189 - val_loss: 0.5359
#
# Epoch 00077: val_loss did not improve from 0.49769
# Epoch 78/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.7097 - val_loss: 0.5482
#
# Epoch 00078: val_loss did not improve from 0.49769
# Epoch 79/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.7027 - val_loss: 0.5057
#
# Epoch 00079: val_loss did not improve from 0.49769
# Epoch 80/300
# 67/67 [==============================] - 2s 29ms/step - loss: 0.6946 - val_loss: 0.5617
#
# Epoch 00080: val_loss did not improve from 0.49769
# Epoch 81/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6981 - val_loss: 0.5436
#
# Epoch 00081: ReduceLROnPlateau reducing learning rate to 0.0007500000356230885.
#
# Epoch 00081: val_loss did not improve from 0.49769
# Epoch 82/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6804 - val_loss: 0.4768
#
# Epoch 00082: val_loss improved from 0.49769 to 0.47681, saving model to folds6.hdf5
# Epoch 83/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6876 - val_loss: 0.5130
#
# Epoch 00083: val_loss did not improve from 0.47681
# Epoch 84/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6721 - val_loss: 0.5294
#
# Epoch 00084: val_loss did not improve from 0.47681
# Epoch 85/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6900 - val_loss: 0.5281
#
# Epoch 00085: val_loss did not improve from 0.47681
# Epoch 86/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.7089 - val_loss: 0.4669
#
# Epoch 00086: val_loss improved from 0.47681 to 0.46685, saving model to folds6.hdf5
# Epoch 87/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6690 - val_loss: 0.4680
#
# Epoch 00087: val_loss did not improve from 0.46685
# Epoch 88/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6987 - val_loss: 0.4622
#
# Epoch 00088: val_loss improved from 0.46685 to 0.46220, saving model to folds6.hdf5
# Epoch 89/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6816 - val_loss: 0.4780
#
# Epoch 00089: val_loss did not improve from 0.46220
# Epoch 90/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6615 - val_loss: 0.4707
#
# Epoch 00090: val_loss did not improve from 0.46220
# Epoch 91/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6712 - val_loss: 0.4674
#
# Epoch 00091: val_loss did not improve from 0.46220
# Epoch 92/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6842 - val_loss: 0.4458
#
# Epoch 00092: val_loss improved from 0.46220 to 0.44579, saving model to folds6.hdf5
# Epoch 93/300
# 67/67 [==============================] - 2s 29ms/step - loss: 0.6828 - val_loss: 0.4981
#
# Epoch 00093: val_loss did not improve from 0.44579
# Epoch 94/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6678 - val_loss: 0.5023
#
# Epoch 00094: val_loss did not improve from 0.44579
# Epoch 95/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6996 - val_loss: 0.4441
#
# Epoch 00095: val_loss improved from 0.44579 to 0.44412, saving model to folds6.hdf5
# Epoch 96/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6684 - val_loss: 0.4854
#
# Epoch 00096: val_loss did not improve from 0.44412
# Epoch 97/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6776 - val_loss: 0.4468
#
# Epoch 00097: val_loss did not improve from 0.44412
# Epoch 98/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6662 - val_loss: 0.5161
#
# Epoch 00098: val_loss did not improve from 0.44412
# Epoch 99/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6599 - val_loss: 0.4897
#
# Epoch 00099: val_loss did not improve from 0.44412
# Epoch 100/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6762 - val_loss: 0.5017
#
# Epoch 00100: val_loss did not improve from 0.44412
# Epoch 101/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6732 - val_loss: 0.4701
#
# Epoch 00101: val_loss did not improve from 0.44412
# Epoch 102/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6795 - val_loss: 0.5234
#
# Epoch 00102: val_loss did not improve from 0.44412
# Epoch 103/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6844 - val_loss: 0.5229
#
# Epoch 00103: val_loss did not improve from 0.44412
# Epoch 104/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6719 - val_loss: 0.4580
#
# Epoch 00104: val_loss did not improve from 0.44412
# Epoch 105/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6672 - val_loss: 0.4588
#
# Epoch 00105: ReduceLROnPlateau reducing learning rate to 0.0005625000048894435.
#
# Epoch 00105: val_loss did not improve from 0.44412
# Epoch 106/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6411 - val_loss: 0.4436
#
# Epoch 00106: val_loss improved from 0.44412 to 0.44359, saving model to folds6.hdf5
# Epoch 107/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6512 - val_loss: 0.4405
#
# Epoch 00107: val_loss improved from 0.44359 to 0.44045, saving model to folds6.hdf5
# Epoch 108/300
# 67/67 [==============================] - 2s 29ms/step - loss: 0.6383 - val_loss: 0.4347
#
# Epoch 00108: val_loss improved from 0.44045 to 0.43468, saving model to folds6.hdf5
# Epoch 109/300
# 67/67 [==============================] - 2s 36ms/step - loss: 0.6456 - val_loss: 0.4755
#
# Epoch 00109: val_loss did not improve from 0.43468
# Epoch 110/300
# 67/67 [==============================] - 2s 29ms/step - loss: 0.6582 - val_loss: 0.4350
#
# Epoch 00110: val_loss did not improve from 0.43468
# Epoch 111/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6506 - val_loss: 0.4454
#
# Epoch 00111: val_loss did not improve from 0.43468
# Epoch 112/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6485 - val_loss: 0.4683
#
# Epoch 00112: val_loss did not improve from 0.43468
# Epoch 113/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6562 - val_loss: 0.4468
#
# Epoch 00113: val_loss did not improve from 0.43468
# Epoch 114/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6693 - val_loss: 0.4536
#
# Epoch 00114: val_loss did not improve from 0.43468
# Epoch 115/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6349 - val_loss: 0.4513
#
# Epoch 00115: val_loss did not improve from 0.43468
# Epoch 116/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6651 - val_loss: 0.5072
#
# Epoch 00116: val_loss did not improve from 0.43468
# Epoch 117/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6716 - val_loss: 0.4832
#
# Epoch 00117: val_loss did not improve from 0.43468
# Epoch 118/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6556 - val_loss: 0.5004
#
# Epoch 00118: ReduceLROnPlateau reducing learning rate to 0.0004218749818392098.
#
# Epoch 00118: val_loss did not improve from 0.43468
# Epoch 119/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6266 - val_loss: 0.4582
#
# Epoch 00119: val_loss did not improve from 0.43468
# Epoch 120/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6337 - val_loss: 0.4321
#
# Epoch 00120: val_loss improved from 0.43468 to 0.43211, saving model to folds6.hdf5
# Epoch 121/300
# 67/67 [==============================] - 2s 29ms/step - loss: 0.6241 - val_loss: 0.4606
#
# Epoch 00121: val_loss did not improve from 0.43211
# Epoch 122/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6342 - val_loss: 0.4480
#
# Epoch 00122: val_loss did not improve from 0.43211
# Epoch 123/300
# 67/67 [==============================] - 2s 29ms/step - loss: 0.6482 - val_loss: 0.4182
#
# Epoch 00123: val_loss improved from 0.43211 to 0.41816, saving model to folds6.hdf5
# Epoch 124/300
# 67/67 [==============================] - 2s 29ms/step - loss: 0.6366 - val_loss: 0.5146
#
# Epoch 00124: val_loss did not improve from 0.41816
# Epoch 125/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6538 - val_loss: 0.4494
#
# Epoch 00125: val_loss did not improve from 0.41816
# Epoch 126/300
# 67/67 [==============================] - 2s 29ms/step - loss: 0.6197 - val_loss: 0.4118
#
# Epoch 00126: val_loss improved from 0.41816 to 0.41179, saving model to folds6.hdf5
# Epoch 127/300
# 67/67 [==============================] - 2s 29ms/step - loss: 0.6241 - val_loss: 0.4556
#
# Epoch 00127: val_loss did not improve from 0.41179
# Epoch 128/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6348 - val_loss: 0.4231
#
# Epoch 00128: val_loss did not improve from 0.41179
# Epoch 129/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6050 - val_loss: 0.4202
#
# Epoch 00129: val_loss did not improve from 0.41179
# Epoch 130/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6296 - val_loss: 0.4320
#
# Epoch 00130: val_loss did not improve from 0.41179
# Epoch 131/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6271 - val_loss: 0.4529
#
# Epoch 00131: val_loss did not improve from 0.41179
# Epoch 132/300
# 67/67 [==============================] - 2s 29ms/step - loss: 0.6519 - val_loss: 0.4430
#
# Epoch 00132: val_loss did not improve from 0.41179
# Epoch 133/300
# 67/67 [==============================] - 2s 29ms/step - loss: 0.6361 - val_loss: 0.4174
#
# Epoch 00133: val_loss did not improve from 0.41179
# Epoch 134/300
# 67/67 [==============================] - 2s 29ms/step - loss: 0.6249 - val_loss: 0.4222
#
# Epoch 00134: val_loss did not improve from 0.41179
# Epoch 135/300
# 67/67 [==============================] - 2s 29ms/step - loss: 0.6373 - val_loss: 0.4280
#
# Epoch 00135: val_loss did not improve from 0.41179
# Epoch 136/300
# 67/67 [==============================] - 2s 29ms/step - loss: 0.6047 - val_loss: 0.4352
#
# Epoch 00136: ReduceLROnPlateau reducing learning rate to 0.00031640623637940735.
#
# Epoch 00136: val_loss did not improve from 0.41179
# Epoch 137/300
# 67/67 [==============================] - 2s 29ms/step - loss: 0.6234 - val_loss: 0.4159
#
# Epoch 00137: val_loss did not improve from 0.41179
# Epoch 138/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6101 - val_loss: 0.4467
#
# Epoch 00138: val_loss did not improve from 0.41179
# Epoch 139/300
# 67/67 [==============================] - 2s 29ms/step - loss: 0.6163 - val_loss: 0.4169
#
# Epoch 00139: val_loss did not improve from 0.41179
# Epoch 140/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6230 - val_loss: 0.4309
#
# Epoch 00140: val_loss did not improve from 0.41179
# Epoch 141/300
# 67/67 [==============================] - 2s 29ms/step - loss: 0.6176 - val_loss: 0.4370
#
# Epoch 00141: val_loss did not improve from 0.41179
# Epoch 142/300
# 67/67 [==============================] - 2s 29ms/step - loss: 0.6026 - val_loss: 0.4417
#
# Epoch 00142: val_loss did not improve from 0.41179
# Epoch 143/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6317 - val_loss: 0.4086
#
# Epoch 00143: val_loss improved from 0.41179 to 0.40855, saving model to folds6.hdf5
# Epoch 144/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6300 - val_loss: 0.4272
#
# Epoch 00144: val_loss did not improve from 0.40855
# Epoch 145/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.5959 - val_loss: 0.4321
#
# Epoch 00145: val_loss did not improve from 0.40855
# Epoch 146/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6432 - val_loss: 0.4355
#
# Epoch 00146: val_loss did not improve from 0.40855
# Epoch 147/300
# 67/67 [==============================] - 2s 36ms/step - loss: 0.6336 - val_loss: 0.4253
#
# Epoch 00147: val_loss did not improve from 0.40855
# Epoch 148/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6107 - val_loss: 0.4160
#
# Epoch 00148: val_loss did not improve from 0.40855
# Epoch 149/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6366 - val_loss: 0.4364
#
# Epoch 00149: val_loss did not improve from 0.40855
# Epoch 150/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6162 - val_loss: 0.4253
#
# Epoch 00150: val_loss did not improve from 0.40855
# Epoch 151/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6220 - val_loss: 0.4220
#
# Epoch 00151: val_loss did not improve from 0.40855
# Epoch 152/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6368 - val_loss: 0.4244
#
# Epoch 00152: val_loss did not improve from 0.40855
# Epoch 153/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6284 - val_loss: 0.4274
#
# Epoch 00153: ReduceLROnPlateau reducing learning rate to 0.00023730468819849193.
#
# Epoch 00153: val_loss did not improve from 0.40855
# Epoch 154/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6187 - val_loss: 0.4177
#
# Epoch 00154: val_loss did not improve from 0.40855
# Epoch 155/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6202 - val_loss: 0.4262
#
# Epoch 00155: val_loss did not improve from 0.40855
# Epoch 156/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6074 - val_loss: 0.4128
#
# Epoch 00156: val_loss did not improve from 0.40855
# Epoch 157/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6251 - val_loss: 0.4141
#
# Epoch 00157: val_loss did not improve from 0.40855
# Epoch 158/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6108 - val_loss: 0.3977
#
# Epoch 00158: val_loss improved from 0.40855 to 0.39775, saving model to folds6.hdf5
# Epoch 159/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6245 - val_loss: 0.4089
#
# Epoch 00159: val_loss did not improve from 0.39775
# Epoch 160/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.5912 - val_loss: 0.4305
#
# Epoch 00160: val_loss did not improve from 0.39775
# Epoch 161/300
# 67/67 [==============================] - 2s 29ms/step - loss: 0.6194 - val_loss: 0.4129
#
# Epoch 00161: val_loss did not improve from 0.39775
# Epoch 162/300
# 67/67 [==============================] - 2s 29ms/step - loss: 0.5987 - val_loss: 0.4097
#
# Epoch 00162: val_loss did not improve from 0.39775
# Epoch 163/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6232 - val_loss: 0.4101
#
# Epoch 00163: val_loss did not improve from 0.39775
# Epoch 164/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6204 - val_loss: 0.4185
#
# Epoch 00164: val_loss did not improve from 0.39775
# Epoch 165/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6149 - val_loss: 0.4486
#
# Epoch 00165: val_loss did not improve from 0.39775
# Epoch 166/300
# 67/67 [==============================] - 2s 29ms/step - loss: 0.6269 - val_loss: 0.4207
#
# Epoch 00166: val_loss did not improve from 0.39775
# Epoch 167/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6271 - val_loss: 0.3969
#
# Epoch 00167: val_loss improved from 0.39775 to 0.39687, saving model to folds6.hdf5
# Epoch 168/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.5910 - val_loss: 0.4228
#
# Epoch 00168: val_loss did not improve from 0.39687
# Epoch 169/300
# 67/67 [==============================] - 2s 29ms/step - loss: 0.6120 - val_loss: 0.4126
#
# Epoch 00169: val_loss did not improve from 0.39687
# Epoch 170/300
# 67/67 [==============================] - 2s 29ms/step - loss: 0.6213 - val_loss: 0.4174
#
# Epoch 00170: val_loss did not improve from 0.39687
# Epoch 171/300
# 67/67 [==============================] - 2s 29ms/step - loss: 0.6085 - val_loss: 0.4018
#
# Epoch 00171: val_loss did not improve from 0.39687
# Epoch 172/300
# 67/67 [==============================] - 2s 29ms/step - loss: 0.6086 - val_loss: 0.4390
#
# Epoch 00172: val_loss did not improve from 0.39687
# Epoch 173/300
# 67/67 [==============================] - 2s 29ms/step - loss: 0.6034 - val_loss: 0.3969
#
# Epoch 00173: val_loss did not improve from 0.39687
# Epoch 174/300
# 67/67 [==============================] - 2s 29ms/step - loss: 0.6172 - val_loss: 0.4154
#
# Epoch 00174: val_loss did not improve from 0.39687
# Epoch 175/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6086 - val_loss: 0.4043
#
# Epoch 00175: val_loss did not improve from 0.39687
# Epoch 176/300
# 67/67 [==============================] - 2s 31ms/step - loss: 0.6021 - val_loss: 0.4130
#
# Epoch 00176: val_loss did not improve from 0.39687
# Epoch 177/300
# 67/67 [==============================] - 2s 31ms/step - loss: 0.5854 - val_loss: 0.4140
#
# Epoch 00177: ReduceLROnPlateau reducing learning rate to 0.00017797851614886895.
#
# Epoch 00177: val_loss did not improve from 0.39687
# Epoch 178/300
# 67/67 [==============================] - 2s 31ms/step - loss: 0.6183 - val_loss: 0.3995
#
# Epoch 00178: val_loss did not improve from 0.39687
# Epoch 179/300
# 67/67 [==============================] - 2s 31ms/step - loss: 0.6088 - val_loss: 0.4193
#
# Epoch 00179: val_loss did not improve from 0.39687
# Epoch 180/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6112 - val_loss: 0.4017
#
# Epoch 00180: val_loss did not improve from 0.39687
# Epoch 181/300
# 67/67 [==============================] - 2s 29ms/step - loss: 0.5909 - val_loss: 0.4118
#
# Epoch 00181: val_loss did not improve from 0.39687
# Epoch 182/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.5929 - val_loss: 0.3945
#
# Epoch 00182: val_loss improved from 0.39687 to 0.39454, saving model to folds6.hdf5
# Epoch 183/300
# 67/67 [==============================] - 2s 29ms/step - loss: 0.5809 - val_loss: 0.4302
#
# Epoch 00183: val_loss did not improve from 0.39454
# Epoch 184/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6148 - val_loss: 0.4101
#
# Epoch 00184: val_loss did not improve from 0.39454
# Epoch 185/300
# 67/67 [==============================] - 2s 36ms/step - loss: 0.6032 - val_loss: 0.4163
#
# Epoch 00185: val_loss did not improve from 0.39454
# Epoch 186/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6195 - val_loss: 0.3905
#
# Epoch 00186: val_loss improved from 0.39454 to 0.39045, saving model to folds6.hdf5
# Epoch 187/300
# 67/67 [==============================] - 2s 29ms/step - loss: 0.6036 - val_loss: 0.4105
#
# Epoch 00187: val_loss did not improve from 0.39045
# Epoch 188/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6012 - val_loss: 0.4190
#
# Epoch 00188: val_loss did not improve from 0.39045
# Epoch 189/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.5854 - val_loss: 0.4037
#
# Epoch 00189: val_loss did not improve from 0.39045
# Epoch 190/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6212 - val_loss: 0.4086
#
# Epoch 00190: val_loss did not improve from 0.39045
# Epoch 191/300
# 67/67 [==============================] - 2s 29ms/step - loss: 0.6175 - val_loss: 0.4133
#
# Epoch 00191: val_loss did not improve from 0.39045
# Epoch 192/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.5904 - val_loss: 0.4095
#
# Epoch 00192: val_loss did not improve from 0.39045
# Epoch 193/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6004 - val_loss: 0.4060
#
# Epoch 00193: val_loss did not improve from 0.39045
# Epoch 194/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6035 - val_loss: 0.4108
#
# Epoch 00194: val_loss did not improve from 0.39045
# Epoch 195/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6232 - val_loss: 0.3960
#
# Epoch 00195: val_loss did not improve from 0.39045
# Epoch 196/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6008 - val_loss: 0.4128
#
# Epoch 00196: ReduceLROnPlateau reducing learning rate to 0.0001334838816546835.
#
# Epoch 00196: val_loss did not improve from 0.39045
# Epoch 197/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6112 - val_loss: 0.4001
#
# Epoch 00197: val_loss did not improve from 0.39045
# Epoch 198/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.5993 - val_loss: 0.3924
#
# Epoch 00198: val_loss did not improve from 0.39045
# Epoch 199/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6135 - val_loss: 0.3961
#
# Epoch 00199: val_loss did not improve from 0.39045
# Epoch 200/300
# 67/67 [==============================] - 2s 29ms/step - loss: 0.6011 - val_loss: 0.4013
#
# Epoch 00200: val_loss did not improve from 0.39045
# Epoch 201/300
# 67/67 [==============================] - 2s 29ms/step - loss: 0.6196 - val_loss: 0.4109
#
# Epoch 00201: val_loss did not improve from 0.39045
# Epoch 202/300
# 67/67 [==============================] - 2s 29ms/step - loss: 0.5971 - val_loss: 0.4003
#
# Epoch 00202: val_loss did not improve from 0.39045
# Epoch 203/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6003 - val_loss: 0.4017
#
# Epoch 00203: val_loss did not improve from 0.39045
# Epoch 204/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6027 - val_loss: 0.4096
#
# Epoch 00204: val_loss did not improve from 0.39045
# Epoch 205/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6027 - val_loss: 0.3995
#
# Epoch 00205: val_loss did not improve from 0.39045
# Epoch 206/300
# 67/67 [==============================] - 2s 29ms/step - loss: 0.6013 - val_loss: 0.4031
#
# Epoch 00206: ReduceLROnPlateau reducing learning rate to 0.00010011290578404441.
#
# Epoch 00206: val_loss did not improve from 0.39045
# Epoch 207/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.5904 - val_loss: 0.4041
#
# Epoch 00207: val_loss did not improve from 0.39045
# Epoch 208/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6201 - val_loss: 0.3995
#
# Epoch 00208: val_loss did not improve from 0.39045
# Epoch 209/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.5940 - val_loss: 0.3933
#
# Epoch 00209: val_loss did not improve from 0.39045
# Epoch 210/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.5943 - val_loss: 0.3978
#
# Epoch 00210: val_loss did not improve from 0.39045
# Epoch 211/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.5937 - val_loss: 0.3913
#
# Epoch 00211: val_loss did not improve from 0.39045
# Epoch 212/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6204 - val_loss: 0.3905
#
# Epoch 00212: val_loss did not improve from 0.39045
# Epoch 213/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.5965 - val_loss: 0.4002
#
# Epoch 00213: val_loss did not improve from 0.39045
# Epoch 214/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.5879 - val_loss: 0.4071
#
# Epoch 00214: val_loss did not improve from 0.39045
# Epoch 215/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.5933 - val_loss: 0.3861
#
# Epoch 00215: val_loss improved from 0.39045 to 0.38607, saving model to folds6.hdf5
# Epoch 216/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6042 - val_loss: 0.4133
#
# Epoch 00216: val_loss did not improve from 0.38607
# Epoch 217/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.5992 - val_loss: 0.3913
#
# Epoch 00217: val_loss did not improve from 0.38607
# Epoch 218/300
# 67/67 [==============================] - 2s 29ms/step - loss: 0.5937 - val_loss: 0.3993
#
# Epoch 00218: val_loss did not improve from 0.38607
# Epoch 219/300
# 67/67 [==============================] - 2s 29ms/step - loss: 0.6047 - val_loss: 0.3961
#
# Epoch 00219: val_loss did not improve from 0.38607
# Epoch 220/300
# 67/67 [==============================] - 2s 29ms/step - loss: 0.6095 - val_loss: 0.4029
#
# Epoch 00220: val_loss did not improve from 0.38607
# Epoch 221/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6060 - val_loss: 0.3935
#
# Epoch 00221: val_loss did not improve from 0.38607
# Epoch 222/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.5845 - val_loss: 0.3986
#
# Epoch 00222: val_loss did not improve from 0.38607
# Epoch 223/300
# 67/67 [==============================] - 2s 31ms/step - loss: 0.6136 - val_loss: 0.3983
#
# Epoch 00223: val_loss did not improve from 0.38607
# Epoch 224/300
# 67/67 [==============================] - 2s 36ms/step - loss: 0.5895 - val_loss: 0.4041
#
# Epoch 00224: val_loss did not improve from 0.38607
# Epoch 225/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6120 - val_loss: 0.3979
#
# Epoch 00225: ReduceLROnPlateau reducing learning rate to 7.508467933803331e-05.
#
# Epoch 00225: val_loss did not improve from 0.38607
# Epoch 226/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.5891 - val_loss: 0.3930
#
# Epoch 00226: val_loss did not improve from 0.38607
# Epoch 227/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6006 - val_loss: 0.3950
#
# Epoch 00227: val_loss did not improve from 0.38607
# Epoch 228/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.5941 - val_loss: 0.3901
#
# Epoch 00228: val_loss did not improve from 0.38607
# Epoch 229/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.5991 - val_loss: 0.3946
#
# Epoch 00229: val_loss did not improve from 0.38607
# Epoch 230/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6055 - val_loss: 0.3861
#
# Epoch 00230: val_loss did not improve from 0.38607
# Epoch 231/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6029 - val_loss: 0.3891
#
# Epoch 00231: val_loss did not improve from 0.38607
# Epoch 232/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.5861 - val_loss: 0.4035
#
# Epoch 00232: val_loss did not improve from 0.38607
# Epoch 233/300
# 67/67 [==============================] - 2s 29ms/step - loss: 0.5922 - val_loss: 0.3974
#
# Epoch 00233: val_loss did not improve from 0.38607
# Epoch 234/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.5897 - val_loss: 0.3966
#
# Epoch 00234: val_loss did not improve from 0.38607
# Epoch 235/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6039 - val_loss: 0.3982
#
# Epoch 00235: ReduceLROnPlateau reducing learning rate to 5.6313510867767036e-05.
#
# Epoch 00235: val_loss did not improve from 0.38607
# Epoch 236/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6057 - val_loss: 0.3913
#
# Epoch 00236: val_loss did not improve from 0.38607
# Epoch 237/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.5948 - val_loss: 0.3933
#
# ...
#
# Epoch 00201: val_loss did not improve from 0.39031
# Epoch 202/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6216 - val_loss: 0.3997
#
# Epoch 00202: val_loss did not improve from 0.39031
# Epoch 203/300
# 67/67 [==============================] - 2s 29ms/step - loss: 0.5968 - val_loss: 0.4318
#
# Epoch 00203: val_loss did not improve from 0.39031
# Epoch 204/300
# 67/67 [==============================] - 2s 31ms/step - loss: 0.5955 - val_loss: 0.4205
#
# Epoch 00204: val_loss did not improve from 0.39031
# Epoch 205/300
# 67/67 [==============================] - 2s 31ms/step - loss: 0.6031 - val_loss: 0.4034
#
# Epoch 00205: val_loss did not improve from 0.39031
# Epoch 206/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.5875 - val_loss: 0.4068
#
# Epoch 00206: val_loss did not improve from 0.39031
# Epoch 207/300
# 67/67 [==============================] - 2s 31ms/step - loss: 0.6085 - val_loss: 0.3959
#
# Epoch 00207: val_loss did not improve from 0.39031
# Epoch 208/300
# 67/67 [==============================] - 2s 31ms/step - loss: 0.6102 - val_loss: 0.3988
#
# Epoch 00208: val_loss did not improve from 0.39031
# Epoch 209/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6019 - val_loss: 0.3982
#
# Epoch 00209: val_loss did not improve from 0.39031
# Epoch 210/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6049 - val_loss: 0.3968
#
# Epoch 00210: ReduceLROnPlateau reducing learning rate to 7.508467933803331e-05.
#
# Epoch 00210: val_loss did not improve from 0.39031
# Epoch 211/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.5838 - val_loss: 0.3940
#
# Epoch 00211: val_loss did not improve from 0.39031
# Epoch 212/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.5967 - val_loss: 0.3959
#
# Epoch 00212: val_loss did not improve from 0.39031
# Epoch 213/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6107 - val_loss: 0.3945
#
# Epoch 00213: val_loss did not improve from 0.39031
# Epoch 214/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.5846 - val_loss: 0.3991
#
# Epoch 00214: val_loss did not improve from 0.39031
# Epoch 215/300
# 67/67 [==============================] - 2s 36ms/step - loss: 0.5855 - val_loss: 0.4139
#
# Epoch 00215: val_loss did not improve from 0.39031
# Epoch 216/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6033 - val_loss: 0.4003
#
# Epoch 00216: val_loss did not improve from 0.39031
# Epoch 217/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6108 - val_loss: 0.3943
#
# Epoch 00217: val_loss did not improve from 0.39031
# Epoch 218/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6031 - val_loss: 0.4038
#
# Epoch 00218: val_loss did not improve from 0.39031
# Epoch 219/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6117 - val_loss: 0.4009
#
# Epoch 00219: val_loss did not improve from 0.39031
# Epoch 220/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.5893 - val_loss: 0.4039
#
# Epoch 00220: ReduceLROnPlateau reducing learning rate to 5.6313510867767036e-05.
#
# Epoch 00220: val_loss did not improve from 0.39031
# Epoch 221/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.5935 - val_loss: 0.3977
#
# Epoch 00221: val_loss did not improve from 0.39031
# Epoch 222/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.5982 - val_loss: 0.4009
#
# Epoch 00222: val_loss did not improve from 0.39031
# Epoch 223/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6058 - val_loss: 0.3992
#
# Epoch 00223: val_loss did not improve from 0.39031
# Epoch 224/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6024 - val_loss: 0.3978
#
# Epoch 00224: val_loss did not improve from 0.39031
# Epoch 225/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6031 - val_loss: 0.4081
#
# Epoch 00225: val_loss did not improve from 0.39031
# Epoch 226/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6119 - val_loss: 0.3896
#
# Epoch 00226: val_loss improved from 0.39031 to 0.38960, saving model to folds9.hdf5
# Epoch 227/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6070 - val_loss: 0.3967
#
# Epoch 00227: val_loss did not improve from 0.38960
# Epoch 228/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.5881 - val_loss: 0.3950
#
# Epoch 00228: val_loss did not improve from 0.38960
# Epoch 229/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6072 - val_loss: 0.3940
#
# Epoch 00229: val_loss did not improve from 0.38960
# Epoch 230/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6032 - val_loss: 0.4070
#
# Epoch 00230: val_loss did not improve from 0.38960
# Epoch 231/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.5991 - val_loss: 0.3931
#
# Epoch 00231: val_loss did not improve from 0.38960
# Epoch 232/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6095 - val_loss: 0.3981
#
# Epoch 00232: val_loss did not improve from 0.38960
# Epoch 233/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6053 - val_loss: 0.3922
#
# Epoch 00233: val_loss did not improve from 0.38960
# Epoch 234/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.5971 - val_loss: 0.4037
#
# Epoch 00234: val_loss did not improve from 0.38960
# Epoch 235/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6047 - val_loss: 0.3986
#
# Epoch 00235: val_loss did not improve from 0.38960
# Epoch 236/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6093 - val_loss: 0.3971
#
# Epoch 00236: ReduceLROnPlateau reducing learning rate to 4.223513315082528e-05.
#
# Epoch 00236: val_loss did not improve from 0.38960
# Epoch 237/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6061 - val_loss: 0.4011
#
# Epoch 00237: val_loss did not improve from 0.38960
# Epoch 238/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6117 - val_loss: 0.3956
#
# Epoch 00238: val_loss did not improve from 0.38960
# Epoch 239/300
# 67/67 [==============================] - 2s 29ms/step - loss: 0.5795 - val_loss: 0.3898
#
# Epoch 00239: val_loss did not improve from 0.38960
# Epoch 240/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.5903 - val_loss: 0.3988
#
# Epoch 00240: val_loss did not improve from 0.38960
# Epoch 241/300
# 67/67 [==============================] - 2s 29ms/step - loss: 0.5649 - val_loss: 0.3917
#
# Epoch 00241: val_loss did not improve from 0.38960
# Epoch 242/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.5796 - val_loss: 0.3907
#
# Epoch 00242: val_loss did not improve from 0.38960
# Epoch 243/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.5971 - val_loss: 0.3958
#
# Epoch 00243: val_loss did not improve from 0.38960
# Epoch 244/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.5701 - val_loss: 0.3903
#
# Epoch 00244: val_loss did not improve from 0.38960
# Epoch 245/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6009 - val_loss: 0.3883
#
# Epoch 00245: val_loss improved from 0.38960 to 0.38831, saving model to folds9.hdf5
# Epoch 246/300
# 67/67 [==============================] - 2s 29ms/step - loss: 0.5747 - val_loss: 0.3957
#
# Epoch 00246: val_loss did not improve from 0.38831
# Epoch 247/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.5995 - val_loss: 0.3909
#
# Epoch 00247: val_loss did not improve from 0.38831
# Epoch 248/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6058 - val_loss: 0.3929
#
# Epoch 00248: val_loss did not improve from 0.38831
# Epoch 249/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.5952 - val_loss: 0.3862
#
# Epoch 00249: val_loss improved from 0.38831 to 0.38618, saving model to folds9.hdf5
# Epoch 250/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.5901 - val_loss: 0.3998
#
# Epoch 00250: val_loss did not improve from 0.38618
# Epoch 251/300
# 67/67 [==============================] - 2s 29ms/step - loss: 0.5875 - val_loss: 0.3957
#
# Epoch 00251: val_loss did not improve from 0.38618
# Epoch 252/300
# 67/67 [==============================] - 2s 36ms/step - loss: 0.5969 - val_loss: 0.3956
#
# Epoch 00252: val_loss did not improve from 0.38618
# Epoch 253/300
# 67/67 [==============================] - 2s 29ms/step - loss: 0.5786 - val_loss: 0.3867
#
# Epoch 00253: val_loss did not improve from 0.38618
# Epoch 254/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6289 - val_loss: 0.3895
#
# Epoch 00254: val_loss did not improve from 0.38618
# Epoch 255/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6208 - val_loss: 0.4002
#
# Epoch 00255: val_loss did not improve from 0.38618
# Epoch 256/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.5906 - val_loss: 0.3901
#
# Epoch 00256: val_loss did not improve from 0.38618
# Epoch 257/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.5925 - val_loss: 0.3946
#
# Epoch 00257: val_loss did not improve from 0.38618
# Epoch 258/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6260 - val_loss: 0.3909
#
# Epoch 00258: val_loss did not improve from 0.38618
# Epoch 259/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.5836 - val_loss: 0.3950
#
# Epoch 00259: ReduceLROnPlateau reducing learning rate to 3.167634986311896e-05.
#
# Epoch 00259: val_loss did not improve from 0.38618
# Epoch 260/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.5942 - val_loss: 0.3918
#
# Epoch 00260: val_loss did not improve from 0.38618
# Epoch 261/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6009 - val_loss: 0.3907
#
# Epoch 00261: val_loss did not improve from 0.38618
# Epoch 262/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.5912 - val_loss: 0.3921
#
# Epoch 00262: val_loss did not improve from 0.38618
# Epoch 263/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6080 - val_loss: 0.3869
#
# Epoch 00263: val_loss did not improve from 0.38618
# Epoch 264/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.5834 - val_loss: 0.3848
#
# Epoch 00264: val_loss improved from 0.38618 to 0.38475, saving model to folds9.hdf5
# Epoch 265/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.5941 - val_loss: 0.3880
#
# Epoch 00265: val_loss did not improve from 0.38475
# Epoch 266/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6009 - val_loss: 0.3893
#
# Epoch 00266: val_loss did not improve from 0.38475
# Epoch 267/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6007 - val_loss: 0.3933
#
# Epoch 00267: val_loss did not improve from 0.38475
# Epoch 268/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.5893 - val_loss: 0.3974
#
# Epoch 00268: val_loss did not improve from 0.38475
# Epoch 269/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.5934 - val_loss: 0.3904
#
# Epoch 00269: val_loss did not improve from 0.38475
# Epoch 270/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.5924 - val_loss: 0.3990
#
# Epoch 00270: val_loss did not improve from 0.38475
# Epoch 271/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.5892 - val_loss: 0.3881
#
# Epoch 00271: val_loss did not improve from 0.38475
# Epoch 272/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.5840 - val_loss: 0.3859
#
# Epoch 00272: val_loss did not improve from 0.38475
# Epoch 273/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.5965 - val_loss: 0.3912
#
# Epoch 00273: val_loss did not improve from 0.38475
# Epoch 274/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.5702 - val_loss: 0.3935
#
# Epoch 00274: ReduceLROnPlateau reducing learning rate to 2.3757263079460245e-05.
#
# Epoch 00274: val_loss did not improve from 0.38475
# Epoch 275/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.5607 - val_loss: 0.3915
#
# Epoch 00275: val_loss did not improve from 0.38475
# Epoch 276/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.5952 - val_loss: 0.3941
#
# Epoch 00276: val_loss did not improve from 0.38475
# Epoch 277/300
# 67/67 [==============================] - 2s 29ms/step - loss: 0.5913 - val_loss: 0.3908
#
# Epoch 00277: val_loss did not improve from 0.38475
# Epoch 278/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.5969 - val_loss: 0.3946
#
# Epoch 00278: val_loss did not improve from 0.38475
# Epoch 279/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6122 - val_loss: 0.3930
#
# Epoch 00279: val_loss did not improve from 0.38475
# Epoch 280/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6044 - val_loss: 0.3862
#
# Epoch 00280: val_loss did not improve from 0.38475
# Epoch 281/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6115 - val_loss: 0.3904
#
# Epoch 00281: val_loss did not improve from 0.38475
# Epoch 282/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6026 - val_loss: 0.3911
#
# Epoch 00282: val_loss did not improve from 0.38475
# Epoch 283/300
# 67/67 [==============================] - 2s 31ms/step - loss: 0.5891 - val_loss: 0.3927
#
# Epoch 00283: val_loss did not improve from 0.38475
# Epoch 284/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6171 - val_loss: 0.3904
#
# Epoch 00284: ReduceLROnPlateau reducing learning rate to 1.781794799171621e-05.
#
# Epoch 00284: val_loss did not improve from 0.38475
# Epoch 285/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.5922 - val_loss: 0.3930
#
# Epoch 00285: val_loss did not improve from 0.38475
# Epoch 286/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.5825 - val_loss: 0.3910
#
# Epoch 00286: val_loss did not improve from 0.38475
# Epoch 287/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.5857 - val_loss: 0.3872
#
# Epoch 00287: val_loss did not improve from 0.38475
# Epoch 288/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.5719 - val_loss: 0.3860
#
# Epoch 00288: val_loss did not improve from 0.38475
# Epoch 289/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.5804 - val_loss: 0.3898
#
# Epoch 00289: val_loss did not improve from 0.38475
# Epoch 290/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.5946 - val_loss: 0.3864
#
# Epoch 00290: val_loss did not improve from 0.38475
# Epoch 291/300
# 67/67 [==============================] - 2s 36ms/step - loss: 0.5967 - val_loss: 0.3900
#
# Epoch 00291: val_loss did not improve from 0.38475
# Epoch 292/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.6070 - val_loss: 0.3896
#
# Epoch 00292: val_loss did not improve from 0.38475
# Epoch 293/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.5971 - val_loss: 0.3933
#
# Epoch 00293: val_loss did not improve from 0.38475
# Epoch 294/300
# 67/67 [==============================] - 2s 29ms/step - loss: 0.6108 - val_loss: 0.3856
#
# Epoch 00294: ReduceLROnPlateau reducing learning rate to 1.3363460311666131e-05.
#
# Epoch 00294: val_loss did not improve from 0.38475
# Epoch 295/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.5984 - val_loss: 0.3912
#
# Epoch 00295: val_loss did not improve from 0.38475
# Epoch 296/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.5836 - val_loss: 0.3903
#
# Epoch 00296: val_loss did not improve from 0.38475
# Epoch 297/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.5973 - val_loss: 0.3893
#
# Epoch 00297: val_loss did not improve from 0.38475
# Epoch 298/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.5817 - val_loss: 0.3866
#
# Epoch 00298: val_loss did not improve from 0.38475
# Epoch 299/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.5813 - val_loss: 0.3923
#
# Epoch 00299: val_loss did not improve from 0.38475
# Epoch 300/300
# 67/67 [==============================] - 2s 30ms/step - loss: 0.5965 - val_loss: 0.3888
#
# Epoch 00300: val_loss did not improve from 0.38475

# %%
PRESSURE_STEP = 0.07030214545120961
PRESSURE_MIN = -1.8957442945646408
PRESSURE_MAX = 64.82099173863948

# %%
# ENSEMBLE FOLDS WITH MEAN
submission["pressure"] = sum(test_preds)/NUM_FOLDS
submission.to_csv('submission_mean.csv', index=False)

# %%
# ENSEMBLE FOLDS WITH MEDIAN
submission["pressure"] = np.median(np.vstack(test_preds),axis=0)
submission.to_csv('submission_median.csv', index=False)

# %%
# ENSEMBLE FOLDS WITH MEDIAN AND ROUND PREDICTIONS
submission["pressure"] =\
    np.round( (submission.pressure - PRESSURE_MIN)/PRESSURE_STEP ) * PRESSURE_STEP + PRESSURE_MIN
submission.pressure = np.clip(submission.pressure, PRESSURE_MIN, PRESSURE_MAX)
submission.to_csv('submission_median_round.csv', index=False)

# %%
from google.colab import files

files.download('submission_mean.csv')
files.download('submission_median.csv')
files.download('submission_median_round.csv')
