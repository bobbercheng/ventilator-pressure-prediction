# %% [markdown]
# <a href="https://colab.research.google.com/github/bobbercheng/ventilator-pressure-prediction/blob/master/ventilator_pressure_transformer_V1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# V1: Add PositionalEncoding

# %%
#!pip install pandas==1.3.2

# %%
from google.colab import drive
drive.mount("/gdrive", force_remount=True)
# Out:
# Mounted at /gdrive

# %%
# !pip install kaggle
# !mkdir /root/.kaggle
# !cp /gdrive/MyDrive/ventilator-pressure-prediction/kaggle.json /root/.kaggle
# !kaggle competitions download -c ventilator-pressure-prediction
# !mkdir -p /kaggle/input/ventilator-pressure-prediction
# !unzip '*.zip' -d /kaggle/input/ventilator-pressure-prediction
# !ls /kaggle/input/ventilator-pressure-prediction
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.7/dist-packages (1.5.12)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.15.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from kaggle) (2021.5.30)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from kaggle) (4.62.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.23.0)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.7/dist-packages (from kaggle) (5.0.2)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.24.3)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.7/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (3.0.4)
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.5.12 / client 1.5.4)
# Downloading sample_submission.csv.zip to /content
#   0% 0.00/8.50M [00:00<?, ?B/s]
# 100% 8.50M/8.50M [00:00<00:00, 139MB/s]
# Downloading test.csv.zip to /content
#  81% 61.0M/75.4M [00:00<00:00, 94.1MB/s]
# 100% 75.4M/75.4M [00:00<00:00, 170MB/s]
# Downloading train.csv.zip to /content
#  93% 130M/139M [00:00<00:00, 191MB/s]
# 100% 139M/139M [00:00<00:00, 219MB/s]
# Archive:  sample_submission.csv.zip
#   inflating: /kaggle/input/ventilator-pressure-prediction/sample_submission.csv
#
# Archive:  test.csv.zip
#   inflating: /kaggle/input/ventilator-pressure-prediction/test.csv
#
# Archive:  train.csv.zip
#   inflating: /kaggle/input/ventilator-pressure-prediction/train.csv
#
# 3 archives were successfully processed.
# sample_submission.csv  test.csv  train.csv

# %%
import numpy as np
import pandas as pd

# import optuna

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.callbacks import LearningRateScheduler, ReduceLROnPlateau
from tensorflow.keras.optimizers.schedules import ExponentialDecay

from sklearn.metrics import mean_absolute_error as mae
from sklearn.preprocessing import RobustScaler, normalize
from sklearn.model_selection import train_test_split, GroupKFold, KFold

from IPython.display import display

# %%
DEBUG = False

train = pd.read_csv('/kaggle/input/ventilator-pressure-prediction/train.csv')
test = pd.read_csv('/kaggle/input/ventilator-pressure-prediction/test.csv')
submission = pd.read_csv('/kaggle/input/ventilator-pressure-prediction/sample_submission.csv')

if DEBUG:
    train = train[:80*1000]

# %%
def add_feats(train):
    # # rewritten calculation of lag features from this notebook: https://www.kaggle.com/patrick0302/add-lag-u-in-as-new-feat
# # some of ideas from this notebook: https://www.kaggle.com/mst8823/google-brain-lightgbm-baseline
    # train[["15_out_mean"]] = train.groupby('breath_id')['u_out'].rolling(window=15,min_periods=1).agg({"15_out_mean":"mean"}).reset_index(level=0,drop=True)
    train['last_value_u_in'] = train.groupby('breath_id')['u_in'].transform('last')
    train['u_in_lag1'] = train.groupby('breath_id')['u_in'].shift(1)
    train['u_out_lag1'] = train.groupby('breath_id')['u_out'].shift(1)
    train['u_in_lag_back1'] = train.groupby('breath_id')['u_in'].shift(-1)
    train['u_out_lag_back1'] = train.groupby('breath_id')['u_out'].shift(-1)
    train['u_in_lag2'] = train.groupby('breath_id')['u_in'].shift(2)
    train['u_out_lag2'] = train.groupby('breath_id')['u_out'].shift(2)
    train['u_in_lag3'] = train.groupby('breath_id')['u_in'].shift(3)
    train['u_out_lag3'] = train.groupby('breath_id')['u_out'].shift(3)
    train['u_in_lag_back2'] = train.groupby('breath_id')['u_in'].shift(-2)
    train['u_out_lag_back2'] = train.groupby('breath_id')['u_out'].shift(-2)
    train['u_in_lag_back3'] = train.groupby('breath_id')['u_in'].shift(-3)
    train['u_out_lag_back3'] = train.groupby('breath_id')['u_out'].shift(-3)
    train['u_in_lag_back10'] = train.groupby('breath_id')['u_in'].shift(-10)
    train['u_out_lag_back10'] = train.groupby('breath_id')['u_out'].shift(-10)

    train['u_in_first'] = train.groupby('breath_id')['u_in'].first()
    train['u_out_first'] = train.groupby('breath_id')['u_out'].first()

    ## time since last step
    train['time_step_diff'] = train.groupby('breath_id')['time_step'].diff().fillna(0)
    ### rolling window ts feats
    train['ewm_u_in_mean'] = train.groupby('breath_id')['u_in'].ewm(halflife=9).mean().reset_index(level=0,drop=True)
    train['ewm_u_in_std'] = train.groupby('breath_id')['u_in'].ewm(halflife=10).std().reset_index(level=0,drop=True) ## could add covar?
    train['ewm_u_in_corr'] = train.groupby('breath_id')['u_in'].ewm(halflife=15).corr().reset_index(level=0,drop=True) # self umin corr
    # train['ewm_u_in_corr'] = train.groupby('breath_id')['u_in'].ewm(halflife=6).corr(train.groupby('breath_id')["u_out"]).reset_index(level=0,drop=True) # corr with u_out # error
    ## rolling window of 15 periods
    train[["15_in_sum","15_in_min","15_in_max","15_in_mean","15_out_std"]] = train.groupby('breath_id')['u_in'].rolling(window=15,min_periods=1).agg({"15_in_sum":"sum","15_in_min":"min","15_in_max":"max","15_in_mean":"mean","15_in_std":"std"}).reset_index(level=0,drop=True)
#     train[["45_in_sum","45_in_min","45_in_max","45_in_mean","45_out_std"]] = train.groupby('breath_id')['u_in'].rolling(window=45,min_periods=1).agg({"45_in_sum":"sum","45_in_min":"min","45_in_max":"max","45_in_mean":"mean","45_in_std":"std"}).reset_index(level=0,drop=True)
    train[["45_in_sum","45_in_min","45_in_max","45_in_mean","45_out_std"]] = train.groupby('breath_id')['u_in'].rolling(window=45,min_periods=1).agg({"45_in_sum":"sum","45_in_min":"min","45_in_max":"max","45_in_mean":"mean","45_in_std":"std"}).reset_index(level=0,drop=True)

    train[["15_out_mean"]] = train.groupby('breath_id')['u_out'].rolling(window=15,min_periods=1).agg({"15_out_mean":"mean"}).reset_index(level=0,drop=True)

    print(train.shape[0])
    display(train)
    train = train.fillna(0) # ORIG

    # max, min, mean value of u_in and u_out for each breath
    train['breath_id__u_in__max'] = train.groupby(['breath_id'])['u_in'].transform('max')
    train['breath_id__u_out__max'] = train.groupby(['breath_id'])['u_out'].transform('max')

    train['breath_id__u_out__mean'] =train.groupby(['breath_id'])['u_out'].mean()
    train['breath_id__u_in__mean'] =train.groupby(['breath_id'])['u_in'].mean()

    train['breath_id__u_in__min'] = train.groupby(['breath_id'])['u_in'].transform('min')
    train['breath_id__u_out__min'] = train.groupby(['breath_id'])['u_out'].transform('min')

    train['u_in_first'] = train.groupby(['breath_id'])['u_in'].transform('first')
    train['u_in_last'] = train.groupby(['breath_id'])['u_in'].transform('last')

    train['R_div_C'] = train["R"].div(train["C"])

    # difference between consequitive values
    train['R__C'] = train["R"].astype(str) + '__' + train["C"].astype(str)
    train['u_in_diff1'] = train['u_in'] - train['u_in_lag1']
    train['u_out_diff1'] = train['u_out'] - train['u_out_lag1']
    train['u_in_diff2'] = train['u_in'] - train['u_in_lag2']
    train['u_out_diff2'] = train['u_out'] - train['u_out_lag2']
    train['u_in_diff3'] = train['u_in'] - train['u_in_lag3']
    train['u_out_diff3'] = train['u_out'] - train['u_out_lag3']
    ## diff between last 2 steps
    train['u_in_diff_1_2'] = train['u_in_lag1'] - train['u_in_lag2']
    train['u_out_diff_1_2'] = train['u_out_lag1'] - train['u_out_lag2']
    train['u_in_lagback_diff_1_2'] = train['u_in_lag_back1'] - train['u_in_lag_back2']
    train['u_out_lagback_diff_1_2'] = train['u_out_lag_back1'] - train['u_out_lag_back2']

    train['u_in_lagback_diff1'] = train['u_in'] - train['u_in_lag_back1']
    train['u_out_lagback_diff1'] = train['u_out'] - train['u_out_lag_back1']
    train['u_in_lagback_diff2'] = train['u_in'] - train['u_in_lag_back2']
    train['u_out_lagback_diff2'] = train['u_out'] - train['u_out_lag_back2']

    # from here: https://www.kaggle.com/yasufuminakama/ventilator-pressure-lstm-starter
    train.loc[train['time_step'] == 0, 'u_in_diff'] = 0
    train.loc[train['time_step'] == 0, 'u_out_diff'] = 0

    # difference between the current value of u_in and the max value within the breath
    train['breath_id__u_in__diffmax'] = train.groupby(['breath_id'])['u_in'].transform('max') - train['u_in']
    train['breath_id__u_in__diffmean'] = train.groupby(['breath_id'])['u_in'].transform('mean') - train['u_in']

    print("before OHE")
    display(train)

    # OHE
    train = train.merge(pd.get_dummies(train['R'], prefix='R'), left_index=True, right_index=True).drop(['R'], axis=1)
    train = train.merge(pd.get_dummies(train['C'], prefix='C'), left_index=True, right_index=True).drop(['C'], axis=1)
    train = train.merge(pd.get_dummies(train['R__C'], prefix='R__C'), left_index=True, right_index=True).drop(['R__C'], axis=1)

    # https://www.kaggle.com/c/ventilator-pressure-prediction/discussion/273974
    train['u_in_cumsum'] = train.groupby(['breath_id'])['u_in'].cumsum()
    train['time_step_cumsum'] = train.groupby(['breath_id'])['time_step'].cumsum()

    # feature by u in or out (ideally - make 2 sep columns for each state) # dan
    train['u_in_partition_out_sum'] = train.groupby(['breath_id',"u_out"])['u_in'].transform("sum")

    train = train.fillna(0) # add for consistency with how test is done - dan

    return train

train = add_feats(train)
test = add_feats(test)
# Out:
# 6036000
#               id  breath_id   R  ...  45_in_mean  45_out_std  15_out_mean
# 0              1          1  20  ...    0.083334         NaN          0.0
# 1              2          1  20  ...    9.233188   12.939847          0.0
# 2              3          1  20  ...   13.658551   11.936136          0.0
# 3              4          1  20  ...   15.946119   10.766279          0.0
# 4              5          1  20  ...   17.828065   10.229525          0.0
# ...          ...        ...  ..  ...         ...         ...          ...
# 6035995  6035996     125749  50  ...    3.132079    4.277354          1.0
# 6035996  6035997     125749  50  ...    3.165156    4.258295          1.0
# 6035997  6035998     125749  50  ...    2.890898    3.936430          1.0
# 6035998  6035999     125749  50  ...    2.607671    3.557961          1.0
# 6035999  6036000     125749  50  ...    2.361694    3.221585          1.0
#
# [6036000 rows x 40 columns]
# before OHE
#               id  ...  breath_id__u_in__diffmean
# 0              1  ...                  10.062673
# 1              2  ...                  -8.237035
# 2              3  ...                 -12.363271
# 3              4  ...                 -12.662816
# 4              5  ...                 -15.209844
# ...          ...  ...                        ...
# 6035995  6035996  ...                   3.421689
# 6035996  6035997  ...                   3.422905
# 6035997  6035998  ...                   3.352424
# 6035998  6035999  ...                   3.638739
# 6035999  6036000  ...                   3.428663
#
# [6036000 rows x 67 columns]
# 4024000
#               id  breath_id   R  ...  45_in_mean  45_out_std  15_out_mean
# 0              1          0   5  ...    0.000000         NaN          0.0
# 1              2          0   5  ...    3.757523    5.313940          0.0
# 2              3          0   5  ...    7.388907    7.326652          0.0
# 3              4          0   5  ...   10.849333    9.147936          0.0
# 4              5          0   5  ...   13.943657   10.518450          0.0
# ...          ...        ...  ..  ...         ...         ...          ...
# 4023995  4023996     125748  20  ...    2.794529    2.152980          1.0
# 4023996  4023997     125748  20  ...    2.905101    2.133884          1.0
# 4023997  4023998     125748  20  ...    3.015755    2.108773          1.0
# 4023998  4023999     125748  20  ...    3.126481    2.077404          1.0
# 4023999  4024000     125748  20  ...    3.237267    2.039469          1.0
#
# [4024000 rows x 39 columns]
# before OHE
#               id  ...  breath_id__u_in__diffmean
# 0              1  ...                   9.327338
# 1              2  ...                   1.812292
# 2              3  ...                  -5.324338
# 3              4  ...                 -11.903272
# 4              5  ...                 -16.993619
# ...          ...  ...                        ...
# 4023995  4023996  ...                  -2.288270
# 4023996  4023997  ...                  -2.292733
# 4023997  4023998  ...                  -2.296492
# 4023998  4023999  ...                  -2.299672
# 4023999  4024000  ...                  -2.302397
#
# [4024000 rows x 66 columns]

# %%
train.head()
# Out:
#    id  breath_id  ...  time_step_cumsum  u_in_partition_out_sum
# 0   1          1  ...          0.000000              663.594727
# 1   2          1  ...          0.033652              663.594727
# 2   3          1  ...          0.101167              663.594727
# 3   4          1  ...          0.202709              663.594727
# 4   5          1  ...          0.338464              663.594727
#
# [5 rows x 82 columns]

# %%
train.shape
# Out:
# (6036000, 82)

# %%
targets = train[['pressure']].to_numpy().reshape(-1, 80)
#u_outs = train[['u_out']].to_numpy().reshape(-1, 80)
train.drop(['pressure', 'id', 'breath_id'], axis=1, inplace=True)
test = test.drop(['id', 'breath_id'], axis=1)

# %%
RS = RobustScaler()
train = RS.fit_transform(train)
test = RS.transform(test)

# %%
train = train.reshape(-1, 80, train.shape[-1])
test = test.reshape(-1, 80, train.shape[-1])

# %%
def GBVPP_loss(y_true, y_pred, cols = 80):
    u_out = y_true[:, cols: ]
    y = y_true[:, :cols ]

    w = 1 - u_out
    mae = w * tf.abs(y - y_pred)
    return tf.reduce_sum(mae, axis=-1) / tf.reduce_sum(w, axis=-1)

# %%
from tensorflow.keras.layers import Layer
from tensorflow.keras import backend as K

class Attention(Layer):
    
    def __init__(self, return_sequences=True):
        self.return_sequences = return_sequences
        super(Attention,self).__init__()
        
    def build(self, input_shape):
        
        self.W=self.add_weight(name="att_weight", shape=(input_shape[-1],1),
                               initializer="normal")
        self.b=self.add_weight(name="att_bias", shape=(input_shape[1],1),
                               initializer="zeros")
        
        super(Attention,self).build(input_shape)
        
    def call(self, x):
        
        e = K.tanh(K.dot(x,self.W)+self.b)
        a = K.softmax(e, axis=1)
        output = x*a
        
        if self.return_sequences:
            return output
        
        return K.sum(output, axis=1)

    def get_config(self):
        return super(Attention, self).get_config()

# %%
def get_cnn_model(train):
  inputs = keras.layers.Input(shape=train.shape[-2:])
  X = inputs

  X = keras.layers.Conv1D(filters=2048, kernel_size=3, activation='relu')(X)
  X = keras.layers.BatchNormalization()(X)
  X = keras.layers.Conv1D(filters=2048, kernel_size=3, activation='relu')(X)
  X = keras.layers.BatchNormalization()(X)
  X = keras.layers.AveragePooling1D(pool_size=2)(X)

  X = Attention(return_sequences=True)(X)

  X = keras.layers.Conv1D(filters=1024, kernel_size=3, activation='relu')(X)
  X = keras.layers.BatchNormalization()(X)
  X = keras.layers.Conv1D(filters=1024, kernel_size=3, activation='relu')(X)
  X = keras.layers.BatchNormalization()(X)
  X = keras.layers.AveragePooling1D(pool_size=2)(X)

  X = Attention(return_sequences=True)(X)


  X = keras.layers.Conv1D(filters=512, kernel_size=3, activation='relu')(X)
  X = keras.layers.BatchNormalization()(X)
  X = keras.layers.Conv1D(filters=512, kernel_size=3, activation='relu')(X)
  X = keras.layers.BatchNormalization()(X)
  X = keras.layers.AveragePooling1D(pool_size=2)(X)

  X = Attention(return_sequences=True)(X)

  X = keras.layers.Conv1D(filters=256, kernel_size=3, activation='relu')(X)
  X = keras.layers.BatchNormalization()(X)
  X = keras.layers.Conv1D(filters=256, kernel_size=3, activation='relu')(X)
  X = keras.layers.BatchNormalization()(X)
  X = keras.layers.AveragePooling1D(pool_size=2)(X)

  X = Attention(return_sequences=True)(X)

  X = keras.layers.Flatten()(X) #256

  input_X = keras.layers.Flatten()(inputs)
  input_X = keras.layers.Dense(512, activation='selu', kernel_initializer='lecun_normal')(input_X)
  input_X = keras.layers.BatchNormalization()(input_X)
  input_X = keras.layers.Dense(256, activation='selu', kernel_initializer='lecun_normal')(input_X)
  input_X = keras.layers.BatchNormalization()(input_X) #256

  X = keras.layers.Concatenate()([X, input_X])

  X = keras.layers.Dense(256, activation='selu', kernel_initializer='lecun_normal')(X)
  X = keras.layers.BatchNormalization()(X)
  outputs = keras.layers.Dense(80)(X)
  model  = keras.Model(inputs=inputs, outputs=outputs)
  model.summary()
  return model

# %%
from tensorflow.keras import layers
from tensorflow import keras

# %%
#refer to https://rubikscode.net/2019/08/19/transformer-with-python-and-tensorflow-2-0-encoder-decoder/
class PositionalEncoding(object):
    def __init__(self, position, d):
        angle_rads = self._get_angles(np.arange(position)[:, np.newaxis], np.arange(d)[np.newaxis, :], d)

        sines = np.sin(angle_rads[:, 0::2])
        cosines = np.cos(angle_rads[:, 1::2])
        self._encoding = np.concatenate([sines, cosines], axis=-1)
        self._encoding = self._encoding[np.newaxis, ...]
    
    def _get_angles(self, position, i, d):
        angle_rates = 1 / np.power(10000, (2 * (i//2)) / np.float32(d))
        return position * angle_rates
    
    def get_positional_encoding(self):
        return tf.cast(self._encoding, dtype=tf.float32)

# %%
#refer to https://keras.io/examples/timeseries/timeseries_classification_transformer/
def transformer_encoder(inputs, head_size, num_heads, ff_dim, dropout=0):
    # Normalization and Attention
    x = layers.LayerNormalization(epsilon=1e-6)(inputs)
    x = layers.MultiHeadAttention(
        key_dim=head_size, num_heads=num_heads, dropout=dropout
    )(x, x)
    x = layers.Dropout(dropout)(x)
    res = x + inputs

    # Feed Forward Part
    x = layers.LayerNormalization(epsilon=1e-6)(res)
    x = layers.Conv1D(filters=ff_dim, kernel_size=1, activation="relu")(x)
    x = layers.Dropout(dropout)(x)
    x = layers.Conv1D(filters=inputs.shape[-1], kernel_size=1)(x)
    return x + res

# %%
# refer to https://rubikscode.net/2019/08/19/transformer-with-python-and-tensorflow-2-0-encoder-decoder/
def build_transfer_model(
    input_shape,
    head_size=256,
    num_heads=8,
    ff_dim=1024,
    num_transformer_blocks=8,
    mlp_units=[16, 1],
    dropout=0.01,
    mlp_dropout=0.01,
):
    # print(input_shape)
    inputs = keras.Input(shape=input_shape)
    sequence_lenght = input_shape[0]
    print('sequence_lenght:', sequence_lenght)
    positional_encoding_handler = PositionalEncoding(sequence_lenght, input_shape[-1])
    positional_encoding = positional_encoding_handler.get_positional_encoding()
    print('positional_encoding:', positional_encoding)

    x = inputs

    x += positional_encoding[:, :sequence_lenght, :]

    for _ in range(num_transformer_blocks):
        x = transformer_encoder(x, head_size, num_heads, ff_dim, dropout)

    x_pool = layers.GlobalAveragePooling1D(data_format="channels_first")(x)
    x_pool = tf.expand_dims(x_pool, -1)

    for dim in mlp_units:
        x = layers.Dense(dim, activation="relu")(x)
        x = layers.Dropout(mlp_dropout)(x)

    outputs = layers.Dense(dim, activation="relu")(x + x_pool)
    model = keras.Model(inputs, outputs)
    model.summary()
    return model

# %%
# model = build_transfer_model(train.shape[1:])
# del model
# Out:
# sequence_lenght: 80
# positional_encoding: tf.Tensor(
# [[[ 0.          0.          0.         ...  1.          1.
#     1.        ]
#   [ 0.84147096  0.7117711   0.5869528  ...  1.          1.
#     1.        ]
#   [ 0.9092974   0.9999124   0.95041883 ...  0.9999999   0.99999994
#     0.99999994]
#   ...
#   [ 0.9995202  -0.9622094  -0.9236275  ...  0.99984837  0.9999049
#     0.99994034]
#   [ 0.5139785  -0.86968976 -0.9727623  ...  0.9998444   0.99990237
#     0.9999388 ]
#   [-0.44411266 -0.25955084 -0.65151036 ...  0.9998404   0.99989986
#     0.9999372 ]]], shape=(1, 80, 79), dtype=float32)
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_9 (InputLayer)            [(None, 80, 79)]     0
# __________________________________________________________________________________________________
# tf.__operators__.add_18 (TFOpLa (None, 80, 79)       0           input_9[0][0]
# __________________________________________________________________________________________________
# layer_normalization_16 (LayerNo (None, 80, 79)       158         tf.__operators__.add_18[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_8 (MultiHe (None, 80, 79)       653391      layer_normalization_16[0][0]
#                                                                  layer_normalization_16[0][0]
# __________________________________________________________________________________________________
# dropout_18 (Dropout)            (None, 80, 79)       0           multi_head_attention_8[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_19 (TFOpLa (None, 80, 79)       0           dropout_18[0][0]
#                                                                  tf.__operators__.add_18[0][0]
# __________________________________________________________________________________________________
# layer_normalization_17 (LayerNo (None, 80, 79)       158         tf.__operators__.add_19[0][0]
# __________________________________________________________________________________________________
# conv1d_16 (Conv1D)              (None, 80, 1024)     81920       layer_normalization_17[0][0]
# __________________________________________________________________________________________________
# dropout_19 (Dropout)            (None, 80, 1024)     0           conv1d_16[0][0]
# __________________________________________________________________________________________________
# conv1d_17 (Conv1D)              (None, 80, 79)       80975       dropout_19[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_20 (TFOpLa (None, 80, 79)       0           conv1d_17[0][0]
#                                                                  tf.__operators__.add_19[0][0]
# __________________________________________________________________________________________________
# layer_normalization_18 (LayerNo (None, 80, 79)       158         tf.__operators__.add_20[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_9 (MultiHe (None, 80, 79)       653391      layer_normalization_18[0][0]
#                                                                  layer_normalization_18[0][0]
# __________________________________________________________________________________________________
# dropout_20 (Dropout)            (None, 80, 79)       0           multi_head_attention_9[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_21 (TFOpLa (None, 80, 79)       0           dropout_20[0][0]
#                                                                  tf.__operators__.add_20[0][0]
# __________________________________________________________________________________________________
# layer_normalization_19 (LayerNo (None, 80, 79)       158         tf.__operators__.add_21[0][0]
# __________________________________________________________________________________________________
# conv1d_18 (Conv1D)              (None, 80, 1024)     81920       layer_normalization_19[0][0]
# __________________________________________________________________________________________________
# dropout_21 (Dropout)            (None, 80, 1024)     0           conv1d_18[0][0]
# __________________________________________________________________________________________________
# conv1d_19 (Conv1D)              (None, 80, 79)       80975       dropout_21[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_22 (TFOpLa (None, 80, 79)       0           conv1d_19[0][0]
#                                                                  tf.__operators__.add_21[0][0]
# __________________________________________________________________________________________________
# layer_normalization_20 (LayerNo (None, 80, 79)       158         tf.__operators__.add_22[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_10 (MultiH (None, 80, 79)       653391      layer_normalization_20[0][0]
#                                                                  layer_normalization_20[0][0]
# __________________________________________________________________________________________________
# dropout_22 (Dropout)            (None, 80, 79)       0           multi_head_attention_10[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_23 (TFOpLa (None, 80, 79)       0           dropout_22[0][0]
#                                                                  tf.__operators__.add_22[0][0]
# __________________________________________________________________________________________________
# layer_normalization_21 (LayerNo (None, 80, 79)       158         tf.__operators__.add_23[0][0]
# __________________________________________________________________________________________________
# conv1d_20 (Conv1D)              (None, 80, 1024)     81920       layer_normalization_21[0][0]
# __________________________________________________________________________________________________
# dropout_23 (Dropout)            (None, 80, 1024)     0           conv1d_20[0][0]
# __________________________________________________________________________________________________
# conv1d_21 (Conv1D)              (None, 80, 79)       80975       dropout_23[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_24 (TFOpLa (None, 80, 79)       0           conv1d_21[0][0]
#                                                                  tf.__operators__.add_23[0][0]
# __________________________________________________________________________________________________
# layer_normalization_22 (LayerNo (None, 80, 79)       158         tf.__operators__.add_24[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_11 (MultiH (None, 80, 79)       653391      layer_normalization_22[0][0]
#                                                                  layer_normalization_22[0][0]
# __________________________________________________________________________________________________
# dropout_24 (Dropout)            (None, 80, 79)       0           multi_head_attention_11[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_25 (TFOpLa (None, 80, 79)       0           dropout_24[0][0]
#                                                                  tf.__operators__.add_24[0][0]
# __________________________________________________________________________________________________
# layer_normalization_23 (LayerNo (None, 80, 79)       158         tf.__operators__.add_25[0][0]
# __________________________________________________________________________________________________
# conv1d_22 (Conv1D)              (None, 80, 1024)     81920       layer_normalization_23[0][0]
# __________________________________________________________________________________________________
# dropout_25 (Dropout)            (None, 80, 1024)     0           conv1d_22[0][0]
# __________________________________________________________________________________________________
# conv1d_23 (Conv1D)              (None, 80, 79)       80975       dropout_25[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_26 (TFOpLa (None, 80, 79)       0           conv1d_23[0][0]
#                                                                  tf.__operators__.add_25[0][0]
# __________________________________________________________________________________________________
# layer_normalization_24 (LayerNo (None, 80, 79)       158         tf.__operators__.add_26[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_12 (MultiH (None, 80, 79)       653391      layer_normalization_24[0][0]
#                                                                  layer_normalization_24[0][0]
# __________________________________________________________________________________________________
# dropout_26 (Dropout)            (None, 80, 79)       0           multi_head_attention_12[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_27 (TFOpLa (None, 80, 79)       0           dropout_26[0][0]
#                                                                  tf.__operators__.add_26[0][0]
# __________________________________________________________________________________________________
# layer_normalization_25 (LayerNo (None, 80, 79)       158         tf.__operators__.add_27[0][0]
# __________________________________________________________________________________________________
# conv1d_24 (Conv1D)              (None, 80, 1024)     81920       layer_normalization_25[0][0]
# __________________________________________________________________________________________________
# dropout_27 (Dropout)            (None, 80, 1024)     0           conv1d_24[0][0]
# __________________________________________________________________________________________________
# conv1d_25 (Conv1D)              (None, 80, 79)       80975       dropout_27[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_28 (TFOpLa (None, 80, 79)       0           conv1d_25[0][0]
#                                                                  tf.__operators__.add_27[0][0]
# __________________________________________________________________________________________________
# layer_normalization_26 (LayerNo (None, 80, 79)       158         tf.__operators__.add_28[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_13 (MultiH (None, 80, 79)       653391      layer_normalization_26[0][0]
#                                                                  layer_normalization_26[0][0]
# __________________________________________________________________________________________________
# dropout_28 (Dropout)            (None, 80, 79)       0           multi_head_attention_13[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_29 (TFOpLa (None, 80, 79)       0           dropout_28[0][0]
#                                                                  tf.__operators__.add_28[0][0]
# __________________________________________________________________________________________________
# layer_normalization_27 (LayerNo (None, 80, 79)       158         tf.__operators__.add_29[0][0]
# __________________________________________________________________________________________________
# conv1d_26 (Conv1D)              (None, 80, 1024)     81920       layer_normalization_27[0][0]
# __________________________________________________________________________________________________
# dropout_29 (Dropout)            (None, 80, 1024)     0           conv1d_26[0][0]
# __________________________________________________________________________________________________
# conv1d_27 (Conv1D)              (None, 80, 79)       80975       dropout_29[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_30 (TFOpLa (None, 80, 79)       0           conv1d_27[0][0]
#                                                                  tf.__operators__.add_29[0][0]
# __________________________________________________________________________________________________
# layer_normalization_28 (LayerNo (None, 80, 79)       158         tf.__operators__.add_30[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_14 (MultiH (None, 80, 79)       653391      layer_normalization_28[0][0]
#                                                                  layer_normalization_28[0][0]
# __________________________________________________________________________________________________
# dropout_30 (Dropout)            (None, 80, 79)       0           multi_head_attention_14[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_31 (TFOpLa (None, 80, 79)       0           dropout_30[0][0]
#                                                                  tf.__operators__.add_30[0][0]
# __________________________________________________________________________________________________
# layer_normalization_29 (LayerNo (None, 80, 79)       158         tf.__operators__.add_31[0][0]
# __________________________________________________________________________________________________
# conv1d_28 (Conv1D)              (None, 80, 1024)     81920       layer_normalization_29[0][0]
# __________________________________________________________________________________________________
# dropout_31 (Dropout)            (None, 80, 1024)     0           conv1d_28[0][0]
# __________________________________________________________________________________________________
# conv1d_29 (Conv1D)              (None, 80, 79)       80975       dropout_31[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_32 (TFOpLa (None, 80, 79)       0           conv1d_29[0][0]
#                                                                  tf.__operators__.add_31[0][0]
# __________________________________________________________________________________________________
# layer_normalization_30 (LayerNo (None, 80, 79)       158         tf.__operators__.add_32[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_15 (MultiH (None, 80, 79)       653391      layer_normalization_30[0][0]
#                                                                  layer_normalization_30[0][0]
# __________________________________________________________________________________________________
# dropout_32 (Dropout)            (None, 80, 79)       0           multi_head_attention_15[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_33 (TFOpLa (None, 80, 79)       0           dropout_32[0][0]
#                                                                  tf.__operators__.add_32[0][0]
# __________________________________________________________________________________________________
# layer_normalization_31 (LayerNo (None, 80, 79)       158         tf.__operators__.add_33[0][0]
# __________________________________________________________________________________________________
# conv1d_30 (Conv1D)              (None, 80, 1024)     81920       layer_normalization_31[0][0]
# __________________________________________________________________________________________________
# dropout_33 (Dropout)            (None, 80, 1024)     0           conv1d_30[0][0]
# __________________________________________________________________________________________________
# conv1d_31 (Conv1D)              (None, 80, 79)       80975       dropout_33[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_34 (TFOpLa (None, 80, 79)       0           conv1d_31[0][0]
#                                                                  tf.__operators__.add_33[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 80, 16)       1280        tf.__operators__.add_34[0][0]
# __________________________________________________________________________________________________
# dropout_34 (Dropout)            (None, 80, 16)       0           dense_3[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 80, 1)        17          dropout_34[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_1 (Glo (None, 80)           0           tf.__operators__.add_34[0][0]
# __________________________________________________________________________________________________
# dropout_35 (Dropout)            (None, 80, 1)        0           dense_4[0][0]
# __________________________________________________________________________________________________
# tf.expand_dims_1 (TFOpLambda)   (None, 80, 1)        0           global_average_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_35 (TFOpLa (None, 80, 1)        0           dropout_35[0][0]
#                                                                  tf.expand_dims_1[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 80, 1)        2           tf.__operators__.add_35[0][0]
# ==================================================================================================
# Total params: 6,534,115
# Trainable params: 6,534,115
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.optimizers.schedules import ExponentialDecay
EPOCH = 300
BATCH_SIZE = 1024
NUM_FOLDS = 5

# detect and init the TPU
tpu = tf.distribute.cluster_resolver.TPUClusterResolver.connect()

# instantiate a distribution strategy
tpu_strategy = tf.distribute.experimental.TPUStrategy(tpu)

with tpu_strategy.scope():
    kf = KFold(n_splits=NUM_FOLDS, shuffle=True, random_state=2021)
    test_preds = []
    for fold, (train_idx, test_idx) in enumerate(kf.split(train, targets)):
        print('-'*15, '>', f'Fold {fold+1}', '<', '-'*15)
        X_train, X_valid = train[train_idx], train[test_idx]
        y_train, y_valid = targets[train_idx], targets[test_idx]
        #u_out_train, u_out_valid = u_outs[train_idx], u_outs[test_idx]
        
        #model = get_cnn_model(train)
        model = build_transfer_model(train.shape[1:])
        model.compile(optimizer='adam', 
                      # loss=GBVPP_loss,
                      loss="mae"
                      )

        #scheduler = ExponentialDecay(1e-3, 40*((len(train)*0.8)/BATCH_SIZE), 1e-5)
        #lr = LearningRateScheduler(scheduler, verbose=1)
        lr = ReduceLROnPlateau(monitor="val_loss", factor=0.75, patience=10, verbose=1)
        es = EarlyStopping(monitor="val_loss", patience=50, verbose=1, mode="min", restore_best_weights=True)
        checkpoint_filepath = f"folds{fold}.hdf5"
        sv = keras.callbacks.ModelCheckpoint(
            checkpoint_filepath, monitor='val_loss', verbose=1, save_best_only=True,
            save_weights_only=False, mode='auto', save_freq='epoch',
            options=None)

        history = model.fit(X_train,
                            y_train,
                            # validation_data=(X_valid, np.append(y_valid, u_out_valid, axis =1)), 
                            validation_data=(X_valid, y_valid), 
                            epochs=EPOCH, 
                            batch_size=1024, 
                            callbacks=[lr,
                                       es,
                                       sv])
        
        with open('/gdrive/MyDrive/ventilator-pressure-prediction/'+checkpoint_filepath, 'wb') as f:
          f.write(open(checkpoint_filepath, 'rb').read())
    
        test_preds.append(model.predict(test).squeeze().reshape(-1, 1).squeeze())
# Out:
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Initializing the TPU system: grpc://10.74.56.10:8470
# INFO:tensorflow:Initializing the TPU system: grpc://10.74.56.10:8470
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Finished initializing TPU system.
# WARNING:absl:`tf.distribute.experimental.TPUStrategy` is deprecated, please use  the non experimental symbol `tf.distribute.TPUStrategy` instead.
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:2, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:2, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:3, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:3, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:4, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:4, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:5, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:5, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:6, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:6, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:7, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:7, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)
# Streaming output truncated to the last 5000 lines.
# Epoch 00122: val_loss did not improve from 0.29956
# Epoch 123/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2926 - val_loss: 0.2975
#
# Epoch 00123: val_loss improved from 0.29956 to 0.29748, saving model to folds1.hdf5
# Epoch 124/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.3002 - val_loss: 0.3097
#
# Epoch 00124: val_loss did not improve from 0.29748
# Epoch 125/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2969 - val_loss: 0.3021
#
# Epoch 00125: val_loss did not improve from 0.29748
# Epoch 126/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2921 - val_loss: 0.2944
#
# Epoch 00126: val_loss improved from 0.29748 to 0.29443, saving model to folds1.hdf5
# Epoch 127/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2993 - val_loss: 0.2938
#
# Epoch 00127: val_loss improved from 0.29443 to 0.29378, saving model to folds1.hdf5
# Epoch 128/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2931 - val_loss: 0.3065
#
# Epoch 00128: val_loss did not improve from 0.29378
# Epoch 129/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2865 - val_loss: 0.2994
#
# Epoch 00129: val_loss did not improve from 0.29378
# Epoch 130/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2864 - val_loss: 0.3004
#
# Epoch 00130: val_loss did not improve from 0.29378
# Epoch 131/300
# 59/59 [==============================] - 9s 159ms/step - loss: 0.2929 - val_loss: 0.3182
#
# Epoch 00131: val_loss did not improve from 0.29378
# Epoch 132/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2899 - val_loss: 0.3069
#
# Epoch 00132: val_loss did not improve from 0.29378
# Epoch 133/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2939 - val_loss: 0.2952
#
# Epoch 00133: val_loss did not improve from 0.29378
# Epoch 134/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2868 - val_loss: 0.2981
#
# Epoch 00134: val_loss did not improve from 0.29378
# Epoch 135/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2808 - val_loss: 0.2877
#
# Epoch 00135: val_loss improved from 0.29378 to 0.28775, saving model to folds1.hdf5
# Epoch 136/300
# 59/59 [==============================] - 9s 153ms/step - loss: 0.2831 - val_loss: 0.2917
#
# Epoch 00136: val_loss did not improve from 0.28775
# Epoch 137/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2812 - val_loss: 0.2934
#
# Epoch 00137: val_loss did not improve from 0.28775
# Epoch 138/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2891 - val_loss: 0.3002
#
# Epoch 00138: val_loss did not improve from 0.28775
# Epoch 139/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2809 - val_loss: 0.2877
#
# Epoch 00139: val_loss did not improve from 0.28775
# Epoch 140/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2782 - val_loss: 0.2998
#
# Epoch 00140: val_loss did not improve from 0.28775
# Epoch 141/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2811 - val_loss: 0.2985
#
# Epoch 00141: val_loss did not improve from 0.28775
# Epoch 142/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2831 - val_loss: 0.3114
#
# Epoch 00142: val_loss did not improve from 0.28775
# Epoch 143/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2833 - val_loss: 0.2971
#
# Epoch 00143: val_loss did not improve from 0.28775
# Epoch 144/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2791 - val_loss: 0.2912
#
# Epoch 00144: val_loss did not improve from 0.28775
# Epoch 145/300
# 59/59 [==============================] - 9s 155ms/step - loss: 0.2806 - val_loss: 0.2873
#
# Epoch 00145: val_loss improved from 0.28775 to 0.28730, saving model to folds1.hdf5
# Epoch 146/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2761 - val_loss: 0.2875
#
# Epoch 00146: val_loss did not improve from 0.28730
# Epoch 147/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2773 - val_loss: 0.2840
#
# Epoch 00147: val_loss improved from 0.28730 to 0.28402, saving model to folds1.hdf5
# Epoch 148/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2751 - val_loss: 0.2861
#
# Epoch 00148: val_loss did not improve from 0.28402
# Epoch 149/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2734 - val_loss: 0.2870
#
# Epoch 00149: val_loss did not improve from 0.28402
# Epoch 150/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2812 - val_loss: 0.2849
#
# Epoch 00150: val_loss did not improve from 0.28402
# Epoch 151/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2744 - val_loss: 0.2878
#
# Epoch 00151: val_loss did not improve from 0.28402
# Epoch 152/300
# 59/59 [==============================] - 9s 155ms/step - loss: 0.2754 - val_loss: 0.2804
#
# Epoch 00152: val_loss improved from 0.28402 to 0.28036, saving model to folds1.hdf5
# Epoch 153/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2709 - val_loss: 0.2855
#
# Epoch 00153: val_loss did not improve from 0.28036
# Epoch 154/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2751 - val_loss: 0.2816
#
# Epoch 00154: val_loss did not improve from 0.28036
# Epoch 155/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2680 - val_loss: 0.2834
#
# Epoch 00155: val_loss did not improve from 0.28036
# Epoch 156/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2779 - val_loss: 0.2938
#
# Epoch 00156: val_loss did not improve from 0.28036
# Epoch 157/300
# 59/59 [==============================] - 9s 155ms/step - loss: 0.2735 - val_loss: 0.2908
#
# Epoch 00157: val_loss did not improve from 0.28036
# Epoch 158/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2695 - val_loss: 0.2747
#
# Epoch 00158: val_loss improved from 0.28036 to 0.27471, saving model to folds1.hdf5
# Epoch 159/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2774 - val_loss: 0.2943
#
# Epoch 00159: val_loss did not improve from 0.27471
# Epoch 160/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2761 - val_loss: 0.2969
#
# Epoch 00160: val_loss did not improve from 0.27471
# Epoch 161/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2666 - val_loss: 0.2947
#
# Epoch 00161: val_loss did not improve from 0.27471
# Epoch 162/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2691 - val_loss: 0.3027
#
# Epoch 00162: val_loss did not improve from 0.27471
# Epoch 163/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2665 - val_loss: 0.2808
#
# Epoch 00163: val_loss did not improve from 0.27471
# Epoch 164/300
# 59/59 [==============================] - 9s 155ms/step - loss: 0.2637 - val_loss: 0.2800
#
# Epoch 00164: val_loss did not improve from 0.27471
# Epoch 165/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2666 - val_loss: 0.2799
#
# Epoch 00165: val_loss did not improve from 0.27471
# Epoch 166/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2619 - val_loss: 0.2995
#
# Epoch 00166: val_loss did not improve from 0.27471
# Epoch 167/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2662 - val_loss: 0.2845
#
# Epoch 00167: val_loss did not improve from 0.27471
# Epoch 168/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2683 - val_loss: 0.2799
#
# Epoch 00168: ReduceLROnPlateau reducing learning rate to 0.0007500000356230885.
#
# Epoch 00168: val_loss did not improve from 0.27471
# Epoch 169/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2487 - val_loss: 0.2640
#
# Epoch 00169: val_loss improved from 0.27471 to 0.26399, saving model to folds1.hdf5
# Epoch 170/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2456 - val_loss: 0.2636
#
# Epoch 00170: val_loss improved from 0.26399 to 0.26365, saving model to folds1.hdf5
# Epoch 171/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2467 - val_loss: 0.2677
#
# Epoch 00171: val_loss did not improve from 0.26365
# Epoch 172/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2480 - val_loss: 0.2651
#
# Epoch 00172: val_loss did not improve from 0.26365
# Epoch 173/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2445 - val_loss: 0.2647
#
# Epoch 00173: val_loss did not improve from 0.26365
# Epoch 174/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2449 - val_loss: 0.2605
#
# Epoch 00174: val_loss improved from 0.26365 to 0.26048, saving model to folds1.hdf5
# Epoch 175/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2444 - val_loss: 0.2624
#
# Epoch 00175: val_loss did not improve from 0.26048
# Epoch 176/300
# 59/59 [==============================] - 10s 165ms/step - loss: 0.2459 - val_loss: 0.2696
#
# Epoch 00176: val_loss did not improve from 0.26048
# Epoch 177/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2486 - val_loss: 0.2825
#
# Epoch 00177: val_loss did not improve from 0.26048
# Epoch 178/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2518 - val_loss: 0.2636
#
# Epoch 00178: val_loss did not improve from 0.26048
# Epoch 179/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2441 - val_loss: 0.2580
#
# Epoch 00179: val_loss improved from 0.26048 to 0.25795, saving model to folds1.hdf5
# Epoch 180/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2413 - val_loss: 0.2702
#
# Epoch 00180: val_loss did not improve from 0.25795
# Epoch 181/300
# 59/59 [==============================] - 9s 155ms/step - loss: 0.2491 - val_loss: 0.2717
#
# Epoch 00181: val_loss did not improve from 0.25795
# Epoch 182/300
# 59/59 [==============================] - 9s 155ms/step - loss: 0.2435 - val_loss: 0.2649
#
# Epoch 00182: val_loss did not improve from 0.25795
# Epoch 183/300
# 59/59 [==============================] - 9s 155ms/step - loss: 0.2479 - val_loss: 0.2578
#
# Epoch 00183: val_loss improved from 0.25795 to 0.25776, saving model to folds1.hdf5
# Epoch 184/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2418 - val_loss: 0.2602
#
# Epoch 00184: val_loss did not improve from 0.25776
# Epoch 185/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2431 - val_loss: 0.2604
#
# Epoch 00185: val_loss did not improve from 0.25776
# Epoch 186/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2405 - val_loss: 0.2569
#
# Epoch 00186: val_loss improved from 0.25776 to 0.25688, saving model to folds1.hdf5
# Epoch 187/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2408 - val_loss: 0.2686
#
# Epoch 00187: val_loss did not improve from 0.25688
# Epoch 188/300
# 59/59 [==============================] - 9s 155ms/step - loss: 0.2461 - val_loss: 0.2640
#
# Epoch 00188: val_loss did not improve from 0.25688
# Epoch 189/300
# 59/59 [==============================] - 9s 155ms/step - loss: 0.2441 - val_loss: 0.2613
#
# Epoch 00189: val_loss did not improve from 0.25688
# Epoch 190/300
# 59/59 [==============================] - 9s 155ms/step - loss: 0.2420 - val_loss: 0.2619
#
# Epoch 00190: val_loss did not improve from 0.25688
# Epoch 191/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2399 - val_loss: 0.2568
#
# Epoch 00191: val_loss improved from 0.25688 to 0.25676, saving model to folds1.hdf5
# Epoch 192/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2433 - val_loss: 0.2574
#
# Epoch 00192: val_loss did not improve from 0.25676
# Epoch 193/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2389 - val_loss: 0.2641
#
# Epoch 00193: val_loss did not improve from 0.25676
# Epoch 194/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2394 - val_loss: 0.2693
#
# Epoch 00194: val_loss did not improve from 0.25676
# Epoch 195/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2410 - val_loss: 0.2525
#
# Epoch 00195: val_loss improved from 0.25676 to 0.25255, saving model to folds1.hdf5
# Epoch 196/300
# 59/59 [==============================] - 9s 155ms/step - loss: 0.2362 - val_loss: 0.2615
#
# Epoch 00196: val_loss did not improve from 0.25255
# Epoch 197/300
# 59/59 [==============================] - 9s 156ms/step - loss: 0.2428 - val_loss: 0.2696
#
# Epoch 00197: val_loss did not improve from 0.25255
# Epoch 198/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2420 - val_loss: 0.2574
#
# Epoch 00198: val_loss did not improve from 0.25255
# Epoch 199/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2351 - val_loss: 0.2512
#
# Epoch 00199: val_loss improved from 0.25255 to 0.25123, saving model to folds1.hdf5
# Epoch 200/300
# 59/59 [==============================] - 9s 155ms/step - loss: 0.2355 - val_loss: 0.2574
#
# Epoch 00200: val_loss did not improve from 0.25123
# Epoch 201/300
# 59/59 [==============================] - 9s 155ms/step - loss: 0.2357 - val_loss: 0.2609
#
# Epoch 00201: val_loss did not improve from 0.25123
# Epoch 202/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2393 - val_loss: 0.2606
#
# Epoch 00202: val_loss did not improve from 0.25123
# Epoch 203/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2409 - val_loss: 0.2646
#
# Epoch 00203: val_loss did not improve from 0.25123
# Epoch 204/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2429 - val_loss: 0.2608
#
# Epoch 00204: val_loss did not improve from 0.25123
# Epoch 205/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2361 - val_loss: 0.2495
#
# Epoch 00205: val_loss improved from 0.25123 to 0.24955, saving model to folds1.hdf5
# Epoch 206/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2422 - val_loss: 0.2575
#
# Epoch 00206: val_loss did not improve from 0.24955
# Epoch 207/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2347 - val_loss: 0.2582
#
# Epoch 00207: val_loss did not improve from 0.24955
# Epoch 208/300
# 59/59 [==============================] - 9s 155ms/step - loss: 0.2368 - val_loss: 0.2548
#
# Epoch 00208: val_loss did not improve from 0.24955
# Epoch 209/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2360 - val_loss: 0.2577
#
# Epoch 00209: val_loss did not improve from 0.24955
# Epoch 210/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2352 - val_loss: 0.2522
#
# Epoch 00210: val_loss did not improve from 0.24955
# Epoch 211/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2314 - val_loss: 0.2541
#
# Epoch 00211: val_loss did not improve from 0.24955
# Epoch 212/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2358 - val_loss: 0.2559
#
# Epoch 00212: val_loss did not improve from 0.24955
# Epoch 213/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2331 - val_loss: 0.2518
#
# Epoch 00213: val_loss did not improve from 0.24955
# Epoch 214/300
# 59/59 [==============================] - 9s 155ms/step - loss: 0.2365 - val_loss: 0.2525
#
# Epoch 00214: val_loss did not improve from 0.24955
# Epoch 215/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2270 - val_loss: 0.2690
#
# Epoch 00215: ReduceLROnPlateau reducing learning rate to 0.0005625000048894435.
#
# Epoch 00215: val_loss did not improve from 0.24955
# Epoch 216/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2230 - val_loss: 0.2435
#
# Epoch 00216: val_loss improved from 0.24955 to 0.24352, saving model to folds1.hdf5
# Epoch 217/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2192 - val_loss: 0.2472
#
# Epoch 00217: val_loss did not improve from 0.24352
# Epoch 218/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2178 - val_loss: 0.2399
#
# Epoch 00218: val_loss improved from 0.24352 to 0.23993, saving model to folds1.hdf5
# Epoch 219/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2183 - val_loss: 0.2414
#
# Epoch 00219: val_loss did not improve from 0.23993
# Epoch 220/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2202 - val_loss: 0.2533
#
# Epoch 00220: val_loss did not improve from 0.23993
# Epoch 221/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2199 - val_loss: 0.2416
#
# Epoch 00221: val_loss did not improve from 0.23993
# Epoch 222/300
# 59/59 [==============================] - 9s 153ms/step - loss: 0.2177 - val_loss: 0.2458
#
# Epoch 00222: val_loss did not improve from 0.23993
# Epoch 223/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2176 - val_loss: 0.2477
#
# Epoch 00223: val_loss did not improve from 0.23993
# Epoch 224/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2189 - val_loss: 0.2441
#
# Epoch 00224: val_loss did not improve from 0.23993
# Epoch 225/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2192 - val_loss: 0.2456
#
# Epoch 00225: val_loss did not improve from 0.23993
# Epoch 226/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2160 - val_loss: 0.2419
#
# Epoch 00226: val_loss did not improve from 0.23993
# Epoch 227/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2187 - val_loss: 0.2515
#
# Epoch 00227: val_loss did not improve from 0.23993
# Epoch 228/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2194 - val_loss: 0.2395
#
# Epoch 00228: val_loss improved from 0.23993 to 0.23952, saving model to folds1.hdf5
# Epoch 229/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2181 - val_loss: 0.2390
#
# Epoch 00229: val_loss improved from 0.23952 to 0.23896, saving model to folds1.hdf5
# Epoch 230/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2176 - val_loss: 0.2432
#
# Epoch 00230: val_loss did not improve from 0.23896
# Epoch 231/300
# 59/59 [==============================] - 9s 155ms/step - loss: 0.2160 - val_loss: 0.2428
#
# Epoch 00231: val_loss did not improve from 0.23896
# Epoch 232/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2169 - val_loss: 0.2410
#
# Epoch 00232: val_loss did not improve from 0.23896
# Epoch 233/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2180 - val_loss: 0.2421
#
# Epoch 00233: val_loss did not improve from 0.23896
# Epoch 234/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2162 - val_loss: 0.2382
#
# Epoch 00234: val_loss improved from 0.23896 to 0.23824, saving model to folds1.hdf5
# Epoch 235/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2188 - val_loss: 0.2463
#
# Epoch 00235: val_loss did not improve from 0.23824
# Epoch 236/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2169 - val_loss: 0.2475
#
# Epoch 00236: val_loss did not improve from 0.23824
# Epoch 237/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2157 - val_loss: 0.2463
#
# Epoch 00237: val_loss did not improve from 0.23824
# Epoch 238/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2159 - val_loss: 0.2420
#
# Epoch 00238: val_loss did not improve from 0.23824
# Epoch 239/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2181 - val_loss: 0.2432
#
# Epoch 00239: val_loss did not improve from 0.23824
# Epoch 240/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2185 - val_loss: 0.2438
#
# Epoch 00240: val_loss did not improve from 0.23824
# Epoch 241/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2143 - val_loss: 0.2398
#
# Epoch 00241: val_loss did not improve from 0.23824
# Epoch 242/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2136 - val_loss: 0.2380
#
# Epoch 00242: val_loss improved from 0.23824 to 0.23799, saving model to folds1.hdf5
# Epoch 243/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2144 - val_loss: 0.2433
#
# Epoch 00243: val_loss did not improve from 0.23799
# Epoch 244/300
# 59/59 [==============================] - 10s 166ms/step - loss: 0.2136 - val_loss: 0.2338
#
# Epoch 00244: val_loss improved from 0.23799 to 0.23383, saving model to folds1.hdf5
# Epoch 245/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2132 - val_loss: 0.2370
#
# Epoch 00245: val_loss did not improve from 0.23383
# Epoch 246/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2139 - val_loss: 0.2379
#
# Epoch 00246: val_loss did not improve from 0.23383
# Epoch 247/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2128 - val_loss: 0.2380
#
# Epoch 00247: val_loss did not improve from 0.23383
# Epoch 248/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2111 - val_loss: 0.2439
#
# Epoch 00248: val_loss did not improve from 0.23383
# Epoch 249/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2134 - val_loss: 0.2397
#
# Epoch 00249: val_loss did not improve from 0.23383
# Epoch 250/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2123 - val_loss: 0.2404
#
# Epoch 00250: val_loss did not improve from 0.23383
# Epoch 251/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2106 - val_loss: 0.2366
#
# Epoch 00251: val_loss did not improve from 0.23383
# Epoch 252/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2118 - val_loss: 0.2373
#
# Epoch 00252: val_loss did not improve from 0.23383
# Epoch 253/300
# 59/59 [==============================] - 9s 155ms/step - loss: 0.2131 - val_loss: 0.2511
#
# Epoch 00253: val_loss did not improve from 0.23383
# Epoch 254/300
# 59/59 [==============================] - 9s 155ms/step - loss: 0.2205 - val_loss: 0.2397
#
# Epoch 00254: ReduceLROnPlateau reducing learning rate to 0.0004218749818392098.
#
# Epoch 00254: val_loss did not improve from 0.23383
# Epoch 255/300
# 59/59 [==============================] - 9s 155ms/step - loss: 0.2067 - val_loss: 0.2359
#
# Epoch 00255: val_loss did not improve from 0.23383
# Epoch 256/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2024 - val_loss: 0.2271
#
# Epoch 00256: val_loss improved from 0.23383 to 0.22710, saving model to folds1.hdf5
# Epoch 257/300
# 59/59 [==============================] - 9s 156ms/step - loss: 0.2030 - val_loss: 0.2334
#
# Epoch 00257: val_loss did not improve from 0.22710
# Epoch 258/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2054 - val_loss: 0.2337
#
# Epoch 00258: val_loss did not improve from 0.22710
# Epoch 259/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2018 - val_loss: 0.2280
#
# Epoch 00259: val_loss did not improve from 0.22710
# Epoch 260/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2013 - val_loss: 0.2310
#
# Epoch 00260: val_loss did not improve from 0.22710
# Epoch 261/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2030 - val_loss: 0.2289
#
# Epoch 00261: val_loss did not improve from 0.22710
# Epoch 262/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2033 - val_loss: 0.2302
#
# Epoch 00262: val_loss did not improve from 0.22710
# Epoch 263/300
# 59/59 [==============================] - 9s 155ms/step - loss: 0.2001 - val_loss: 0.2274
#
# Epoch 00263: val_loss did not improve from 0.22710
# Epoch 264/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.1997 - val_loss: 0.2289
#
# Epoch 00264: val_loss did not improve from 0.22710
# Epoch 265/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2031 - val_loss: 0.2345
#
# Epoch 00265: val_loss did not improve from 0.22710
# Epoch 266/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2026 - val_loss: 0.2284
#
# Epoch 00266: ReduceLROnPlateau reducing learning rate to 0.00031640623637940735.
#
# Epoch 00266: val_loss did not improve from 0.22710
# Epoch 267/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.1972 - val_loss: 0.2245
#
# Epoch 00267: val_loss improved from 0.22710 to 0.22445, saving model to folds1.hdf5
# Epoch 268/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.1954 - val_loss: 0.2248
#
# Epoch 00268: val_loss did not improve from 0.22445
# Epoch 269/300
# 59/59 [==============================] - 9s 155ms/step - loss: 0.1954 - val_loss: 0.2247
#
# Epoch 00269: val_loss did not improve from 0.22445
# Epoch 270/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.1954 - val_loss: 0.2255
#
# Epoch 00270: val_loss did not improve from 0.22445
# Epoch 271/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.1955 - val_loss: 0.2242
#
# Epoch 00271: val_loss improved from 0.22445 to 0.22418, saving model to folds1.hdf5
# Epoch 272/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.1943 - val_loss: 0.2239
#
# Epoch 00272: val_loss improved from 0.22418 to 0.22391, saving model to folds1.hdf5
# Epoch 273/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.1944 - val_loss: 0.2262
#
# Epoch 00273: val_loss did not improve from 0.22391
# Epoch 274/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.1951 - val_loss: 0.2282
#
# Epoch 00274: val_loss did not improve from 0.22391
# Epoch 275/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.1954 - val_loss: 0.2273
#
# Epoch 00275: val_loss did not improve from 0.22391
# Epoch 276/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.1945 - val_loss: 0.2236
#
# Epoch 00276: val_loss improved from 0.22391 to 0.22361, saving model to folds1.hdf5
# Epoch 277/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.1942 - val_loss: 0.2238
#
# Epoch 00277: val_loss did not improve from 0.22361
# Epoch 278/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.1933 - val_loss: 0.2237
#
# Epoch 00278: val_loss did not improve from 0.22361
# Epoch 279/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.1948 - val_loss: 0.2236
#
# Epoch 00279: val_loss did not improve from 0.22361
# Epoch 280/300
# 59/59 [==============================] - 9s 155ms/step - loss: 0.1946 - val_loss: 0.2249
#
# Epoch 00280: val_loss did not improve from 0.22361
# Epoch 281/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.1959 - val_loss: 0.2248
#
# Epoch 00281: val_loss did not improve from 0.22361
# Epoch 282/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.1940 - val_loss: 0.2232
#
# Epoch 00282: val_loss improved from 0.22361 to 0.22319, saving model to folds1.hdf5
# Epoch 283/300
# 59/59 [==============================] - 9s 153ms/step - loss: 0.1931 - val_loss: 0.2259
#
# Epoch 00283: val_loss did not improve from 0.22319
# Epoch 284/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.1948 - val_loss: 0.2254
#
# Epoch 00284: val_loss did not improve from 0.22319
# Epoch 285/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.1931 - val_loss: 0.2240
#
# Epoch 00285: val_loss did not improve from 0.22319
# Epoch 286/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.1945 - val_loss: 0.2247
#
# Epoch 00286: val_loss did not improve from 0.22319
# Epoch 287/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.1943 - val_loss: 0.2226
#
# Epoch 00287: val_loss improved from 0.22319 to 0.22263, saving model to folds1.hdf5
# Epoch 288/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.1922 - val_loss: 0.2226
#
# Epoch 00288: val_loss improved from 0.22263 to 0.22262, saving model to folds1.hdf5
# Epoch 289/300
# 59/59 [==============================] - 9s 153ms/step - loss: 0.1935 - val_loss: 0.2240
#
# Epoch 00289: val_loss did not improve from 0.22262
# Epoch 290/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.1945 - val_loss: 0.2246
#
# Epoch 00290: val_loss did not improve from 0.22262
# Epoch 291/300
# 59/59 [==============================] - 9s 153ms/step - loss: 0.1935 - val_loss: 0.2220
#
# Epoch 00291: val_loss improved from 0.22262 to 0.22205, saving model to folds1.hdf5
# Epoch 292/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.1922 - val_loss: 0.2245
#
# Epoch 00292: val_loss did not improve from 0.22205
# Epoch 293/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.1929 - val_loss: 0.2255
#
# Epoch 00293: val_loss did not improve from 0.22205
# Epoch 294/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.1925 - val_loss: 0.2223
#
# Epoch 00294: val_loss did not improve from 0.22205
# Epoch 295/300
# 59/59 [==============================] - 9s 155ms/step - loss: 0.1914 - val_loss: 0.2215
#
# Epoch 00295: val_loss improved from 0.22205 to 0.22151, saving model to folds1.hdf5
# Epoch 296/300
# 59/59 [==============================] - 10s 166ms/step - loss: 0.1929 - val_loss: 0.2267
#
# Epoch 00296: val_loss did not improve from 0.22151
# Epoch 297/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.1940 - val_loss: 0.2222
#
# Epoch 00297: val_loss did not improve from 0.22151
# Epoch 298/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.1913 - val_loss: 0.2223
#
# Epoch 00298: val_loss did not improve from 0.22151
# Epoch 299/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.1935 - val_loss: 0.2240
#
# Epoch 00299: val_loss did not improve from 0.22151
# Epoch 300/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.1917 - val_loss: 0.2206
#
# Epoch 00300: val_loss improved from 0.22151 to 0.22061, saving model to folds1.hdf5
# --------------- > Fold 3 < ---------------
# sequence_lenght: 80
# positional_encoding: tf.Tensor(
# [[[ 0.          0.          0.         ...  1.          1.
#     1.        ]
#   [ 0.84147096  0.7117711   0.5869528  ...  1.          1.
#     1.        ]
#   [ 0.9092974   0.9999124   0.95041883 ...  0.9999999   0.99999994
#     0.99999994]
#   ...
#   [ 0.9995202  -0.9622094  -0.9236275  ...  0.99984837  0.9999049
#     0.99994034]
#   [ 0.5139785  -0.86968976 -0.9727623  ...  0.9998444   0.99990237
#     0.9999388 ]
#   [-0.44411266 -0.25955084 -0.65151036 ...  0.9998404   0.99989986
#     0.9999372 ]]], shape=(1, 80, 79), dtype=float32)
# Model: "model_4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_12 (InputLayer)           [(None, 80, 79)]     0
# __________________________________________________________________________________________________
# tf.__operators__.add_72 (TFOpLa (None, 80, 79)       0           input_12[0][0]
# __________________________________________________________________________________________________
# layer_normalization_64 (LayerNo (None, 80, 79)       158         tf.__operators__.add_72[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_32 (MultiH (None, 80, 79)       653391      layer_normalization_64[0][0]
#                                                                  layer_normalization_64[0][0]
# __________________________________________________________________________________________________
# dropout_72 (Dropout)            (None, 80, 79)       0           multi_head_attention_32[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_73 (TFOpLa (None, 80, 79)       0           dropout_72[0][0]
#                                                                  tf.__operators__.add_72[0][0]
# __________________________________________________________________________________________________
# layer_normalization_65 (LayerNo (None, 80, 79)       158         tf.__operators__.add_73[0][0]
# __________________________________________________________________________________________________
# conv1d_64 (Conv1D)              (None, 80, 1024)     81920       layer_normalization_65[0][0]
# __________________________________________________________________________________________________
# dropout_73 (Dropout)            (None, 80, 1024)     0           conv1d_64[0][0]
# __________________________________________________________________________________________________
# conv1d_65 (Conv1D)              (None, 80, 79)       80975       dropout_73[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_74 (TFOpLa (None, 80, 79)       0           conv1d_65[0][0]
#                                                                  tf.__operators__.add_73[0][0]
# __________________________________________________________________________________________________
# layer_normalization_66 (LayerNo (None, 80, 79)       158         tf.__operators__.add_74[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_33 (MultiH (None, 80, 79)       653391      layer_normalization_66[0][0]
#                                                                  layer_normalization_66[0][0]
# __________________________________________________________________________________________________
# dropout_74 (Dropout)            (None, 80, 79)       0           multi_head_attention_33[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_75 (TFOpLa (None, 80, 79)       0           dropout_74[0][0]
#                                                                  tf.__operators__.add_74[0][0]
# __________________________________________________________________________________________________
# layer_normalization_67 (LayerNo (None, 80, 79)       158         tf.__operators__.add_75[0][0]
# __________________________________________________________________________________________________
# conv1d_66 (Conv1D)              (None, 80, 1024)     81920       layer_normalization_67[0][0]
# __________________________________________________________________________________________________
# dropout_75 (Dropout)            (None, 80, 1024)     0           conv1d_66[0][0]
# __________________________________________________________________________________________________
# conv1d_67 (Conv1D)              (None, 80, 79)       80975       dropout_75[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_76 (TFOpLa (None, 80, 79)       0           conv1d_67[0][0]
#                                                                  tf.__operators__.add_75[0][0]
# __________________________________________________________________________________________________
# layer_normalization_68 (LayerNo (None, 80, 79)       158         tf.__operators__.add_76[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_34 (MultiH (None, 80, 79)       653391      layer_normalization_68[0][0]
#                                                                  layer_normalization_68[0][0]
# __________________________________________________________________________________________________
# dropout_76 (Dropout)            (None, 80, 79)       0           multi_head_attention_34[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_77 (TFOpLa (None, 80, 79)       0           dropout_76[0][0]
#                                                                  tf.__operators__.add_76[0][0]
# __________________________________________________________________________________________________
# layer_normalization_69 (LayerNo (None, 80, 79)       158         tf.__operators__.add_77[0][0]
# __________________________________________________________________________________________________
# conv1d_68 (Conv1D)              (None, 80, 1024)     81920       layer_normalization_69[0][0]
# __________________________________________________________________________________________________
# dropout_77 (Dropout)            (None, 80, 1024)     0           conv1d_68[0][0]
# __________________________________________________________________________________________________
# conv1d_69 (Conv1D)              (None, 80, 79)       80975       dropout_77[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_78 (TFOpLa (None, 80, 79)       0           conv1d_69[0][0]
#                                                                  tf.__operators__.add_77[0][0]
# __________________________________________________________________________________________________
# layer_normalization_70 (LayerNo (None, 80, 79)       158         tf.__operators__.add_78[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_35 (MultiH (None, 80, 79)       653391      layer_normalization_70[0][0]
#                                                                  layer_normalization_70[0][0]
# __________________________________________________________________________________________________
# dropout_78 (Dropout)            (None, 80, 79)       0           multi_head_attention_35[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_79 (TFOpLa (None, 80, 79)       0           dropout_78[0][0]
#                                                                  tf.__operators__.add_78[0][0]
# __________________________________________________________________________________________________
# layer_normalization_71 (LayerNo (None, 80, 79)       158         tf.__operators__.add_79[0][0]
# __________________________________________________________________________________________________
# conv1d_70 (Conv1D)              (None, 80, 1024)     81920       layer_normalization_71[0][0]
# __________________________________________________________________________________________________
# dropout_79 (Dropout)            (None, 80, 1024)     0           conv1d_70[0][0]
# __________________________________________________________________________________________________
# conv1d_71 (Conv1D)              (None, 80, 79)       80975       dropout_79[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_80 (TFOpLa (None, 80, 79)       0           conv1d_71[0][0]
#                                                                  tf.__operators__.add_79[0][0]
# __________________________________________________________________________________________________
# layer_normalization_72 (LayerNo (None, 80, 79)       158         tf.__operators__.add_80[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_36 (MultiH (None, 80, 79)       653391      layer_normalization_72[0][0]
#                                                                  layer_normalization_72[0][0]
# __________________________________________________________________________________________________
# dropout_80 (Dropout)            (None, 80, 79)       0           multi_head_attention_36[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_81 (TFOpLa (None, 80, 79)       0           dropout_80[0][0]
#                                                                  tf.__operators__.add_80[0][0]
# __________________________________________________________________________________________________
# layer_normalization_73 (LayerNo (None, 80, 79)       158         tf.__operators__.add_81[0][0]
# __________________________________________________________________________________________________
# conv1d_72 (Conv1D)              (None, 80, 1024)     81920       layer_normalization_73[0][0]
# __________________________________________________________________________________________________
# dropout_81 (Dropout)            (None, 80, 1024)     0           conv1d_72[0][0]
# __________________________________________________________________________________________________
# conv1d_73 (Conv1D)              (None, 80, 79)       80975       dropout_81[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_82 (TFOpLa (None, 80, 79)       0           conv1d_73[0][0]
#                                                                  tf.__operators__.add_81[0][0]
# __________________________________________________________________________________________________
# layer_normalization_74 (LayerNo (None, 80, 79)       158         tf.__operators__.add_82[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_37 (MultiH (None, 80, 79)       653391      layer_normalization_74[0][0]
#                                                                  layer_normalization_74[0][0]
# __________________________________________________________________________________________________
# dropout_82 (Dropout)            (None, 80, 79)       0           multi_head_attention_37[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_83 (TFOpLa (None, 80, 79)       0           dropout_82[0][0]
#                                                                  tf.__operators__.add_82[0][0]
# __________________________________________________________________________________________________
# layer_normalization_75 (LayerNo (None, 80, 79)       158         tf.__operators__.add_83[0][0]
# __________________________________________________________________________________________________
# conv1d_74 (Conv1D)              (None, 80, 1024)     81920       layer_normalization_75[0][0]
# __________________________________________________________________________________________________
# dropout_83 (Dropout)            (None, 80, 1024)     0           conv1d_74[0][0]
# __________________________________________________________________________________________________
# conv1d_75 (Conv1D)              (None, 80, 79)       80975       dropout_83[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_84 (TFOpLa (None, 80, 79)       0           conv1d_75[0][0]
#                                                                  tf.__operators__.add_83[0][0]
# __________________________________________________________________________________________________
# layer_normalization_76 (LayerNo (None, 80, 79)       158         tf.__operators__.add_84[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_38 (MultiH (None, 80, 79)       653391      layer_normalization_76[0][0]
#                                                                  layer_normalization_76[0][0]
# __________________________________________________________________________________________________
# dropout_84 (Dropout)            (None, 80, 79)       0           multi_head_attention_38[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_85 (TFOpLa (None, 80, 79)       0           dropout_84[0][0]
#                                                                  tf.__operators__.add_84[0][0]
# __________________________________________________________________________________________________
# layer_normalization_77 (LayerNo (None, 80, 79)       158         tf.__operators__.add_85[0][0]
# __________________________________________________________________________________________________
# conv1d_76 (Conv1D)              (None, 80, 1024)     81920       layer_normalization_77[0][0]
# __________________________________________________________________________________________________
# dropout_85 (Dropout)            (None, 80, 1024)     0           conv1d_76[0][0]
# ...
# Epoch 203/300
# 59/59 [==============================] - 9s 155ms/step - loss: 0.2112 - val_loss: 0.2322
#
# Epoch 00203: val_loss did not improve from 0.23059
# Epoch 204/300
# 59/59 [==============================] - 9s 155ms/step - loss: 0.2141 - val_loss: 0.2376
#
# Epoch 00204: val_loss did not improve from 0.23059
# Epoch 205/300
# 59/59 [==============================] - 9s 155ms/step - loss: 0.2132 - val_loss: 0.2317
#
# Epoch 00205: val_loss did not improve from 0.23059
# Epoch 206/300
# 59/59 [==============================] - 9s 155ms/step - loss: 0.2120 - val_loss: 0.2382
#
# Epoch 00206: val_loss did not improve from 0.23059
# Epoch 207/300
# 59/59 [==============================] - 9s 155ms/step - loss: 0.2121 - val_loss: 0.2304
#
# Epoch 00207: val_loss improved from 0.23059 to 0.23040, saving model to folds4.hdf5
# Epoch 208/300
# 59/59 [==============================] - 9s 155ms/step - loss: 0.2109 - val_loss: 0.2348
#
# Epoch 00208: val_loss did not improve from 0.23040
# Epoch 209/300
# 59/59 [==============================] - 9s 157ms/step - loss: 0.2107 - val_loss: 0.2311
#
# Epoch 00209: val_loss did not improve from 0.23040
# Epoch 210/300
# 59/59 [==============================] - 9s 155ms/step - loss: 0.2108 - val_loss: 0.2340
#
# Epoch 00210: val_loss did not improve from 0.23040
# Epoch 211/300
# 59/59 [==============================] - 9s 155ms/step - loss: 0.2113 - val_loss: 0.2326
#
# Epoch 00211: val_loss did not improve from 0.23040
# Epoch 212/300
# 59/59 [==============================] - 9s 155ms/step - loss: 0.2105 - val_loss: 0.2334
#
# Epoch 00212: val_loss did not improve from 0.23040
# Epoch 213/300
# 59/59 [==============================] - 9s 155ms/step - loss: 0.2097 - val_loss: 0.2300
#
# Epoch 00213: val_loss improved from 0.23040 to 0.23001, saving model to folds4.hdf5
# Epoch 214/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2105 - val_loss: 0.2327
#
# Epoch 00214: val_loss did not improve from 0.23001
# Epoch 215/300
# 59/59 [==============================] - 9s 155ms/step - loss: 0.2119 - val_loss: 0.2346
#
# Epoch 00215: val_loss did not improve from 0.23001
# Epoch 216/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2109 - val_loss: 0.2306
#
# Epoch 00216: val_loss did not improve from 0.23001
# Epoch 217/300
# 59/59 [==============================] - 9s 155ms/step - loss: 0.2099 - val_loss: 0.2327
#
# Epoch 00217: val_loss did not improve from 0.23001
# Epoch 218/300
# 59/59 [==============================] - 9s 155ms/step - loss: 0.2118 - val_loss: 0.2324
#
# Epoch 00218: val_loss did not improve from 0.23001
# Epoch 219/300
# 59/59 [==============================] - 9s 155ms/step - loss: 0.2096 - val_loss: 0.2372
#
# Epoch 00219: val_loss did not improve from 0.23001
# Epoch 220/300
# 59/59 [==============================] - 9s 155ms/step - loss: 0.2104 - val_loss: 0.2292
#
# Epoch 00220: val_loss improved from 0.23001 to 0.22922, saving model to folds4.hdf5
# Epoch 221/300
# 59/59 [==============================] - 9s 155ms/step - loss: 0.2075 - val_loss: 0.2289
#
# Epoch 00221: val_loss improved from 0.22922 to 0.22893, saving model to folds4.hdf5
# Epoch 222/300
# 59/59 [==============================] - 9s 155ms/step - loss: 0.2084 - val_loss: 0.2299
#
# Epoch 00222: val_loss did not improve from 0.22893
# Epoch 223/300
# 59/59 [==============================] - 9s 155ms/step - loss: 0.2089 - val_loss: 0.2310
#
# Epoch 00223: val_loss did not improve from 0.22893
# Epoch 224/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2084 - val_loss: 0.2329
#
# Epoch 00224: val_loss did not improve from 0.22893
# Epoch 225/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2087 - val_loss: 0.2352
#
# Epoch 00225: val_loss did not improve from 0.22893
# Epoch 226/300
# 59/59 [==============================] - 9s 155ms/step - loss: 0.2085 - val_loss: 0.2301
#
# Epoch 00226: val_loss did not improve from 0.22893
# Epoch 227/300
# 59/59 [==============================] - 9s 155ms/step - loss: 0.2091 - val_loss: 0.2292
#
# Epoch 00227: val_loss did not improve from 0.22893
# Epoch 228/300
# 59/59 [==============================] - 9s 155ms/step - loss: 0.2089 - val_loss: 0.2325
#
# Epoch 00228: val_loss did not improve from 0.22893
# Epoch 229/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2090 - val_loss: 0.2308
#
# Epoch 00229: val_loss did not improve from 0.22893
# Epoch 230/300
# 59/59 [==============================] - 9s 155ms/step - loss: 0.2075 - val_loss: 0.2327
#
# Epoch 00230: val_loss did not improve from 0.22893
# Epoch 231/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2073 - val_loss: 0.2297
#
# Epoch 00231: ReduceLROnPlateau reducing learning rate to 0.00023730468819849193.
#
# Epoch 00231: val_loss did not improve from 0.22893
# Epoch 232/300
# 59/59 [==============================] - 9s 155ms/step - loss: 0.2023 - val_loss: 0.2256
#
# Epoch 00232: val_loss improved from 0.22893 to 0.22557, saving model to folds4.hdf5
# Epoch 233/300
# 59/59 [==============================] - 9s 155ms/step - loss: 0.2022 - val_loss: 0.2259
#
# Epoch 00233: val_loss did not improve from 0.22557
# Epoch 234/300
# 59/59 [==============================] - 9s 155ms/step - loss: 0.2013 - val_loss: 0.2270
#
# Epoch 00234: val_loss did not improve from 0.22557
# Epoch 235/300
# 59/59 [==============================] - 9s 155ms/step - loss: 0.2008 - val_loss: 0.2229
#
# Epoch 00235: val_loss improved from 0.22557 to 0.22294, saving model to folds4.hdf5
# Epoch 236/300
# 59/59 [==============================] - 9s 155ms/step - loss: 0.2001 - val_loss: 0.2253
#
# Epoch 00236: val_loss did not improve from 0.22294
# Epoch 237/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2009 - val_loss: 0.2259
#
# Epoch 00237: val_loss did not improve from 0.22294
# Epoch 238/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2010 - val_loss: 0.2237
#
# Epoch 00238: val_loss did not improve from 0.22294
# Epoch 239/300
# 59/59 [==============================] - 9s 155ms/step - loss: 0.2008 - val_loss: 0.2253
#
# Epoch 00239: val_loss did not improve from 0.22294
# Epoch 240/300
# 59/59 [==============================] - 9s 155ms/step - loss: 0.1999 - val_loss: 0.2236
#
# Epoch 00240: val_loss did not improve from 0.22294
# Epoch 241/300
# 59/59 [==============================] - 9s 155ms/step - loss: 0.2003 - val_loss: 0.2248
#
# Epoch 00241: val_loss did not improve from 0.22294
# Epoch 242/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.2003 - val_loss: 0.2247
#
# Epoch 00242: val_loss did not improve from 0.22294
# Epoch 243/300
# 59/59 [==============================] - 9s 155ms/step - loss: 0.2006 - val_loss: 0.2242
#
# Epoch 00243: val_loss did not improve from 0.22294
# Epoch 244/300
# 59/59 [==============================] - 9s 155ms/step - loss: 0.1993 - val_loss: 0.2232
#
# Epoch 00244: val_loss did not improve from 0.22294
# Epoch 245/300
# 59/59 [==============================] - 9s 155ms/step - loss: 0.2004 - val_loss: 0.2228
#
# Epoch 00245: ReduceLROnPlateau reducing learning rate to 0.00017797851614886895.
#
# Epoch 00245: val_loss improved from 0.22294 to 0.22285, saving model to folds4.hdf5
# Epoch 246/300
# 59/59 [==============================] - 10s 166ms/step - loss: 0.1963 - val_loss: 0.2209
#
# Epoch 00246: val_loss improved from 0.22285 to 0.22095, saving model to folds4.hdf5
# Epoch 247/300
# 59/59 [==============================] - 9s 155ms/step - loss: 0.1966 - val_loss: 0.2208
#
# Epoch 00247: val_loss improved from 0.22095 to 0.22080, saving model to folds4.hdf5
# Epoch 248/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.1961 - val_loss: 0.2199
#
# Epoch 00248: val_loss improved from 0.22080 to 0.21986, saving model to folds4.hdf5
# Epoch 249/300
# 59/59 [==============================] - 9s 155ms/step - loss: 0.1953 - val_loss: 0.2222
#
# Epoch 00249: val_loss did not improve from 0.21986
# Epoch 250/300
# 59/59 [==============================] - 9s 155ms/step - loss: 0.1958 - val_loss: 0.2236
#
# Epoch 00250: val_loss did not improve from 0.21986
# Epoch 251/300
# 59/59 [==============================] - 9s 155ms/step - loss: 0.1961 - val_loss: 0.2206
#
# Epoch 00251: val_loss did not improve from 0.21986
# Epoch 252/300
# 59/59 [==============================] - 9s 155ms/step - loss: 0.1953 - val_loss: 0.2207
#
# Epoch 00252: val_loss did not improve from 0.21986
# Epoch 253/300
# 59/59 [==============================] - 9s 155ms/step - loss: 0.1946 - val_loss: 0.2212
#
# Epoch 00253: val_loss did not improve from 0.21986
# Epoch 254/300
# 59/59 [==============================] - 9s 155ms/step - loss: 0.1954 - val_loss: 0.2202
#
# Epoch 00254: val_loss did not improve from 0.21986
# Epoch 255/300
# 59/59 [==============================] - 9s 156ms/step - loss: 0.1956 - val_loss: 0.2209
#
# Epoch 00255: val_loss did not improve from 0.21986
# Epoch 256/300
# 59/59 [==============================] - 9s 155ms/step - loss: 0.1952 - val_loss: 0.2207
#
# Epoch 00256: val_loss did not improve from 0.21986
# Epoch 257/300
# 59/59 [==============================] - 9s 155ms/step - loss: 0.1947 - val_loss: 0.2197
#
# Epoch 00257: val_loss improved from 0.21986 to 0.21966, saving model to folds4.hdf5
# Epoch 258/300
# 59/59 [==============================] - 9s 155ms/step - loss: 0.1944 - val_loss: 0.2206
#
# Epoch 00258: val_loss did not improve from 0.21966
# Epoch 259/300
# 59/59 [==============================] - 9s 155ms/step - loss: 0.1944 - val_loss: 0.2211
#
# Epoch 00259: val_loss did not improve from 0.21966
# Epoch 260/300
# 59/59 [==============================] - 9s 155ms/step - loss: 0.1953 - val_loss: 0.2190
#
# Epoch 00260: val_loss improved from 0.21966 to 0.21904, saving model to folds4.hdf5
# Epoch 261/300
# 59/59 [==============================] - 9s 155ms/step - loss: 0.1943 - val_loss: 0.2197
#
# Epoch 00261: val_loss did not improve from 0.21904
# Epoch 262/300
# 59/59 [==============================] - 9s 155ms/step - loss: 0.1941 - val_loss: 0.2210
#
# Epoch 00262: val_loss did not improve from 0.21904
# Epoch 263/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.1951 - val_loss: 0.2229
#
# Epoch 00263: val_loss did not improve from 0.21904
# Epoch 264/300
# 59/59 [==============================] - 9s 155ms/step - loss: 0.1941 - val_loss: 0.2194
#
# Epoch 00264: val_loss did not improve from 0.21904
# Epoch 265/300
# 59/59 [==============================] - 9s 156ms/step - loss: 0.1938 - val_loss: 0.2199
#
# Epoch 00265: val_loss did not improve from 0.21904
# Epoch 266/300
# 59/59 [==============================] - 9s 156ms/step - loss: 0.1944 - val_loss: 0.2190
#
# Epoch 00266: val_loss improved from 0.21904 to 0.21901, saving model to folds4.hdf5
# Epoch 267/300
# 59/59 [==============================] - 9s 156ms/step - loss: 0.1936 - val_loss: 0.2209
#
# Epoch 00267: val_loss did not improve from 0.21901
# Epoch 268/300
# 59/59 [==============================] - 9s 156ms/step - loss: 0.1932 - val_loss: 0.2180
#
# Epoch 00268: val_loss improved from 0.21901 to 0.21799, saving model to folds4.hdf5
# Epoch 269/300
# 59/59 [==============================] - 9s 156ms/step - loss: 0.1931 - val_loss: 0.2194
#
# Epoch 00269: val_loss did not improve from 0.21799
# Epoch 270/300
# 59/59 [==============================] - 9s 155ms/step - loss: 0.1937 - val_loss: 0.2196
#
# Epoch 00270: val_loss did not improve from 0.21799
# Epoch 271/300
# 59/59 [==============================] - 9s 155ms/step - loss: 0.1933 - val_loss: 0.2182
#
# Epoch 00271: val_loss did not improve from 0.21799
# Epoch 272/300
# 59/59 [==============================] - 9s 155ms/step - loss: 0.1931 - val_loss: 0.2187
#
# Epoch 00272: val_loss did not improve from 0.21799
# Epoch 273/300
# 59/59 [==============================] - 9s 155ms/step - loss: 0.1942 - val_loss: 0.2192
#
# Epoch 00273: val_loss did not improve from 0.21799
# Epoch 274/300
# 59/59 [==============================] - 9s 155ms/step - loss: 0.1942 - val_loss: 0.2208
#
# Epoch 00274: val_loss did not improve from 0.21799
# Epoch 275/300
# 59/59 [==============================] - 9s 155ms/step - loss: 0.1937 - val_loss: 0.2189
#
# Epoch 00275: val_loss did not improve from 0.21799
# Epoch 276/300
# 59/59 [==============================] - 9s 155ms/step - loss: 0.1920 - val_loss: 0.2196
#
# Epoch 00276: val_loss did not improve from 0.21799
# Epoch 277/300
# 59/59 [==============================] - 9s 155ms/step - loss: 0.1922 - val_loss: 0.2178
#
# Epoch 00277: val_loss improved from 0.21799 to 0.21777, saving model to folds4.hdf5
# Epoch 278/300
# 59/59 [==============================] - 9s 155ms/step - loss: 0.1922 - val_loss: 0.2197
#
# Epoch 00278: val_loss did not improve from 0.21777
# Epoch 279/300
# 59/59 [==============================] - 9s 155ms/step - loss: 0.1928 - val_loss: 0.2184
#
# Epoch 00279: val_loss did not improve from 0.21777
# Epoch 280/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.1921 - val_loss: 0.2185
#
# Epoch 00280: val_loss did not improve from 0.21777
# Epoch 281/300
# 59/59 [==============================] - 9s 155ms/step - loss: 0.1912 - val_loss: 0.2201
#
# Epoch 00281: val_loss did not improve from 0.21777
# Epoch 282/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.1914 - val_loss: 0.2206
#
# Epoch 00282: val_loss did not improve from 0.21777
# Epoch 283/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.1908 - val_loss: 0.2186
#
# Epoch 00283: val_loss did not improve from 0.21777
# Epoch 284/300
# 59/59 [==============================] - 9s 155ms/step - loss: 0.1913 - val_loss: 0.2198
#
# Epoch 00284: val_loss did not improve from 0.21777
# Epoch 285/300
# 59/59 [==============================] - 9s 156ms/step - loss: 0.1914 - val_loss: 0.2187
#
# Epoch 00285: val_loss did not improve from 0.21777
# Epoch 286/300
# 59/59 [==============================] - 9s 155ms/step - loss: 0.1912 - val_loss: 0.2180
#
# Epoch 00286: val_loss did not improve from 0.21777
# Epoch 287/300
# 59/59 [==============================] - 9s 155ms/step - loss: 0.1914 - val_loss: 0.2170
#
# Epoch 00287: val_loss improved from 0.21777 to 0.21700, saving model to folds4.hdf5
# Epoch 288/300
# 59/59 [==============================] - 9s 156ms/step - loss: 0.1909 - val_loss: 0.2196
#
# Epoch 00288: val_loss did not improve from 0.21700
# Epoch 289/300
# 59/59 [==============================] - 9s 155ms/step - loss: 0.1905 - val_loss: 0.2188
#
# Epoch 00289: val_loss did not improve from 0.21700
# Epoch 290/300
# 59/59 [==============================] - 9s 156ms/step - loss: 0.1914 - val_loss: 0.2204
#
# Epoch 00290: val_loss did not improve from 0.21700
# Epoch 291/300
# 59/59 [==============================] - 9s 155ms/step - loss: 0.1909 - val_loss: 0.2205
#
# Epoch 00291: val_loss did not improve from 0.21700
# Epoch 292/300
# 59/59 [==============================] - 9s 155ms/step - loss: 0.1909 - val_loss: 0.2180
#
# Epoch 00292: val_loss did not improve from 0.21700
# Epoch 293/300
# 59/59 [==============================] - 9s 155ms/step - loss: 0.1903 - val_loss: 0.2200
#
# Epoch 00293: val_loss did not improve from 0.21700
# Epoch 294/300
# 59/59 [==============================] - 9s 155ms/step - loss: 0.1899 - val_loss: 0.2192
#
# Epoch 00294: val_loss did not improve from 0.21700
# Epoch 295/300
# 59/59 [==============================] - 9s 155ms/step - loss: 0.1907 - val_loss: 0.2177
#
# Epoch 00295: val_loss did not improve from 0.21700
# Epoch 296/300
# 59/59 [==============================] - 9s 156ms/step - loss: 0.1897 - val_loss: 0.2181
#
# Epoch 00296: val_loss did not improve from 0.21700
# Epoch 297/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.1909 - val_loss: 0.2179
#
# Epoch 00297: ReduceLROnPlateau reducing learning rate to 0.0001334838816546835.
#
# Epoch 00297: val_loss did not improve from 0.21700
# Epoch 298/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.1883 - val_loss: 0.2148
#
# Epoch 00298: val_loss improved from 0.21700 to 0.21479, saving model to folds4.hdf5
# Epoch 299/300
# 59/59 [==============================] - 9s 155ms/step - loss: 0.1870 - val_loss: 0.2151
#
# Epoch 00299: val_loss did not improve from 0.21479
# Epoch 300/300
# 59/59 [==============================] - 9s 154ms/step - loss: 0.1867 - val_loss: 0.2155
#
# Epoch 00300: val_loss did not improve from 0.21479

# %%
PRESSURE_STEP = 0.07030214545120961
PRESSURE_MIN = -1.8957442945646408
PRESSURE_MAX = 64.82099173863948

# %%
# ENSEMBLE FOLDS WITH MEAN
submission["pressure"] = sum(test_preds)/NUM_FOLDS
submission.to_csv('submission_mean.csv', index=False)

# %%
# ENSEMBLE FOLDS WITH MEDIAN
submission["pressure"] = np.median(np.vstack(test_preds),axis=0)
submission.to_csv('submission_median.csv', index=False)

# %%
# ENSEMBLE FOLDS WITH MEDIAN AND ROUND PREDICTIONS
submission["pressure"] =\
    np.round( (submission.pressure - PRESSURE_MIN)/PRESSURE_STEP ) * PRESSURE_STEP + PRESSURE_MIN
submission.pressure = np.clip(submission.pressure, PRESSURE_MIN, PRESSURE_MAX)
submission.to_csv('submission_median_round.csv', index=False)

# %%
# !zip cnn_models.zip *.hdf5
# Out:
#   adding: folds0.hdf5 (deflated 9%)
#   adding: folds1.hdf5 (deflated 8%)
#   adding: folds2.hdf5 (deflated 9%)
#   adding: folds3.hdf5 (deflated 9%)
#   adding: folds4.hdf5 (deflated 9%)

# %%
# !zip submission.zip *.csv
# Out:
#   adding: submission_mean.csv (deflated 60%)
#   adding: submission_median.csv (deflated 60%)
#   adding: submission_median_round.csv (deflated 80%)

# %%
with open('/gdrive/MyDrive/ventilator-pressure-prediction/submission.zip', 'wb') as f:
  f.write(open('submission.zip', 'rb').read())

# %%
with open('/gdrive/MyDrive/ventilator-pressure-prediction/cnn_models.zip', 'wb') as f:
  f.write(open('cnn_models.zip', 'rb').read())

# %%
# !unzip -t /gdrive/MyDrive/ventilator-pressure-prediction/cnn_models.zip
# Out:
# Archive:  /gdrive/MyDrive/ventilator-pressure-prediction/cnn_models.zip
#     testing: folds0.hdf5              OK
#     testing: folds1.hdf5              OK
#     testing: folds2.hdf5              OK
#     testing: folds3.hdf5              OK
#     testing: folds4.hdf5              OK
# No errors detected in compressed data of /gdrive/MyDrive/ventilator-pressure-prediction/cnn_models.zip.

# %%
# !ls
# Out:
# sample_data
