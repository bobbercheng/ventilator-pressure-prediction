# %% [markdown]
# <a href="https://colab.research.google.com/github/bobbercheng/ventilator-pressure-prediction/blob/master/ventilator_gb_rescaling_V13_GPU.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# V1: Keep R/C, improve
#
# V2: Add R**2, no improve
#
# V3: Update model from https://www.kaggle.com/dlaststark/gb-vpp-pulp-fiction. Not much improve compare V1
#
# V4: Use whole db for test Fold-1
# Fold-1 | OOF Score: 0.15912771348961205
#
# Run it again in Kaggle:
#
# Fold-1 | OOF Score: 0.1606402072946816
#
# V5: Add loading ScaleLayer from saved model
#
# V6: Add TransformerEncoder. TransformerEncoder(128, 512, 8, name="transformer_layer")(x). Testing in GPU.
#
# V7: Try to scale targe to 0-1, but it slow the train as MASE cannot be scaled.
#
# V8: Removed target scale.
# Epoch 00022: val_loss improved from 0.32912 to 0.30967, saving model to ./model-gpu/Bidirect_LSTM_model_1C.h5
# Epoch 23/150
# 127/127 [==============================] - 161s 1s/step - loss: 0.3176 - val_loss: 0.2917
#
# Not Good as without TransformerEncoder. Change paramemter back to
#
# V8: Change attention result to multiple instead of concate.
#
# Loss is smaller than without LayerNormalization, but CV is bigger. It means it overfit the train data.
#
# TransformerEncoder(128, 512, 8, 0.3, name="transformer_layer")
#
# Epoch 00181: val_loss did not improve from 0.16212
# Epoch 182/200
# 127/127 [==============================] - 163s 1s/step - loss: 0.0448 - val_loss: 0.1655
#
# Epoch 00182: ReduceLROnPlateau reducing learning rate to 5.6313510867767036e-05.
#
# Epoch 00182: val_loss did not improve from 0.16212
# Restoring model weights from the end of the best epoch.
# Epoch 00182: early stopping
# Fold-1 | OOF Score: 0.16211654680482343
#
# V9: Increase attention dropout to 0.6, add 0.01 droupout to input
# Epoch 00123: ReduceLROnPlateau reducing learning rate to 0.00031640623637940735.
#
# Epoch 00123: val_loss did not improve from 0.16714
# Epoch 124/200
# 127/127 - 161s - loss: 0.0838 - val_loss: 0.1694
#
# Epoch 00124: val_loss did not improve from 0.16714
# Epoch 125/200
# 127/127 - 161s - loss: 0.0796 - val_loss: 0.1727
#
# V10: add TransformerEncoder to all layer with Multiply
#
# Epoch 164/200
# 253/253 - 387s - loss: 0.0568 - val_loss: 0.1679
#
# Epoch 00164: val_loss did not improve from 0.16158
# Restoring model weights from the end of the best epoch.
# Epoch 00164: early stopping
# Fold-1 | OOF Score: 0.16158229343436334
#
# V10: analy_predict.
#
# Here is analyze result for V4:
# 20__10 - MAE  0.16386306650915122, count: 25870
# 20__20 - MAE  0.15764106283234391, count: 26272
# 20__50 - MAE  0.16384391190488698, count: 34729
# 50__10 - MAE  0.1585241009544335, count: 60574
# 50__20 - MAE  0.24078390163257296, count: 37108
# 50__50 - MAE  0.23760641023725088, count: 34699
# 5__10 - MAE  0.15540978004136713, count: 36361
# 5__20 - MAE  0.10102388763185534, count: 35935
# 5__50 - MAE  0.11535413256937187, count: 35522
#
#
# V11: add dnn_model_GaussianNoise(), no improve
#
# Epoch 00183: val_loss did not improve from 0.16240
# Epoch 184/200
# 127/127 - 150s - loss: 0.0498 - val_loss: 0.1642
#
# Epoch 00184: ReduceLROnPlateau reducing learning rate to 7.508467933803331e-05.
#
# Epoch 00184: val_loss did not improve from 0.16240
# Restoring model weights from the end of the best epoch.
# Epoch 00184: early stopping
# Fold-1 | OOF Score: 0.16240143234043636
#
# V12: dnn_model_aen(), use auto encoder to remove noise and learn encode.
#
# Epoch 200/200
# 127/127 - 153s - loss: 4.1734 - decoder_loss: 3.8822 - ae_action_loss: 0.2257 - output_loss: 0.0654 - val_loss: 0.7126 - val_decoder_loss: 0.3742 - val_ae_action_loss: 0.1702 - val_output_loss: 0.1682
#
# Epoch 00200: val_loss did not improve from 0.69120
#
# Fold-1 | OOF Score: 0.16817480317739367
# 20__10 - MAE  0.16644539428012722, count: 25870
# 20__20 - MAE  0.15768315124243204, count: 26272
# 20__50 - MAE  0.16684243562006307, count: 34729
# 50__10 - MAE  0.16641273893399433, count: 60574
# 50__20 - MAE  0.2518146440943941, count: 37108
# 50__50 - MAE  0.2752187431993935, count: 34699
# 5__10 - MAE  0.16763255549569941, count: 36361
# 5__20 - MAE  0.10697168010290617, count: 35935
# 5__50 - MAE  0.11503387157283243, count: 35522
#
# decoder_loss is very large. It means GaussianNoise() and dropout causes side effect.
#
# V13. Remove GaussianNoise and dropout, use encoder feature only. CV score is a little worse.
#
# Epoch 200/200
# 127/127 - 150s - loss: 0.5841 - decoder_loss: 0.3983 - ae_action_loss: 0.1025 - output_loss: 0.0832 - val_loss: 0.4930 - val_decoder_loss: 0.1541 - val_ae_action_loss: 0.1693 - val_output_loss: 0.1696
#
# Epoch 00200: val_output_loss did not improve from 0.16793
# Fold-1 | OOF Score: 0.16959694784227083
# 20__10 - MAE  0.18958046275757853, count: 25870
# 20__20 - MAE  0.16960937531364753, count: 26272
# 20__50 - MAE  0.1714088869810135, count: 34729
# 50__10 - MAE  0.17159657573233353, count: 60574
# 50__20 - MAE  0.2590598477978727, count: 37108
# 50__50 - MAE  0.26932839218852966, count: 34699
# 5__10 - MAE  0.16335297055531042, count: 36361
# 5__20 - MAE  0.11217990298083265, count: 35935
# 5__50 - MAE  0.12327488392594069, count: 35522

# %%
# Update pandas version for Colab TPU
# !pip install pandas==1.3.2
# Out:
# Requirement already satisfied: pandas==1.3.2 in /usr/local/lib/python3.7/dist-packages (1.3.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas==1.3.2) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas==1.3.2) (2.8.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas==1.3.2) (1.19.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas==1.3.2) (1.15.0)

# %% [markdown]
# ## Import libraries

# %%
try:
  import google.colab
  IN_COLAB = True
except:
  IN_COLAB = False

LOAD_PRE_FEATURE = True

# %%
if IN_COLAB:
  from google.colab import drive
  drive.mount("/gdrive", force_remount=True)
# Out:
# Mounted at /gdrive

# %%
if IN_COLAB:
  # !pip install kaggle
  # !mkdir /root/.kaggle
  # !cp /gdrive/MyDrive/ventilator-pressure-prediction/kaggle.json /root/.kaggle
  # !kaggle competitions download -c ventilator-pressure-prediction
  # !kaggle datasets download -d  ventilatorpressurepredictionfeatures
  # !mkdir -p ../input/ventilator-pressure-prediction
  # !unzip '*.zip' -d ../input/ventilator-pressure-prediction
  # !ls ../input/ventilator-pressure-prediction
  # !mkdir /gdrive/MyDrive/ventilator-pressure-prediction/gb-rescaling-eda-v3-gpu
  #Map Google driver folder to local folder model to save model
  # !ln -s /gdrive/MyDrive/ventilator-pressure-prediction/gb-rescaling-eda-v3-gpu model-gpu
else:
  # !mkdir ./model-gpu
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.7/dist-packages (1.5.12)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from kaggle) (2021.5.30)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from kaggle) (4.62.3)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.15.0)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.7/dist-packages (from kaggle) (5.0.2)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.23.0)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.24.3)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.7/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (3.0.4)
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.5.12 / client 1.5.4)
# Downloading sample_submission.csv.zip to /content
#   0% 0.00/8.50M [00:00<?, ?B/s]
# 100% 8.50M/8.50M [00:00<00:00, 78.4MB/s]
# Downloading train.csv.zip to /content
#  93% 129M/139M [00:03<00:00, 44.4MB/s]
# 100% 139M/139M [00:03<00:00, 38.7MB/s]
# Downloading test.csv.zip to /content
#  86% 65.0M/75.4M [00:02<00:01, 9.19MB/s]
# 100% 75.4M/75.4M [00:02<00:00, 28.0MB/s]
# Downloading ventilatorpressurepredictionfeatures.zip to /content
# 100% 1.94G/1.95G [01:04<00:00, 30.0MB/s]
# 100% 1.95G/1.95G [01:04<00:00, 32.3MB/s]
# Archive:  train.csv.zip
#   inflating: ../input/ventilator-pressure-prediction/train.csv
#
# Archive:  sample_submission.csv.zip
#   inflating: ../input/ventilator-pressure-prediction/sample_submission.csv
#
# Archive:  test.csv.zip
#   inflating: ../input/ventilator-pressure-prediction/test.csv
#
# Archive:  ventilatorpressurepredictionfeatures.zip
#   inflating: ../input/ventilator-pressure-prediction/test.npy
#   inflating: ../input/ventilator-pressure-prediction/train.npy
#
# 4 archives were successfully processed.
# sample_submission.csv  test.csv  test.npy  train.csv  train.npy
# mkdir: cannot create directory ‘/gdrive/MyDrive/ventilator-pressure-prediction/gb-rescaling-eda-v3-gpu’: File exists

# %%
import gc
import numpy as np
import pandas as pd
import random
import os
from sklearn.model_selection import KFold
from sklearn.preprocessing import RobustScaler, MinMaxScaler
from sklearn.metrics import mean_absolute_error

import tensorflow as tf
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
  tf.config.experimental.set_memory_growth(gpu, True)

from tensorflow.keras.utils import plot_model
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Dense, Dropout, Input
from tensorflow.keras.layers import Concatenate, LSTM, GRU
from tensorflow.keras.layers import Bidirectional, Multiply



# Random Seed Initialize
RANDOM_SEED = 42

def seed_everything(seed=RANDOM_SEED):
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    random.seed(seed)
    tf.random.set_seed(seed)
    
seed_everything()

# %% [markdown]
# ## Load datasets

# %%
train_df = pd.read_csv('../input/ventilator-pressure-prediction/train.csv')
print(f"train_df: {train_df.shape}")
train_df.head()
# Out:
# train_df: (6036000, 8)
#    id  breath_id   R   C  time_step       u_in  u_out   pressure
# 0   1          1  20  50   0.000000   0.083334      0   5.837492
# 1   2          1  20  50   0.033652  18.383041      0   5.907794
# 2   3          1  20  50   0.067514  22.509278      0   7.876254
# 3   4          1  20  50   0.101542  22.808822      0  11.742872
# 4   5          1  20  50   0.135756  25.355850      0  12.234987

# %%
all_pressure = np.sort(train_df['pressure'].unique())
pressure_min =  all_pressure[0].item()
pressure_max = all_pressure[-1].item()
pressure_step = (all_pressure[1] - all_pressure[0]).item()

pressure_min,pressure_max,pressure_step
# Out:
# (-1.895744294564641, 64.8209917386395, 0.07030214545121005)

# %%
DEBUG = False

if DEBUG:
    train_df = train_df[:80*10000]

targets = train_df[['pressure']].to_numpy().reshape(-1, 80)

# %%
test_df = pd.read_csv('../input/ventilator-pressure-prediction/test.csv')
print(f"test_df: {test_df.shape}")
test_df.head()
# Out:
# test_df: (4024000, 7)
#    id  breath_id  R   C  time_step       u_in  u_out
# 0   1          0  5  20   0.000000   0.000000      0
# 1   2          0  5  20   0.031904   7.515046      0
# 2   3          0  5  20   0.063827  14.651675      0
# 3   4          0  5  20   0.095751  21.230610      0
# 4   5          0  5  20   0.127644  26.320956      0

# %% [markdown]
# ## Feature Engineering

# %%
def add_features(df):
    df['cross']= df['u_in'] * df['u_out']
    df['cross2']= df['time_step'] * df['u_out']
    df['area'] = df['time_step'] * df['u_in']
    df['area'] = df.groupby('breath_id')['area'].cumsum()
    df['time_step_cumsum'] = df.groupby(['breath_id'])['time_step'].cumsum()
    df['u_in_cumsum'] = (df['u_in']).groupby(df['breath_id']).cumsum()
    print("Step-1...Completed")
    
    df['u_in_lag1'] = df.groupby('breath_id')['u_in'].shift(1)
    df['u_out_lag1'] = df.groupby('breath_id')['u_out'].shift(1)
    df['u_in_lag_back1'] = df.groupby('breath_id')['u_in'].shift(-1)
    df['u_out_lag_back1'] = df.groupby('breath_id')['u_out'].shift(-1)
    df['u_in_lag2'] = df.groupby('breath_id')['u_in'].shift(2)
    df['u_out_lag2'] = df.groupby('breath_id')['u_out'].shift(2)
    df['u_in_lag_back2'] = df.groupby('breath_id')['u_in'].shift(-2)
    df['u_out_lag_back2'] = df.groupby('breath_id')['u_out'].shift(-2)
    df['u_in_lag3'] = df.groupby('breath_id')['u_in'].shift(3)
    df['u_out_lag3'] = df.groupby('breath_id')['u_out'].shift(3)
    df['u_in_lag_back3'] = df.groupby('breath_id')['u_in'].shift(-3)
    df['u_out_lag_back3'] = df.groupby('breath_id')['u_out'].shift(-3)
    df['u_in_lag4'] = df.groupby('breath_id')['u_in'].shift(4)
    df['u_out_lag4'] = df.groupby('breath_id')['u_out'].shift(4)
    df['u_in_lag_back4'] = df.groupby('breath_id')['u_in'].shift(-4)
    df['u_out_lag_back4'] = df.groupby('breath_id')['u_out'].shift(-4)
    df = df.fillna(0)
    print("Step-2...Completed")
    
    df['breath_id__u_in__max'] = df.groupby(['breath_id'])['u_in'].transform('max')
    df['breath_id__u_out__max'] = df.groupby(['breath_id'])['u_out'].transform('max')
    df['breath_id__u_in__diffmax'] = df.groupby(['breath_id'])['u_in'].transform('max') - df['u_in']
    df['breath_id__u_in__diffmean'] = df.groupby(['breath_id'])['u_in'].transform('mean') - df['u_in']
    df['breath_id__u_in__diffmax'] = df.groupby(['breath_id'])['u_in'].transform('max') - df['u_in']
    df['breath_id__u_in__diffmean'] = df.groupby(['breath_id'])['u_in'].transform('mean') - df['u_in']
    print("Step-3...Completed")
    
    df['u_in_diff1'] = df['u_in'] - df['u_in_lag1']
    df['u_out_diff1'] = df['u_out'] - df['u_out_lag1']
    df['u_in_diff2'] = df['u_in'] - df['u_in_lag2']
    df['u_out_diff2'] = df['u_out'] - df['u_out_lag2']
    df['u_in_diff3'] = df['u_in'] - df['u_in_lag3']
    df['u_out_diff3'] = df['u_out'] - df['u_out_lag3']
    df['u_in_diff4'] = df['u_in'] - df['u_in_lag4']
    df['u_out_diff4'] = df['u_out'] - df['u_out_lag4']
    print("Step-4...Completed")
    
    df['one'] = 1
    df['count'] = (df['one']).groupby(df['breath_id']).cumsum()
    df['u_in_cummean'] =df['u_in_cumsum'] /df['count']
    
    df['breath_id_lag']=df['breath_id'].shift(1).fillna(0)
    df['breath_id_lag2']=df['breath_id'].shift(2).fillna(0)
    df['breath_id_lagsame']=np.select([df['breath_id_lag']==df['breath_id']],[1],0)
    df['breath_id_lag2same']=np.select([df['breath_id_lag2']==df['breath_id']],[1],0)
    df['breath_id__u_in_lag'] = df['u_in'].shift(1).fillna(0)
    df['breath_id__u_in_lag'] = df['breath_id__u_in_lag'] * df['breath_id_lagsame']
    df['breath_id__u_in_lag2'] = df['u_in'].shift(2).fillna(0)
    df['breath_id__u_in_lag2'] = df['breath_id__u_in_lag2'] * df['breath_id_lag2same']
    print("Step-5...Completed")
    
    df['time_step_diff'] = df.groupby('breath_id')['time_step'].diff().fillna(0)
    df['ewm_u_in_mean'] = (df\
                           .groupby('breath_id')['u_in']\
                           .ewm(halflife=9)\
                           .mean()\
                           .reset_index(level=0,drop=True))
    df[["15_in_sum","15_in_min","15_in_max","15_in_mean"]] = (df\
                                                              .groupby('breath_id')['u_in']\
                                                              .rolling(window=15,min_periods=1)\
                                                              .agg({"15_in_sum":"sum",
                                                                    "15_in_min":"min",
                                                                    "15_in_max":"max",
                                                                    "15_in_mean":"mean"
                                                                    #"15_in_std":"std"
                                                               })\
                                                               .reset_index(level=0,drop=True))
    print("Step-6...Completed")
    
    #df['u_in_diff_1_2'] = df['u_in_lag1'] - df['u_in_lag2']
    #df['u_out_diff_1_2'] = df['u_out_lag1'] - df['u_out_lag2']
    #df['u_in_lagback_diff_1_2'] = df['u_in_lag_back1'] - df['u_in_lag_back2']
    #df['u_out_lagback_diff_1_2'] = df['u_out_lag_back1'] - df['u_out_lag_back2']
    
    df['u_in_lagback_diff1'] = df['u_in'] - df['u_in_lag_back1']
    df['u_out_lagback_diff1'] = df['u_out'] - df['u_out_lag_back1']
    df['u_in_lagback_diff2'] = df['u_in'] - df['u_in_lag_back2']
    df['u_out_lagback_diff2'] = df['u_out'] - df['u_out_lag_back2']
    print("Step-7...Completed")
    
    df['R_cat'] = df['R'].astype(str)
    df['C_cat'] = df['C'].astype(str)
    df['R__C'] = df["R"].astype(str) + '__' + df["C"].astype(str)
    df = pd.get_dummies(df)
    print("Step-8...Completed")
    
    return df

if not LOAD_PRE_FEATURE:
  print("Train data...\n")
  train = add_features(train_df)

  print("\nTest data...\n")
  test = add_features(test_df)

# %%
del train_df
del test_df
gc.collect()
# Out:
# 50

# %%
if not LOAD_PRE_FEATURE:
  train.drop(['pressure','id', 'breath_id','one','count',
              'breath_id_lag','breath_id_lag2','breath_id_lagsame',
              'breath_id_lag2same'], axis=1, inplace=True)

  test = test.drop(['id', 'breath_id','one','count','breath_id_lag',
                    'breath_id_lag2','breath_id_lagsame',
                    'breath_id_lag2same'], axis=1)

  print(f"train: {train.shape} \ntest: {test.shape}")
  train.head()

# %%
if not LOAD_PRE_FEATURE:
  scaler = RobustScaler()
  train = scaler.fit_transform(train)
  test = scaler.transform(test)

  train = train.reshape(-1, 80, train.shape[-1])
  test = test.reshape(-1, 80, train.shape[-1])
else:
  train = np.load('../input/ventilator-pressure-prediction/train.npy')
  test = np.load('../input/ventilator-pressure-prediction/test.npy')

print(f"train: {train.shape} \ntest: {test.shape} \ntargets: {targets.shape}")
# Out:
# train: (75450, 80, 66)
# test: (50300, 80, 66)
# targets: (75450, 80)

# %%
train[:3, 0, :]
# Out:
# array([[ 0.00000000e+00,  7.50000000e-01, -9.89052161e-01,
#         -9.37384450e-01, -1.00000000e+00,  0.00000000e+00,
#         -6.65541311e-01, -5.16580501e-01, -4.96657632e-01,
#         -7.25227791e-01, -8.64120606e-01, -1.00000000e+00,
#          2.89020724e+00, -1.00000000e+00, -8.42526591e-01,
#         -1.00000000e+00,  3.66402550e+00, -1.00000000e+00,
#         -8.19257888e-01, -1.00000000e+00,  3.74391547e+00,
#         -1.00000000e+00, -7.94151600e-01, -1.00000000e+00,
#          4.27782420e+00, -1.00000000e+00,  1.12207936e-01,
#          0.00000000e+00,  3.26940916e-01,  1.27386353e+00,
#          4.71408803e-01,  0.00000000e+00,  2.17993186e-01,
#          0.00000000e+00,  1.21027987e-01,  0.00000000e+00,
#          6.83146754e-02,  0.00000000e+00, -6.48438329e-01,
#         -8.64120606e-01, -8.42526591e-01, -1.54759382e+01,
#         -6.74414709e-01, -8.06258228e-01,  7.89341177e-03,
#         -4.28435589e-01, -6.68749817e-01, -1.24171952e+02,
#          0.00000000e+00, -6.75689043e+01,  0.00000000e+00,
#          1.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  1.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  1.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#        [ 0.00000000e+00,  0.00000000e+00, -9.89052161e-01,
#          1.69886631e+00, -1.00000000e+00,  0.00000000e+00,
#         -6.65541311e-01, -5.16580501e-01, -4.96657632e-01,
#         -6.93368579e-01, -8.64120606e-01, -1.00000000e+00,
#          1.98375688e+00, -1.00000000e+00, -8.42526591e-01,
#         -1.00000000e+00,  1.66759161e+00, -1.00000000e+00,
#         -8.19257888e-01, -1.00000000e+00,  1.51578530e+00,
#         -1.00000000e+00, -7.94151600e-01, -1.00000000e+00,
#          1.61468559e+00, -1.00000000e+00, -2.33263833e-01,
#          0.00000000e+00, -4.03073965e-01, -1.27954654e+00,
#          7.55340661e+01,  0.00000000e+00,  3.89316910e+01,
#          0.00000000e+00,  2.52293431e+01,  0.00000000e+00,
#          1.74186111e+01,  0.00000000e+00,  4.24631929e-01,
#         -8.64120606e-01, -8.42526591e-01, -1.54759382e+01,
#          1.23221688e+00, -6.47954643e-01,  2.88771552e+00,
#          6.35990341e-01,  1.21524300e+00, -1.21453746e+01,
#          0.00000000e+00, -1.14038297e+00,  0.00000000e+00,
#          1.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  1.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  1.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#        [ 6.66666667e-01,  0.00000000e+00, -9.89052161e-01,
#         -9.55539088e-01, -1.00000000e+00,  0.00000000e+00,
#         -6.65541311e-01, -5.16580501e-01, -4.96657632e-01,
#         -7.25447190e-01, -8.64120606e-01, -1.00000000e+00,
#          5.85230064e-01, -1.00000000e+00, -8.42526591e-01,
#         -1.00000000e+00,  1.82123950e+00, -1.00000000e+00,
#         -8.19257888e-01, -1.00000000e+00,  2.59800328e+00,
#         -1.00000000e+00, -7.94151600e-01, -1.00000000e+00,
#          2.86855243e+00, -1.00000000e+00, -1.27840434e-01,
#          0.00000000e+00,  5.42062162e-02,  5.88358917e-01,
#         -4.55129464e-02,  0.00000000e+00, -4.86101177e-02,
#          0.00000000e+00, -5.18813481e-02,  0.00000000e+00,
#         -5.11687786e-02,  0.00000000e+00, -6.55828066e-01,
#         -8.64120606e-01, -8.42526591e-01, -1.54759382e+01,
#         -6.87544798e-01, -8.07348391e-01, -1.19385891e-02,
#         -4.35765797e-01, -6.81724002e-01, -4.87415356e+01,
#          0.00000000e+00, -4.01753866e+01,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  1.00000000e+00,
#          0.00000000e+00,  1.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  1.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00]])

# %%
# np.save('train.npy', train)
# np.save('test.npy', test)
# !zip features.zip train.npy test.npy

# %% [markdown]
# ## Hardware config

# %%
try:
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
    tf.config.experimental_connect_to_cluster(tpu)
    tf.tpu.experimental.initialize_tpu_system(tpu)
    tpu_strategy = tf.distribute.experimental.TPUStrategy(tpu)
    BATCH_SIZE = tpu_strategy.num_replicas_in_sync * 64
    print("Running on TPU:", tpu.master())
    print(f"Batch Size: {BATCH_SIZE}")
    
except ValueError:
    tpu_strategy = tf.distribute.get_strategy()
    BATCH_SIZE = 512
    print(f"Running on {tpu_strategy.num_replicas_in_sync} replicas")
    print(f"Batch Size: {BATCH_SIZE}")
# Out:
# Running on 1 replicas
# Batch Size: 512

# %% [markdown]
# ## Rescaling layer

# %%
@tf.custom_gradient
def round_with_gradients(x):
    def grad(dy):
        return dy
    return tf.round(x), grad

class ScaleLayer(tf.keras.layers.Layer):
    def __init__(self, **kwargs):
        super(ScaleLayer, self).__init__(**kwargs)
        self.min = tf.constant(pressure_min, dtype=np.float32)
        self.max = tf.constant(pressure_max, dtype=np.float32)
        self.step = tf.constant(pressure_step, dtype=np.float32)

    def call(self, inputs):
        steps = tf.math.divide(tf.math.add(inputs, -self.min), self.step)
        int_steps = round_with_gradients(steps)
        rescaled_steps = tf.math.add(tf.math.multiply(int_steps, self.step), self.min)
        clipped = tf.clip_by_value(rescaled_steps, self.min, self.max)
        return clipped
    # def get_config(self):
    #     return super(ScaleLayer, self).get_config()

# %%
class TransformerEncoder(tf.keras.layers.Layer):
    def __init__(self, embed_dim, dense_dim, num_heads, dropout=0.3, **kwargs):
        super().__init__(**kwargs)
        self.embed_dim = embed_dim
        self.dense_dim = dense_dim
        self.num_heads = num_heads
        self.attention_dropout = dropout
        self.attention = tf.keras.layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim, dropout=0.3
        )
        self.dense_proj = tf.keras.Sequential(
            [tf.keras.layers.Dense(dense_dim, activation=tf.nn.gelu), tf.keras.layers.Dense(embed_dim),]
        )
        self.layernorm_1 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
        self.layernorm_2 = tf.keras.layers.LayerNormalization(epsilon=1e-6)

    def call(self, inputs, mask=None):
        if mask is not None:
            mask = mask[:, tf.newaxis, :]

        attention_output = self.attention(inputs, inputs, attention_mask=mask)
        proj_input = self.layernorm_1(inputs + attention_output)
        proj_output = self.dense_proj(proj_input)
        return self.layernorm_2(proj_input + proj_output)
    def get_config(self):
        config = super(TransformerEncoder, self).get_config()
        config.update({"embed_dim": self.embed_dim,
            "dense_dim": self.dense_dim,
            "num_heads": self.num_heads})
        return config

class PositionalEmbedding(tf.keras.layers.Layer):
    def __init__(self, sequence_length, vocab_size, embed_dim, **kwargs):
        super(PositionalEmbedding, self).__init__(**kwargs)
        self.token_embeddings = tf.keras.layers.Layer.Embedding(
            input_dim=vocab_size, output_dim=embed_dim
        )
        self.position_embeddings = tf.keras.layers.Layer.Embedding(
            input_dim=sequence_length, output_dim=embed_dim
        )
        self.sequence_length = sequence_length
        self.vocab_size = vocab_size
        self.embed_dim = embed_dim

    def call(self, inputs):
        length = tf.shape(inputs)[-1]
        positions = tf.range(start=0, limit=length, delta=1)
        embedded_tokens = self.token_embeddings(inputs)
        embedded_positions = self.position_embeddings(positions)
        return embedded_tokens + embedded_positions

    def compute_mask(self, inputs, mask=None):
        return tf.math.not_equal(inputs, 0)


class TransformerDecoder(tf.keras.layers.Layer):
    def __init__(self, embed_dim, latent_dim, num_heads, **kwargs):
        super(TransformerDecoder, self).__init__(**kwargs)
        self.embed_dim = embed_dim
        self.latent_dim = latent_dim
        self.num_heads = num_heads
        self.attention_1 = tf.keras.layers.Layer.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim
        )
        self.attention_2 = tf.keras.layers.Layer.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim
        )
        self.dense_proj = keras.Sequential(
            [layers.Dense(latent_dim, activation="relu"), layers.Dense(embed_dim),]
        )
        self.layernorm_1 = tf.keras.layers.Layer.LayerNormalization()
        self.layernorm_2 = tf.keras.layers.Layer.LayerNormalization()
        self.layernorm_3 = tf.keras.layers.Layer.LayerNormalization()
        self.supports_masking = True

    def call(self, inputs, encoder_outputs, mask=None):
        causal_mask = self.get_causal_attention_mask(inputs)
        if mask is not None:
            padding_mask = tf.cast(mask[:, tf.newaxis, :], dtype="int32")
            padding_mask = tf.minimum(padding_mask, causal_mask)

        attention_output_1 = self.attention_1(
            query=inputs, value=inputs, key=inputs, attention_mask=causal_mask
        )
        out_1 = self.layernorm_1(inputs + attention_output_1)

        attention_output_2 = self.attention_2(
            query=out_1,
            value=encoder_outputs,
            key=encoder_outputs,
            attention_mask=padding_mask,
        )
        out_2 = self.layernorm_2(out_1 + attention_output_2)

        proj_output = self.dense_proj(out_2)
        return self.layernorm_3(out_2 + proj_output)

    def get_causal_attention_mask(self, inputs):
        input_shape = tf.shape(inputs)
        batch_size, sequence_length = input_shape[0], input_shape[1]
        i = tf.range(sequence_length)[:, tf.newaxis]
        j = tf.range(sequence_length)
        mask = tf.cast(i >= j, dtype="int32")
        mask = tf.reshape(mask, (1, input_shape[1], input_shape[1]))
        mult = tf.concat(
            [tf.expand_dims(batch_size, -1), tf.constant([1, 1], dtype=tf.int32)],
            axis=0,
        )
        return tf.tile(mask, mult)

# %% [markdown]
# ## Keras DNN Model

# %%
def dnn_model_v4():
    
    x_input = Input(shape=(train.shape[-2:]))
    
    x1 = Bidirectional(LSTM(units=768, return_sequences=True))(x_input)
    x2 = Bidirectional(LSTM(units=512, return_sequences=True))(x1)
    x3 = Bidirectional(LSTM(units=384, return_sequences=True))(x2)
    x4 = Bidirectional(LSTM(units=256, return_sequences=True))(x3)
    x5 = Bidirectional(LSTM(units=128, return_sequences=True))(x4)
    
    z2 = Bidirectional(GRU(units=384, return_sequences=True))(x2)
    
    z31 = Multiply()([x3, z2])
    z31 = BatchNormalization()(z31)
    z3 = Bidirectional(GRU(units=256, return_sequences=True))(z31)
    
    z41 = Multiply()([x4, z3])
    z41 = BatchNormalization()(z41)
    z4 = Bidirectional(GRU(units=128, return_sequences=True))(z41)
    
    z51 = Multiply()([x5, z4])
    z51 = BatchNormalization()(z51)
    z5 = Bidirectional(GRU(units=64, return_sequences=True))(z51)
    
    x = Concatenate(axis=2)([x5, z2, z3, z4, z5])
    
    x = Dense(units=128, activation='selu')(x)
    
    x_output = Dense(units=1)(x)
    
    x_output = ScaleLayer()(x_output)

    model = Model(inputs=x_input, outputs=x_output, 
                  name='DNN_Model')
    return model

# %%
def dnn_model_aen():
    
    x_input = Input(shape=(train.shape[-2:]))

    x0 = tf.keras.layers.BatchNormalization()(x_input)
    
    #remove noise
    # encoder = tf.keras.layers.GaussianNoise(0.03527936123679956)(x0)
    encoder = tf.keras.layers.Dense(16)(x0)
    encoder = tf.keras.layers.BatchNormalization()(encoder)
    encoder = tf.keras.layers.Activation('swish')(encoder)
    
    decoder = tf.keras.layers.Dropout(0.0)(encoder)
    decoder = tf.keras.layers.Dense(train.shape[-1], name = 'decoder')(decoder)


    # x = tf.keras.layers.Concatenate()([x0, encoder])
    x = encoder
    
    x1 = Bidirectional(LSTM(units=768, return_sequences=True))(x)
    x2 = Bidirectional(LSTM(units=512, return_sequences=True))(x1)
    x3 = Bidirectional(LSTM(units=384, return_sequences=True))(x2)
    x4 = Bidirectional(LSTM(units=256, return_sequences=True))(x3)
    x5 = Bidirectional(LSTM(units=128, return_sequences=True))(x4)

    x_ae = tf.keras.layers.Dense(128, activation='swish')(x5)
    x_ae = tf.keras.layers.Dropout(0.0)(x_ae)

    out_ae = tf.keras.layers.Dense(1, name = 'ae_action')(x_ae)

    z2 = Bidirectional(GRU(units=384, return_sequences=True))(x2)
    
    z31 = Multiply()([x3, z2])
    z31 = BatchNormalization()(z31)
    z3 = Bidirectional(GRU(units=256, return_sequences=True))(z31)
    
    z41 = Multiply()([x4, z3])
    z41 = BatchNormalization()(z41)
    z4 = Bidirectional(GRU(units=128, return_sequences=True))(z41)
    
    z51 = Multiply()([x5, z4])
    z51 = BatchNormalization()(z51)
    z5 = Bidirectional(GRU(units=64, return_sequences=True))(z51)
    
    x = Concatenate(axis=2)([x5, z2, z3, z4, z5])
    
    x = Dense(units=128, activation='swish')(x)
    
    x_output = Dense(units=1)(x)
    
    x_output = ScaleLayer(name = 'output')(x_output)

    model = Model(inputs=x_input, outputs=[decoder, out_ae, x_output], 
                  name='DNN_Model')
    return model

# %%
def dnn_model_GaussianNoise():
    
    x_input = Input(shape=(train.shape[-2:]))
    
    x1 = Bidirectional(LSTM(units=768, return_sequences=True))(x_input)
    x2 = Bidirectional(LSTM(units=512, return_sequences=True))(x1)
    x3 = Bidirectional(LSTM(units=384, return_sequences=True))(x2)
    x4 = Bidirectional(LSTM(units=256, return_sequences=True))(x3)
    x5 = Bidirectional(LSTM(units=128, return_sequences=True))(x4)
    
    z2 = Bidirectional(GRU(units=384, return_sequences=True))(x2)
    
    z31 = Multiply()([x3, z2])
    z31 = BatchNormalization()(z31)
    z31 = tf.keras.layers.GaussianNoise(0.035)(z31)
    z3 = Bidirectional(GRU(units=256, return_sequences=True))(z31)
    
    z41 = Multiply()([x4, z3])
    z41 = BatchNormalization()(z41)
    z4 = Bidirectional(GRU(units=128, return_sequences=True))(z41)
    
    z51 = Multiply()([x5, z4])
    z51 = BatchNormalization()(z51)
    z5 = Bidirectional(GRU(units=64, return_sequences=True))(z51)
    
    x = Concatenate(axis=2)([x5, z2, z3, z4, z5])
    
    x = Dense(units=128, activation='selu')(x)
    
    x_output = Dense(units=1)(x)
    
    x_output = ScaleLayer()(x_output)

    model = Model(inputs=x_input, outputs=x_output, 
                  name='DNN_Model')
    return model

# %%
def dnn_model():
    
    x_input = Input(shape=(train.shape[-2:]))
    
    x1 = Bidirectional(LSTM(units=768, return_sequences=True))(x_input)
    x2 = Bidirectional(LSTM(units=512, return_sequences=True))(x1)
    x3 = Bidirectional(LSTM(units=384, return_sequences=True))(x2)
    x4 = Bidirectional(LSTM(units=256, return_sequences=True))(x3)
    x5 = Bidirectional(LSTM(units=128, return_sequences=True))(x4)
    
    z2 = Bidirectional(GRU(units=384, return_sequences=True))(x2)

    dropout_r = 0.01
    
    z31 = Multiply()([x3, z2])
    z31 = BatchNormalization()(z31)
    z31_transformer = TransformerEncoder(384*2, 512*2, 8, dropout_r, name="transformer_layer_z31")(z31)
    z31 = Multiply()([z31, z31_transformer])
    
    z3 = Bidirectional(GRU(units=256, return_sequences=True))(z31)
    
    z41 = Multiply()([x4, z3])
    z41 = BatchNormalization()(z41)
    z41_transformer = TransformerEncoder(256*2, 384*2, 8, dropout_r, name="transformer_layer_z41")(z41)
    z41 = Multiply()([z41, z41_transformer])
    
    z4 = Bidirectional(GRU(units=128, return_sequences=True))(z41)
    
    z51 = Multiply()([x5, z4])
    z51 = BatchNormalization()(z51)
    z51_transformer = TransformerEncoder(128*2, 256*2, 8, dropout_r, name="transformer_layer_z51")(z51)
    z51 = Multiply()([z51, z51_transformer])
    
    z5 = Bidirectional(GRU(units=64, return_sequences=True))(z51)
    
    x = Concatenate(axis=2)([x5, z2, z3, z4, z5])

    x = Dense(units=128)(x)

    x_transformer = BatchNormalization()(x)
    x_transformer = TransformerEncoder(128, 512, 8, dropout_r, name="transformer_layer_128")(x_transformer)
    x = Multiply()([Dropout(0.01)(x), x_transformer])
    
    x = Dense(units=128, activation='selu')(x)
    
    x_output = Dense(units=1)(x)
    
    x_output = ScaleLayer()(x_output)

    model = Model(inputs=x_input, outputs=x_output, 
                  name='DNN_Model')
    return model

# %%
model = dnn_model_aen()
model.summary()
# Out:
# Model: "DNN_Model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 80, 66)]     0
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 80, 66)       264         input_1[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 80, 16)       1072        batch_normalization[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 80, 16)       64          dense[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 80, 16)       0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# bidirectional (Bidirectional)   (None, 80, 1536)     4823040     activation[0][0]
# __________________________________________________________________________________________________
# bidirectional_1 (Bidirectional) (None, 80, 1024)     8392704     bidirectional[0][0]
# __________________________________________________________________________________________________
# bidirectional_2 (Bidirectional) (None, 80, 768)      4328448     bidirectional_1[0][0]
# __________________________________________________________________________________________________
# bidirectional_5 (Bidirectional) (None, 80, 768)      3248640     bidirectional_1[0][0]
# __________________________________________________________________________________________________
# multiply (Multiply)             (None, 80, 768)      0           bidirectional_2[0][0]
#                                                                  bidirectional_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 80, 768)      3072        multiply[0][0]
# __________________________________________________________________________________________________
# bidirectional_3 (Bidirectional) (None, 80, 512)      2099200     bidirectional_2[0][0]
# __________________________________________________________________________________________________
# bidirectional_6 (Bidirectional) (None, 80, 512)      1575936     batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 80, 512)      0           bidirectional_3[0][0]
#                                                                  bidirectional_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 80, 512)      2048        multiply_1[0][0]
# __________________________________________________________________________________________________
# bidirectional_4 (Bidirectional) (None, 80, 256)      656384      bidirectional_3[0][0]
# __________________________________________________________________________________________________
# bidirectional_7 (Bidirectional) (None, 80, 256)      493056      batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 80, 256)      0           bidirectional_4[0][0]
#                                                                  bidirectional_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 80, 256)      1024        multiply_2[0][0]
# __________________________________________________________________________________________________
# bidirectional_8 (Bidirectional) (None, 80, 128)      123648      batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 80, 1920)     0           bidirectional_4[0][0]
#                                                                  bidirectional_5[0][0]
#                                                                  bidirectional_6[0][0]
#                                                                  bidirectional_7[0][0]
#                                                                  bidirectional_8[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 80, 128)      32896       bidirectional_4[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 80, 128)      245888      concatenate[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 80, 16)       0           activation[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 80, 128)      0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 80, 1)        129         dense_2[0][0]
# __________________________________________________________________________________________________
# decoder (Dense)                 (None, 80, 66)       1122        dropout[0][0]
# __________________________________________________________________________________________________
# ae_action (Dense)               (None, 80, 1)        129         dropout_1[0][0]
# __________________________________________________________________________________________________
# output (ScaleLayer)             (None, 80, 1)        0           dense_3[0][0]
# ==================================================================================================
# Total params: 26,028,764
# Trainable params: 26,025,528
# Non-trainable params: 3,236
# __________________________________________________________________________________________________

# %%
plot_model(
    model, 
    to_file='Google_Brain_Keras_Model.png', 
    show_shapes=True,
    show_layer_names=True
)

# %%
del model
gc.collect()
# Out:
# 34753

# %%
#reset Keras Session
def reset_keras():
    sess = tf.compat.v1.keras.backend.get_session()
    tf.compat.v1.keras.backend.clear_session()
    sess.close()
    sess = tf.compat.v1.keras.backend.get_session()

    # use the same config as you used to create the session
    config = tf.compat.v1.ConfigProto()
    config.gpu_options.per_process_gpu_memory_fraction = 1
    config.gpu_options.visible_device_list = "0"
    tf.compat.v1.keras.backend.set_session(tf.compat.v1.Session(config=config))
    gc.collect()

reset_keras()

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
import seaborn as sns

def press_diff(series: np.ndarray):
  return series.diff().abs()


def analy_predict(last_test_idx, train_pred):
  train_df = pd.read_csv('../input/ventilator-pressure-prediction/train.csv')
  last_test_breath_ids = train_df['breath_id'].values.reshape(-1, 80)
  last_test_breath_ids = last_test_breath_ids[:, 0]
  last_test_breath_ids = last_test_breath_ids.flatten()
  last_test_breath_ids = last_test_breath_ids[last_test_idx]

  train_pred = train_pred[last_test_idx]
  train_pred = train_pred.flatten()

  train_df = train_df[train_df['breath_id'].isin(last_test_breath_ids)]
  train_df['pred'] = train_pred
  train_df['abs_error'] = np.abs(train_pred-train_df['pressure'])
  train_df['RC'] = train_df["R"].astype(str) + '__' + train_df["C"].astype(str)
  train_df['press_diff'] = train_df.groupby('breath_id')['pressure'].apply(press_diff)

  df_feature = train_df[train_df['u_out']<1].groupby('breath_id').agg({'abs_error': ['mean' , 'max', 'min', 'sum', 'count'], 
                                                                      'RC': ['first'], 
                                                                      'press_diff':['mean', 'max'],
                                                                      'u_in':['first', 'last'],
                                                                      'pressure':['first', 'last', 'mean', 'std']
                                                                      })
  df_feature.columns = ['_'.join(col) for col in df_feature.columns]

  plt.figure(figsize=(16,16))

  plt.title("abs_error distribution by RC")

  for key, grp in df_feature.groupby(['RC_first']):
    print(f'{key} - MAE  {grp.abs_error_mean.mean()}, count: {grp.abs_error_count.sum()}')
    sns.kdeplot(grp['abs_error_mean'], clip=(0.0, 1), 
                label=key)

  plt.axvline(df_feature['abs_error_mean'].mean())
  plt.legend()
  plt.show()

# %% [markdown]
# with tpu_strategy.scope():
#     skip_folds = np.arange(1)
#     VERBOSE = 2
#     EPOCHS = 200
#     FOLDS = 7
#     if DEBUG:
#       EPOCHS = 100
#     test_preds = []
#     kf = KFold(n_splits=FOLDS, shuffle=True, random_state=2021)
#     last_test_idx = []
#
#     for fold, (train_idx, test_idx) in enumerate(kf.split(train, targets)):
#         last_test_idx = test_idx
#         if len(test_preds) > fold:
#           print(f'Ignore corrent fold {fold+1} as we already predicted test data')
#
#         if DEBUG and fold > 0:
#           continue
#         X_train, X_valid = train[train_idx], train[test_idx]
#         y_train, y_valid = targets[train_idx], targets[test_idx]
#
#         model = dnn_model_GaussianNoise()
#         model.compile(optimizer="adam", loss="mae")
#
#         lr = ReduceLROnPlateau(monitor="val_loss", factor=0.75,
#                                patience=10, verbose=VERBOSE)
#         checkpoint_name = f'./model-gpu/Bidirect_LSTM_model_{fold+1}C.h5'
#         chk_point = ModelCheckpoint(checkpoint_name,
#                                     monitor='val_loss', verbose=VERBOSE,
#                                     save_best_only=True, mode='min')
#
#         es = EarlyStopping(monitor="val_loss", patience=50,
#                            verbose=VERBOSE, mode="min",
#                            restore_best_weights=True)
#
#         if fold not in skip_folds:
#           model.fit(X_train, y_train,
#                     validation_data=(X_valid, y_valid),
#                     epochs=EPOCHS,
#                     verbose=VERBOSE,
#                     batch_size=BATCH_SIZE,
#                     callbacks=[lr, chk_point, es])
#         else:
#           print('Load pretrain weight from ', checkpoint_name)
#           load_locally = tf.saved_model.LoadOptions(experimental_io_device='/job:localhost')
#           try:
#             # At loading time, register the custom objects with a `custom_object_scope`:
#             custom_objects = {"ScaleLayer": ScaleLayer}
#             with tf.keras.utils.custom_object_scope(custom_objects):
#                 model = load_model(checkpoint_name, options=load_locally)
#           except (OSError):
#             print('Cannot load pretrain weight from ', checkpoint_name)
#             break
#
#         y_true = y_valid.squeeze().reshape(-1, 1)
#         y_pred = model.predict(X_valid, batch_size=BATCH_SIZE).squeeze().reshape(-1, 1)
#         train_pred[test_idx] = y_pred.reshape(-1, 80)
#         score = mean_absolute_error(y_true, y_pred)
#         test_preds.append(model.predict(test, batch_size=BATCH_SIZE).squeeze().reshape(-1, 1).squeeze())
#
#         print(f"Fold-{fold+1} | OOF Score: {score}")
#
#         del X_train, X_valid, y_train, y_valid, model
#         reset_keras()
#         gc.collect()
#
#         analy_predict(test_idx, train_pred)
#         break

# %%
#skip_folds = np.arange(1)
skip_folds = []
train_pred = np.zeros(targets.shape)

# %%
with tpu_strategy.scope():
    
    VERBOSE = 2
    EPOCHS = 200
    FOLDS = 7
    if DEBUG:
      EPOCHS = 100
    test_preds = []
    kf = KFold(n_splits=FOLDS, shuffle=True, random_state=2021)
    last_test_idx = []
    
    for fold, (train_idx, test_idx) in enumerate(kf.split(train, targets)):
        last_test_idx = test_idx
        if len(test_preds) > fold:
          print(f'Ignore corrent fold {fold+1} as we already predicted test data')

        if DEBUG and fold > 0:
          continue
        X_train, X_valid = train[train_idx], train[test_idx]
        y_train, y_valid = targets[train_idx], targets[test_idx]
        
        model = dnn_model_aen()
        model.compile(optimizer = tf.keras.optimizers.Adam(learning_rate = 1e-3), 
              # loss="mae"
              loss = {
                  'decoder': tf.keras.losses.MeanSquaredError(), 
                  #'decoder': tf.keras.losses.MeanAbsoluteError(), 
                  'ae_action': tf.keras.losses.MeanAbsoluteError(),
                  'output': tf.keras.losses.MeanAbsoluteError(), 
                  },
              loss_weights = [1, 1, 1]
              )

        lr = ReduceLROnPlateau(monitor="val_output_loss", factor=0.75, 
                               patience=10, verbose=VERBOSE)
        checkpoint_name = f'./model-gpu/Bidirect_LSTM_model_{fold+1}C.h5'
        chk_point = ModelCheckpoint(checkpoint_name,
                                    monitor='val_output_loss', 
                                    verbose=VERBOSE, 
                                    save_best_only=True, mode='min')

        es = EarlyStopping(monitor="val_output_loss", patience=50,
                           verbose=VERBOSE, mode="min",
                           restore_best_weights=True)
        
        if fold not in skip_folds:
          model.fit(X_train, [X_train, y_train, y_train], 
                    validation_data=(X_valid, [X_valid, y_valid, y_valid]), 
                    epochs=EPOCHS,
                    verbose=VERBOSE,
                    batch_size=BATCH_SIZE, 
                    callbacks=[lr, chk_point, es])
        else:
          print('Load pretrain weight from ', checkpoint_name)
          load_locally = tf.saved_model.LoadOptions(experimental_io_device='/job:localhost')
          try:
            # At loading time, register the custom objects with a `custom_object_scope`:
            custom_objects = {"ScaleLayer": ScaleLayer}
            with tf.keras.utils.custom_object_scope(custom_objects):
                model = load_model(checkpoint_name, options=load_locally)
          except (OSError):
            print('Cannot load pretrain weight from ', checkpoint_name)
            break
                
        y_true = y_valid.squeeze().reshape(-1, 1)
        y_pred = model.predict(X_valid, batch_size=BATCH_SIZE)[-1].squeeze().reshape(-1, 1)
        train_pred[test_idx] = y_pred.reshape(-1, 80)
        score = mean_absolute_error(y_true, y_pred)
        test_preds.append(model.predict(test, batch_size=BATCH_SIZE)[-1].squeeze().reshape(-1, 1).squeeze())

        print(f"Fold-{fold+1} | OOF Score: {score}")
        
        del X_train, X_valid, y_train, y_valid, model
        reset_keras()
        gc.collect()

        analy_predict(test_idx, train_pred)
# Out:
# Epoch 1/200
# 127/127 - 177s - loss: 118.9566 - decoder_loss: 114.6191 - ae_action_loss: 2.5450 - output_loss: 1.7925 - val_loss: 106.3010 - val_decoder_loss: 102.7252 - val_ae_action_loss: 1.4585 - val_output_loss: 2.1172
#
# Epoch 00001: val_output_loss improved from inf to 2.11724, saving model to ./model-gpu/Bidirect_LSTM_model_1C.h5
# /usr/local/lib/python3.7/dist-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# Epoch 2/200
# 127/127 - 150s - loss: 107.5361 - decoder_loss: 105.6610 - ae_action_loss: 1.0095 - output_loss: 0.8656 - val_loss: 95.1354 - val_decoder_loss: 92.8665 - val_ae_action_loss: 1.1844 - val_output_loss: 1.0845
#
# Epoch 00002: val_output_loss improved from 2.11724 to 1.08450, saving model to ./model-gpu/Bidirect_LSTM_model_1C.h5
# Epoch 3/200
# 127/127 - 150s - loss: 97.0225 - decoder_loss: 95.4121 - ae_action_loss: 0.8641 - output_loss: 0.7463 - val_loss: 85.5246 - val_decoder_loss: 83.7149 - val_ae_action_loss: 0.7514 - val_output_loss: 1.0583
#
# Epoch 00003: val_output_loss improved from 1.08450 to 1.05829, saving model to ./model-gpu/Bidirect_LSTM_model_1C.h5
# Epoch 4/200
# 127/127 - 150s - loss: 86.5447 - decoder_loss: 85.1216 - ae_action_loss: 0.7581 - output_loss: 0.6651 - val_loss: 75.2547 - val_decoder_loss: 74.0646 - val_ae_action_loss: 0.5960 - val_output_loss: 0.5941
#
# Epoch 00004: val_output_loss improved from 1.05829 to 0.59413, saving model to ./model-gpu/Bidirect_LSTM_model_1C.h5
# Epoch 5/200
# 127/127 - 150s - loss: 76.2492 - decoder_loss: 74.9780 - ae_action_loss: 0.6718 - output_loss: 0.5995 - val_loss: 67.6290 - val_decoder_loss: 66.1929 - val_ae_action_loss: 0.6765 - val_output_loss: 0.7596
#
# Epoch 00005: val_output_loss did not improve from 0.59413
# Epoch 6/200
# 127/127 - 150s - loss: 67.9633 - decoder_loss: 66.7099 - ae_action_loss: 0.6704 - output_loss: 0.5831 - val_loss: 61.3725 - val_decoder_loss: 59.6726 - val_ae_action_loss: 0.8127 - val_output_loss: 0.8871
#
# Epoch 00006: val_output_loss did not improve from 0.59413
# Epoch 7/200
# 127/127 - 150s - loss: 61.1840 - decoder_loss: 59.9767 - ae_action_loss: 0.6450 - output_loss: 0.5623 - val_loss: 55.1043 - val_decoder_loss: 53.9609 - val_ae_action_loss: 0.5408 - val_output_loss: 0.6026
#
# Epoch 00007: val_output_loss did not improve from 0.59413
# Epoch 8/200
# 127/127 - 150s - loss: 55.4528 - decoder_loss: 54.3658 - ae_action_loss: 0.5795 - output_loss: 0.5076 - val_loss: 50.1800 - val_decoder_loss: 49.0490 - val_ae_action_loss: 0.5573 - val_output_loss: 0.5736
#
# Epoch 00008: val_output_loss improved from 0.59413 to 0.57363, saving model to ./model-gpu/Bidirect_LSTM_model_1C.h5
# Epoch 9/200
# 127/127 - 150s - loss: 50.7079 - decoder_loss: 49.5490 - ae_action_loss: 0.6273 - output_loss: 0.5316 - val_loss: 45.8795 - val_decoder_loss: 44.8023 - val_ae_action_loss: 0.5684 - val_output_loss: 0.5088
#
# Epoch 00009: val_output_loss improved from 0.57363 to 0.50878, saving model to ./model-gpu/Bidirect_LSTM_model_1C.h5
# Epoch 10/200
# 127/127 - 150s - loss: 46.1952 - decoder_loss: 45.0674 - ae_action_loss: 0.6016 - output_loss: 0.5261 - val_loss: 41.7310 - val_decoder_loss: 40.6687 - val_ae_action_loss: 0.5349 - val_output_loss: 0.5274
#
# Epoch 00010: val_output_loss did not improve from 0.50878
# Epoch 11/200
# 127/127 - 150s - loss: 41.6556 - decoder_loss: 40.6990 - ae_action_loss: 0.5048 - output_loss: 0.4519 - val_loss: 37.7457 - val_decoder_loss: 36.3939 - val_ae_action_loss: 0.6488 - val_output_loss: 0.7030
#
# Epoch 00011: val_output_loss did not improve from 0.50878
# Epoch 12/200
# 127/127 - 150s - loss: 37.4367 - decoder_loss: 36.4258 - ae_action_loss: 0.5412 - output_loss: 0.4698 - val_loss: 33.4423 - val_decoder_loss: 32.3691 - val_ae_action_loss: 0.5861 - val_output_loss: 0.4871
#
# Epoch 00012: val_output_loss improved from 0.50878 to 0.48715, saving model to ./model-gpu/Bidirect_LSTM_model_1C.h5
# Epoch 13/200
# 127/127 - 150s - loss: 33.3868 - decoder_loss: 32.3819 - ae_action_loss: 0.5411 - output_loss: 0.4638 - val_loss: 29.4592 - val_decoder_loss: 28.5157 - val_ae_action_loss: 0.4266 - val_output_loss: 0.5169
#
# Epoch 00013: val_output_loss did not improve from 0.48715
# Epoch 14/200
# 127/127 - 150s - loss: 29.3466 - decoder_loss: 28.4552 - ae_action_loss: 0.4676 - output_loss: 0.4237 - val_loss: 25.7564 - val_decoder_loss: 24.9907 - val_ae_action_loss: 0.3951 - val_output_loss: 0.3706
#
# Epoch 00014: val_output_loss improved from 0.48715 to 0.37064, saving model to ./model-gpu/Bidirect_LSTM_model_1C.h5
# Epoch 15/200
# 127/127 - 150s - loss: 25.6939 - decoder_loss: 24.8103 - ae_action_loss: 0.4769 - output_loss: 0.4067 - val_loss: 22.5157 - val_decoder_loss: 21.6656 - val_ae_action_loss: 0.4217 - val_output_loss: 0.4284
#
# Epoch 00015: val_output_loss did not improve from 0.37064
# Epoch 16/200
# 127/127 - 150s - loss: 22.2775 - decoder_loss: 21.3843 - ae_action_loss: 0.4760 - output_loss: 0.4172 - val_loss: 19.4589 - val_decoder_loss: 18.6125 - val_ae_action_loss: 0.4455 - val_output_loss: 0.4009
#
# Epoch 00016: val_output_loss did not improve from 0.37064
# Epoch 17/200
# 127/127 - 150s - loss: 19.1630 - decoder_loss: 18.3159 - ae_action_loss: 0.4547 - output_loss: 0.3924 - val_loss: 17.1120 - val_decoder_loss: 15.8714 - val_ae_action_loss: 0.5526 - val_output_loss: 0.6880
#
# Epoch 00017: val_output_loss did not improve from 0.37064
# Epoch 18/200
# 127/127 - 150s - loss: 16.4346 - decoder_loss: 15.6114 - ae_action_loss: 0.4329 - output_loss: 0.3903 - val_loss: 14.2937 - val_decoder_loss: 13.5943 - val_ae_action_loss: 0.3564 - val_output_loss: 0.3430
#
# Epoch 00018: val_output_loss improved from 0.37064 to 0.34296, saving model to ./model-gpu/Bidirect_LSTM_model_1C.h5
# Epoch 19/200
# 127/127 - 150s - loss: 14.1523 - decoder_loss: 13.3459 - ae_action_loss: 0.4359 - output_loss: 0.3705 - val_loss: 13.1775 - val_decoder_loss: 11.5985 - val_ae_action_loss: 0.8864 - val_output_loss: 0.6927
#
# Epoch 00019: val_output_loss did not improve from 0.34296
# Epoch 20/200
# 127/127 - 150s - loss: 12.1810 - decoder_loss: 11.3859 - ae_action_loss: 0.4321 - output_loss: 0.3630 - val_loss: 10.6660 - val_decoder_loss: 9.9102 - val_ae_action_loss: 0.3919 - val_output_loss: 0.3639
#
# Epoch 00020: val_output_loss did not improve from 0.34296
# Epoch 21/200
# 127/127 - 150s - loss: 10.6478 - decoder_loss: 9.8064 - ae_action_loss: 0.4684 - output_loss: 0.3730 - val_loss: 9.6796 - val_decoder_loss: 8.5218 - val_ae_action_loss: 0.7000 - val_output_loss: 0.4578
#
# Epoch 00021: val_output_loss did not improve from 0.34296
# Epoch 22/200
# 127/127 - 150s - loss: 9.2657 - decoder_loss: 8.4867 - ae_action_loss: 0.4238 - output_loss: 0.3552 - val_loss: 7.9635 - val_decoder_loss: 7.2614 - val_ae_action_loss: 0.3515 - val_output_loss: 0.3506
#
# Epoch 00022: val_output_loss did not improve from 0.34296
# Epoch 23/200
# 127/127 - 150s - loss: 8.0147 - decoder_loss: 7.2713 - ae_action_loss: 0.4135 - output_loss: 0.3298 - val_loss: 7.1024 - val_decoder_loss: 6.1979 - val_ae_action_loss: 0.5502 - val_output_loss: 0.3543
#
# Epoch 00023: val_output_loss did not improve from 0.34296
# Epoch 24/200
# 127/127 - 150s - loss: 6.9975 - decoder_loss: 6.2642 - ae_action_loss: 0.3984 - output_loss: 0.3349 - val_loss: 6.0341 - val_decoder_loss: 5.3522 - val_ae_action_loss: 0.3428 - val_output_loss: 0.3391
#
# Epoch 00024: val_output_loss improved from 0.34296 to 0.33913, saving model to ./model-gpu/Bidirect_LSTM_model_1C.h5
# Epoch 25/200
# 127/127 - 150s - loss: 6.1150 - decoder_loss: 5.3742 - ae_action_loss: 0.4093 - output_loss: 0.3315 - val_loss: 5.2303 - val_decoder_loss: 4.4897 - val_ae_action_loss: 0.4158 - val_output_loss: 0.3248
#
# Epoch 00025: val_output_loss improved from 0.33913 to 0.32476, saving model to ./model-gpu/Bidirect_LSTM_model_1C.h5
# Epoch 26/200
# 127/127 - 150s - loss: 5.4043 - decoder_loss: 4.7021 - ae_action_loss: 0.3765 - output_loss: 0.3257 - val_loss: 4.5369 - val_decoder_loss: 3.8065 - val_ae_action_loss: 0.3890 - val_output_loss: 0.3415
#
# Epoch 00026: val_output_loss did not improve from 0.32476
# Epoch 27/200
# 127/127 - 150s - loss: 4.8517 - decoder_loss: 4.1631 - ae_action_loss: 0.3739 - output_loss: 0.3147 - val_loss: 3.9586 - val_decoder_loss: 3.2152 - val_ae_action_loss: 0.3758 - val_output_loss: 0.3676
#
# Epoch 00027: val_output_loss did not improve from 0.32476
# Epoch 28/200
# 127/127 - 150s - loss: 4.2179 - decoder_loss: 3.5472 - ae_action_loss: 0.3530 - output_loss: 0.3178 - val_loss: 3.4089 - val_decoder_loss: 2.7685 - val_ae_action_loss: 0.3442 - val_output_loss: 0.2963
#
# Epoch 00028: val_output_loss improved from 0.32476 to 0.29628, saving model to ./model-gpu/Bidirect_LSTM_model_1C.h5
# Epoch 29/200
# 127/127 - 150s - loss: 3.8951 - decoder_loss: 3.2122 - ae_action_loss: 0.3728 - output_loss: 0.3101 - val_loss: 3.1290 - val_decoder_loss: 2.4561 - val_ae_action_loss: 0.3420 - val_output_loss: 0.3309
#
# Epoch 00029: val_output_loss did not improve from 0.29628
# Epoch 30/200
# 127/127 - 150s - loss: 3.5311 - decoder_loss: 2.8397 - ae_action_loss: 0.3680 - output_loss: 0.3234 - val_loss: 2.7992 - val_decoder_loss: 2.1769 - val_ae_action_loss: 0.3189 - val_output_loss: 0.3035
#
# Epoch 00030: val_output_loss did not improve from 0.29628
# Epoch 31/200
# 127/127 - 150s - loss: 3.3311 - decoder_loss: 2.6616 - ae_action_loss: 0.3554 - output_loss: 0.3141 - val_loss: 2.8368 - val_decoder_loss: 1.9868 - val_ae_action_loss: 0.3972 - val_output_loss: 0.4528
#
# Epoch 00031: val_output_loss did not improve from 0.29628
# Epoch 32/200
# 127/127 - 150s - loss: 3.1776 - decoder_loss: 2.5028 - ae_action_loss: 0.3624 - output_loss: 0.3124 - val_loss: 2.4983 - val_decoder_loss: 1.8721 - val_ae_action_loss: 0.3279 - val_output_loss: 0.2983
#
# Epoch 00032: val_output_loss did not improve from 0.29628
# Epoch 33/200
# 127/127 - 150s - loss: 2.7774 - decoder_loss: 2.1705 - ae_action_loss: 0.3260 - output_loss: 0.2809 - val_loss: 2.2642 - val_decoder_loss: 1.6866 - val_ae_action_loss: 0.2865 - val_output_loss: 0.2911
#
# Epoch 00033: val_output_loss improved from 0.29628 to 0.29109, saving model to ./model-gpu/Bidirect_LSTM_model_1C.h5
# Epoch 34/200
# 127/127 - 150s - loss: 2.7319 - decoder_loss: 2.0941 - ae_action_loss: 0.3361 - output_loss: 0.3017 - val_loss: 2.2128 - val_decoder_loss: 1.6202 - val_ae_action_loss: 0.3186 - val_output_loss: 0.2740
#
# Epoch 00034: val_output_loss improved from 0.29109 to 0.27399, saving model to ./model-gpu/Bidirect_LSTM_model_1C.h5
# Epoch 35/200
# 127/127 - 150s - loss: 2.6617 - decoder_loss: 1.9870 - ae_action_loss: 0.3554 - output_loss: 0.3193 - val_loss: 2.1136 - val_decoder_loss: 1.4770 - val_ae_action_loss: 0.3483 - val_output_loss: 0.2882
#
# Epoch 00035: val_output_loss did not improve from 0.27399
# Epoch 36/200
# 127/127 - 150s - loss: 2.4528 - decoder_loss: 1.8397 - ae_action_loss: 0.3325 - output_loss: 0.2806 - val_loss: 2.1505 - val_decoder_loss: 1.4059 - val_ae_action_loss: 0.4333 - val_output_loss: 0.3113
#
# Epoch 00036: val_output_loss did not improve from 0.27399
# Epoch 37/200
# 127/127 - 150s - loss: 2.3839 - decoder_loss: 1.7800 - ae_action_loss: 0.3215 - output_loss: 0.2825 - val_loss: 1.8742 - val_decoder_loss: 1.2913 - val_ae_action_loss: 0.3131 - val_output_loss: 0.2698
#
# Epoch 00037: val_output_loss improved from 0.27399 to 0.26984, saving model to ./model-gpu/Bidirect_LSTM_model_1C.h5
# Epoch 38/200
# 127/127 - 150s - loss: 2.1830 - decoder_loss: 1.5926 - ae_action_loss: 0.3145 - output_loss: 0.2759 - val_loss: 1.8051 - val_decoder_loss: 1.2452 - val_ae_action_loss: 0.2857 - val_output_loss: 0.2742
#
# Epoch 00038: val_output_loss did not improve from 0.26984
# Epoch 39/200
# 127/127 - 150s - loss: 2.1294 - decoder_loss: 1.5560 - ae_action_loss: 0.3027 - output_loss: 0.2707 - val_loss: 1.8961 - val_decoder_loss: 1.1956 - val_ae_action_loss: 0.3662 - val_output_loss: 0.3343
#
# Epoch 00039: val_output_loss did not improve from 0.26984
# Epoch 40/200
# 127/127 - 150s - loss: 2.1711 - decoder_loss: 1.5433 - ae_action_loss: 0.3338 - output_loss: 0.2939 - val_loss: 1.6861 - val_decoder_loss: 1.0972 - val_ae_action_loss: 0.3016 - val_output_loss: 0.2873
#
# Epoch 00040: val_output_loss did not improve from 0.26984
# Epoch 41/200
# 127/127 - 150s - loss: 2.1901 - decoder_loss: 1.5985 - ae_action_loss: 0.3161 - output_loss: 0.2755 - val_loss: 1.6442 - val_decoder_loss: 1.0143 - val_ae_action_loss: 0.3288 - val_output_loss: 0.3011
#
# Epoch 00041: val_output_loss did not improve from 0.26984
# Epoch 42/200
# 127/127 - 150s - loss: 2.0231 - decoder_loss: 1.4604 - ae_action_loss: 0.2974 - output_loss: 0.2652 - val_loss: 1.5203 - val_decoder_loss: 1.0140 - val_ae_action_loss: 0.2607 - val_output_loss: 0.2456
#
# Epoch 00042: val_output_loss improved from 0.26984 to 0.24559, saving model to ./model-gpu/Bidirect_LSTM_model_1C.h5
# Epoch 43/200
# 127/127 - 150s - loss: 1.8494 - decoder_loss: 1.3165 - ae_action_loss: 0.2787 - output_loss: 0.2542 - val_loss: 1.5772 - val_decoder_loss: 0.9038 - val_ae_action_loss: 0.3413 - val_output_loss: 0.3321
#
# Epoch 00043: val_output_loss did not improve from 0.24559
# Epoch 44/200
# 127/127 - 150s - loss: 1.8495 - decoder_loss: 1.2658 - ae_action_loss: 0.3087 - output_loss: 0.2750 - val_loss: 1.4776 - val_decoder_loss: 0.8704 - val_ae_action_loss: 0.2996 - val_output_loss: 0.3076
#
# Epoch 00044: val_output_loss did not improve from 0.24559
# Epoch 45/200
# 127/127 - 150s - loss: 1.8979 - decoder_loss: 1.3009 - ae_action_loss: 0.3234 - output_loss: 0.2736 - val_loss: 1.4215 - val_decoder_loss: 0.8578 - val_ae_action_loss: 0.2829 - val_output_loss: 0.2808
#
# Epoch 00045: val_output_loss did not improve from 0.24559
# Epoch 46/200
# 127/127 - 150s - loss: 1.7117 - decoder_loss: 1.1706 - ae_action_loss: 0.2845 - output_loss: 0.2566 - val_loss: 1.3721 - val_decoder_loss: 0.8195 - val_ae_action_loss: 0.2938 - val_output_loss: 0.2588
#
# Epoch 00046: val_output_loss did not improve from 0.24559
# Epoch 47/200
# 127/127 - 150s - loss: 1.7563 - decoder_loss: 1.2107 - ae_action_loss: 0.2871 - output_loss: 0.2586 - val_loss: 1.2681 - val_decoder_loss: 0.7480 - val_ae_action_loss: 0.2674 - val_output_loss: 0.2527
#
# Epoch 00047: val_output_loss did not improve from 0.24559
# Epoch 48/200
# 127/127 - 150s - loss: 1.6383 - decoder_loss: 1.1010 - ae_action_loss: 0.2856 - output_loss: 0.2516 - val_loss: 1.2931 - val_decoder_loss: 0.7227 - val_ae_action_loss: 0.2615 - val_output_loss: 0.3089
#
# Epoch 00048: val_output_loss did not improve from 0.24559
# Epoch 49/200
# 127/127 - 150s - loss: 1.5372 - decoder_loss: 1.0337 - ae_action_loss: 0.2625 - output_loss: 0.2410 - val_loss: 1.3023 - val_decoder_loss: 0.7393 - val_ae_action_loss: 0.2751 - val_output_loss: 0.2878
#
# Epoch 00049: val_output_loss did not improve from 0.24559
# Epoch 50/200
# 127/127 - 150s - loss: 1.5362 - decoder_loss: 0.9942 - ae_action_loss: 0.2851 - output_loss: 0.2568 - val_loss: 1.2688 - val_decoder_loss: 0.6516 - val_ae_action_loss: 0.3078 - val_output_loss: 0.3094
#
# Epoch 00050: val_output_loss did not improve from 0.24559
# Epoch 51/200
# 127/127 - 150s - loss: 1.4540 - decoder_loss: 0.9304 - ae_action_loss: 0.2718 - output_loss: 0.2518 - val_loss: 1.2380 - val_decoder_loss: 0.6596 - val_ae_action_loss: 0.3210 - val_output_loss: 0.2575
#
# Epoch 00051: val_output_loss did not improve from 0.24559
# Epoch 52/200
# 127/127 - 150s - loss: 1.5575 - decoder_loss: 0.9889 - ae_action_loss: 0.2981 - output_loss: 0.2706 - val_loss: 1.3090 - val_decoder_loss: 0.6233 - val_ae_action_loss: 0.3473 - val_output_loss: 0.3385
#
# Epoch 00052: ReduceLROnPlateau reducing learning rate to 0.0007500000356230885.
#
# Epoch 00052: val_output_loss did not improve from 0.24559
# Epoch 53/200
# 127/127 - 150s - loss: 1.3961 - decoder_loss: 0.8957 - ae_action_loss: 0.2652 - output_loss: 0.2352 - val_loss: 1.0511 - val_decoder_loss: 0.5689 - val_ae_action_loss: 0.2491 - val_output_loss: 0.2332
#
# Epoch 00053: val_output_loss improved from 0.24559 to 0.23318, saving model to ./model-gpu/Bidirect_LSTM_model_1C.h5
# Epoch 54/200
# 127/127 - 150s - loss: 1.3374 - decoder_loss: 0.8726 - ae_action_loss: 0.2436 - output_loss: 0.2212 - val_loss: 1.0942 - val_decoder_loss: 0.5678 - val_ae_action_loss: 0.2878 - val_output_loss: 0.2386
#
# Epoch 00054: val_output_loss did not improve from 0.23318
# Epoch 55/200
# 127/127 - 150s - loss: 1.3456 - decoder_loss: 0.8789 - ae_action_loss: 0.2462 - output_loss: 0.2204 - val_loss: 1.0739 - val_decoder_loss: 0.5325 - val_ae_action_loss: 0.3083 - val_output_loss: 0.2331
#
# Epoch 00055: val_output_loss improved from 0.23318 to 0.23309, saving model to ./model-gpu/Bidirect_LSTM_model_1C.h5
# Epoch 56/200
# 127/127 - 150s - loss: 1.2482 - decoder_loss: 0.7973 - ae_action_loss: 0.2375 - output_loss: 0.2134 - val_loss: 0.9753 - val_decoder_loss: 0.5263 - val_ae_action_loss: 0.2304 - val_output_loss: 0.2186
#
# Epoch 00056: val_output_loss improved from 0.23309 to 0.21858, saving model to ./model-gpu/Bidirect_LSTM_model_1C.h5
# Epoch 57/200
# 127/127 - 150s - loss: 1.2293 - decoder_loss: 0.7990 - ae_action_loss: 0.2244 - output_loss: 0.2059 - val_loss: 0.9632 - val_decoder_loss: 0.5065 - val_ae_action_loss: 0.2388 - val_output_loss: 0.2178
#
# Epoch 00057: val_output_loss improved from 0.21858 to 0.21785, saving model to ./model-gpu/Bidirect_LSTM_model_1C.h5
# Epoch 58/200
# 127/127 - 150s - loss: 1.2354 - decoder_loss: 0.7782 - ae_action_loss: 0.2409 - output_loss: 0.2163 - val_loss: 1.0044 - val_decoder_loss: 0.4846 - val_ae_action_loss: 0.2730 - val_output_loss: 0.2468
#
# Epoch 00058: val_output_loss did not improve from 0.21785
# Epoch 59/200
# 127/127 - 150s - loss: 1.2843 - decoder_loss: 0.8134 - ae_action_loss: 0.2506 - output_loss: 0.2202 - val_loss: 0.9616 - val_decoder_loss: 0.4839 - val_ae_action_loss: 0.2480 - val_output_loss: 0.2297
#
# Epoch 00059: val_output_loss did not improve from 0.21785
# Epoch 60/200
# 127/127 - 150s - loss: 1.2245 - decoder_loss: 0.8017 - ae_action_loss: 0.2223 - output_loss: 0.2006 - val_loss: 0.9027 - val_decoder_loss: 0.4572 - val_ae_action_loss: 0.2290 - val_output_loss: 0.2165
#
# Epoch 00060: val_output_loss improved from 0.21785 to 0.21645, saving model to ./model-gpu/Bidirect_LSTM_model_1C.h5
# Epoch 61/200
# 127/127 - 150s - loss: 1.2074 - decoder_loss: 0.7738 - ae_action_loss: 0.2262 - output_loss: 0.2075 - val_loss: 0.9381 - val_decoder_loss: 0.4524 - val_ae_action_loss: 0.2552 - val_output_loss: 0.2305
#
# Epoch 00061: val_output_loss did not improve from 0.21645
# Epoch 62/200
# 127/127 - 150s - loss: 1.1910 - decoder_loss: 0.7604 - ae_action_loss: 0.2254 - output_loss: 0.2053 - val_loss: 0.9270 - val_decoder_loss: 0.4286 - val_ae_action_loss: 0.2570 - val_output_loss: 0.2414
#
# Epoch 00062: val_output_loss did not improve from 0.21645
# Epoch 63/200
# 127/127 - 150s - loss: 1.2261 - decoder_loss: 0.7506 - ae_action_loss: 0.2512 - output_loss: 0.2243 - val_loss: 0.9068 - val_decoder_loss: 0.4217 - val_ae_action_loss: 0.2469 - val_output_loss: 0.2382
#
# Epoch 00063: val_output_loss did not improve from 0.21645
# Epoch 64/200
# 127/127 - 150s - loss: 1.1602 - decoder_loss: 0.7473 - ae_action_loss: 0.2152 - output_loss: 0.1977 - val_loss: 1.0097 - val_decoder_loss: 0.4325 - val_ae_action_loss: 0.2915 - val_output_loss: 0.2857
#
# Epoch 00064: val_output_loss did not improve from 0.21645
# Epoch 65/200
# 127/127 - 150s - loss: 1.2011 - decoder_loss: 0.7322 - ae_action_loss: 0.2449 - output_loss: 0.2239 - val_loss: 0.8475 - val_decoder_loss: 0.4042 - val_ae_action_loss: 0.2246 - val_output_loss: 0.2187
#
# Epoch 00065: val_output_loss did not improve from 0.21645
# Epoch 66/200
# 127/127 - 150s - loss: 1.0647 - decoder_loss: 0.6508 - ae_action_loss: 0.2159 - output_loss: 0.1979 - val_loss: 0.8664 - val_decoder_loss: 0.4213 - val_ae_action_loss: 0.2263 - val_output_loss: 0.2188
#
# Epoch 00066: val_output_loss did not improve from 0.21645
# Epoch 67/200
# 127/127 - 150s - loss: 1.0751 - decoder_loss: 0.6458 - ae_action_loss: 0.2259 - output_loss: 0.2034 - val_loss: 0.8899 - val_decoder_loss: 0.3830 - val_ae_action_loss: 0.2760 - val_output_loss: 0.2310
#
# Epoch 00067: val_output_loss did not improve from 0.21645
# Epoch 68/200
# 127/127 - 150s - loss: 1.0281 - decoder_loss: 0.6141 - ae_action_loss: 0.2173 - output_loss: 0.1966 - val_loss: 0.8554 - val_decoder_loss: 0.3785 - val_ae_action_loss: 0.2447 - val_output_loss: 0.2321
#
# Epoch 00068: val_output_loss did not improve from 0.21645
# Epoch 69/200
# 127/127 - 150s - loss: 1.0793 - decoder_loss: 0.6633 - ae_action_loss: 0.2177 - output_loss: 0.1983 - val_loss: 0.9660 - val_decoder_loss: 0.3779 - val_ae_action_loss: 0.3173 - val_output_loss: 0.2708
#
# Epoch 00069: val_output_loss did not improve from 0.21645
# Epoch 70/200
# 127/127 - 150s - loss: 1.1068 - decoder_loss: 0.6586 - ae_action_loss: 0.2356 - output_loss: 0.2126 - val_loss: 0.8202 - val_decoder_loss: 0.3651 - val_ae_action_loss: 0.2347 - val_output_loss: 0.2204
#
# Epoch 00070: ReduceLROnPlateau reducing learning rate to 0.0005625000048894435.
#
# Epoch 00070: val_output_loss did not improve from 0.21645
# Epoch 71/200
# 127/127 - 150s - loss: 1.0240 - decoder_loss: 0.6347 - ae_action_loss: 0.2041 - output_loss: 0.1852 - val_loss: 0.7728 - val_decoder_loss: 0.3450 - val_ae_action_loss: 0.2176 - val_output_loss: 0.2102
#
# Epoch 00071: val_output_loss improved from 0.21645 to 0.21017, saving model to ./model-gpu/Bidirect_LSTM_model_1C.h5
# Epoch 72/200
# 127/127 - 150s - loss: 1.0466 - decoder_loss: 0.6726 - ae_action_loss: 0.1960 - output_loss: 0.1780 - val_loss: 0.7640 - val_decoder_loss: 0.3517 - val_ae_action_loss: 0.2100 - val_output_loss: 0.2023
#
# Epoch 00072: val_output_loss improved from 0.21017 to 0.20232, saving model to ./model-gpu/Bidirect_LSTM_model_1C.h5
# Epoch 73/200
# 127/127 - 150s - loss: 0.9980 - decoder_loss: 0.6255 - ae_action_loss: 0.1960 - output_loss: 0.1766 - val_loss: 0.7789 - val_decoder_loss: 0.3479 - val_ae_action_loss: 0.2197 - val_output_loss: 0.2112
#
# Epoch 00073: val_output_loss did not improve from 0.20232
# Epoch 74/200
# 127/127 - 150s - loss: 0.9891 - decoder_loss: 0.6223 - ae_action_loss: 0.1916 - output_loss: 0.1752 - val_loss: 0.7316 - val_decoder_loss: 0.3332 - val_ae_action_loss: 0.2024 - val_output_loss: 0.1960
#
# Epoch 00074: val_output_loss improved from 0.20232 to 0.19597, saving model to ./model-gpu/Bidirect_LSTM_model_1C.h5
# Epoch 75/200
# 127/127 - 150s - loss: 1.0411 - decoder_loss: 0.6657 - ae_action_loss: 0.1974 - output_loss: 0.1780 - val_loss: 0.7395 - val_decoder_loss: 0.3257 - val_ae_action_loss: 0.2108 - val_output_loss: 0.2029
#
# Epoch 00075: val_output_loss did not improve from 0.19597
# Epoch 76/200
# 127/127 - 150s - loss: 0.9400 - decoder_loss: 0.5816 - ae_action_loss: 0.1872 - output_loss: 0.1713 - val_loss: 0.7434 - val_decoder_loss: 0.3200 - val_ae_action_loss: 0.2242 - val_output_loss: 0.1992
#
# Epoch 00076: val_output_loss did not improve from 0.19597
# Epoch 77/200
# 127/127 - 150s - loss: 0.9736 - decoder_loss: 0.6115 - ae_action_loss: 0.1897 - output_loss: 0.1725 - val_loss: 0.7247 - val_decoder_loss: 0.3232 - val_ae_action_loss: 0.2037 - val_output_loss: 0.1978
#
# Epoch 00077: val_output_loss did not improve from 0.19597
# Epoch 78/200
# 127/127 - 150s - loss: 1.0124 - decoder_loss: 0.6491 - ae_action_loss: 0.1906 - output_loss: 0.1727 - val_loss: 0.7177 - val_decoder_loss: 0.3184 - val_ae_action_loss: 0.2041 - val_output_loss: 0.1953
#
# Epoch 00078: val_output_loss improved from 0.19597 to 0.19525, saving model to ./model-gpu/Bidirect_LSTM_model_1C.h5
# Epoch 79/200
# 127/127 - 150s - loss: 0.9551 - decoder_loss: 0.6051 - ae_action_loss: 0.1835 - output_loss: 0.1665 - val_loss: 0.7418 - val_decoder_loss: 0.3236 - val_ae_action_loss: 0.2157 - val_output_loss: 0.2025
#
# Epoch 00079: val_output_loss did not improve from 0.19525
# Epoch 80/200
# 127/127 - 150s - loss: 0.9518 - decoder_loss: 0.5937 - ae_action_loss: 0.1872 - output_loss: 0.1709 - val_loss: 0.8144 - val_decoder_loss: 0.3067 - val_ae_action_loss: 0.2684 - val_output_loss: 0.2393
#
# Epoch 00080: val_output_loss did not improve from 0.19525
# Epoch 81/200
# 127/127 - 150s - loss: 0.9622 - decoder_loss: 0.5667 - ae_action_loss: 0.2084 - output_loss: 0.1872 - val_loss: 0.7095 - val_decoder_loss: 0.3005 - val_ae_action_loss: 0.2088 - val_output_loss: 0.2002
#
# Epoch 00081: val_output_loss did not improve from 0.19525
# Epoch 82/200
# 127/127 - 150s - loss: 0.9650 - decoder_loss: 0.6120 - ae_action_loss: 0.1844 - output_loss: 0.1686 - val_loss: 0.6913 - val_decoder_loss: 0.2979 - val_ae_action_loss: 0.1978 - val_output_loss: 0.1956
#
# Epoch 00082: val_output_loss did not improve from 0.19525
# Epoch 83/200
# 127/127 - 150s - loss: 0.9226 - decoder_loss: 0.5607 - ae_action_loss: 0.1891 - output_loss: 0.1728 - val_loss: 0.6932 - val_decoder_loss: 0.2894 - val_ae_action_loss: 0.2023 - val_output_loss: 0.2015
#
# Epoch 00083: val_output_loss did not improve from 0.19525
# Epoch 84/200
# 127/127 - 150s - loss: 0.8712 - decoder_loss: 0.5275 - ae_action_loss: 0.1802 - output_loss: 0.1635 - val_loss: 0.6907 - val_decoder_loss: 0.2854 - val_ae_action_loss: 0.2060 - val_output_loss: 0.1993
#
# Epoch 00084: val_output_loss did not improve from 0.19525
# Epoch 85/200
# 127/127 - 150s - loss: 0.9517 - decoder_loss: 0.5671 - ae_action_loss: 0.2011 - output_loss: 0.1835 - val_loss: 0.6938 - val_decoder_loss: 0.3033 - val_ae_action_loss: 0.2001 - val_output_loss: 0.1904
#
# Epoch 00085: val_output_loss improved from 0.19525 to 0.19043, saving model to ./model-gpu/Bidirect_LSTM_model_1C.h5
# Epoch 86/200
# 127/127 - 150s - loss: 0.9550 - decoder_loss: 0.6096 - ae_action_loss: 0.1810 - output_loss: 0.1644 - val_loss: 0.6847 - val_decoder_loss: 0.2922 - val_ae_action_loss: 0.2008 - val_output_loss: 0.1917
#
# Epoch 00086: val_output_loss did not improve from 0.19043
# Epoch 87/200
# 127/127 - 150s - loss: 0.8584 - decoder_loss: 0.5273 - ae_action_loss: 0.1733 - output_loss: 0.1578 - val_loss: 0.6809 - val_decoder_loss: 0.2833 - val_ae_action_loss: 0.2053 - val_output_loss: 0.1924
#
# Epoch 00087: val_output_loss did not improve from 0.19043
# Epoch 88/200
# 127/127 - 150s - loss: 0.9338 - decoder_loss: 0.5861 - ae_action_loss: 0.1815 - output_loss: 0.1662 - val_loss: 0.6848 - val_decoder_loss: 0.2795 - val_ae_action_loss: 0.2104 - val_output_loss: 0.1950
#
# Epoch 00088: val_output_loss did not improve from 0.19043
# Epoch 89/200
# 127/127 - 150s - loss: 0.9521 - decoder_loss: 0.5751 - ae_action_loss: 0.1985 - output_loss: 0.1785 - val_loss: 0.7341 - val_decoder_loss: 0.2776 - val_ae_action_loss: 0.2371 - val_output_loss: 0.2195
#
# Epoch 00089: val_output_loss did not improve from 0.19043
# Epoch 90/200
# 127/127 - 150s - loss: 0.9234 - decoder_loss: 0.5711 - ae_action_loss: 0.1846 - output_loss: 0.1678 - val_loss: 0.6710 - val_decoder_loss: 0.2723 - val_ae_action_loss: 0.2010 - val_output_loss: 0.1978
#
# Epoch 00090: val_output_loss did not improve from 0.19043
# Epoch 91/200
# 127/127 - 150s - loss: 0.8983 - decoder_loss: 0.5525 - ae_action_loss: 0.1824 - output_loss: 0.1634 - val_loss: 0.6793 - val_decoder_loss: 0.2687 - val_ae_action_loss: 0.2095 - val_output_loss: 0.2011
#
# Epoch 00091: val_output_loss did not improve from 0.19043
# Epoch 92/200
# 127/127 - 150s - loss: 0.8252 - decoder_loss: 0.4955 - ae_action_loss: 0.1722 - output_loss: 0.1574 - val_loss: 0.6392 - val_decoder_loss: 0.2647 - val_ae_action_loss: 0.1898 - val_output_loss: 0.1847
#
# Epoch 00092: val_output_loss improved from 0.19043 to 0.18472, saving model to ./model-gpu/Bidirect_LSTM_model_1C.h5
# Epoch 93/200
# 127/127 - 150s - loss: 1.0565 - decoder_loss: 0.6239 - ae_action_loss: 0.2252 - output_loss: 0.2075 - val_loss: 0.6935 - val_decoder_loss: 0.2753 - val_ae_action_loss: 0.2119 - val_output_loss: 0.2063
#
# Epoch 00093: val_output_loss did not improve from 0.18472
# Epoch 94/200
# 127/127 - 150s - loss: 0.8600 - decoder_loss: 0.5011 - ae_action_loss: 0.1875 - output_loss: 0.1714 - val_loss: 0.6788 - val_decoder_loss: 0.2623 - val_ae_action_loss: 0.2124 - val_output_loss: 0.2041
#
# Epoch 00094: val_output_loss did not improve from 0.18472
# Epoch 95/200
# 127/127 - 150s - loss: 0.8269 - decoder_loss: 0.4931 - ae_action_loss: 0.1740 - output_loss: 0.1598 - val_loss: 0.6689 - val_decoder_loss: 0.2616 - val_ae_action_loss: 0.2067 - val_output_loss: 0.2005
#
# Epoch 00095: val_output_loss did not improve from 0.18472
# Epoch 96/200
# 127/127 - 150s - loss: 0.8040 - decoder_loss: 0.4730 - ae_action_loss: 0.1730 - output_loss: 0.1580 - val_loss: 0.6710 - val_decoder_loss: 0.2534 - val_ae_action_loss: 0.2130 - val_output_loss: 0.2047
#
# Epoch 00096: val_output_loss did not improve from 0.18472
# Epoch 97/200
# 127/127 - 150s - loss: 0.8461 - decoder_loss: 0.5204 - ae_action_loss: 0.1710 - output_loss: 0.1548 - val_loss: 0.6402 - val_decoder_loss: 0.2526 - val_ae_action_loss: 0.1973 - val_output_loss: 0.1904
#
# Epoch 00097: val_output_loss did not improve from 0.18472
# Epoch 98/200
# 127/127 - 150s - loss: 0.8360 - decoder_loss: 0.4939 - ae_action_loss: 0.1801 - output_loss: 0.1619 - val_loss: 0.7064 - val_decoder_loss: 0.2608 - val_ae_action_loss: 0.2258 - val_output_loss: 0.2198
#
# Epoch 00098: val_output_loss did not improve from 0.18472
# Epoch 99/200
# 127/127 - 150s - loss: 0.8248 - decoder_loss: 0.4888 - ae_action_loss: 0.1764 - output_loss: 0.1596 - val_loss: 0.6350 - val_decoder_loss: 0.2571 - val_ae_action_loss: 0.1939 - val_output_loss: 0.1840
#
# Epoch 00099: val_output_loss improved from 0.18472 to 0.18397, saving model to ./model-gpu/Bidirect_LSTM_model_1C.h5
# Epoch 100/200
# 127/127 - 150s - loss: 0.8329 - decoder_loss: 0.5075 - ae_action_loss: 0.1701 - output_loss: 0.1553 - val_loss: 0.6314 - val_decoder_loss: 0.2450 - val_ae_action_loss: 0.1941 - val_output_loss: 0.1923
#
# Epoch 00100: val_output_loss did not improve from 0.18397
# Epoch 101/200
# 127/127 - 150s - loss: 0.7736 - decoder_loss: 0.4572 - ae_action_loss: 0.1659 - output_loss: 0.1505 - val_loss: 0.6167 - val_decoder_loss: 0.2444 - val_ae_action_loss: 0.1880 - val_output_loss: 0.1843
#
# Epoch 00101: val_output_loss did not improve from 0.18397
# Epoch 102/200
# 127/127 - 150s - loss: 0.8453 - decoder_loss: 0.5078 - ae_action_loss: 0.1775 - output_loss: 0.1600 - val_loss: 0.6438 - val_decoder_loss: 0.2380 - val_ae_action_loss: 0.2038 - val_output_loss: 0.2021
#
# Epoch 00102: val_output_loss did not improve from 0.18397
# Epoch 103/200
# 127/127 - 150s - loss: 0.8227 - decoder_loss: 0.5001 - ae_action_loss: 0.1686 - output_loss: 0.1540 - val_loss: 0.6211 - val_decoder_loss: 0.2380 - val_ae_action_loss: 0.1959 - val_output_loss: 0.1872
#
# Epoch 00103: val_output_loss did not improve from 0.18397
# Epoch 104/200
# 127/127 - 150s - loss: 0.8200 - decoder_loss: 0.5012 - ae_action_loss: 0.1670 - output_loss: 0.1518 - val_loss: 0.6178 - val_decoder_loss: 0.2325 - val_ae_action_loss: 0.1940 - val_output_loss: 0.1913
#
# Epoch 00104: val_output_loss did not improve from 0.18397
# Epoch 105/200
# 127/127 - 150s - loss: 0.8116 - decoder_loss: 0.4962 - ae_action_loss: 0.1658 - output_loss: 0.1496 - val_loss: 0.6086 - val_decoder_loss: 0.2385 - val_ae_action_loss: 0.1888 - val_output_loss: 0.1814
#
# Epoch 00105: val_output_loss improved from 0.18397 to 0.18138, saving model to ./model-gpu/Bidirect_LSTM_model_1C.h5
# Epoch 106/200
# 127/127 - 150s - loss: 0.7579 - decoder_loss: 0.4390 - ae_action_loss: 0.1674 - output_loss: 0.1515 - val_loss: 0.6642 - val_decoder_loss: 0.2511 - val_ae_action_loss: 0.2055 - val_output_loss: 0.2076
#
# Epoch 00106: val_output_loss did not improve from 0.18138
# Epoch 107/200
# 127/127 - 150s - loss: 0.8607 - decoder_loss: 0.5304 - ae_action_loss: 0.1729 - output_loss: 0.1575 - val_loss: 0.8670 - val_decoder_loss: 0.2283 - val_ae_action_loss: 0.3284 - val_output_loss: 0.3103
#
# Epoch 00107: val_output_loss did not improve from 0.18138
# Epoch 108/200
# 127/127 - 150s - loss: 0.8876 - decoder_loss: 0.5200 - ae_action_loss: 0.1940 - output_loss: 0.1736 - val_loss: 0.6226 - val_decoder_loss: 0.2330 - val_ae_action_loss: 0.2017 - val_output_loss: 0.1879
#
# Epoch 00108: val_output_loss did not improve from 0.18138
# Epoch 109/200
# 127/127 - 150s - loss: 1.0548 - decoder_loss: 0.5786 - ae_action_loss: 0.2540 - output_loss: 0.2221 - val_loss: 0.6468 - val_decoder_loss: 0.2275 - val_ae_action_loss: 0.2155 - val_output_loss: 0.2038
#
# Epoch 00109: val_output_loss did not improve from 0.18138
# Epoch 110/200
# 127/127 - 150s - loss: 0.8218 - decoder_loss: 0.4759 - ae_action_loss: 0.1817 - output_loss: 0.1641 - val_loss: 0.6683 - val_decoder_loss: 0.2335 - val_ae_action_loss: 0.2215 - val_output_loss: 0.2134
#
# Epoch 00110: val_output_loss did not improve from 0.18138
# Epoch 111/200
# 127/127 - 150s - loss: 0.8239 - decoder_loss: 0.4774 - ae_action_loss: 0.1832 - output_loss: 0.1632 - val_loss: 0.6048 - val_decoder_loss: 0.2256 - val_ae_action_loss: 0.1934 - val_output_loss: 0.1858
#
# Epoch 00111: val_output_loss did not improve from 0.18138
# Epoch 112/200
# 127/127 - 150s - loss: 0.7829 - decoder_loss: 0.4689 - ae_action_loss: 0.1644 - output_loss: 0.1496 - val_loss: 0.6084 - val_decoder_loss: 0.2249 - val_ae_action_loss: 0.1990 - val_output_loss: 0.1845
#
# Epoch 00112: val_output_loss did not improve from 0.18138
# Epoch 113/200
# 127/127 - 150s - loss: 0.8298 - decoder_loss: 0.5184 - ae_action_loss: 0.1639 - output_loss: 0.1475 - val_loss: 0.6088 - val_decoder_loss: 0.2261 - val_ae_action_loss: 0.1951 - val_output_loss: 0.1876
#
# Epoch 00113: val_output_loss did not improve from 0.18138
# Epoch 114/200
# 127/127 - 150s - loss: 0.7972 - decoder_loss: 0.4920 - ae_action_loss: 0.1605 - output_loss: 0.1448 - val_loss: 0.5768 - val_decoder_loss: 0.2140 - val_ae_action_loss: 0.1846 - val_output_loss: 0.1782
#
# Epoch 00114: val_output_loss improved from 0.18138 to 0.17824, saving model to ./model-gpu/Bidirect_LSTM_model_1C.h5
# Epoch 115/200
# 127/127 - 150s - loss: 0.7800 - decoder_loss: 0.4757 - ae_action_loss: 0.1598 - output_loss: 0.1445 - val_loss: 0.5987 - val_decoder_loss: 0.2235 - val_ae_action_loss: 0.1883 - val_output_loss: 0.1869
#
# Epoch 00115: val_output_loss did not improve from 0.17824
# Epoch 116/200
# 127/127 - 150s - loss: 0.7809 - decoder_loss: 0.4602 - ae_action_loss: 0.1684 - output_loss: 0.1523 - val_loss: 0.6024 - val_decoder_loss: 0.2201 - val_ae_action_loss: 0.1931 - val_output_loss: 0.1893
#
# Epoch 00116: val_output_loss did not improve from 0.17824
# Epoch 117/200
# 127/127 - 150s - loss: 0.7824 - decoder_loss: 0.4689 - ae_action_loss: 0.1641 - output_loss: 0.1494 - val_loss: 0.6032 - val_decoder_loss: 0.2153 - val_ae_action_loss: 0.1957 - val_output_loss: 0.1922
#
# Epoch 00117: val_output_loss did not improve from 0.17824
# Epoch 118/200
# 127/127 - 150s - loss: 0.7531 - decoder_loss: 0.4439 - ae_action_loss: 0.1619 - output_loss: 0.1473 - val_loss: 0.6017 - val_decoder_loss: 0.2109 - val_ae_action_loss: 0.1961 - val_output_loss: 0.1947
#
# Epoch 00118: val_output_loss did not improve from 0.17824
# Epoch 119/200
# 127/127 - 150s - loss: 0.7633 - decoder_loss: 0.4562 - ae_action_loss: 0.1610 - output_loss: 0.1461 - val_loss: 0.5967 - val_decoder_loss: 0.2147 - val_ae_action_loss: 0.1938 - val_output_loss: 0.1883
#
# Epoch 00119: val_output_loss did not improve from 0.17824
# Epoch 120/200
# 127/127 - 150s - loss: 0.7653 - decoder_loss: 0.4693 - ae_action_loss: 0.1555 - output_loss: 0.1405 - val_loss: 0.5843 - val_decoder_loss: 0.2061 - val_ae_action_loss: 0.1936 - val_output_loss: 0.1846
#
# Epoch 00120: val_output_loss did not improve from 0.17824
# Epoch 121/200
# 127/127 - 150s - loss: 0.7239 - decoder_loss: 0.4207 - ae_action_loss: 0.1596 - output_loss: 0.1436 - val_loss: 0.5805 - val_decoder_loss: 0.2039 - val_ae_action_loss: 0.1916 - val_output_loss: 0.1850
#
# Epoch 00121: val_output_loss did not improve from 0.17824
# Epoch 122/200
# 127/127 - 150s - loss: 0.7619 - decoder_loss: 0.4697 - ae_action_loss: 0.1533 - output_loss: 0.1389 - val_loss: 0.5895 - val_decoder_loss: 0.2077 - val_ae_action_loss: 0.1929 - val_output_loss: 0.1889
#
# Epoch 00122: val_output_loss did not improve from 0.17824
# Epoch 123/200
# 127/127 - 150s - loss: 0.7351 - decoder_loss: 0.4327 - ae_action_loss: 0.1586 - output_loss: 0.1438 - val_loss: 0.5957 - val_decoder_loss: 0.2101 - val_ae_action_loss: 0.1942 - val_output_loss: 0.1914
#
# Epoch 00123: val_output_loss did not improve from 0.17824
# Epoch 124/200
# 127/127 - 150s - loss: 0.7322 - decoder_loss: 0.4282 - ae_action_loss: 0.1603 - output_loss: 0.1436 - val_loss: 0.5834 - val_decoder_loss: 0.2003 - val_ae_action_loss: 0.1921 - val_output_loss: 0.1910
#
# Epoch 00124: ReduceLROnPlateau reducing learning rate to 0.0004218749818392098.
#
# Epoch 00124: val_output_loss did not improve from 0.17824
# Epoch 125/200
# 127/127 - 150s - loss: 0.7168 - decoder_loss: 0.4339 - ae_action_loss: 0.1497 - output_loss: 0.1332 - val_loss: 0.5670 - val_decoder_loss: 0.1983 - val_ae_action_loss: 0.1867 - val_output_loss: 0.1821
#
# Epoch 00125: val_output_loss did not improve from 0.17824
# Epoch 126/200
# 127/127 - 150s - loss: 0.7006 - decoder_loss: 0.4201 - ae_action_loss: 0.1483 - output_loss: 0.1322 - val_loss: 0.5513 - val_decoder_loss: 0.1955 - val_ae_action_loss: 0.1800 - val_output_loss: 0.1758
#
# Epoch 00126: val_output_loss improved from 0.17824 to 0.17575, saving model to ./model-gpu/Bidirect_LSTM_model_1C.h5
# Epoch 127/200
# 127/127 - 150s - loss: 0.7783 - decoder_loss: 0.5057 - ae_action_loss: 0.1444 - output_loss: 0.1282 - val_loss: 0.5766 - val_decoder_loss: 0.2057 - val_ae_action_loss: 0.1872 - val_output_loss: 0.1837
#
# Epoch 00127: val_output_loss did not improve from 0.17575
# Epoch 128/200
# 127/127 - 150s - loss: 0.7334 - decoder_loss: 0.4506 - ae_action_loss: 0.1493 - output_loss: 0.1336 - val_loss: 0.5741 - val_decoder_loss: 0.2070 - val_ae_action_loss: 0.1834 - val_output_loss: 0.1837
#
# Epoch 00128: val_output_loss did not improve from 0.17575
# Epoch 129/200
# 127/127 - 150s - loss: 0.7912 - decoder_loss: 0.5130 - ae_action_loss: 0.1472 - output_loss: 0.1310 - val_loss: 0.5703 - val_decoder_loss: 0.1974 - val_ae_action_loss: 0.1898 - val_output_loss: 0.1831
#
# Epoch 00129: val_output_loss did not improve from 0.17575
# Epoch 130/200
# 127/127 - 150s - loss: 0.6628 - decoder_loss: 0.3920 - ae_action_loss: 0.1430 - output_loss: 0.1277 - val_loss: 0.5642 - val_decoder_loss: 0.2001 - val_ae_action_loss: 0.1846 - val_output_loss: 0.1795
#
# Epoch 00130: val_output_loss did not improve from 0.17575
# Epoch 131/200
# 127/127 - 150s - loss: 0.6975 - decoder_loss: 0.4243 - ae_action_loss: 0.1446 - output_loss: 0.1287 - val_loss: 0.5443 - val_decoder_loss: 0.1938 - val_ae_action_loss: 0.1768 - val_output_loss: 0.1737
#
# Epoch 00131: val_output_loss improved from 0.17575 to 0.17373, saving model to ./model-gpu/Bidirect_LSTM_model_1C.h5
# Epoch 132/200
# 127/127 - 150s - loss: 0.7074 - decoder_loss: 0.4428 - ae_action_loss: 0.1400 - output_loss: 0.1246 - val_loss: 0.5538 - val_decoder_loss: 0.1920 - val_ae_action_loss: 0.1829 - val_output_loss: 0.1790
#
# Epoch 00132: val_output_loss did not improve from 0.17373
# Epoch 133/200
# 127/127 - 150s - loss: 0.7049 - decoder_loss: 0.4288 - ae_action_loss: 0.1463 - output_loss: 0.1298 - val_loss: 0.5744 - val_decoder_loss: 0.1907 - val_ae_action_loss: 0.1977 - val_output_loss: 0.1860
#
# Epoch 00133: val_output_loss did not improve from 0.17373
# Epoch 134/200
# 127/127 - 150s - loss: 0.7099 - decoder_loss: 0.4367 - ae_action_loss: 0.1449 - output_loss: 0.1283 - val_loss: 0.5565 - val_decoder_loss: 0.1957 - val_ae_action_loss: 0.1836 - val_output_loss: 0.1773
#
# Epoch 00134: val_output_loss did not improve from 0.17373
# Epoch 135/200
# 127/127 - 150s - loss: 0.6407 - decoder_loss: 0.3793 - ae_action_loss: 0.1387 - output_loss: 0.1227 - val_loss: 0.5379 - val_decoder_loss: 0.1880 - val_ae_action_loss: 0.1759 - val_output_loss: 0.1740
#
# Epoch 00135: val_output_loss did not improve from 0.17373
# Epoch 136/200
# 127/127 - 150s - loss: 0.6740 - decoder_loss: 0.4134 - ae_action_loss: 0.1382 - output_loss: 0.1225 - val_loss: 0.5444 - val_decoder_loss: 0.1882 - val_ae_action_loss: 0.1814 - val_output_loss: 0.1747
#
# Epoch 00136: val_output_loss did not improve from 0.17373
# Epoch 137/200
# 127/127 - 150s - loss: 0.6881 - decoder_loss: 0.4276 - ae_action_loss: 0.1381 - output_loss: 0.1223 - val_loss: 0.5379 - val_decoder_loss: 0.1844 - val_ae_action_loss: 0.1794 - val_output_loss: 0.1741
#
# Epoch 00137: val_output_loss did not improve from 0.17373
# Epoch 138/200
# 127/127 - 150s - loss: 0.6645 - decoder_loss: 0.4047 - ae_action_loss: 0.1377 - output_loss: 0.1222 - val_loss: 0.5727 - val_decoder_loss: 0.1907 - val_ae_action_loss: 0.1904 - val_output_loss: 0.1916
#
# Epoch 00138: val_output_loss did not improve from 0.17373
# Epoch 139/200
# 127/127 - 150s - loss: 0.6962 - decoder_loss: 0.4361 - ae_action_loss: 0.1375 - output_loss: 0.1226 - val_loss: 0.5420 - val_decoder_loss: 0.1842 - val_ae_action_loss: 0.1804 - val_output_loss: 0.1774
#
# Epoch 00139: val_output_loss did not improve from 0.17373
# Epoch 140/200
# 127/127 - 150s - loss: 0.6912 - decoder_loss: 0.4327 - ae_action_loss: 0.1370 - output_loss: 0.1214 - val_loss: 0.5557 - val_decoder_loss: 0.1945 - val_ae_action_loss: 0.1822 - val_output_loss: 0.1789
#
# Epoch 00140: val_output_loss did not improve from 0.17373
# Epoch 141/200
# 127/127 - 150s - loss: 0.6568 - decoder_loss: 0.3983 - ae_action_loss: 0.1366 - output_loss: 0.1219 - val_loss: 0.5388 - val_decoder_loss: 0.1817 - val_ae_action_loss: 0.1767 - val_output_loss: 0.1805
#
# Epoch 00141: ReduceLROnPlateau reducing learning rate to 0.00031640623637940735.
#
# Epoch 00141: val_output_loss did not improve from 0.17373
# Epoch 142/200
# 127/127 - 150s - loss: 0.6232 - decoder_loss: 0.3743 - ae_action_loss: 0.1323 - output_loss: 0.1166 - val_loss: 0.5315 - val_decoder_loss: 0.1810 - val_ae_action_loss: 0.1780 - val_output_loss: 0.1725
#
# Epoch 00142: val_output_loss improved from 0.17373 to 0.17246, saving model to ./model-gpu/Bidirect_LSTM_model_1C.h5
# Epoch 143/200
# 127/127 - 150s - loss: 0.6978 - decoder_loss: 0.4485 - ae_action_loss: 0.1331 - output_loss: 0.1162 - val_loss: 0.5298 - val_decoder_loss: 0.1807 - val_ae_action_loss: 0.1757 - val_output_loss: 0.1733
#
# Epoch 00143: val_output_loss did not improve from 0.17246
# Epoch 144/200
# 127/127 - 150s - loss: 0.6474 - decoder_loss: 0.4034 - ae_action_loss: 0.1303 - output_loss: 0.1137 - val_loss: 0.5516 - val_decoder_loss: 0.1772 - val_ae_action_loss: 0.1902 - val_output_loss: 0.1842
#
# Epoch 00144: val_output_loss did not improve from 0.17246
# Epoch 145/200
# 127/127 - 150s - loss: 0.6611 - decoder_loss: 0.4144 - ae_action_loss: 0.1316 - output_loss: 0.1151 - val_loss: 0.5318 - val_decoder_loss: 0.1822 - val_ae_action_loss: 0.1766 - val_output_loss: 0.1730
#
# Epoch 00145: val_output_loss did not improve from 0.17246
# Epoch 146/200
# 127/127 - 150s - loss: 0.6041 - decoder_loss: 0.3634 - ae_action_loss: 0.1284 - output_loss: 0.1124 - val_loss: 0.5219 - val_decoder_loss: 0.1783 - val_ae_action_loss: 0.1725 - val_output_loss: 0.1711
#
# Epoch 00146: val_output_loss improved from 0.17246 to 0.17114, saving model to ./model-gpu/Bidirect_LSTM_model_1C.h5
# Epoch 147/200
# 127/127 - 150s - loss: 0.6694 - decoder_loss: 0.4214 - ae_action_loss: 0.1326 - output_loss: 0.1154 - val_loss: 0.5227 - val_decoder_loss: 0.1752 - val_ae_action_loss: 0.1742 - val_output_loss: 0.1734
#
# Epoch 00147: val_output_loss did not improve from 0.17114
# Epoch 148/200
# 127/127 - 150s - loss: 0.6296 - decoder_loss: 0.3888 - ae_action_loss: 0.1291 - output_loss: 0.1117 - val_loss: 0.5903 - val_decoder_loss: 0.1790 - val_ae_action_loss: 0.2076 - val_output_loss: 0.2037
#
# Epoch 00148: val_output_loss did not improve from 0.17114
# Epoch 149/200
# 127/127 - 150s - loss: 0.6622 - decoder_loss: 0.4053 - ae_action_loss: 0.1372 - output_loss: 0.1197 - val_loss: 0.5322 - val_decoder_loss: 0.1840 - val_ae_action_loss: 0.1763 - val_output_loss: 0.1719
#
# Epoch 00149: val_output_loss did not improve from 0.17114
# Epoch 150/200
# 127/127 - 150s - loss: 0.6397 - decoder_loss: 0.4006 - ae_action_loss: 0.1282 - output_loss: 0.1109 - val_loss: 0.5161 - val_decoder_loss: 0.1750 - val_ae_action_loss: 0.1721 - val_output_loss: 0.1690
#
# Epoch 00150: val_output_loss improved from 0.17114 to 0.16898, saving model to ./model-gpu/Bidirect_LSTM_model_1C.h5
# Epoch 151/200
# 127/127 - 150s - loss: 0.6412 - decoder_loss: 0.4046 - ae_action_loss: 0.1266 - output_loss: 0.1100 - val_loss: 0.5204 - val_decoder_loss: 0.1752 - val_ae_action_loss: 0.1745 - val_output_loss: 0.1706
#
# Epoch 00151: val_output_loss did not improve from 0.16898
# Epoch 152/200
# 127/127 - 150s - loss: 0.6479 - decoder_loss: 0.4123 - ae_action_loss: 0.1260 - output_loss: 0.1095 - val_loss: 0.5257 - val_decoder_loss: 0.1773 - val_ae_action_loss: 0.1755 - val_output_loss: 0.1729
#
# Epoch 00152: val_output_loss did not improve from 0.16898
# Epoch 153/200
# 127/127 - 150s - loss: 0.6187 - decoder_loss: 0.3828 - ae_action_loss: 0.1262 - output_loss: 0.1096 - val_loss: 0.5241 - val_decoder_loss: 0.1795 - val_ae_action_loss: 0.1741 - val_output_loss: 0.1705
#
# Epoch 00153: val_output_loss did not improve from 0.16898
# Epoch 154/200
# 127/127 - 150s - loss: 0.6254 - decoder_loss: 0.3907 - ae_action_loss: 0.1258 - output_loss: 0.1090 - val_loss: 0.5207 - val_decoder_loss: 0.1723 - val_ae_action_loss: 0.1758 - val_output_loss: 0.1726
#
# Epoch 00154: val_output_loss did not improve from 0.16898
# Epoch 155/200
# 127/127 - 150s - loss: 0.6331 - decoder_loss: 0.3982 - ae_action_loss: 0.1257 - output_loss: 0.1092 - val_loss: 0.5180 - val_decoder_loss: 0.1721 - val_ae_action_loss: 0.1738 - val_output_loss: 0.1721
#
# Epoch 00155: val_output_loss did not improve from 0.16898
# Epoch 156/200
# 127/127 - 150s - loss: 0.6112 - decoder_loss: 0.3826 - ae_action_loss: 0.1227 - output_loss: 0.1059 - val_loss: 0.5196 - val_decoder_loss: 0.1714 - val_ae_action_loss: 0.1756 - val_output_loss: 0.1726
#
# Epoch 00156: val_output_loss did not improve from 0.16898
# Epoch 157/200
# 127/127 - 150s - loss: 0.6230 - decoder_loss: 0.3862 - ae_action_loss: 0.1267 - output_loss: 0.1102 - val_loss: 0.5192 - val_decoder_loss: 0.1728 - val_ae_action_loss: 0.1738 - val_output_loss: 0.1726
#
# Epoch 00157: val_output_loss did not improve from 0.16898
# Epoch 158/200
# 127/127 - 150s - loss: 0.6909 - decoder_loss: 0.4553 - ae_action_loss: 0.1263 - output_loss: 0.1093 - val_loss: 0.5199 - val_decoder_loss: 0.1763 - val_ae_action_loss: 0.1730 - val_output_loss: 0.1706
#
# Epoch 00158: val_output_loss did not improve from 0.16898
# Epoch 159/200
# 127/127 - 150s - loss: 0.6190 - decoder_loss: 0.3884 - ae_action_loss: 0.1236 - output_loss: 0.1070 - val_loss: 0.5290 - val_decoder_loss: 0.1703 - val_ae_action_loss: 0.1800 - val_output_loss: 0.1787
#
# Epoch 00159: val_output_loss did not improve from 0.16898
# Epoch 160/200
# 127/127 - 150s - loss: 0.6703 - decoder_loss: 0.4398 - ae_action_loss: 0.1238 - output_loss: 0.1067 - val_loss: 0.5169 - val_decoder_loss: 0.1696 - val_ae_action_loss: 0.1745 - val_output_loss: 0.1728
#
# Epoch 00160: ReduceLROnPlateau reducing learning rate to 0.00023730468819849193.
#
# Epoch 00160: val_output_loss did not improve from 0.16898
# Epoch 161/200
# 127/127 - 150s - loss: 0.6133 - decoder_loss: 0.3912 - ae_action_loss: 0.1198 - output_loss: 0.1023 - val_loss: 0.5115 - val_decoder_loss: 0.1710 - val_ae_action_loss: 0.1708 - val_output_loss: 0.1697
#
# Epoch 00161: val_output_loss did not improve from 0.16898
# Epoch 162/200
# 127/127 - 150s - loss: 0.6220 - decoder_loss: 0.4017 - ae_action_loss: 0.1191 - output_loss: 0.1013 - val_loss: 0.5155 - val_decoder_loss: 0.1696 - val_ae_action_loss: 0.1739 - val_output_loss: 0.1720
#
# Epoch 00162: val_output_loss did not improve from 0.16898
# Epoch 163/200
# 127/127 - 150s - loss: 0.6436 - decoder_loss: 0.4231 - ae_action_loss: 0.1191 - output_loss: 0.1013 - val_loss: 0.5119 - val_decoder_loss: 0.1661 - val_ae_action_loss: 0.1717 - val_output_loss: 0.1741
#
# Epoch 00163: val_output_loss did not improve from 0.16898
# Epoch 164/200
# 127/127 - 150s - loss: 0.6823 - decoder_loss: 0.4619 - ae_action_loss: 0.1193 - output_loss: 0.1011 - val_loss: 0.5107 - val_decoder_loss: 0.1696 - val_ae_action_loss: 0.1717 - val_output_loss: 0.1694
#
# Epoch 00164: val_output_loss did not improve from 0.16898
# Epoch 165/200
# 127/127 - 150s - loss: 0.5986 - decoder_loss: 0.3799 - ae_action_loss: 0.1185 - output_loss: 0.1002 - val_loss: 0.5071 - val_decoder_loss: 0.1670 - val_ae_action_loss: 0.1708 - val_output_loss: 0.1693
#
# Epoch 00165: val_output_loss did not improve from 0.16898
# Epoch 166/200
# ...
# Epoch 194/200
# 127/127 - 150s - loss: 0.5596 - decoder_loss: 0.3670 - ae_action_loss: 0.1058 - output_loss: 0.0868 - val_loss: 0.4958 - val_decoder_loss: 0.1562 - val_ae_action_loss: 0.1693 - val_output_loss: 0.1703
#
# Epoch 00194: ReduceLROnPlateau reducing learning rate to 0.0001334838816546835.
#
# Epoch 00194: val_output_loss did not improve from 0.16793
# Epoch 195/200
# 127/127 - 150s - loss: 0.5888 - decoder_loss: 0.3998 - ae_action_loss: 0.1041 - output_loss: 0.0849 - val_loss: 0.4940 - val_decoder_loss: 0.1553 - val_ae_action_loss: 0.1694 - val_output_loss: 0.1693
#
# Epoch 00195: val_output_loss did not improve from 0.16793
# Epoch 196/200
# 127/127 - 150s - loss: 0.5864 - decoder_loss: 0.3990 - ae_action_loss: 0.1035 - output_loss: 0.0839 - val_loss: 0.4949 - val_decoder_loss: 0.1546 - val_ae_action_loss: 0.1699 - val_output_loss: 0.1703
#
# Epoch 00196: val_output_loss did not improve from 0.16793
# Epoch 197/200
# 127/127 - 150s - loss: 0.5799 - decoder_loss: 0.3921 - ae_action_loss: 0.1037 - output_loss: 0.0841 - val_loss: 0.4918 - val_decoder_loss: 0.1538 - val_ae_action_loss: 0.1695 - val_output_loss: 0.1685
#
# Epoch 00197: val_output_loss did not improve from 0.16793
# Epoch 198/200
# 127/127 - 150s - loss: 0.5977 - decoder_loss: 0.4096 - ae_action_loss: 0.1039 - output_loss: 0.0842 - val_loss: 0.4989 - val_decoder_loss: 0.1542 - val_ae_action_loss: 0.1712 - val_output_loss: 0.1735
#
# Epoch 00198: val_output_loss did not improve from 0.16793
# Epoch 199/200
# 127/127 - 150s - loss: 0.5821 - decoder_loss: 0.3936 - ae_action_loss: 0.1040 - output_loss: 0.0845 - val_loss: 0.4920 - val_decoder_loss: 0.1540 - val_ae_action_loss: 0.1691 - val_output_loss: 0.1689
#
# Epoch 00199: val_output_loss did not improve from 0.16793
# Epoch 200/200
# 127/127 - 150s - loss: 0.5841 - decoder_loss: 0.3983 - ae_action_loss: 0.1025 - output_loss: 0.0832 - val_loss: 0.4930 - val_decoder_loss: 0.1541 - val_ae_action_loss: 0.1693 - val_output_loss: 0.1696
#
# Epoch 00200: val_output_loss did not improve from 0.16793
# Fold-1 | OOF Score: 0.16959694784227083
# 20__10 - MAE  0.18958046275757853, count: 25870
# 20__20 - MAE  0.16960937531364753, count: 26272
# 20__50 - MAE  0.1714088869810135, count: 34729
# 50__10 - MAE  0.17159657573233353, count: 60574
# 50__20 - MAE  0.2590598477978727, count: 37108
# 50__50 - MAE  0.26932839218852966, count: 34699
# 5__10 - MAE  0.16335297055531042, count: 36361
# 5__20 - MAE  0.11217990298083265, count: 35935
# 5__50 - MAE  0.12327488392594069, count: 35522
# Epoch 1/200
# 127/127 - 176s - loss: 118.9052 - decoder_loss: 114.2592 - ae_action_loss: 2.8777 - output_loss: 1.7683 - val_loss: 111.2064 - val_decoder_loss: 106.8455 - val_ae_action_loss: 1.8538 - val_output_loss: 2.5071
#
# Epoch 00001: val_output_loss improved from inf to 2.50713, saving model to ./model-gpu/Bidirect_LSTM_model_2C.h5
# /usr/local/lib/python3.7/dist-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# Epoch 2/200
# 127/127 - 150s - loss: 107.5126 - decoder_loss: 105.5082 - ae_action_loss: 1.1059 - output_loss: 0.8985 - val_loss: 98.7158 - val_decoder_loss: 96.1084 - val_ae_action_loss: 1.0246 - val_output_loss: 1.5828
#
# Epoch 00002: val_output_loss improved from 2.50713 to 1.58278, saving model to ./model-gpu/Bidirect_LSTM_model_2C.h5
# Epoch 3/200
# 127/127 - 150s - loss: 96.4983 - decoder_loss: 94.8084 - ae_action_loss: 0.9177 - output_loss: 0.7721 - val_loss: 87.6450 - val_decoder_loss: 85.8845 - val_ae_action_loss: 0.9576 - val_output_loss: 0.8028
#
# Epoch 00003: val_output_loss improved from 1.58278 to 0.80284, saving model to ./model-gpu/Bidirect_LSTM_model_2C.h5
# Epoch 4/200
# 127/127 - 150s - loss: 85.3963 - decoder_loss: 83.8625 - ae_action_loss: 0.8257 - output_loss: 0.7081 - val_loss: 78.7113 - val_decoder_loss: 76.3286 - val_ae_action_loss: 1.0327 - val_output_loss: 1.3501
#
# Epoch 00004: val_output_loss did not improve from 0.80284
# Epoch 5/200
# 127/127 - 150s - loss: 75.4152 - decoder_loss: 74.0443 - ae_action_loss: 0.7359 - output_loss: 0.6351 - val_loss: 69.1329 - val_decoder_loss: 67.8443 - val_ae_action_loss: 0.6982 - val_output_loss: 0.5905
#
# Epoch 00005: val_output_loss improved from 0.80284 to 0.59046, saving model to ./model-gpu/Bidirect_LSTM_model_2C.h5
# Epoch 6/200
# 127/127 - 150s - loss: 67.1227 - decoder_loss: 65.7207 - ae_action_loss: 0.7647 - output_loss: 0.6374 - val_loss: 61.7666 - val_decoder_loss: 60.4659 - val_ae_action_loss: 0.7385 - val_output_loss: 0.5622
#
# Epoch 00006: val_output_loss improved from 0.59046 to 0.56219, saving model to ./model-gpu/Bidirect_LSTM_model_2C.h5
# Epoch 7/200
# 127/127 - 150s - loss: 60.2352 - decoder_loss: 58.9583 - ae_action_loss: 0.6994 - output_loss: 0.5775 - val_loss: 56.2882 - val_decoder_loss: 54.6931 - val_ae_action_loss: 0.7526 - val_output_loss: 0.8424
#
# Epoch 00007: val_output_loss did not improve from 0.56219
# Epoch 8/200
# 127/127 - 150s - loss: 54.7055 - decoder_loss: 53.5625 - ae_action_loss: 0.6193 - output_loss: 0.5236 - val_loss: 50.9351 - val_decoder_loss: 49.8567 - val_ae_action_loss: 0.5222 - val_output_loss: 0.5562
#
# Epoch 00008: val_output_loss improved from 0.56219 to 0.55625, saving model to ./model-gpu/Bidirect_LSTM_model_2C.h5
# Epoch 9/200
# 127/127 - 150s - loss: 50.1844 - decoder_loss: 49.0542 - ae_action_loss: 0.6212 - output_loss: 0.5090 - val_loss: 46.8404 - val_decoder_loss: 45.8418 - val_ae_action_loss: 0.5267 - val_output_loss: 0.4718
#
# Epoch 00009: val_output_loss improved from 0.55625 to 0.47182, saving model to ./model-gpu/Bidirect_LSTM_model_2C.h5
# Epoch 10/200
# 127/127 - 150s - loss: 46.1480 - decoder_loss: 45.0436 - ae_action_loss: 0.6015 - output_loss: 0.5029 - val_loss: 43.4322 - val_decoder_loss: 42.0602 - val_ae_action_loss: 0.6472 - val_output_loss: 0.7248
#
# Epoch 00010: val_output_loss did not improve from 0.47182
# Epoch 11/200
# 127/127 - 150s - loss: 41.9349 - decoder_loss: 40.8454 - ae_action_loss: 0.5882 - output_loss: 0.5013 - val_loss: 39.2958 - val_decoder_loss: 37.8547 - val_ae_action_loss: 0.8017 - val_output_loss: 0.6394
#
# Epoch 00011: val_output_loss did not improve from 0.47182
# Epoch 12/200
# 127/127 - 150s - loss: 37.4772 - decoder_loss: 36.4758 - ae_action_loss: 0.5371 - output_loss: 0.4643 - val_loss: 34.3703 - val_decoder_loss: 33.3105 - val_ae_action_loss: 0.5669 - val_output_loss: 0.4930
#
# Epoch 00012: val_output_loss did not improve from 0.47182
# Epoch 13/200
# 127/127 - 150s - loss: 32.7862 - decoder_loss: 31.7729 - ae_action_loss: 0.5346 - output_loss: 0.4787 - val_loss: 29.6742 - val_decoder_loss: 28.5673 - val_ae_action_loss: 0.4935 - val_output_loss: 0.6134
#
# Epoch 00013: val_output_loss did not improve from 0.47182
# Epoch 14/200
# 127/127 - 150s - loss: 28.0443 - decoder_loss: 27.1043 - ae_action_loss: 0.5093 - output_loss: 0.4307 - val_loss: 25.3063 - val_decoder_loss: 24.1370 - val_ae_action_loss: 0.5729 - val_output_loss: 0.5964
#
# Epoch 00014: val_output_loss did not improve from 0.47182
# Epoch 15/200
# 127/127 - 150s - loss: 23.6120 - decoder_loss: 22.6829 - ae_action_loss: 0.5116 - output_loss: 0.4175 - val_loss: 20.9953 - val_decoder_loss: 20.2203 - val_ae_action_loss: 0.4005 - val_output_loss: 0.3746
#
# Epoch 00015: val_output_loss improved from 0.47182 to 0.37461, saving model to ./model-gpu/Bidirect_LSTM_model_2C.h5
# Epoch 16/200
# 127/127 - 150s - loss: 19.7995 - decoder_loss: 18.8325 - ae_action_loss: 0.5180 - output_loss: 0.4490 - val_loss: 17.5522 - val_decoder_loss: 16.6871 - val_ae_action_loss: 0.4711 - val_output_loss: 0.3940
#
# Epoch 00016: val_output_loss did not improve from 0.37461
# Epoch 17/200
# 127/127 - 150s - loss: 16.4981 - decoder_loss: 15.5778 - ae_action_loss: 0.5026 - output_loss: 0.4177 - val_loss: 14.4795 - val_decoder_loss: 13.5569 - val_ae_action_loss: 0.4695 - val_output_loss: 0.4530
#
# Epoch 00017: val_output_loss did not improve from 0.37461
# Epoch 18/200
# 127/127 - 150s - loss: 13.7894 - decoder_loss: 12.9352 - ae_action_loss: 0.4665 - output_loss: 0.3877 - val_loss: 12.9945 - val_decoder_loss: 11.4140 - val_ae_action_loss: 0.8468 - val_output_loss: 0.7337
#
# Epoch 00018: val_output_loss did not improve from 0.37461
# Epoch 19/200
# 127/127 - 150s - loss: 11.5938 - decoder_loss: 10.7506 - ae_action_loss: 0.4612 - output_loss: 0.3820 - val_loss: 10.4829 - val_decoder_loss: 9.4794 - val_ae_action_loss: 0.5751 - val_output_loss: 0.4284
#
# Epoch 00019: val_output_loss did not improve from 0.37461
# Epoch 20/200
# 127/127 - 150s - loss: 9.7930 - decoder_loss: 8.9845 - ae_action_loss: 0.4436 - output_loss: 0.3649 - val_loss: 8.7396 - val_decoder_loss: 8.0102 - val_ae_action_loss: 0.3774 - val_output_loss: 0.3520
#
# Epoch 00020: val_output_loss improved from 0.37461 to 0.35200, saving model to ./model-gpu/Bidirect_LSTM_model_2C.h5
# Epoch 21/200
# 127/127 - 150s - loss: 8.5750 - decoder_loss: 7.7707 - ae_action_loss: 0.4317 - output_loss: 0.3726 - val_loss: 7.8152 - val_decoder_loss: 6.7473 - val_ae_action_loss: 0.5442 - val_output_loss: 0.5237
#
# Epoch 00021: val_output_loss did not improve from 0.35200
# Epoch 22/200
# 127/127 - 150s - loss: 7.4519 - decoder_loss: 6.6315 - ae_action_loss: 0.4496 - output_loss: 0.3709 - val_loss: 6.4628 - val_decoder_loss: 5.7484 - val_ae_action_loss: 0.3709 - val_output_loss: 0.3435
#
# Epoch 00022: val_output_loss improved from 0.35200 to 0.34346, saving model to ./model-gpu/Bidirect_LSTM_model_2C.h5
# Epoch 23/200
# 127/127 - 150s - loss: 6.5452 - decoder_loss: 5.7834 - ae_action_loss: 0.4130 - output_loss: 0.3489 - val_loss: 5.7416 - val_decoder_loss: 4.9786 - val_ae_action_loss: 0.4302 - val_output_loss: 0.3328
#
# Epoch 00023: val_output_loss improved from 0.34346 to 0.33280, saving model to ./model-gpu/Bidirect_LSTM_model_2C.h5
# Epoch 24/200
# 127/127 - 150s - loss: 5.7670 - decoder_loss: 5.0234 - ae_action_loss: 0.4077 - output_loss: 0.3359 - val_loss: 5.0636 - val_decoder_loss: 4.3412 - val_ae_action_loss: 0.3893 - val_output_loss: 0.3331
#
# Epoch 00024: val_output_loss did not improve from 0.33280
# Epoch 25/200
# 127/127 - 150s - loss: 5.1254 - decoder_loss: 4.3986 - ae_action_loss: 0.3944 - output_loss: 0.3324 - val_loss: 4.4514 - val_decoder_loss: 3.7168 - val_ae_action_loss: 0.4375 - val_output_loss: 0.2970
#
# Epoch 00025: val_output_loss improved from 0.33280 to 0.29704, saving model to ./model-gpu/Bidirect_LSTM_model_2C.h5
# Epoch 26/200
# 127/127 - 150s - loss: 4.6250 - decoder_loss: 3.9101 - ae_action_loss: 0.3874 - output_loss: 0.3275 - val_loss: 3.9037 - val_decoder_loss: 3.2685 - val_ae_action_loss: 0.3308 - val_output_loss: 0.3044
#
# Epoch 00026: val_output_loss did not improve from 0.29704
# Epoch 27/200
# 127/127 - 150s - loss: 4.6299 - decoder_loss: 3.6410 - ae_action_loss: 0.5438 - output_loss: 0.4451 - val_loss: 3.6772 - val_decoder_loss: 2.9097 - val_ae_action_loss: 0.3888 - val_output_loss: 0.3787
#
# Epoch 00027: val_output_loss did not improve from 0.29704
# Epoch 28/200
# 127/127 - 150s - loss: 3.9246 - decoder_loss: 3.1879 - ae_action_loss: 0.4017 - output_loss: 0.3350 - val_loss: 3.2687 - val_decoder_loss: 2.5687 - val_ae_action_loss: 0.3936 - val_output_loss: 0.3064
#
# Epoch 00028: val_output_loss did not improve from 0.29704
# Epoch 29/200
# 127/127 - 150s - loss: 3.6157 - decoder_loss: 2.9235 - ae_action_loss: 0.3792 - output_loss: 0.3130 - val_loss: 3.0280 - val_decoder_loss: 2.2973 - val_ae_action_loss: 0.3916 - val_output_loss: 0.3391
#
# Epoch 00029: val_output_loss did not improve from 0.29704
# Epoch 30/200
# 127/127 - 150s - loss: 3.3639 - decoder_loss: 2.6493 - ae_action_loss: 0.3929 - output_loss: 0.3217 - val_loss: 2.8108 - val_decoder_loss: 2.0943 - val_ae_action_loss: 0.4057 - val_output_loss: 0.3109
#
# Epoch 00030: val_output_loss did not improve from 0.29704
# Epoch 31/200
# 127/127 - 150s - loss: 3.1026 - decoder_loss: 2.3988 - ae_action_loss: 0.3878 - output_loss: 0.3160 - val_loss: 2.6253 - val_decoder_loss: 1.9416 - val_ae_action_loss: 0.3599 - val_output_loss: 0.3239
#
# Epoch 00031: val_output_loss did not improve from 0.29704
# Epoch 32/200
# 127/127 - 150s - loss: 2.9221 - decoder_loss: 2.2266 - ae_action_loss: 0.3835 - output_loss: 0.3120 - val_loss: 2.6948 - val_decoder_loss: 1.7703 - val_ae_action_loss: 0.5485 - val_output_loss: 0.3760
#
# Epoch 00032: val_output_loss did not improve from 0.29704
# Epoch 33/200
# 127/127 - 150s - loss: 2.8137 - decoder_loss: 2.1590 - ae_action_loss: 0.3527 - output_loss: 0.3020 - val_loss: 2.5734 - val_decoder_loss: 1.7703 - val_ae_action_loss: 0.3917 - val_output_loss: 0.4113
#
# Epoch 00033: val_output_loss did not improve from 0.29704
# Epoch 34/200
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-c836213e5eb8> in <module>()
#      50                     verbose=VERBOSE,
#      51                     batch_size=BATCH_SIZE,
# ---> 52                     callbacks=[lr, chk_point, es])
#      53         else:
#      54           print('Load pretrain weight from ', checkpoint_name)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1182                 _r=1):
#    1183               callbacks.on_train_batch_begin(step)
# -> 1184               tmp_logs = self.train_function(iterator)
#    1185               if data_handler.should_sync:
#    1186                 context.async_wait()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     883
#     884       with OptionalXlaContext(self._jit_compile):
# --> 885         result = self._call(*args, **kwds)
#     886
#     887       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     915       # In this case we have created variables on the first call, so we run the
#     916       # defunned version which is guaranteed to never create variables.
# --> 917       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     918     elif self._stateful_fn is not None:
#     919       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    3038        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    3039     return graph_function._call_flat(
# -> 3040         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    3041
#    3042   @property
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1962       # No tape is watching; skip to running the function.
#    1963       return self._build_call_outputs(self._inference_function.call(
# -> 1964           ctx, args, cancellation_manager=cancellation_manager))
#    1965     forward_backward = self._select_forward_and_backward_functions(
#    1966         args,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     594               inputs=args,
#     595               attrs=attrs,
# --> 596               ctx=ctx)
#     597         else:
#     598           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# with tpu_strategy.scope():
#
#     VERBOSE = 2
#     EPOCHS = 200
#     FOLDS = 7
#     if DEBUG:
#       EPOCHS = 100
#     test_preds = []
#     kf = KFold(n_splits=FOLDS, shuffle=True, random_state=2021)
#     last_test_idx = []
#
#     for fold, (train_idx, test_idx) in enumerate(kf.split(train, targets)):
#         last_test_idx = test_idx
#         if len(test_preds) > fold:
#           print(f'Ignore corrent fold {fold+1} as we already predicted test data')
#
#         if DEBUG and fold > 0:
#           continue
#         X_train, X_valid = train[train_idx], train[test_idx]
#         y_train, y_valid = targets[train_idx], targets[test_idx]
#
#         model = dnn_model_GaussianNoise()
#         model.compile(optimizer="adam", loss="mae")
#
#         lr = ReduceLROnPlateau(monitor="val_loss", factor=0.75,
#                                patience=10, verbose=VERBOSE)
#         checkpoint_name = f'./model-gpu/Bidirect_LSTM_model_{fold+1}C.h5'
#         chk_point = ModelCheckpoint(checkpoint_name,
#                                     monitor='val_loss', verbose=VERBOSE,
#                                     save_best_only=True, mode='min')
#
#         es = EarlyStopping(monitor="val_loss", patience=50,
#                            verbose=VERBOSE, mode="min",
#                            restore_best_weights=True)
#
#         if fold not in skip_folds:
#           model.fit(X_train, y_train,
#                     validation_data=(X_valid, y_valid),
#                     epochs=EPOCHS,
#                     verbose=VERBOSE,
#                     batch_size=BATCH_SIZE,
#                     callbacks=[lr, chk_point, es])
#         else:
#           print('Load pretrain weight from ', checkpoint_name)
#           load_locally = tf.saved_model.LoadOptions(experimental_io_device='/job:localhost')
#           try:
#             # At loading time, register the custom objects with a `custom_object_scope`:
#             custom_objects = {"ScaleLayer": ScaleLayer}
#             with tf.keras.utils.custom_object_scope(custom_objects):
#                 model = load_model(checkpoint_name, options=load_locally)
#           except (OSError):
#             print('Cannot load pretrain weight from ', checkpoint_name)
#             break
#
#         y_true = y_valid.squeeze().reshape(-1, 1)
#         y_pred = model.predict(X_valid, batch_size=BATCH_SIZE).squeeze().reshape(-1, 1)
#         train_pred[test_idx] = y_pred.reshape(-1, 80)
#         score = mean_absolute_error(y_true, y_pred)
#         test_preds.append(model.predict(test, batch_size=BATCH_SIZE).squeeze().reshape(-1, 1).squeeze())
#
#         print(f"Fold-{fold+1} | OOF Score: {score}")
#
#         del X_train, X_valid, y_train, y_valid, model
#         reset_keras()
#         gc.collect()

# %%
if not DEBUG:
  train_pred = train_pred.flatten()
  targets = targets.flatten()
  score = mean_absolute_error(targets, train_pred)
  print(f"Train Score: {score}")

# %% [markdown]
# ## Create submission file

# %%
if not DEBUG:
  submission = pd.read_csv('../input/ventilator-pressure-prediction/sample_submission.csv')
  submission["pressure"] = sum(test_preds)/5
  submission.to_csv('submission.csv', index=False)

  # ENSEMBLE FOLDS WITH MEDIAN
  #取中位数
  submission["pressure"] = np.median(np.vstack(test_preds),axis=0)
  submission.to_csv('submission_median.csv', index=False)


  # ENSEMBLE FOLDS WITH MEDIAN AND ROUND PREDICTIONS
  submission["pressure"] =\
      np.round( (submission.pressure - pressure_min)/pressure_step ) * pressure_step + pressure_min
  submission.pressure = np.clip(submission.pressure, pressure_min, pressure_max)
  submission.to_csv('submission_median_round.csv', index=False)

# %% [markdown]
# # Analyze predict data

# %%
analy_predict(last_test_idx, train_pred)
