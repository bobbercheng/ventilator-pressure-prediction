# %% [markdown]
# <a href="https://colab.research.google.com/github/bobbercheng/ventilator-pressure-prediction/blob/master/ventilator_gb_rescaling_eda_V8_GPU.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# V1: Keep R/C, improve
#
# V2: Add R**2, no improve
#
# V3: Update model from https://www.kaggle.com/dlaststark/gb-vpp-pulp-fiction. Not much improve compare V1
#
# V4: Use whole db for test Fold-1
# Fold-1 | OOF Score: 0.15912771348961205
#
# V5: Add loading ScaleLayer from saved model
#
# V6: Add TransformerEncoder. TransformerEncoder(128, 512, 8, name="transformer_layer")(x). Testing in GPU.
#
# V7: Try to scale targe to 0-1, but it slow the train as MASE cannot be scaled.
#
# V8: Removed target scale.
# Epoch 00022: val_loss improved from 0.32912 to 0.30967, saving model to ./model-gpu/Bidirect_LSTM_model_1C.h5
# Epoch 23/150
# 127/127 [==============================] - 161s 1s/step - loss: 0.3176 - val_loss: 0.2917
#
# Not Good as without TransformerEncoder. Change paramemter back to
#
# V8: Change attention result to multiple instead of concate.
#
# Loss is smaller than without LayerNormalization, but CV is bigger. It means it overfit the train data.
#
# TransformerEncoder(128, 512, 8, 0.3, name="transformer_layer")
#
# Epoch 00181: val_loss did not improve from 0.16212
# Epoch 182/200
# 127/127 [==============================] - 163s 1s/step - loss: 0.0448 - val_loss: 0.1655
#
# Epoch 00182: ReduceLROnPlateau reducing learning rate to 5.6313510867767036e-05.
#
# Epoch 00182: val_loss did not improve from 0.16212
# Restoring model weights from the end of the best epoch.
# Epoch 00182: early stopping
# Fold-1 | OOF Score: 0.16211654680482343

# %%
# Update pandas version for Colab TPU
# !pip install pandas==1.3.2
# Out:
# Requirement already satisfied: pandas==1.3.2 in /usr/local/lib/python3.7/dist-packages (1.3.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas==1.3.2) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas==1.3.2) (2.8.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas==1.3.2) (1.19.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas==1.3.2) (1.15.0)

# %% [markdown]
# ## Import libraries

# %%
try:
  import google.colab
  IN_COLAB = True
except:
  IN_COLAB = False

# %%
if IN_COLAB:
  from google.colab import drive
  drive.mount("/gdrive", force_remount=True)
# Out:
# Mounted at /gdrive

# %%
if IN_COLAB:
  # !pip install kaggle
  # !mkdir /root/.kaggle
  # !cp /gdrive/MyDrive/ventilator-pressure-prediction/kaggle.json /root/.kaggle
  # !kaggle competitions download -c ventilator-pressure-prediction
  # !mkdir -p ../input/ventilator-pressure-prediction
  # !unzip '*.zip' -d ../input/ventilator-pressure-prediction
  # !ls ../input/ventilator-pressure-prediction
  # !mkdir /gdrive/MyDrive/ventilator-pressure-prediction/gb-rescaling-eda-v3-gpu
  #Map Google driver folder to local folder model to save model
  # !ln -s /gdrive/MyDrive/ventilator-pressure-prediction/gb-rescaling-eda-v3-gpu model-gpu
else:
  # !mkdir ./model-gpu
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.7/dist-packages (1.5.12)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from kaggle) (4.62.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from kaggle) (2021.5.30)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.15.0)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.7/dist-packages (from kaggle) (5.0.2)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.24.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.23.0)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.7/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (2.10)
# mkdir: cannot create directory ‘/root/.kaggle’: File exists
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.5.12 / client 1.5.4)
# test.csv.zip: Skipping, found more recently modified local copy (use --force to force download)
# train.csv.zip: Skipping, found more recently modified local copy (use --force to force download)
# sample_submission.csv.zip: Skipping, found more recently modified local copy (use --force to force download)
# Archive:  train.csv.zip
# replace ../input/ventilator-pressure-prediction/train.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: N
#
# Archive:  features.zip
#   inflating: ../input/ventilator-pressure-prediction/train.npy  N
# N
# N
#
#   inflating: ../input/ventilator-pressure-prediction/test.npy
#
# Archive:  sample_submission.csv.zip
#
# Archive:  test.csv.zip
#
# 4 archives were successfully processed.
# sample_submission.csv  test.csv  test.npy  train.csv  train.npy
# mkdir: cannot create directory ‘/gdrive/MyDrive/ventilator-pressure-prediction/gb-rescaling-eda-v3-gpu’: File exists
# ln: failed to create symbolic link 'model-gpu/gb-rescaling-eda-v3-gpu': File exists

# %%
import gc
import numpy as np
import pandas as pd
import random
import os
from sklearn.model_selection import KFold
from sklearn.preprocessing import RobustScaler, MinMaxScaler
from sklearn.metrics import mean_absolute_error

import tensorflow as tf
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
  tf.config.experimental.set_memory_growth(gpu, True)

from tensorflow.keras.utils import plot_model
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Dense, Dropout, Input
from tensorflow.keras.layers import Concatenate, LSTM, GRU
from tensorflow.keras.layers import Bidirectional, Multiply



# Random Seed Initialize
RANDOM_SEED = 42

def seed_everything(seed=RANDOM_SEED):
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    random.seed(seed)
    tf.random.set_seed(seed)
    
seed_everything()

# %% [markdown]
# ## Load datasets

# %%
train_df = pd.read_csv('../input/ventilator-pressure-prediction/train.csv')
print(f"train_df: {train_df.shape}")
train_df.head()
# Out:
# train_df: (6036000, 8)
#    id  breath_id   R   C  time_step       u_in  u_out   pressure
# 0   1          1  20  50   0.000000   0.083334      0   5.837492
# 1   2          1  20  50   0.033652  18.383041      0   5.907794
# 2   3          1  20  50   0.067514  22.509278      0   7.876254
# 3   4          1  20  50   0.101542  22.808822      0  11.742872
# 4   5          1  20  50   0.135756  25.355850      0  12.234987

# %%
all_pressure = np.sort(train_df['pressure'].unique())
pressure_min =  all_pressure[0].item()
pressure_max = all_pressure[-1].item()
pressure_step = (all_pressure[1] - all_pressure[0]).item()

pressure_min,pressure_max,pressure_step

# %%
DEBUG = False

if DEBUG:
    train_df = train_df[:80*10000]

# %%
test_df = pd.read_csv('../input/ventilator-pressure-prediction/test.csv')
print(f"test_df: {test_df.shape}")
test_df.head()
# Out:
# test_df: (4024000, 7)
#    id  breath_id  R   C  time_step       u_in  u_out
# 0   1          0  5  20   0.000000   0.000000      0
# 1   2          0  5  20   0.031904   7.515046      0
# 2   3          0  5  20   0.063827  14.651675      0
# 3   4          0  5  20   0.095751  21.230610      0
# 4   5          0  5  20   0.127644  26.320956      0

# %% [markdown]
# ## Feature Engineering

# %%
def add_features(df):
    df['cross']= df['u_in'] * df['u_out']
    df['cross2']= df['time_step'] * df['u_out']
    df['area'] = df['time_step'] * df['u_in']
    df['area'] = df.groupby('breath_id')['area'].cumsum()
    df['time_step_cumsum'] = df.groupby(['breath_id'])['time_step'].cumsum()
    df['u_in_cumsum'] = (df['u_in']).groupby(df['breath_id']).cumsum()
    print("Step-1...Completed")
    
    df['u_in_lag1'] = df.groupby('breath_id')['u_in'].shift(1)
    df['u_out_lag1'] = df.groupby('breath_id')['u_out'].shift(1)
    df['u_in_lag_back1'] = df.groupby('breath_id')['u_in'].shift(-1)
    df['u_out_lag_back1'] = df.groupby('breath_id')['u_out'].shift(-1)
    df['u_in_lag2'] = df.groupby('breath_id')['u_in'].shift(2)
    df['u_out_lag2'] = df.groupby('breath_id')['u_out'].shift(2)
    df['u_in_lag_back2'] = df.groupby('breath_id')['u_in'].shift(-2)
    df['u_out_lag_back2'] = df.groupby('breath_id')['u_out'].shift(-2)
    df['u_in_lag3'] = df.groupby('breath_id')['u_in'].shift(3)
    df['u_out_lag3'] = df.groupby('breath_id')['u_out'].shift(3)
    df['u_in_lag_back3'] = df.groupby('breath_id')['u_in'].shift(-3)
    df['u_out_lag_back3'] = df.groupby('breath_id')['u_out'].shift(-3)
    df['u_in_lag4'] = df.groupby('breath_id')['u_in'].shift(4)
    df['u_out_lag4'] = df.groupby('breath_id')['u_out'].shift(4)
    df['u_in_lag_back4'] = df.groupby('breath_id')['u_in'].shift(-4)
    df['u_out_lag_back4'] = df.groupby('breath_id')['u_out'].shift(-4)
    df = df.fillna(0)
    print("Step-2...Completed")
    
    df['breath_id__u_in__max'] = df.groupby(['breath_id'])['u_in'].transform('max')
    df['breath_id__u_out__max'] = df.groupby(['breath_id'])['u_out'].transform('max')
    df['breath_id__u_in__diffmax'] = df.groupby(['breath_id'])['u_in'].transform('max') - df['u_in']
    df['breath_id__u_in__diffmean'] = df.groupby(['breath_id'])['u_in'].transform('mean') - df['u_in']
    df['breath_id__u_in__diffmax'] = df.groupby(['breath_id'])['u_in'].transform('max') - df['u_in']
    df['breath_id__u_in__diffmean'] = df.groupby(['breath_id'])['u_in'].transform('mean') - df['u_in']
    print("Step-3...Completed")
    
    df['u_in_diff1'] = df['u_in'] - df['u_in_lag1']
    df['u_out_diff1'] = df['u_out'] - df['u_out_lag1']
    df['u_in_diff2'] = df['u_in'] - df['u_in_lag2']
    df['u_out_diff2'] = df['u_out'] - df['u_out_lag2']
    df['u_in_diff3'] = df['u_in'] - df['u_in_lag3']
    df['u_out_diff3'] = df['u_out'] - df['u_out_lag3']
    df['u_in_diff4'] = df['u_in'] - df['u_in_lag4']
    df['u_out_diff4'] = df['u_out'] - df['u_out_lag4']
    print("Step-4...Completed")
    
    df['one'] = 1
    df['count'] = (df['one']).groupby(df['breath_id']).cumsum()
    df['u_in_cummean'] =df['u_in_cumsum'] /df['count']
    
    df['breath_id_lag']=df['breath_id'].shift(1).fillna(0)
    df['breath_id_lag2']=df['breath_id'].shift(2).fillna(0)
    df['breath_id_lagsame']=np.select([df['breath_id_lag']==df['breath_id']],[1],0)
    df['breath_id_lag2same']=np.select([df['breath_id_lag2']==df['breath_id']],[1],0)
    df['breath_id__u_in_lag'] = df['u_in'].shift(1).fillna(0)
    df['breath_id__u_in_lag'] = df['breath_id__u_in_lag'] * df['breath_id_lagsame']
    df['breath_id__u_in_lag2'] = df['u_in'].shift(2).fillna(0)
    df['breath_id__u_in_lag2'] = df['breath_id__u_in_lag2'] * df['breath_id_lag2same']
    print("Step-5...Completed")
    
    df['time_step_diff'] = df.groupby('breath_id')['time_step'].diff().fillna(0)
    df['ewm_u_in_mean'] = (df\
                           .groupby('breath_id')['u_in']\
                           .ewm(halflife=9)\
                           .mean()\
                           .reset_index(level=0,drop=True))
    df[["15_in_sum","15_in_min","15_in_max","15_in_mean"]] = (df\
                                                              .groupby('breath_id')['u_in']\
                                                              .rolling(window=15,min_periods=1)\
                                                              .agg({"15_in_sum":"sum",
                                                                    "15_in_min":"min",
                                                                    "15_in_max":"max",
                                                                    "15_in_mean":"mean"
                                                                    #"15_in_std":"std"
                                                               })\
                                                               .reset_index(level=0,drop=True))
    print("Step-6...Completed")
    
    #df['u_in_diff_1_2'] = df['u_in_lag1'] - df['u_in_lag2']
    #df['u_out_diff_1_2'] = df['u_out_lag1'] - df['u_out_lag2']
    #df['u_in_lagback_diff_1_2'] = df['u_in_lag_back1'] - df['u_in_lag_back2']
    #df['u_out_lagback_diff_1_2'] = df['u_out_lag_back1'] - df['u_out_lag_back2']
    
    df['u_in_lagback_diff1'] = df['u_in'] - df['u_in_lag_back1']
    df['u_out_lagback_diff1'] = df['u_out'] - df['u_out_lag_back1']
    df['u_in_lagback_diff2'] = df['u_in'] - df['u_in_lag_back2']
    df['u_out_lagback_diff2'] = df['u_out'] - df['u_out_lag_back2']
    print("Step-7...Completed")
    
    df['R_cat'] = df['R'].astype(str)
    df['C_cat'] = df['C'].astype(str)
    df['R__C'] = df["R"].astype(str) + '__' + df["C"].astype(str)
    df = pd.get_dummies(df)
    print("Step-8...Completed")
    
    return df


print("Train data...\n")
train = add_features(train_df)

print("\nTest data...\n")
test = add_features(test_df)
# Out:
# Train data...
#
# Step-1...Completed
# Step-2...Completed
# Step-3...Completed
# Step-4...Completed
# Step-5...Completed
# Step-6...Completed
# Step-7...Completed
# Step-8...Completed
#
# Test data...
#
# Step-1...Completed
# Step-2...Completed
# Step-3...Completed
# Step-4...Completed
# Step-5...Completed
# Step-6...Completed
# Step-7...Completed
# Step-8...Completed

# %%
train.head()
# Out:
#    id  breath_id   R   C  ...  R__C_50__50  R__C_5__10  R__C_5__20  R__C_5__50
# 0   1          1  20  50  ...            0           0           0           0
# 1   2          1  20  50  ...            0           0           0           0
# 2   3          1  20  50  ...            0           0           0           0
# 3   4          1  20  50  ...            0           0           0           0
# 4   5          1  20  50  ...            0           0           0           0
#
# [5 rows x 75 columns]

# %%
del train_df
del test_df
gc.collect()
# Out:
# 50

# %%
targets = train[['pressure']].to_numpy().reshape(-1, 80)

train.drop(['pressure','id', 'breath_id','one','count',
            'breath_id_lag','breath_id_lag2','breath_id_lagsame',
            'breath_id_lag2same'], axis=1, inplace=True)

test = test.drop(['id', 'breath_id','one','count','breath_id_lag',
                  'breath_id_lag2','breath_id_lagsame',
                  'breath_id_lag2same'], axis=1)

print(f"train: {train.shape} \ntest: {test.shape}")
# Out:
# train: (6036000, 66)
# test: (4024000, 66)

# %%
scaler = RobustScaler()
train = scaler.fit_transform(train)
test = scaler.transform(test)

train = train.reshape(-1, 80, train.shape[-1])
test = test.reshape(-1, 80, train.shape[-1])

print(f"train: {train.shape} \ntest: {test.shape} \ntargets: {targets.shape}")
# Out:
# train: (75450, 80, 66)
# test: (50300, 80, 66)
# targets: (75450, 80)

# %%
# np.save('train.npy', train)
# np.save('test.npy', test)
# !zip features.zip train.npy test.npy

# %% [markdown]
# ## Hardware config

# %%
try:
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
    tf.config.experimental_connect_to_cluster(tpu)
    tf.tpu.experimental.initialize_tpu_system(tpu)
    tpu_strategy = tf.distribute.experimental.TPUStrategy(tpu)
    BATCH_SIZE = tpu_strategy.num_replicas_in_sync * 64
    print("Running on TPU:", tpu.master())
    print(f"Batch Size: {BATCH_SIZE}")
    
except ValueError:
    tpu_strategy = tf.distribute.get_strategy()
    BATCH_SIZE = 512
    print(f"Running on {tpu_strategy.num_replicas_in_sync} replicas")
    print(f"Batch Size: {BATCH_SIZE}")
# Out:
# Running on 1 replicas
# Batch Size: 512

# %% [markdown]
# ## Rescaling layer

# %%
@tf.custom_gradient
def round_with_gradients(x):
    def grad(dy):
        return dy
    return tf.round(x), grad

class ScaleLayer(tf.keras.layers.Layer):
    def __init__(self, **kwargs):
        super(ScaleLayer, self).__init__(**kwargs)
        self.min = tf.constant(pressure_min, dtype=np.float32)
        self.max = tf.constant(pressure_max, dtype=np.float32)
        self.step = tf.constant(pressure_step, dtype=np.float32)

    def call(self, inputs):
        steps = tf.math.divide(tf.math.add(inputs, -self.min), self.step)
        int_steps = round_with_gradients(steps)
        rescaled_steps = tf.math.add(tf.math.multiply(int_steps, self.step), self.min)
        clipped = tf.clip_by_value(rescaled_steps, self.min, self.max)
        return clipped
    # def get_config(self):
    #     return super(ScaleLayer, self).get_config()

# %%
class TransformerEncoder(tf.keras.layers.Layer):
    def __init__(self, embed_dim, dense_dim, num_heads, dropout=0.3, **kwargs):
        super().__init__(**kwargs)
        self.embed_dim = embed_dim
        self.dense_dim = dense_dim
        self.num_heads = num_heads
        self.attention_dropout = dropout
        self.attention = tf.keras.layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim, dropout=0.3
        )
        self.dense_proj = tf.keras.Sequential(
            [tf.keras.layers.Dense(dense_dim, activation=tf.nn.gelu), tf.keras.layers.Dense(embed_dim),]
        )
        self.layernorm_1 = tf.keras.layers.LayerNormalization()
        self.layernorm_2 = tf.keras.layers.LayerNormalization()

    def call(self, inputs, mask=None):
        if mask is not None:
            mask = mask[:, tf.newaxis, :]

        attention_output = self.attention(inputs, inputs, attention_mask=mask)
        proj_input = self.layernorm_1(inputs + attention_output)
        proj_output = self.dense_proj(proj_input)
        return self.layernorm_2(proj_input + proj_output)
    def get_config(self):
        config = super(TransformerEncoder, self).get_config()
        config.update({"embed_dim": self.embed_dim,
            "dense_dim": self.dense_dim,
            "num_heads": self.num_heads})
        return config

# %% [markdown]
# ## Keras DNN Model

# %%
def dnn_model():
    
    x_input = Input(shape=(train.shape[-2:]))
    
    x1 = Bidirectional(LSTM(units=768, return_sequences=True))(x_input)
    x2 = Bidirectional(LSTM(units=512, return_sequences=True))(x1)
    x3 = Bidirectional(LSTM(units=384, return_sequences=True))(x2)
    x4 = Bidirectional(LSTM(units=256, return_sequences=True))(x3)
    x5 = Bidirectional(LSTM(units=128, return_sequences=True))(x4)
    
    z2 = Bidirectional(GRU(units=384, return_sequences=True))(x2)
    
    z31 = Multiply()([x3, z2])
    z31 = BatchNormalization()(z31)
    z3 = Bidirectional(GRU(units=256, return_sequences=True))(z31)
    
    z41 = Multiply()([x4, z3])
    z41 = BatchNormalization()(z41)
    z4 = Bidirectional(GRU(units=128, return_sequences=True))(z41)
    
    z51 = Multiply()([x5, z4])
    z51 = BatchNormalization()(z51)
    z5 = Bidirectional(GRU(units=64, return_sequences=True))(z51)
    
    x = Concatenate(axis=2)([x5, z2, z3, z4, z5])

    x = Dense(units=128)(x)

    x_transformer = BatchNormalization()(x)
    x_transformer = TransformerEncoder(128, 512, 8, 0.3, name="transformer_layer")(x_transformer)
    x = Multiply()([x, x_transformer])
    
    x = Dense(units=128, activation='selu')(x)
    
    x_output = Dense(units=1)(x)
    
    x_output = ScaleLayer()(x_output)

    model = Model(inputs=x_input, outputs=x_output, 
                  name='DNN_Model')
    return model

# %%
model = dnn_model()
model.summary()
# Out:
# Model: "DNN_Model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 80, 66)]     0
# __________________________________________________________________________________________________
# bidirectional (Bidirectional)   (None, 80, 1536)     5130240     input_1[0][0]
# __________________________________________________________________________________________________
# bidirectional_1 (Bidirectional) (None, 80, 1024)     8392704     bidirectional[0][0]
# __________________________________________________________________________________________________
# bidirectional_2 (Bidirectional) (None, 80, 768)      4328448     bidirectional_1[0][0]
# __________________________________________________________________________________________________
# bidirectional_5 (Bidirectional) (None, 80, 768)      3248640     bidirectional_1[0][0]
# __________________________________________________________________________________________________
# multiply (Multiply)             (None, 80, 768)      0           bidirectional_2[0][0]
#                                                                  bidirectional_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 80, 768)      3072        multiply[0][0]
# __________________________________________________________________________________________________
# bidirectional_3 (Bidirectional) (None, 80, 512)      2099200     bidirectional_2[0][0]
# __________________________________________________________________________________________________
# bidirectional_6 (Bidirectional) (None, 80, 512)      1575936     batch_normalization[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 80, 512)      0           bidirectional_3[0][0]
#                                                                  bidirectional_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 80, 512)      2048        multiply_1[0][0]
# __________________________________________________________________________________________________
# bidirectional_4 (Bidirectional) (None, 80, 256)      656384      bidirectional_3[0][0]
# __________________________________________________________________________________________________
# bidirectional_7 (Bidirectional) (None, 80, 256)      493056      batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 80, 256)      0           bidirectional_4[0][0]
#                                                                  bidirectional_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 80, 256)      1024        multiply_2[0][0]
# __________________________________________________________________________________________________
# bidirectional_8 (Bidirectional) (None, 80, 128)      123648      batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 80, 1920)     0           bidirectional_4[0][0]
#                                                                  bidirectional_5[0][0]
#                                                                  bidirectional_6[0][0]
#                                                                  bidirectional_7[0][0]
#                                                                  bidirectional_8[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 80, 128)      245888      concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 80, 128)      512         dense[0][0]
# __________________________________________________________________________________________________
# transformer_layer (TransformerE (None, 80, 128)      659712      batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# multiply_3 (Multiply)           (None, 80, 128)      0           dense[0][0]
#                                                                  transformer_layer[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 80, 128)      16512       multiply_3[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 80, 1)        129         dense_3[0][0]
# __________________________________________________________________________________________________
# scale_layer (ScaleLayer)        (None, 80, 1)        0           dense_4[0][0]
# ==================================================================================================
# Total params: 26,977,153
# Trainable params: 26,973,825
# Non-trainable params: 3,328
# __________________________________________________________________________________________________

# %%
plot_model(
    model, 
    to_file='Google_Brain_Keras_Model.png', 
    show_shapes=True,
    show_layer_names=True
)

# %%
del model
gc.collect()
# Out:
# 22831

# %%
#reset Keras Session
def reset_keras():
    sess = tf.compat.v1.keras.backend.get_session()
    tf.compat.v1.keras.backend.clear_session()
    sess.close()
    sess = tf.compat.v1.keras.backend.get_session()

    # use the same config as you used to create the session
    config = tf.compat.v1.ConfigProto()
    config.gpu_options.per_process_gpu_memory_fraction = 1
    config.gpu_options.visible_device_list = "0"
    tf.compat.v1.keras.backend.set_session(tf.compat.v1.Session(config=config))
    gc.collect()

reset_keras()

# %%
train_pred = np.zeros(targets.shape)

# %%
#skip_folds = np.arange(1)
skip_folds = []

# %%
with tpu_strategy.scope():
    
    VERBOSE = 1
    EPOCHS = 200
    FOLDS = 7
    if DEBUG:
      EPOCHS = 100
    test_preds = []
    kf = KFold(n_splits=FOLDS, shuffle=True, random_state=2021)
    
    for fold, (train_idx, test_idx) in enumerate(kf.split(train, targets)):
        if len(test_preds) > fold:
          print(f'Ignore corrent fold {fold+1} as we already predicted test data')

        if DEBUG and fold > 0:
          continue
        X_train, X_valid = train[train_idx], train[test_idx]
        y_train, y_valid = targets[train_idx], targets[test_idx]
        
        model = dnn_model()
        model.compile(optimizer="adam", loss="mae")

        lr = ReduceLROnPlateau(monitor="val_loss", factor=0.75, 
                               patience=10, verbose=VERBOSE)
        checkpoint_name = f'./model-gpu/Bidirect_LSTM_model_{fold+1}C.h5'
        chk_point = ModelCheckpoint(checkpoint_name,
                                    monitor='val_loss', verbose=VERBOSE, 
                                    save_best_only=True, mode='min')

        es = EarlyStopping(monitor="val_loss", patience=50, 
                           verbose=VERBOSE, mode="min", 
                           restore_best_weights=True)
        
        if fold not in skip_folds:
          model.fit(X_train, y_train, 
                    validation_data=(X_valid, y_valid), 
                    epochs=EPOCHS,
                    verbose=VERBOSE,
                    batch_size=BATCH_SIZE, 
                    callbacks=[lr, chk_point, es])
        else:
          print('Load pretrain weight from ', checkpoint_name)
          load_locally = tf.saved_model.LoadOptions(experimental_io_device='/job:localhost')
          try:
            # At loading time, register the custom objects with a `custom_object_scope`:
            custom_objects = {"ScaleLayer": ScaleLayer}
            with tf.keras.utils.custom_object_scope(custom_objects):
                model = load_model(checkpoint_name, options=load_locally)
          except (OSError):
            print('Cannot load pretrain weight from ', checkpoint_name)
            break
                
        y_true = y_valid.squeeze().reshape(-1, 1)
        y_pred = model.predict(X_valid, batch_size=BATCH_SIZE).squeeze().reshape(-1, 1)
        train_pred[test_idx] = y_pred.reshape(-1, 80)
        score = mean_absolute_error(y_true, y_pred)
        test_preds.append(model.predict(test, batch_size=BATCH_SIZE).squeeze().reshape(-1, 1).squeeze())

        print(f"Fold-{fold+1} | OOF Score: {score}")
        
        del X_train, X_valid, y_train, y_valid, model
        reset_keras()
        gc.collect()
# Out:
# Epoch 1/200
# 127/127 [==============================] - 199s 1s/step - loss: 1.4014 - val_loss: 1.5946
#
# Epoch 00001: val_loss improved from inf to 1.59460, saving model to ./model-gpu/Bidirect_LSTM_model_1C.h5
# /usr/local/lib/python3.7/dist-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# Epoch 2/200
# 127/127 [==============================] - 161s 1s/step - loss: 0.6075 - val_loss: 0.8406
#
# Epoch 00002: val_loss improved from 1.59460 to 0.84064, saving model to ./model-gpu/Bidirect_LSTM_model_1C.h5
# Epoch 3/200
# 127/127 [==============================] - 161s 1s/step - loss: 0.5435 - val_loss: 0.9137
#
# Epoch 00003: val_loss did not improve from 0.84064
# Epoch 4/200
# 127/127 [==============================] - 161s 1s/step - loss: 0.4927 - val_loss: 0.5022
#
# Epoch 00004: val_loss improved from 0.84064 to 0.50222, saving model to ./model-gpu/Bidirect_LSTM_model_1C.h5
# Epoch 5/200
# 127/127 [==============================] - 162s 1s/step - loss: 0.4673 - val_loss: 0.6438
#
# Epoch 00005: val_loss did not improve from 0.50222
# Epoch 6/200
# 127/127 [==============================] - 161s 1s/step - loss: 0.4613 - val_loss: 0.5085
#
# Epoch 00006: val_loss did not improve from 0.50222
# Epoch 7/200
# 127/127 [==============================] - 162s 1s/step - loss: 0.4261 - val_loss: 0.4284
#
# Epoch 00007: val_loss improved from 0.50222 to 0.42835, saving model to ./model-gpu/Bidirect_LSTM_model_1C.h5
# Epoch 8/200
# 127/127 [==============================] - 161s 1s/step - loss: 0.3988 - val_loss: 0.3771
#
# Epoch 00008: val_loss improved from 0.42835 to 0.37713, saving model to ./model-gpu/Bidirect_LSTM_model_1C.h5
# Epoch 9/200
# 127/127 [==============================] - 161s 1s/step - loss: 0.4065 - val_loss: 0.3854
#
# Epoch 00009: val_loss did not improve from 0.37713
# Epoch 10/200
# 127/127 [==============================] - 161s 1s/step - loss: 0.4075 - val_loss: 0.3849
#
# Epoch 00010: val_loss did not improve from 0.37713
# Epoch 11/200
# 127/127 [==============================] - 161s 1s/step - loss: 0.3531 - val_loss: 0.3331
#
# Epoch 00011: val_loss improved from 0.37713 to 0.33308, saving model to ./model-gpu/Bidirect_LSTM_model_1C.h5
# Epoch 12/200
# 127/127 [==============================] - 161s 1s/step - loss: 0.3436 - val_loss: 0.3283
#
# Epoch 00012: val_loss improved from 0.33308 to 0.32833, saving model to ./model-gpu/Bidirect_LSTM_model_1C.h5
# Epoch 13/200
# 127/127 [==============================] - 161s 1s/step - loss: 0.3515 - val_loss: 0.5256
#
# Epoch 00013: val_loss did not improve from 0.32833
# Epoch 14/200
# 127/127 [==============================] - 161s 1s/step - loss: 0.3322 - val_loss: 0.3758
#
# Epoch 00014: val_loss did not improve from 0.32833
# Epoch 15/200
# 127/127 [==============================] - 161s 1s/step - loss: 0.3180 - val_loss: 0.3818
#
# Epoch 00015: val_loss did not improve from 0.32833
# Epoch 16/200
# 127/127 [==============================] - 161s 1s/step - loss: 0.3216 - val_loss: 0.3306
#
# Epoch 00016: val_loss did not improve from 0.32833
# Epoch 17/200
# 127/127 [==============================] - 161s 1s/step - loss: 0.3024 - val_loss: 0.3977
#
# Epoch 00017: val_loss did not improve from 0.32833
# Epoch 18/200
# 127/127 [==============================] - 161s 1s/step - loss: 0.3083 - val_loss: 0.2980
#
# Epoch 00018: val_loss improved from 0.32833 to 0.29797, saving model to ./model-gpu/Bidirect_LSTM_model_1C.h5
# Epoch 19/200
# 127/127 [==============================] - 161s 1s/step - loss: 0.2886 - val_loss: 0.3006
#
# Epoch 00019: val_loss did not improve from 0.29797
# Epoch 20/200
# 127/127 [==============================] - 161s 1s/step - loss: 0.2779 - val_loss: 0.3142
#
# Epoch 00020: val_loss did not improve from 0.29797
# Epoch 21/200
# 127/127 [==============================] - 161s 1s/step - loss: 0.2873 - val_loss: 0.3195
#
# Epoch 00021: val_loss did not improve from 0.29797
# Epoch 22/200
# 127/127 [==============================] - 161s 1s/step - loss: 0.2778 - val_loss: 0.3022
#
# Epoch 00022: val_loss did not improve from 0.29797
# Epoch 23/200
# 127/127 [==============================] - 161s 1s/step - loss: 0.2647 - val_loss: 0.2591
#
# Epoch 00023: val_loss improved from 0.29797 to 0.25913, saving model to ./model-gpu/Bidirect_LSTM_model_1C.h5
# Epoch 24/200
# 127/127 [==============================] - 161s 1s/step - loss: 0.2570 - val_loss: 0.2762
#
# Epoch 00024: val_loss did not improve from 0.25913
# Epoch 25/200
# 127/127 [==============================] - 161s 1s/step - loss: 0.2587 - val_loss: 0.2662
#
# Epoch 00025: val_loss did not improve from 0.25913
# Epoch 26/200
# 127/127 [==============================] - 161s 1s/step - loss: 0.2635 - val_loss: 0.2732
#
# Epoch 00026: val_loss did not improve from 0.25913
# Epoch 27/200
# 127/127 [==============================] - 161s 1s/step - loss: 0.2702 - val_loss: 0.2815
#
# Epoch 00027: val_loss did not improve from 0.25913
# Epoch 28/200
# 127/127 [==============================] - 161s 1s/step - loss: 0.2505 - val_loss: 0.2708
#
# Epoch 00028: val_loss did not improve from 0.25913
# Epoch 29/200
# 127/127 [==============================] - 161s 1s/step - loss: 0.2559 - val_loss: 0.2681
#
# Epoch 00029: val_loss did not improve from 0.25913
# Epoch 30/200
# 127/127 [==============================] - 161s 1s/step - loss: 0.2577 - val_loss: 0.2633
#
# Epoch 00030: val_loss did not improve from 0.25913
# Epoch 31/200
# 127/127 [==============================] - 161s 1s/step - loss: 0.2563 - val_loss: 0.2539
#
# Epoch 00031: val_loss improved from 0.25913 to 0.25389, saving model to ./model-gpu/Bidirect_LSTM_model_1C.h5
# Epoch 32/200
# 127/127 [==============================] - 161s 1s/step - loss: 0.2497 - val_loss: 0.2458
#
# Epoch 00032: val_loss improved from 0.25389 to 0.24584, saving model to ./model-gpu/Bidirect_LSTM_model_1C.h5
# Epoch 33/200
# 127/127 [==============================] - 161s 1s/step - loss: 0.2467 - val_loss: 0.2580
#
# Epoch 00033: val_loss did not improve from 0.24584
# Epoch 34/200
# 127/127 [==============================] - 161s 1s/step - loss: 0.2388 - val_loss: 0.2380
#
# Epoch 00034: val_loss improved from 0.24584 to 0.23799, saving model to ./model-gpu/Bidirect_LSTM_model_1C.h5
# Epoch 35/200
# 127/127 [==============================] - 161s 1s/step - loss: 0.2317 - val_loss: 0.2398
#
# Epoch 00035: val_loss did not improve from 0.23799
# Epoch 36/200
# 127/127 [==============================] - 161s 1s/step - loss: 0.2281 - val_loss: 0.2392
#
# Epoch 00036: val_loss did not improve from 0.23799
# Epoch 37/200
# 127/127 [==============================] - 161s 1s/step - loss: 0.2323 - val_loss: 0.2668
#
# Epoch 00037: val_loss did not improve from 0.23799
# Epoch 38/200
# 127/127 [==============================] - 161s 1s/step - loss: 0.2282 - val_loss: 0.2736
#
# Epoch 00038: val_loss did not improve from 0.23799
# Epoch 39/200
# 127/127 [==============================] - 162s 1s/step - loss: 0.2359 - val_loss: 0.2325
#
# Epoch 00039: val_loss improved from 0.23799 to 0.23247, saving model to ./model-gpu/Bidirect_LSTM_model_1C.h5
# Epoch 40/200
# 127/127 [==============================] - 161s 1s/step - loss: 0.2382 - val_loss: 0.2294
#
# Epoch 00040: val_loss improved from 0.23247 to 0.22945, saving model to ./model-gpu/Bidirect_LSTM_model_1C.h5
# Epoch 41/200
# 127/127 [==============================] - 161s 1s/step - loss: 0.2327 - val_loss: 0.2400
#
# Epoch 00041: val_loss did not improve from 0.22945
# Epoch 42/200
# 127/127 [==============================] - 161s 1s/step - loss: 0.2248 - val_loss: 0.2437
#
# Epoch 00042: val_loss did not improve from 0.22945
# Epoch 43/200
# 127/127 [==============================] - 161s 1s/step - loss: 0.2263 - val_loss: 0.2445
#
# Epoch 00043: val_loss did not improve from 0.22945
# Epoch 44/200
# 127/127 [==============================] - 162s 1s/step - loss: 0.2274 - val_loss: 0.2333
#
# Epoch 00044: val_loss did not improve from 0.22945
# Epoch 45/200
# 127/127 [==============================] - 161s 1s/step - loss: 0.2192 - val_loss: 0.2208
#
# Epoch 00045: val_loss improved from 0.22945 to 0.22082, saving model to ./model-gpu/Bidirect_LSTM_model_1C.h5
# Epoch 46/200
# 127/127 [==============================] - 161s 1s/step - loss: 0.2114 - val_loss: 0.2296
#
# Epoch 00046: val_loss did not improve from 0.22082
# Epoch 47/200
# 127/127 [==============================] - 161s 1s/step - loss: 0.2029 - val_loss: 0.2141
#
# Epoch 00047: val_loss improved from 0.22082 to 0.21408, saving model to ./model-gpu/Bidirect_LSTM_model_1C.h5
# Epoch 48/200
# 127/127 [==============================] - 161s 1s/step - loss: 0.2018 - val_loss: 0.2136
#
# Epoch 00048: val_loss improved from 0.21408 to 0.21356, saving model to ./model-gpu/Bidirect_LSTM_model_1C.h5
# Epoch 49/200
# 127/127 [==============================] - 161s 1s/step - loss: 0.1982 - val_loss: 0.2283
#
# Epoch 00049: val_loss did not improve from 0.21356
# Epoch 50/200
# 127/127 [==============================] - 161s 1s/step - loss: 0.1973 - val_loss: 0.2396
#
# Epoch 00050: val_loss did not improve from 0.21356
# Epoch 51/200
# 127/127 [==============================] - 161s 1s/step - loss: 0.2018 - val_loss: 0.2335
#
# Epoch 00051: val_loss did not improve from 0.21356
# Epoch 52/200
# 127/127 [==============================] - 161s 1s/step - loss: 0.1975 - val_loss: 0.2136
#
# Epoch 00052: val_loss did not improve from 0.21356
# Epoch 53/200
# 127/127 [==============================] - 161s 1s/step - loss: 0.1956 - val_loss: 0.2154
#
# Epoch 00053: val_loss did not improve from 0.21356
# Epoch 54/200
# 127/127 [==============================] - 161s 1s/step - loss: 0.1956 - val_loss: 0.2199
#
# Epoch 00054: val_loss did not improve from 0.21356
# Epoch 55/200
# 127/127 [==============================] - 161s 1s/step - loss: 0.1964 - val_loss: 0.2144
#
# Epoch 00055: val_loss did not improve from 0.21356
# Epoch 56/200
# 127/127 [==============================] - 161s 1s/step - loss: 0.1963 - val_loss: 0.2087
#
# Epoch 00056: val_loss improved from 0.21356 to 0.20875, saving model to ./model-gpu/Bidirect_LSTM_model_1C.h5
# Epoch 57/200
# 127/127 [==============================] - 162s 1s/step - loss: 0.1887 - val_loss: 0.2085
#
# Epoch 00057: val_loss improved from 0.20875 to 0.20847, saving model to ./model-gpu/Bidirect_LSTM_model_1C.h5
# Epoch 58/200
# 127/127 [==============================] - 161s 1s/step - loss: 0.1992 - val_loss: 0.2204
#
# Epoch 00058: val_loss did not improve from 0.20847
# Epoch 59/200
# 127/127 [==============================] - 161s 1s/step - loss: 0.1895 - val_loss: 0.1946
#
# Epoch 00059: val_loss improved from 0.20847 to 0.19459, saving model to ./model-gpu/Bidirect_LSTM_model_1C.h5
# Epoch 60/200
# 127/127 [==============================] - 161s 1s/step - loss: 0.1950 - val_loss: 0.2208
#
# Epoch 00060: val_loss did not improve from 0.19459
# Epoch 61/200
# 127/127 [==============================] - 161s 1s/step - loss: 0.1933 - val_loss: 0.2173
#
# Epoch 00061: val_loss did not improve from 0.19459
# Epoch 62/200
# 127/127 [==============================] - 161s 1s/step - loss: 0.1910 - val_loss: 0.2152
#
# Epoch 00062: val_loss did not improve from 0.19459
# Epoch 63/200
# 127/127 [==============================] - 161s 1s/step - loss: 0.1796 - val_loss: 0.2095
#
# Epoch 00063: val_loss did not improve from 0.19459
# Epoch 64/200
# 127/127 [==============================] - 161s 1s/step - loss: 0.1891 - val_loss: 0.2355
#
# Epoch 00064: val_loss did not improve from 0.19459
# Epoch 65/200
# 127/127 [==============================] - 162s 1s/step - loss: 0.1768 - val_loss: 0.2008
#
# Epoch 00065: val_loss did not improve from 0.19459
# Epoch 66/200
# 127/127 [==============================] - 161s 1s/step - loss: 0.1781 - val_loss: 0.2129
#
# Epoch 00066: val_loss did not improve from 0.19459
# Epoch 67/200
# 127/127 [==============================] - 161s 1s/step - loss: 0.1805 - val_loss: 0.2006
#
# Epoch 00067: val_loss did not improve from 0.19459
# Epoch 68/200
# 127/127 [==============================] - 161s 1s/step - loss: 0.1786 - val_loss: 0.2058
#
# Epoch 00068: val_loss did not improve from 0.19459
# Epoch 69/200
# 127/127 [==============================] - 161s 1s/step - loss: 0.1773 - val_loss: 0.2035
#
# Epoch 00069: ReduceLROnPlateau reducing learning rate to 0.0007500000356230885.
#
# Epoch 00069: val_loss did not improve from 0.19459
# Epoch 70/200
# 127/127 [==============================] - 161s 1s/step - loss: 0.1590 - val_loss: 0.1994
#
# Epoch 00070: val_loss did not improve from 0.19459
# Epoch 71/200
# 127/127 [==============================] - 161s 1s/step - loss: 0.1537 - val_loss: 0.1756
#
# Epoch 00071: val_loss improved from 0.19459 to 0.17564, saving model to ./model-gpu/Bidirect_LSTM_model_1C.h5
# Epoch 72/200
# 127/127 [==============================] - 161s 1s/step - loss: 0.1488 - val_loss: 0.1833
#
# Epoch 00072: val_loss did not improve from 0.17564
# Epoch 73/200
# 127/127 [==============================] - 161s 1s/step - loss: 0.1547 - val_loss: 0.1908
#
# Epoch 00073: val_loss did not improve from 0.17564
# Epoch 74/200
# 127/127 [==============================] - 161s 1s/step - loss: 0.1503 - val_loss: 0.1853
#
# Epoch 00074: val_loss did not improve from 0.17564
# Epoch 75/200
# 127/127 [==============================] - 161s 1s/step - loss: 0.1514 - val_loss: 0.1762
#
# Epoch 00075: val_loss did not improve from 0.17564
# Epoch 76/200
# 127/127 [==============================] - 161s 1s/step - loss: 0.1429 - val_loss: 0.1940
#
# Epoch 00076: val_loss did not improve from 0.17564
# Epoch 77/200
# 127/127 [==============================] - 162s 1s/step - loss: 0.1486 - val_loss: 0.1782
#
# Epoch 00077: val_loss did not improve from 0.17564
# Epoch 78/200
# 127/127 [==============================] - 162s 1s/step - loss: 0.1506 - val_loss: 0.1804
#
# Epoch 00078: val_loss did not improve from 0.17564
# Epoch 79/200
# 127/127 [==============================] - 161s 1s/step - loss: 0.1445 - val_loss: 0.1756
#
# Epoch 00079: val_loss improved from 0.17564 to 0.17557, saving model to ./model-gpu/Bidirect_LSTM_model_1C.h5
# Epoch 80/200
# 127/127 [==============================] - 161s 1s/step - loss: 0.1451 - val_loss: 0.1999
#
# Epoch 00080: val_loss did not improve from 0.17557
# Epoch 81/200
# 127/127 [==============================] - 162s 1s/step - loss: 0.1447 - val_loss: 0.1824
#
# Epoch 00081: ReduceLROnPlateau reducing learning rate to 0.0005625000048894435.
#
# Epoch 00081: val_loss did not improve from 0.17557
# Epoch 82/200
# 127/127 [==============================] - 161s 1s/step - loss: 0.1340 - val_loss: 0.1717
#
# Epoch 00082: val_loss improved from 0.17557 to 0.17168, saving model to ./model-gpu/Bidirect_LSTM_model_1C.h5
# Epoch 83/200
# 127/127 [==============================] - 161s 1s/step - loss: 0.1294 - val_loss: 0.1714
#
# Epoch 00083: val_loss improved from 0.17168 to 0.17136, saving model to ./model-gpu/Bidirect_LSTM_model_1C.h5
# Epoch 84/200
# 127/127 [==============================] - 161s 1s/step - loss: 0.1278 - val_loss: 0.1820
#
# Epoch 00084: val_loss did not improve from 0.17136
# Epoch 85/200
# 127/127 [==============================] - 162s 1s/step - loss: 0.1296 - val_loss: 0.1692
#
# Epoch 00085: val_loss improved from 0.17136 to 0.16925, saving model to ./model-gpu/Bidirect_LSTM_model_1C.h5
# Epoch 86/200
# 127/127 [==============================] - 161s 1s/step - loss: 0.1240 - val_loss: 0.1674
#
# Epoch 00086: val_loss improved from 0.16925 to 0.16735, saving model to ./model-gpu/Bidirect_LSTM_model_1C.h5
# Epoch 87/200
# 127/127 [==============================] - 161s 1s/step - loss: 0.1219 - val_loss: 0.1678
#
# Epoch 00087: val_loss did not improve from 0.16735
# Epoch 88/200
# 127/127 [==============================] - 162s 1s/step - loss: 0.1245 - val_loss: 0.1713
#
# Epoch 00088: val_loss did not improve from 0.16735
# Epoch 89/200
# 127/127 [==============================] - 161s 1s/step - loss: 0.1217 - val_loss: 0.1721
#
# Epoch 00089: val_loss did not improve from 0.16735
# Epoch 90/200
# 127/127 [==============================] - 161s 1s/step - loss: 0.1263 - val_loss: 0.1729
#
# Epoch 00090: val_loss did not improve from 0.16735
# Epoch 91/200
# 127/127 [==============================] - 162s 1s/step - loss: 0.1188 - val_loss: 0.1715
#
# Epoch 00091: val_loss did not improve from 0.16735
# Epoch 92/200
# 127/127 [==============================] - 163s 1s/step - loss: 0.1228 - val_loss: 0.1843
#
# Epoch 00092: val_loss did not improve from 0.16735
# Epoch 93/200
# 127/127 [==============================] - 163s 1s/step - loss: 0.1211 - val_loss: 0.1787
#
# Epoch 00093: val_loss did not improve from 0.16735
# Epoch 94/200
# 127/127 [==============================] - 163s 1s/step - loss: 0.1179 - val_loss: 0.1692
#
# Epoch 00094: val_loss did not improve from 0.16735
# Epoch 95/200
# 127/127 [==============================] - 163s 1s/step - loss: 0.1139 - val_loss: 0.1675
#
# Epoch 00095: val_loss did not improve from 0.16735
# Epoch 96/200
# 127/127 [==============================] - 163s 1s/step - loss: 0.1147 - val_loss: 0.1681
#
# Epoch 00096: ReduceLROnPlateau reducing learning rate to 0.0004218749818392098.
#
# Epoch 00096: val_loss did not improve from 0.16735
# Epoch 97/200
# 127/127 [==============================] - 163s 1s/step - loss: 0.1096 - val_loss: 0.1652
#
# Epoch 00097: val_loss improved from 0.16735 to 0.16523, saving model to ./model-gpu/Bidirect_LSTM_model_1C.h5
# Epoch 98/200
# 127/127 [==============================] - 163s 1s/step - loss: 0.1054 - val_loss: 0.1664
#
# Epoch 00098: val_loss did not improve from 0.16523
# Epoch 99/200
# 127/127 [==============================] - 163s 1s/step - loss: 0.1030 - val_loss: 0.1721
#
# Epoch 00099: val_loss did not improve from 0.16523
# Epoch 100/200
# 127/127 [==============================] - 163s 1s/step - loss: 0.1043 - val_loss: 0.1707
#
# Epoch 00100: val_loss did not improve from 0.16523
# Epoch 101/200
# 127/127 [==============================] - 163s 1s/step - loss: 0.1022 - val_loss: 0.1665
#
# Epoch 00101: val_loss did not improve from 0.16523
# Epoch 102/200
# 127/127 [==============================] - 163s 1s/step - loss: 0.1013 - val_loss: 0.1650
#
# Epoch 00102: val_loss improved from 0.16523 to 0.16497, saving model to ./model-gpu/Bidirect_LSTM_model_1C.h5
# Epoch 103/200
# 127/127 [==============================] - 163s 1s/step - loss: 0.1018 - val_loss: 0.1645
#
# Epoch 00103: val_loss improved from 0.16497 to 0.16449, saving model to ./model-gpu/Bidirect_LSTM_model_1C.h5
# Epoch 104/200
# 127/127 [==============================] - 163s 1s/step - loss: 0.1003 - val_loss: 0.1648
#
# Epoch 00104: val_loss did not improve from 0.16449
# Epoch 105/200
# 127/127 [==============================] - 163s 1s/step - loss: 0.1005 - val_loss: 0.1663
#
# Epoch 00105: val_loss did not improve from 0.16449
# Epoch 106/200
# 127/127 [==============================] - 163s 1s/step - loss: 0.0995 - val_loss: 0.1662
#
# Epoch 00106: val_loss did not improve from 0.16449
# Epoch 107/200
# 127/127 [==============================] - 163s 1s/step - loss: 0.0984 - val_loss: 0.1684
#
# Epoch 00107: val_loss did not improve from 0.16449
# Epoch 108/200
# 127/127 [==============================] - 163s 1s/step - loss: 0.0981 - val_loss: 0.1645
#
# Epoch 00108: val_loss did not improve from 0.16449
# Epoch 109/200
# 127/127 [==============================] - 163s 1s/step - loss: 0.0966 - val_loss: 0.1642
#
# Epoch 00109: val_loss improved from 0.16449 to 0.16418, saving model to ./model-gpu/Bidirect_LSTM_model_1C.h5
# Epoch 110/200
# 127/127 [==============================] - 163s 1s/step - loss: 0.0980 - val_loss: 0.1649
#
# Epoch 00110: val_loss did not improve from 0.16418
# Epoch 111/200
# 127/127 [==============================] - 163s 1s/step - loss: 0.0964 - val_loss: 0.1672
#
# Epoch 00111: val_loss did not improve from 0.16418
# Epoch 112/200
# 127/127 [==============================] - 163s 1s/step - loss: 0.0950 - val_loss: 0.1675
#
# Epoch 00112: val_loss did not improve from 0.16418
# Epoch 113/200
# 127/127 [==============================] - 163s 1s/step - loss: 0.0920 - val_loss: 0.1733
#
# Epoch 00113: val_loss did not improve from 0.16418
# Epoch 114/200
# 127/127 [==============================] - 163s 1s/step - loss: 0.0913 - val_loss: 0.1667
#
# Epoch 00114: val_loss did not improve from 0.16418
# Epoch 115/200
# 127/127 [==============================] - 163s 1s/step - loss: 0.0908 - val_loss: 0.1657
#
# Epoch 00115: val_loss did not improve from 0.16418
# Epoch 116/200
# 127/127 [==============================] - 163s 1s/step - loss: 0.0934 - val_loss: 0.1695
#
# Epoch 00116: val_loss did not improve from 0.16418
# Epoch 117/200
# 127/127 [==============================] - 164s 1s/step - loss: 0.0895 - val_loss: 0.1656
#
# Epoch 00117: val_loss did not improve from 0.16418
# Epoch 118/200
# 127/127 [==============================] - 163s 1s/step - loss: 0.0911 - val_loss: 0.1702
#
# Epoch 00118: val_loss did not improve from 0.16418
# Epoch 119/200
# 127/127 [==============================] - 164s 1s/step - loss: 0.0882 - val_loss: 0.1653
#
# Epoch 00119: ReduceLROnPlateau reducing learning rate to 0.00031640623637940735.
#
# Epoch 00119: val_loss did not improve from 0.16418
# Epoch 120/200
# 127/127 [==============================] - 163s 1s/step - loss: 0.0821 - val_loss: 0.1641
#
# Epoch 00120: val_loss improved from 0.16418 to 0.16413, saving model to ./model-gpu/Bidirect_LSTM_model_1C.h5
# Epoch 121/200
# 127/127 [==============================] - 163s 1s/step - loss: 0.0809 - val_loss: 0.1630
#
# Epoch 00121: val_loss improved from 0.16413 to 0.16299, saving model to ./model-gpu/Bidirect_LSTM_model_1C.h5
# Epoch 122/200
# 127/127 [==============================] - 163s 1s/step - loss: 0.0783 - val_loss: 0.1676
#
# Epoch 00122: val_loss did not improve from 0.16299
# Epoch 123/200
# 127/127 [==============================] - 163s 1s/step - loss: 0.0808 - val_loss: 0.1659
#
# Epoch 00123: val_loss did not improve from 0.16299
# Epoch 124/200
# 127/127 [==============================] - 163s 1s/step - loss: 0.0793 - val_loss: 0.1630
#
# Epoch 00124: val_loss improved from 0.16299 to 0.16299, saving model to ./model-gpu/Bidirect_LSTM_model_1C.h5
# Epoch 125/200
# 127/127 [==============================] - 164s 1s/step - loss: 0.0765 - val_loss: 0.1631
#
# Epoch 00125: val_loss did not improve from 0.16299
# Epoch 126/200
# 127/127 [==============================] - 163s 1s/step - loss: 0.0765 - val_loss: 0.1682
#
# Epoch 00126: val_loss did not improve from 0.16299
# Epoch 127/200
# 127/127 [==============================] - 164s 1s/step - loss: 0.0776 - val_loss: 0.1655
#
# Epoch 00127: val_loss did not improve from 0.16299
# Epoch 128/200
# 127/127 [==============================] - 163s 1s/step - loss: 0.0779 - val_loss: 0.1663
#
# Epoch 00128: val_loss did not improve from 0.16299
# Epoch 129/200
# 127/127 [==============================] - 163s 1s/step - loss: 0.0772 - val_loss: 0.1658
#
# Epoch 00129: val_loss did not improve from 0.16299
# Epoch 130/200
# 127/127 [==============================] - 163s 1s/step - loss: 0.0741 - val_loss: 0.1631
#
# Epoch 00130: val_loss did not improve from 0.16299
# Epoch 131/200
# 127/127 [==============================] - 163s 1s/step - loss: 0.0747 - val_loss: 0.1639
#
# Epoch 00131: ReduceLROnPlateau reducing learning rate to 0.00023730468819849193.
#
# Epoch 00131: val_loss did not improve from 0.16299
# Epoch 132/200
# 127/127 [==============================] - 163s 1s/step - loss: 0.0704 - val_loss: 0.1621
#
# Epoch 00132: val_loss improved from 0.16299 to 0.16212, saving model to ./model-gpu/Bidirect_LSTM_model_1C.h5
# Epoch 133/200
# 127/127 [==============================] - 163s 1s/step - loss: 0.0683 - val_loss: 0.1637
#
# Epoch 00133: val_loss did not improve from 0.16212
# Epoch 134/200
# 127/127 [==============================] - 163s 1s/step - loss: 0.0662 - val_loss: 0.1649
#
# Epoch 00134: val_loss did not improve from 0.16212
# Epoch 135/200
# 127/127 [==============================] - 163s 1s/step - loss: 0.0664 - val_loss: 0.1644
#
# Epoch 00135: val_loss did not improve from 0.16212
# Epoch 136/200
# 127/127 [==============================] - 163s 1s/step - loss: 0.0665 - val_loss: 0.1634
#
# Epoch 00136: val_loss did not improve from 0.16212
# Epoch 137/200
# 127/127 [==============================] - 163s 1s/step - loss: 0.0656 - val_loss: 0.1660
#
# Epoch 00137: val_loss did not improve from 0.16212
# Epoch 138/200
# 127/127 [==============================] - 163s 1s/step - loss: 0.0643 - val_loss: 0.1663
#
# Epoch 00138: val_loss did not improve from 0.16212
# Epoch 139/200
# 127/127 [==============================] - 163s 1s/step - loss: 0.0653 - val_loss: 0.1642
#
# Epoch 00139: val_loss did not improve from 0.16212
# Epoch 140/200
# 127/127 [==============================] - 163s 1s/step - loss: 0.0660 - val_loss: 0.1655
#
# Epoch 00140: val_loss did not improve from 0.16212
# Epoch 141/200
# 127/127 [==============================] - 163s 1s/step - loss: 0.0664 - val_loss: 0.1648
#
# Epoch 00141: val_loss did not improve from 0.16212
# Epoch 142/200
# 127/127 [==============================] - 163s 1s/step - loss: 0.0638 - val_loss: 0.1638
#
# Epoch 00142: ReduceLROnPlateau reducing learning rate to 0.00017797851614886895.
#
# Epoch 00142: val_loss did not improve from 0.16212
# Epoch 143/200
# 127/127 [==============================] - 163s 1s/step - loss: 0.0606 - val_loss: 0.1641
#
# Epoch 00143: val_loss did not improve from 0.16212
# Epoch 144/200
# 127/127 [==============================] - 163s 1s/step - loss: 0.0598 - val_loss: 0.1632
#
# Epoch 00144: val_loss did not improve from 0.16212
# Epoch 145/200
# 127/127 [==============================] - 163s 1s/step - loss: 0.0589 - val_loss: 0.1660
#
# Epoch 00145: val_loss did not improve from 0.16212
# Epoch 146/200
# 127/127 [==============================] - 163s 1s/step - loss: 0.0594 - val_loss: 0.1640
#
# Epoch 00146: val_loss did not improve from 0.16212
# Epoch 147/200
# 127/127 [==============================] - 163s 1s/step - loss: 0.0583 - val_loss: 0.1636
#
# Epoch 00147: val_loss did not improve from 0.16212
# Epoch 148/200
# 127/127 [==============================] - 163s 1s/step - loss: 0.0577 - val_loss: 0.1630
#
# Epoch 00148: val_loss did not improve from 0.16212
# Epoch 149/200
# 127/127 [==============================] - 163s 1s/step - loss: 0.0573 - val_loss: 0.1634
#
# Epoch 00149: val_loss did not improve from 0.16212
# Epoch 150/200
# 127/127 [==============================] - 163s 1s/step - loss: 0.0577 - val_loss: 0.1631
#
# Epoch 00150: val_loss did not improve from 0.16212
# Epoch 151/200
# 127/127 [==============================] - 163s 1s/step - loss: 0.0575 - val_loss: 0.1669
#
# Epoch 00151: val_loss did not improve from 0.16212
# Epoch 152/200
# 127/127 [==============================] - 163s 1s/step - loss: 0.0579 - val_loss: 0.1642
#
# Epoch 00152: ReduceLROnPlateau reducing learning rate to 0.0001334838816546835.
#
# Epoch 00152: val_loss did not improve from 0.16212
# Epoch 153/200
# 127/127 [==============================] - 164s 1s/step - loss: 0.0540 - val_loss: 0.1648
#
# Epoch 00153: val_loss did not improve from 0.16212
# Epoch 154/200
# 127/127 [==============================] - 163s 1s/step - loss: 0.0527 - val_loss: 0.1632
#
# Epoch 00154: val_loss did not improve from 0.16212
# Epoch 155/200
# 127/127 [==============================] - 163s 1s/step - loss: 0.0528 - val_loss: 0.1649
#
# Epoch 00155: val_loss did not improve from 0.16212
# Epoch 156/200
# 127/127 [==============================] - 163s 1s/step - loss: 0.0524 - val_loss: 0.1636
#
# Epoch 00156: val_loss did not improve from 0.16212
# Epoch 157/200
# 127/127 [==============================] - 163s 1s/step - loss: 0.0528 - val_loss: 0.1673
#
# Epoch 00157: val_loss did not improve from 0.16212
# Epoch 158/200
# 127/127 [==============================] - 163s 1s/step - loss: 0.0531 - val_loss: 0.1642
#
# Epoch 00158: val_loss did not improve from 0.16212
# Epoch 159/200
# 127/127 [==============================] - 163s 1s/step - loss: 0.0527 - val_loss: 0.1648
#
# Epoch 00159: val_loss did not improve from 0.16212
# Epoch 160/200
# 127/127 [==============================] - 164s 1s/step - loss: 0.0524 - val_loss: 0.1671
#
# Epoch 00160: val_loss did not improve from 0.16212
# Epoch 161/200
# 127/127 [==============================] - 163s 1s/step - loss: 0.0516 - val_loss: 0.1658
#
# Epoch 00161: val_loss did not improve from 0.16212
# Epoch 162/200
# 127/127 [==============================] - 163s 1s/step - loss: 0.0519 - val_loss: 0.1638
#
# Epoch 00162: ReduceLROnPlateau reducing learning rate to 0.00010011290578404441.
#
# Epoch 00162: val_loss did not improve from 0.16212
# Epoch 163/200
# 127/127 [==============================] - 163s 1s/step - loss: 0.0503 - val_loss: 0.1636
#
# Epoch 00163: val_loss did not improve from 0.16212
# Epoch 164/200
# 127/127 [==============================] - 164s 1s/step - loss: 0.0492 - val_loss: 0.1636
#
# Epoch 00164: val_loss did not improve from 0.16212
# Epoch 165/200
# 127/127 [==============================] - 163s 1s/step - loss: 0.0489 - val_loss: 0.1639
#
# Epoch 00165: val_loss did not improve from 0.16212
# Epoch 166/200
# 127/127 [==============================] - 164s 1s/step - loss: 0.0492 - val_loss: 0.1648
#
# Epoch 00166: val_loss did not improve from 0.16212
# Epoch 167/200
# 127/127 [==============================] - 163s 1s/step - loss: 0.0485 - val_loss: 0.1653
#
# Epoch 00167: val_loss did not improve from 0.16212
# Epoch 168/200
# 127/127 [==============================] - 163s 1s/step - loss: 0.0485 - val_loss: 0.1637
#
# Epoch 00168: val_loss did not improve from 0.16212
# Epoch 169/200
# 127/127 [==============================] - 163s 1s/step - loss: 0.0485 - val_loss: 0.1662
#
# Epoch 00169: val_loss did not improve from 0.16212
# Epoch 170/200
# 127/127 [==============================] - 163s 1s/step - loss: 0.0480 - val_loss: 0.1649
#
# Epoch 00170: val_loss did not improve from 0.16212
# Epoch 171/200
# 127/127 [==============================] - 163s 1s/step - loss: 0.0480 - val_loss: 0.1637
#
# Epoch 00171: val_loss did not improve from 0.16212
# Epoch 172/200
# 127/127 [==============================] - 163s 1s/step - loss: 0.0478 - val_loss: 0.1651
#
# Epoch 00172: ReduceLROnPlateau reducing learning rate to 7.508467933803331e-05.
#
# Epoch 00172: val_loss did not improve from 0.16212
# Epoch 173/200
# 127/127 [==============================] - 163s 1s/step - loss: 0.0467 - val_loss: 0.1644
#
# Epoch 00173: val_loss did not improve from 0.16212
# Epoch 174/200
# 127/127 [==============================] - 163s 1s/step - loss: 0.0462 - val_loss: 0.1638
#
# Epoch 00174: val_loss did not improve from 0.16212
# Epoch 175/200
# 127/127 [==============================] - 163s 1s/step - loss: 0.0457 - val_loss: 0.1641
#
# Epoch 00175: val_loss did not improve from 0.16212
# Epoch 176/200
# 127/127 [==============================] - 164s 1s/step - loss: 0.0465 - val_loss: 0.1641
#
# Epoch 00176: val_loss did not improve from 0.16212
# Epoch 177/200
# 127/127 [==============================] - 163s 1s/step - loss: 0.0456 - val_loss: 0.1647
#
# Epoch 00177: val_loss did not improve from 0.16212
# Epoch 178/200
# 127/127 [==============================] - 163s 1s/step - loss: 0.0454 - val_loss: 0.1648
#
# Epoch 00178: val_loss did not improve from 0.16212
# Epoch 179/200
# 127/127 [==============================] - 163s 1s/step - loss: 0.0454 - val_loss: 0.1668
#
# Epoch 00179: val_loss did not improve from 0.16212
# Epoch 180/200
# 127/127 [==============================] - 163s 1s/step - loss: 0.0453 - val_loss: 0.1650
#
# Epoch 00180: val_loss did not improve from 0.16212
# Epoch 181/200
# 127/127 [==============================] - 163s 1s/step - loss: 0.0450 - val_loss: 0.1678
#
# Epoch 00181: val_loss did not improve from 0.16212
# Epoch 182/200
# 127/127 [==============================] - 163s 1s/step - loss: 0.0448 - val_loss: 0.1655
#
# Epoch 00182: ReduceLROnPlateau reducing learning rate to 5.6313510867767036e-05.
#
# Epoch 00182: val_loss did not improve from 0.16212
# Restoring model weights from the end of the best epoch.
# Epoch 00182: early stopping
# Fold-1 | OOF Score: 0.16211654680482343
# Epoch 1/200
# 127/127 [==============================] - 201s 1s/step - loss: 1.2274 - val_loss: 1.0773
#
# Epoch 00001: val_loss improved from inf to 1.07734, saving model to ./model-gpu/Bidirect_LSTM_model_2C.h5
# /usr/local/lib/python3.7/dist-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# Epoch 2/200
# 127/127 [==============================] - 164s 1s/step - loss: 0.5865 - val_loss: 0.7055
#
# Epoch 00002: val_loss improved from 1.07734 to 0.70552, saving model to ./model-gpu/Bidirect_LSTM_model_2C.h5
# Epoch 3/200
#  55/127 [===========>..................] - ETA: 1:27 - loss: 0.5373

# %%
if not DEBUG:
  train_pred = train_pred.flatten()
  targets = targets.flatten()
  score = mean_absolute_error(targets, train_pred)
  print(f"Train Score: {score}")

# %% [markdown]
# ## Create submission file

# %%
if not DEBUG:
  submission = pd.read_csv('../input/ventilator-pressure-prediction/sample_submission.csv')
  submission["pressure"] = sum(test_preds)/5
  submission.to_csv('submission.csv', index=False)

  # ENSEMBLE FOLDS WITH MEDIAN
  #取中位数
  submission["pressure"] = np.median(np.vstack(test_preds),axis=0)
  submission.to_csv('submission_median.csv', index=False)


  # ENSEMBLE FOLDS WITH MEDIAN AND ROUND PREDICTIONS
  submission["pressure"] =\
      np.round( (submission.pressure - pressure_min)/pressure_step ) * pressure_step + pressure_min
  submission.pressure = np.clip(submission.pressure, pressure_min, pressure_max)
  submission.to_csv('submission_median_round.csv', index=False)
