# %% [markdown]
# <a href="https://colab.research.google.com/github/bobbercheng/ventilator-pressure-prediction/blob/master/transform_encoder_lstm_GPU_V20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# V1: Keep R/C, improve
#
# V2: Add R**2, no improve
#
# V3: Update model from https://www.kaggle.com/dlaststark/gb-vpp-pulp-fiction. Not much improve compare V1
#
# V4: Use whole db for test Fold-1
# Fold-1 | OOF Score: 0.15912771348961205
#
# Run it again in Kaggle:
#
# Fold-1 | OOF Score: 0.1606402072946816
#
# V5: Add loading ScaleLayer from saved model
#
# V6: Add TransformerEncoder. TransformerEncoder(128, 512, 8, name="transformer_layer")(x). Testing in GPU.
#
# V7: Try to scale targe to 0-1, but it slow the train as MASE cannot be scaled.
#
# V8: Removed target scale.
# Epoch 00022: val_loss improved from 0.32912 to 0.30967, saving model to ./model-gpu/Bidirect_LSTM_model_1C.h5
# Epoch 23/150
# 127/127 [==============================] - 161s 1s/step - loss: 0.3176 - val_loss: 0.2917
#
# Not Good as without TransformerEncoder. Change paramemter back to
#
# V8: Change attention result to multiple instead of concate.
#
# Loss is smaller than without LayerNormalization, but CV is bigger. It means it overfit the train data.
#
# TransformerEncoder(128, 512, 8, 0.3, name="transformer_layer")
#
# Epoch 00181: val_loss did not improve from 0.16212
# Epoch 182/200
# 127/127 [==============================] - 163s 1s/step - loss: 0.0448 - val_loss: 0.1655
#
# Epoch 00182: ReduceLROnPlateau reducing learning rate to 5.6313510867767036e-05.
#
# Epoch 00182: val_loss did not improve from 0.16212
# Restoring model weights from the end of the best epoch.
# Epoch 00182: early stopping
# Fold-1 | OOF Score: 0.16211654680482343
#
# V9: Increase attention dropout to 0.6, add 0.01 droupout to input
# Epoch 00123: ReduceLROnPlateau reducing learning rate to 0.00031640623637940735.
#
# Epoch 00123: val_loss did not improve from 0.16714
# Epoch 124/200
# 127/127 - 161s - loss: 0.0838 - val_loss: 0.1694
#
# Epoch 00124: val_loss did not improve from 0.16714
# Epoch 125/200
# 127/127 - 161s - loss: 0.0796 - val_loss: 0.1727
#
# V10: add TransformerEncoder to all layer with Multiply
#
# Epoch 164/200
# 253/253 - 387s - loss: 0.0568 - val_loss: 0.1679
#
# Epoch 00164: val_loss did not improve from 0.16158
# Restoring model weights from the end of the best epoch.
# Epoch 00164: early stopping
# Fold-1 | OOF Score: 0.16158229343436334
#
# V10: analy_predict.
#
# Here is analyze result for V4:
# 20__10 - MAE  0.16386306650915122, count: 25870
# 20__20 - MAE  0.15764106283234391, count: 26272
# 20__50 - MAE  0.16384391190488698, count: 34729
# 50__10 - MAE  0.1585241009544335, count: 60574
# 50__20 - MAE  0.24078390163257296, count: 37108
# 50__50 - MAE  0.23760641023725088, count: 34699
# 5__10 - MAE  0.15540978004136713, count: 36361
# 5__20 - MAE  0.10102388763185534, count: 35935
# 5__50 - MAE  0.11535413256937187, count: 35522
#
#
# V11: add dnn_model_GaussianNoise(), no improve
#
# Epoch 00183: val_loss did not improve from 0.16240
# Epoch 184/200
# 127/127 - 150s - loss: 0.0498 - val_loss: 0.1642
#
# Epoch 00184: ReduceLROnPlateau reducing learning rate to 7.508467933803331e-05.
#
# Epoch 00184: val_loss did not improve from 0.16240
# Restoring model weights from the end of the best epoch.
# Epoch 00184: early stopping
# Fold-1 | OOF Score: 0.16240143234043636
#
# V12: dnn_model_aen(), use auto encoder to remove noise and learn encode.
#
# Epoch 200/200
# 127/127 - 153s - loss: 4.1734 - decoder_loss: 3.8822 - ae_action_loss: 0.2257 - output_loss: 0.0654 - val_loss: 0.7126 - val_decoder_loss: 0.3742 - val_ae_action_loss: 0.1702 - val_output_loss: 0.1682
#
# Epoch 00200: val_loss did not improve from 0.69120
#
# Fold-1 | OOF Score: 0.16817480317739367
# 20__10 - MAE  0.16644539428012722, count: 25870
# 20__20 - MAE  0.15768315124243204, count: 26272
# 20__50 - MAE  0.16684243562006307, count: 34729
# 50__10 - MAE  0.16641273893399433, count: 60574
# 50__20 - MAE  0.2518146440943941, count: 37108
# 50__50 - MAE  0.2752187431993935, count: 34699
# 5__10 - MAE  0.16763255549569941, count: 36361
# 5__20 - MAE  0.10697168010290617, count: 35935
# 5__50 - MAE  0.11503387157283243, count: 35522
#
# decoder_loss is very large. It means GaussianNoise() and dropout causes side effect.
#
# V13. Remove GaussianNoise and dropout, use encoder feature only. CV score is a little worse.
#
# Epoch 200/200
# 127/127 - 150s - loss: 0.5841 - decoder_loss: 0.3983 - ae_action_loss: 0.1025 - output_loss: 0.0832 - val_loss: 0.4930 - val_decoder_loss: 0.1541 - val_ae_action_loss: 0.1693 - val_output_loss: 0.1696
#
# Epoch 00200: val_output_loss did not improve from 0.16793
# Fold-1 | OOF Score: 0.16959694784227083
# 20__10 - MAE  0.18958046275757853, count: 25870
# 20__20 - MAE  0.16960937531364753, count: 26272
# 20__50 - MAE  0.1714088869810135, count: 34729
# 50__10 - MAE  0.17159657573233353, count: 60574
# 50__20 - MAE  0.2590598477978727, count: 37108
# 50__50 - MAE  0.26932839218852966, count: 34699
# 5__10 - MAE  0.16335297055531042, count: 36361
# 5__20 - MAE  0.11217990298083265, count: 35935
# 5__50 - MAE  0.12327488392594069, count: 35522
#
# V14: add RC_loss
#
# V15: change weight of RC_loss to 50
# Epoch 00209: val_loss did not improve from 2.45837
# Epoch 210/300
# Fold-1 | OOF Score: 0.1673458640660445
# 20__10 - MAE  0.16871429221171652, count: 25870
# 20__20 - MAE  0.17440932964643532, count: 26272
# 20__50 - MAE  0.172235793440684, count: 34729
# 50__10 - MAE  0.17126511889137416, count: 60574
# 50__20 - MAE  0.2432283477323368, count: 37108
# 50__50 - MAE  0.2597899337166222, count: 34699
# 5__10 - MAE  0.16038654333096616, count: 36361
# 5__20 - MAE  0.11624601028942623, count: 35935
# 5__50 - MAE  0.12415466606839251, count: 35522
#
# V16: add transformer-lstm
#
# Use batch size 128 can get CV 0.15877 even less with epoch 300
#
# V17: adjust transformer, add end and 2 blanks CV 0.12991. But whole predict is very bad
#
# 0 0.14148501952069917
# 1 0.14520795916752946
# 2 0.1452920120705252
# 3 0.16967588597394917
# 4 0.17902953346449468
# 5 0.18594049766905138
# 6 0.1955961319424856
# 7 0.20854509522391337
# 8 0.21458597950250358
# 9 0.22118286968390113
# 10 0.22475087682193112
# 11 0.23562216996092814
# 12 0.2417678443098268
# 13 0.2486351801831136
# 14 0.25707959610136394
# 15 0.25895094073793795
# 16 0.26148528485339234
# 17 0.2616311155291766
# 18 0.2680423099231097
# 19 0.27116125351847903
# 20 0.27050861227286466
# 21 0.27409962320381126
# 22 0.27758439665369256
# 23 0.2751211551673223
# 24 0.27539683001756554
# 25 0.27518210369058366
# 26 0.27327358832534837
# 27 0.2812070482037823
# 28 0.28034630644942793
# 29 0.3070858504524672
# 30 0.34370719053457266
# 31 0.36626009688088546
# 32 0.3364974864941008
# 33 0.35649837184149963
# 34 0.2520926541942029
# 35 0.2139278771053048
# 36 0.20732871207058715
# 37 0.20378609724030283
# 38 0.20487927130475114
# 39 0.20411116911993243
# 40 0.2034835872475978
# 41 0.20455316890292993
# 42 0.2163857648260591
# 43 0.21138709981775727
# 44 0.21258259281597885
# 45 0.2225443962031891
# 46 0.22013296614897676
# 47 0.21843655182667077
# 48 0.22779665709708755
# 49 0.2514814428053657
# 50 0.2393066044231237
# 51 0.2371961275997931
# 52 0.23855810637726255
# 53 0.2832852611807417
# 54 0.26864207041740534
# 55 0.23365424894016673
# 56 0.25514406502805875
# 57 0.25370567826900553
# 58 0.23786190881283648
# 59 0.24217545976340044
# 60 0.21483890798534683
# 61 0.1994593563549721
# 62 0.20242457291451288
# 63 0.22787010094293386
# 64 0.21992883879829453
# 65 0.18153990773580572
# 66 0.17615148775825606
# 67 0.17547249258729714
# 68 0.17237692313246988
# 69 0.17496547530222353
# 70 0.1703149892078443
# 71 0.16547015972877682
# 72 0.16692752396584
# 73 0.1666304577570775
# 74 0.16344902026880231
# 75 0.1629157191147663
# 76 0.16264062574575458
# 77 0.16892764732625276
# 78 0.17437231940513767
# 79 0.5044735717026109
#
# V18: ExternalTransformerEncoder_LSTM_model
# bs 512 num_heads=8,num_layers=8
# Epoch 00298: val_loss did not improve from 0.17047
# Restoring model weights from the end of the best epoch.
# Epoch 00298: early stopping
# Fold-1 | OOF Score: 0.1704706018963776
# 20__10 - MAE  0.1770960508129316, count: 25870
# 20__20 - MAE  0.18805404723155397, count: 26272
# 20__50 - MAE  0.17861207574261875, count: 34729
# 50__10 - MAE  0.18550545316333472, count: 60574
# 50__20 - MAE  0.2603605811883633, count: 37108
# 50__50 - MAE  0.2890516329359929, count: 34699
# 5__10 - MAE  0.1792565859583657, count: 36361
# 5__20 - MAE  0.12446280506043439, count: 35935
# 5__50 - MAE  0.1326119992906822, count: 35522
#
# num_layers=2
# Epoch 00255: val_loss did not improve from 0.17006
# Restoring model weights from the end of the best epoch.
# Epoch 00255: early stopping
# Fold-1 | OOF Score: 0.17006428237351293
# 20__10 - MAE  0.1830817254990454, count: 25870
# 20__20 - MAE  0.1822763976914718, count: 26272
# 20__50 - MAE  0.18400984457332253, count: 34729
# 50__10 - MAE  0.18881671004528705, count: 60574
# 50__20 - MAE  0.26606635524604183, count: 37108
# 50__50 - MAE  0.28565957174809764, count: 34699
# 5__10 - MAE  0.17048386957377418, count: 36361
# 5__20 - MAE  0.12707187016601892, count: 35935
# 5__50 - MAE  0.1314206030677611, count: 35522
#
# V19: self attention + external attention
# Epoch 00300: val_loss did not improve from 0.17015
# Fold-1 | OOF Score: 0.17115337799830527
#
# V20: add loss for in_pressure, out_pressure. tf.split resoved the issue that TPU cannot use tf.boolean_mask.

# %%
# Update pandas version for Colab TPU
# !pip install pandas==1.3.2
# Out:
# Requirement already satisfied: pandas==1.3.2 in /usr/local/lib/python3.7/dist-packages (1.3.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas==1.3.2) (1.19.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas==1.3.2) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas==1.3.2) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas==1.3.2) (1.15.0)

# %% [markdown]
# ## Import libraries

# %%
try:
  import google.colab
  IN_COLAB = True
except:
  IN_COLAB = False

LOAD_PRE_FEATURE = True

# %%
if IN_COLAB:
  from google.colab import drive
  drive.mount("/gdrive", force_remount=True)
# Out:
# Mounted at /gdrive

# %%
if IN_COLAB:
  # !pip install kaggle
  # !mkdir /root/.kaggle
  # !cp /gdrive/MyDrive/ventilator-pressure-prediction/kaggle.json /root/.kaggle
  # !kaggle competitions download -c ventilator-pressure-prediction
  # !kaggle datasets download -d  ventilatorpressurepredictionfeatures
  # !mkdir -p ../input/ventilator-pressure-prediction
  # !unzip '*.zip' -d ../input/ventilator-pressure-prediction
  # !ls ../input/ventilator-pressure-prediction
  # !mkdir -p ../input/ventilatorpressurepredictionfeatures/
  # !mv ../input/ventilator-pressure-prediction/*.npy ../input/ventilatorpressurepredictionfeatures
  # !mkdir /gdrive/MyDrive/ventilator-pressure-prediction/transformer_encoder_lstm_gpu
  #Map Google driver folder to local folder model to save model
  # !ln -s /gdrive/MyDrive/ventilator-pressure-prediction/transformer_encoder_lstm_gpu model-gpu
else:
  # !mkdir ./model-gpu
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.7/dist-packages (1.5.12)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.15.0)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.7/dist-packages (from kaggle) (5.0.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from kaggle) (4.62.3)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.24.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.23.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from kaggle) (2021.5.30)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.7/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (3.0.4)
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.5.12 / client 1.5.4)
# Downloading test.csv.zip to /content
#  78% 59.0M/75.4M [00:00<00:00, 48.2MB/s]
# 100% 75.4M/75.4M [00:00<00:00, 119MB/s]
# Downloading train.csv.zip to /content
#  91% 126M/139M [00:00<00:00, 144MB/s]
# 100% 139M/139M [00:00<00:00, 169MB/s]
# Downloading sample_submission.csv.zip to /content
#   0% 0.00/8.50M [00:00<?, ?B/s]
# 100% 8.50M/8.50M [00:00<00:00, 140MB/s]
# Downloading ventilatorpressurepredictionfeatures.zip to /content
# 100% 1.95G/1.95G [00:16<00:00, 112MB/s]
# 100% 1.95G/1.95G [00:16<00:00, 127MB/s]
# Archive:  ventilatorpressurepredictionfeatures.zip
#   inflating: ../input/ventilator-pressure-prediction/test.npy
#   inflating: ../input/ventilator-pressure-prediction/train.npy
#
# Archive:  train.csv.zip
#   inflating: ../input/ventilator-pressure-prediction/train.csv
#
# Archive:  sample_submission.csv.zip
#   inflating: ../input/ventilator-pressure-prediction/sample_submission.csv
#
# Archive:  test.csv.zip
#   inflating: ../input/ventilator-pressure-prediction/test.csv
#
# 4 archives were successfully processed.
# sample_submission.csv  test.csv  test.npy  train.csv  train.npy
# mkdir: cannot create directory ‘/gdrive/MyDrive/ventilator-pressure-prediction/transformer_encoder_lstm_gpu’: File exists

# %%
import gc
import numpy as np
import pandas as pd
import random
import os
from sklearn.model_selection import KFold
from sklearn.preprocessing import RobustScaler, MinMaxScaler
from sklearn.metrics import mean_absolute_error

import tensorflow as tf
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
  tf.config.experimental.set_memory_growth(gpu, True)
from tensorflow.keras import backend as K

from tensorflow.keras.utils import plot_model
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Dense, Dropout, Input
from tensorflow.keras.layers import Concatenate, LSTM, GRU
from tensorflow.keras.layers import Bidirectional, Multiply
from tensorflow.keras import layers



# Random Seed Initialize
RANDOM_SEED = 42

def seed_everything(seed=RANDOM_SEED):
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    random.seed(seed)
    tf.random.set_seed(seed)
    
seed_everything()

# %% [markdown]
# ## Load datasets

# %%
train_df = pd.read_csv('../input/ventilator-pressure-prediction/train.csv')
print(f"train_df: {train_df.shape}")
train_df.head()
# Out:
# train_df: (6036000, 8)
#    id  breath_id   R   C  time_step       u_in  u_out   pressure
# 0   1          1  20  50   0.000000   0.083334      0   5.837492
# 1   2          1  20  50   0.033652  18.383041      0   5.907794
# 2   3          1  20  50   0.067514  22.509278      0   7.876254
# 3   4          1  20  50   0.101542  22.808822      0  11.742872
# 4   5          1  20  50   0.135756  25.355850      0  12.234987

# %%
all_pressure = np.sort(train_df['pressure'].unique())
pressure_min =  all_pressure[0].item()
pressure_max = all_pressure[-1].item()
pressure_step = (all_pressure[1] - all_pressure[0]).item()

pressure_min,pressure_max,pressure_step
# Out:
# (-1.895744294564641, 64.8209917386395, 0.07030214545121005)

# %%
DEBUG = False

if DEBUG:
    train_df = train_df[:80*10000]

targets = train_df[['pressure']].to_numpy().reshape(-1, 80)

# %%
test_df = pd.read_csv('../input/ventilator-pressure-prediction/test.csv')
print(f"test_df: {test_df.shape}")
test_df.head()
# Out:
# test_df: (4024000, 7)
#    id  breath_id  R   C  time_step       u_in  u_out
# 0   1          0  5  20   0.000000   0.000000      0
# 1   2          0  5  20   0.031904   7.515046      0
# 2   3          0  5  20   0.063827  14.651675      0
# 3   4          0  5  20   0.095751  21.230610      0
# 4   5          0  5  20   0.127644  26.320956      0

# %% [markdown]
# ## Feature Engineering

# %%
def add_features(df):
    df['cross']= df['u_in'] * df['u_out']
    df['cross2']= df['time_step'] * df['u_out']
    df['area'] = df['time_step'] * df['u_in']
    df['area'] = df.groupby('breath_id')['area'].cumsum()
    df['time_step_cumsum'] = df.groupby(['breath_id'])['time_step'].cumsum()
    df['u_in_cumsum'] = (df['u_in']).groupby(df['breath_id']).cumsum()
    print("Step-1...Completed")
    
    df['u_in_lag1'] = df.groupby('breath_id')['u_in'].shift(1)
    df['u_out_lag1'] = df.groupby('breath_id')['u_out'].shift(1)
    df['u_in_lag_back1'] = df.groupby('breath_id')['u_in'].shift(-1)
    df['u_out_lag_back1'] = df.groupby('breath_id')['u_out'].shift(-1)
    df['u_in_lag2'] = df.groupby('breath_id')['u_in'].shift(2)
    df['u_out_lag2'] = df.groupby('breath_id')['u_out'].shift(2)
    df['u_in_lag_back2'] = df.groupby('breath_id')['u_in'].shift(-2)
    df['u_out_lag_back2'] = df.groupby('breath_id')['u_out'].shift(-2)
    df['u_in_lag3'] = df.groupby('breath_id')['u_in'].shift(3)
    df['u_out_lag3'] = df.groupby('breath_id')['u_out'].shift(3)
    df['u_in_lag_back3'] = df.groupby('breath_id')['u_in'].shift(-3)
    df['u_out_lag_back3'] = df.groupby('breath_id')['u_out'].shift(-3)
    df['u_in_lag4'] = df.groupby('breath_id')['u_in'].shift(4)
    df['u_out_lag4'] = df.groupby('breath_id')['u_out'].shift(4)
    df['u_in_lag_back4'] = df.groupby('breath_id')['u_in'].shift(-4)
    df['u_out_lag_back4'] = df.groupby('breath_id')['u_out'].shift(-4)
    df = df.fillna(0)
    print("Step-2...Completed")
    
    df['breath_id__u_in__max'] = df.groupby(['breath_id'])['u_in'].transform('max')
    df['breath_id__u_out__max'] = df.groupby(['breath_id'])['u_out'].transform('max')
    df['breath_id__u_in__diffmax'] = df.groupby(['breath_id'])['u_in'].transform('max') - df['u_in']
    df['breath_id__u_in__diffmean'] = df.groupby(['breath_id'])['u_in'].transform('mean') - df['u_in']
    df['breath_id__u_in__diffmax'] = df.groupby(['breath_id'])['u_in'].transform('max') - df['u_in']
    df['breath_id__u_in__diffmean'] = df.groupby(['breath_id'])['u_in'].transform('mean') - df['u_in']
    print("Step-3...Completed")
    
    df['u_in_diff1'] = df['u_in'] - df['u_in_lag1']
    df['u_out_diff1'] = df['u_out'] - df['u_out_lag1']
    df['u_in_diff2'] = df['u_in'] - df['u_in_lag2']
    df['u_out_diff2'] = df['u_out'] - df['u_out_lag2']
    df['u_in_diff3'] = df['u_in'] - df['u_in_lag3']
    df['u_out_diff3'] = df['u_out'] - df['u_out_lag3']
    df['u_in_diff4'] = df['u_in'] - df['u_in_lag4']
    df['u_out_diff4'] = df['u_out'] - df['u_out_lag4']
    print("Step-4...Completed")
    
    df['one'] = 1
    df['count'] = (df['one']).groupby(df['breath_id']).cumsum()
    df['u_in_cummean'] =df['u_in_cumsum'] /df['count']
    
    df['breath_id_lag']=df['breath_id'].shift(1).fillna(0)
    df['breath_id_lag2']=df['breath_id'].shift(2).fillna(0)
    df['breath_id_lagsame']=np.select([df['breath_id_lag']==df['breath_id']],[1],0)
    df['breath_id_lag2same']=np.select([df['breath_id_lag2']==df['breath_id']],[1],0)
    df['breath_id__u_in_lag'] = df['u_in'].shift(1).fillna(0)
    df['breath_id__u_in_lag'] = df['breath_id__u_in_lag'] * df['breath_id_lagsame']
    df['breath_id__u_in_lag2'] = df['u_in'].shift(2).fillna(0)
    df['breath_id__u_in_lag2'] = df['breath_id__u_in_lag2'] * df['breath_id_lag2same']
    print("Step-5...Completed")
    
    df['time_step_diff'] = df.groupby('breath_id')['time_step'].diff().fillna(0)
    df['ewm_u_in_mean'] = (df\
                           .groupby('breath_id')['u_in']\
                           .ewm(halflife=9)\
                           .mean()\
                           .reset_index(level=0,drop=True))
    df[["15_in_sum","15_in_min","15_in_max","15_in_mean"]] = (df\
                                                              .groupby('breath_id')['u_in']\
                                                              .rolling(window=15,min_periods=1)\
                                                              .agg({"15_in_sum":"sum",
                                                                    "15_in_min":"min",
                                                                    "15_in_max":"max",
                                                                    "15_in_mean":"mean"
                                                                    #"15_in_std":"std"
                                                               })\
                                                               .reset_index(level=0,drop=True))
    print("Step-6...Completed")
    
    #df['u_in_diff_1_2'] = df['u_in_lag1'] - df['u_in_lag2']
    #df['u_out_diff_1_2'] = df['u_out_lag1'] - df['u_out_lag2']
    #df['u_in_lagback_diff_1_2'] = df['u_in_lag_back1'] - df['u_in_lag_back2']
    #df['u_out_lagback_diff_1_2'] = df['u_out_lag_back1'] - df['u_out_lag_back2']
    
    df['u_in_lagback_diff1'] = df['u_in'] - df['u_in_lag_back1']
    df['u_out_lagback_diff1'] = df['u_out'] - df['u_out_lag_back1']
    df['u_in_lagback_diff2'] = df['u_in'] - df['u_in_lag_back2']
    df['u_out_lagback_diff2'] = df['u_out'] - df['u_out_lag_back2']
    print("Step-7...Completed")
    
    df['R_cat'] = df['R'].astype(str)
    df['C_cat'] = df['C'].astype(str)
    df['R__C'] = df["R"].astype(str) + '__' + df["C"].astype(str)
    df = pd.get_dummies(df)
    print("Step-8...Completed")
    
    return df

if not LOAD_PRE_FEATURE:
  print("Train data...\n")
  train = add_features(train_df)

  print("\nTest data...\n")
  test = add_features(test_df)

# %%
del train_df
del test_df
gc.collect()
# Out:
# 50

# %%
if not LOAD_PRE_FEATURE:
  train.drop(['pressure','id', 'breath_id','one','count',
              'breath_id_lag','breath_id_lag2','breath_id_lagsame',
              'breath_id_lag2same'], axis=1, inplace=True)

  test = test.drop(['id', 'breath_id','one','count','breath_id_lag',
                    'breath_id_lag2','breath_id_lagsame',
                    'breath_id_lag2same'], axis=1)

  print(f"train: {train.shape} \ntest: {test.shape}")
  train.head()

# %%
if not LOAD_PRE_FEATURE:
  scaler = RobustScaler()
  train = scaler.fit_transform(train)
  test = scaler.transform(test)

  train = train.reshape(-1, 80, train.shape[-1])
  test = test.reshape(-1, 80, train.shape[-1])
else:
  train = np.load('../input/ventilatorpressurepredictionfeatures/train.npy')
  test = np.load('../input/ventilatorpressurepredictionfeatures/test.npy')

print(f"train: {train.shape} \ntest: {test.shape} \ntargets: {targets.shape}")
# Out:
# train: (75450, 80, 66)
# test: (50300, 80, 66)
# targets: (75450, 80)

# %% [markdown]
# R_cat_20	R_cat_5	R_cat_50	C_cat_10	C_cat_20	C_cat_50	R__C_20__10	R__C_20__20	R__C_20__50	R__C_50__10	R__C_50__20	R__C_50__50	R__C_5__10	R__C_5__20	R__C_5__50

# %%
train[:3, 0, :]
# Out:
# array([[ 0.00000000e+00,  7.50000000e-01, -9.89052161e-01,
#         -9.37384450e-01, -1.00000000e+00,  0.00000000e+00,
#         -6.65541311e-01, -5.16580501e-01, -4.96657632e-01,
#         -7.25227791e-01, -8.64120606e-01, -1.00000000e+00,
#          2.89020724e+00, -1.00000000e+00, -8.42526591e-01,
#         -1.00000000e+00,  3.66402550e+00, -1.00000000e+00,
#         -8.19257888e-01, -1.00000000e+00,  3.74391547e+00,
#         -1.00000000e+00, -7.94151600e-01, -1.00000000e+00,
#          4.27782420e+00, -1.00000000e+00,  1.12207936e-01,
#          0.00000000e+00,  3.26940916e-01,  1.27386353e+00,
#          4.71408803e-01,  0.00000000e+00,  2.17993186e-01,
#          0.00000000e+00,  1.21027987e-01,  0.00000000e+00,
#          6.83146754e-02,  0.00000000e+00, -6.48438329e-01,
#         -8.64120606e-01, -8.42526591e-01, -1.54759382e+01,
#         -6.74414709e-01, -8.06258228e-01,  7.89341177e-03,
#         -4.28435589e-01, -6.68749817e-01, -1.24171952e+02,
#          0.00000000e+00, -6.75689043e+01,  0.00000000e+00,
#          1.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  1.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  1.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#        [ 0.00000000e+00,  0.00000000e+00, -9.89052161e-01,
#          1.69886631e+00, -1.00000000e+00,  0.00000000e+00,
#         -6.65541311e-01, -5.16580501e-01, -4.96657632e-01,
#         -6.93368579e-01, -8.64120606e-01, -1.00000000e+00,
#          1.98375688e+00, -1.00000000e+00, -8.42526591e-01,
#         -1.00000000e+00,  1.66759161e+00, -1.00000000e+00,
#         -8.19257888e-01, -1.00000000e+00,  1.51578530e+00,
#         -1.00000000e+00, -7.94151600e-01, -1.00000000e+00,
#          1.61468559e+00, -1.00000000e+00, -2.33263833e-01,
#          0.00000000e+00, -4.03073965e-01, -1.27954654e+00,
#          7.55340661e+01,  0.00000000e+00,  3.89316910e+01,
#          0.00000000e+00,  2.52293431e+01,  0.00000000e+00,
#          1.74186111e+01,  0.00000000e+00,  4.24631929e-01,
#         -8.64120606e-01, -8.42526591e-01, -1.54759382e+01,
#          1.23221688e+00, -6.47954643e-01,  2.88771552e+00,
#          6.35990341e-01,  1.21524300e+00, -1.21453746e+01,
#          0.00000000e+00, -1.14038297e+00,  0.00000000e+00,
#          1.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  1.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  1.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#        [ 6.66666667e-01,  0.00000000e+00, -9.89052161e-01,
#         -9.55539088e-01, -1.00000000e+00,  0.00000000e+00,
#         -6.65541311e-01, -5.16580501e-01, -4.96657632e-01,
#         -7.25447190e-01, -8.64120606e-01, -1.00000000e+00,
#          5.85230064e-01, -1.00000000e+00, -8.42526591e-01,
#         -1.00000000e+00,  1.82123950e+00, -1.00000000e+00,
#         -8.19257888e-01, -1.00000000e+00,  2.59800328e+00,
#         -1.00000000e+00, -7.94151600e-01, -1.00000000e+00,
#          2.86855243e+00, -1.00000000e+00, -1.27840434e-01,
#          0.00000000e+00,  5.42062162e-02,  5.88358917e-01,
#         -4.55129464e-02,  0.00000000e+00, -4.86101177e-02,
#          0.00000000e+00, -5.18813481e-02,  0.00000000e+00,
#         -5.11687786e-02,  0.00000000e+00, -6.55828066e-01,
#         -8.64120606e-01, -8.42526591e-01, -1.54759382e+01,
#         -6.87544798e-01, -8.07348391e-01, -1.19385891e-02,
#         -4.35765797e-01, -6.81724002e-01, -4.87415356e+01,
#          0.00000000e+00, -4.01753866e+01,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  1.00000000e+00,
#          0.00000000e+00,  1.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  1.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00]])

# %%
# np.save('train.npy', train)
# np.save('test.npy', test)
# !zip features.zip train.npy test.npy

# %% [markdown]
# ## Hardware config

# %%
IS_TPU = False
try:
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
    tf.config.experimental_connect_to_cluster(tpu)
    tf.tpu.experimental.initialize_tpu_system(tpu)
    tpu_strategy = tf.distribute.experimental.TPUStrategy(tpu)
    BATCH_SIZE = tpu_strategy.num_replicas_in_sync * 64
    print("Running on TPU:", tpu.master())
    print(f"Batch Size: {BATCH_SIZE}")
    IS_TPU = True    
except ValueError:
    tpu_strategy = tf.distribute.get_strategy()
    BATCH_SIZE = 512
    print(f"Running on {tpu_strategy.num_replicas_in_sync} replicas")
    print(f"Batch Size: {BATCH_SIZE}")
# Out:
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Initializing the TPU system: grpc://10.90.102.18:8470
# INFO:tensorflow:Initializing the TPU system: grpc://10.90.102.18:8470
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Finished initializing TPU system.
# WARNING:absl:`tf.distribute.experimental.TPUStrategy` is deprecated, please use  the non experimental symbol `tf.distribute.TPUStrategy` instead.
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:2, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:2, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:3, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:3, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:4, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:4, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:5, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:5, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:6, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:6, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:7, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:7, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)
# Running on TPU: grpc://10.90.102.18:8470
# Batch Size: 512

# %% [markdown]
# ## Rescaling layer

# %%
@tf.custom_gradient
def round_with_gradients(x):
    def grad(dy):
        return dy
    return tf.round(x), grad

class ScaleLayer(tf.keras.layers.Layer):
    def __init__(self, **kwargs):
        super(ScaleLayer, self).__init__(**kwargs)
        self.min = tf.constant(pressure_min, dtype=np.float32)
        self.max = tf.constant(pressure_max, dtype=np.float32)
        self.step = tf.constant(pressure_step, dtype=np.float32)

    def call(self, inputs):
        steps = tf.math.divide(tf.math.add(inputs, -self.min), self.step)
        int_steps = round_with_gradients(steps)
        rescaled_steps = tf.math.add(tf.math.multiply(int_steps, self.step), self.min)
        clipped = tf.clip_by_value(rescaled_steps, self.min, self.max)
        return clipped
    # def get_config(self):
    #     return super(ScaleLayer, self).get_config()

# %%
def external_attention(
    x, dim, num_heads, dim_coefficient=4, attention_dropout=0, projection_dropout=0
):
    _, num_patch, channel = x.shape
    assert dim % num_heads == 0
    num_heads = num_heads * dim_coefficient

    x = layers.Dense(dim * dim_coefficient)(x)
    # create tensor [batch_size, num_patches, num_heads, dim*dim_coefficient//num_heads]
    x = tf.reshape(
        x, shape=(-1, num_patch, num_heads, dim * dim_coefficient // num_heads)
    )
    x = tf.transpose(x, perm=[0, 2, 1, 3])
    # a linear layer M_k
    attn = layers.Dense(dim // dim_coefficient)(x)
    # normalize attention map
    attn = layers.Softmax(axis=2)(attn)
    # dobule-normalization
    attn = attn / (1e-9 + tf.reduce_sum(attn, axis=-1, keepdims=True))
    attn = layers.Dropout(attention_dropout)(attn)
    # a linear layer M_v
    x = layers.Dense(dim * dim_coefficient // num_heads)(attn)
    x = tf.transpose(x, perm=[0, 2, 1, 3])
    x = tf.reshape(x, [-1, num_patch, dim * dim_coefficient])
    # a linear layer to project original dim
    x = layers.Dense(dim)(x)
    x = layers.Dropout(projection_dropout)(x)
    return x

def mlp(x, embedding_dim, mlp_dim, drop_rate=0.2):
    x = layers.Dense(mlp_dim, activation=tf.nn.gelu)(x)
    x = layers.Dropout(drop_rate)(x)
    x = layers.Dense(embedding_dim)(x)
    x = layers.Dropout(drop_rate)(x)
    return x

def transformer_encoder(
    x,
    embedding_dim,
    mlp_dim,
    num_heads,
    dim_coefficient,
    attention_dropout,
    projection_dropout,
    attention_type="external_attention",
):
    residual_1 = x
    x = layers.LayerNormalization(epsilon=1e-5)(x)
    if attention_type == "external_attention":
        x = external_attention(
            x,
            embedding_dim,
            num_heads,
            dim_coefficient,
            attention_dropout,
            projection_dropout,
        )
    elif attention_type == "self_attention":
        x = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embedding_dim, dropout=attention_dropout
        )(x, x)
    x = layers.add([x, residual_1])
    residual_2 = x
    x = layers.LayerNormalization(epsilon=1e-5)(x)
    x = mlp(x, embedding_dim, mlp_dim)
    x = layers.add([x, residual_2])
    return x

# %%
def external_attention(
    x, dim, num_heads, dim_coefficient=4, attention_dropout=0, projection_dropout=0
):
    _, num_patch, channel = x.shape
    assert dim % num_heads == 0
    num_heads = num_heads * dim_coefficient

    x = layers.Dense(dim * dim_coefficient)(x)
    # create tensor [batch_size, num_patches, num_heads, dim*dim_coefficient//num_heads]
    x = tf.reshape(
        x, shape=(-1, num_patch, num_heads, dim * dim_coefficient // num_heads)
    )
    x = tf.transpose(x, perm=[0, 2, 1, 3])
    # a linear layer M_k
    attn = layers.Dense(dim // dim_coefficient)(x)
    # normalize attention map
    attn = layers.Softmax(axis=2)(attn)
    # dobule-normalization
    attn = attn / (1e-9 + tf.reduce_sum(attn, axis=-1, keepdims=True))
    attn = layers.Dropout(attention_dropout)(attn)
    # a linear layer M_v
    x = layers.Dense(dim * dim_coefficient // num_heads)(attn)
    x = tf.transpose(x, perm=[0, 2, 1, 3])
    x = tf.reshape(x, [-1, num_patch, dim * dim_coefficient])
    # a linear layer to project original dim
    x = layers.Dense(dim)(x)
    x = layers.Dropout(projection_dropout)(x)
    return x

# %%
class TransformerEncoder(tf.keras.layers.Layer):
    def __init__(self, head_size, ff_dim, num_heads, dropout=0.3, **kwargs):
        super().__init__(**kwargs)
        self.embed_dim = head_size
        self.dense_dim = ff_dim
        self.num_heads = num_heads
        self.dropout = dropout
        self.attention_dropout = tf.keras.layers.Dropout(dropout)

        self.attention = tf.keras.layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=head_size, dropout=dropout
        )

        self.attention_norm = tf.keras.layers.LayerNormalization(epsilon=1e-6)

        self.ff_conv1 = tf.keras.layers.Conv1D(filters=ff_dim, kernel_size=1, activation='relu', name='ff_conv1')
        self.ff_dropout = tf.keras.layers.Dropout(dropout)
        self.ff_norm = tf.keras.layers.LayerNormalization(epsilon=1e-6)

    def build(self, input_shape):
      self.ff_conv2 = tf.keras.layers.Conv1D(filters=input_shape[-1], kernel_size=1, name='ff_conv2')

    def call(self, inputs, mask=None):
        if mask is not None:
            mask = mask[:, tf.newaxis, :]

        attention_output = self.attention(inputs, inputs, attention_mask=mask)
        attention_output = self.attention_dropout(attention_output)
        proj_input = self.attention_norm(inputs + attention_output)
        proj_output = self.ff_conv1(proj_input)
        proj_output = self.ff_conv2(proj_output)
        proj_output = self.ff_dropout(proj_output)
        return self.ff_norm(inputs + proj_output)
    
    def get_config(self):
        config = super(TransformerEncoder, self).get_config()
        config.update({"head_size": self.embed_dim,
            "ff_dim": self.dense_dim,
            "num_heads": self.num_heads,
            "dropout": self.dropout})
        return config

#refer to https://www.kaggle.com/aimanlim0/transformer-lstm
class Time2Vec(tf.keras.layers.Layer):
    def __init__(self, kernel_size=1, **kwargs):
        super(Time2Vec, self).__init__(**kwargs)
        self.k = kernel_size
    
    def build(self, input_shape):
        # print(input_shape)
        # trend
        self.wb = self.add_weight(name='wb',shape=(input_shape[1],),initializer='uniform',trainable=True)
        self.bb = self.add_weight(name='bb',shape=(input_shape[1],),initializer='uniform',trainable=True)
        # periodic
        self.wa = self.add_weight(name='wa',shape=(1, input_shape[1], self.k),initializer='uniform',trainable=True)
        self.ba = self.add_weight(name='ba',shape=(1, input_shape[1], self.k),initializer='uniform',trainable=True)
        super(Time2Vec, self).build(input_shape)
    
    def call(self, inputs, **kwargs):
        bias = self.wb * inputs + self.bb
        dp = K.dot(inputs, self.wa) + self.ba
        wgts = K.sin(dp) # or K.cos(.)

        ret = K.concatenate([K.expand_dims(bias, -1), wgts], -1)
        ret = K.reshape(ret, (-1, inputs.shape[1]*(self.k+1)))
        return ret
    
    def compute_output_shape(self, input_shape):
        return (input_shape[0], input_shape[1]*(self.k + 1))

    def get_config(self):
        config = super(Time2Vec, self).get_config()
        config.update({
            "kernel_size": self.k
            })
        return config

class ModelTrunk(tf.keras.Model):
    def __init__(self, name='ModelTrunk', time2vec_dim=1, num_heads=2, head_size=128, ff_dim=None, num_layers=1, dropout=0, **kwargs):
        super().__init__(name=name, **kwargs)
        self.time2vec = Time2Vec(kernel_size=time2vec_dim)
        if ff_dim is None:
            ff_dim = head_size
        self.dropout = dropout
        self.attention_layers = [TransformerEncoder(num_heads=num_heads, head_size=head_size, ff_dim=ff_dim, dropout=dropout) for _ in range(num_layers)]
        #self.pooling=tf.keras.layers.AveragePooling1D(pool_size=4,data_format='channels_first')
        self.final_layer = tf.keras.Sequential([
                Bidirectional(LSTM(256, return_sequences=True)),
                Bidirectional(LSTM(256, return_sequences=True)),
                Dense(128, activation='selu'),
                Dense(1)])
    def call(self, inputs):
        time_embedding = tf.keras.layers.TimeDistributed(self.time2vec)(inputs)
        #time_embedding=inputs
        #print(time_embedding.shape)
        x = K.concatenate([inputs, time_embedding], -1)
        for attention_layer in self.attention_layers:
            x = attention_layer(x)
        x=self.final_layer(x)
        return x

def do_TransformerEncoder_LSTM(inputs, time2vec_dim=1, num_heads=8, head_size=128, ff_dim=None, num_layers=1, dropout=0):
    time2vec = Time2Vec(kernel_size=time2vec_dim)
    if ff_dim is None:
        ff_dim = head_size
    dropout = dropout
    attention_layers = [TransformerEncoder(num_heads=num_heads, head_size=head_size, ff_dim=ff_dim, dropout=dropout) for _ in range(num_layers)]
    #self.pooling=tf.keras.layers.AveragePooling1D(pool_size=4,data_format='channels_first')
    final_layer = tf.keras.Sequential([
            Bidirectional(LSTM(256, return_sequences=True)),
            Bidirectional(LSTM(256, return_sequences=True)),
            Dense(128, activation='selu')
    ])
    
    time_embedding = tf.keras.layers.TimeDistributed(time2vec)(inputs)
    x = K.concatenate([inputs, time_embedding], -1)
    for attention_layer in attention_layers:
        x = attention_layer(x)
    x=final_layer(x)
    return x

def do_ExternalTransformerEncoder_LSTM(inputs, time2vec_dim=1, num_heads=8, head_size=128, ff_dim=None, num_layers=1, 
                                       dropout=0, dim_coefficient = 4, attention_type="external_attention"):
    time2vec = Time2Vec(kernel_size=time2vec_dim)
    if ff_dim is None:
        ff_dim = head_size
    dropout = dropout
    final_layer = tf.keras.Sequential([
            Bidirectional(LSTM(256, return_sequences=True)),
            Bidirectional(LSTM(256, return_sequences=True)),
            Dense(128, activation='selu')
    ])
    
    time_embedding = tf.keras.layers.TimeDistributed(time2vec)(inputs)
    x = K.concatenate([inputs, time_embedding], -1)
    # Change 198 to 128 for external_attention
    x = Dense(units=128)(x)
    #print(x.shape)
    embedding_dim = x.shape[-1]
    for attention_layer in range(num_layers):
        x = transformer_encoder(
            x,
            embedding_dim,
            ff_dim,
            num_heads,
            dim_coefficient,
            dropout,
            dropout,
            attention_type,
        )
    x=final_layer(x)
    return x

class PositionalEmbedding(tf.keras.layers.Layer):
    def __init__(self, sequence_length, vocab_size, embed_dim, **kwargs):
        super(PositionalEmbedding, self).__init__(**kwargs)
        self.token_embeddings = tf.keras.layers.Layer.Embedding(
            input_dim=vocab_size, output_dim=embed_dim
        )
        self.position_embeddings = tf.keras.layers.Layer.Embedding(
            input_dim=sequence_length, output_dim=embed_dim
        )
        self.sequence_length = sequence_length
        self.vocab_size = vocab_size
        self.embed_dim = embed_dim

    def call(self, inputs):
        length = tf.shape(inputs)[-1]
        positions = tf.range(start=0, limit=length, delta=1)
        embedded_tokens = self.token_embeddings(inputs)
        embedded_positions = self.position_embeddings(positions)
        return embedded_tokens + embedded_positions

    def compute_mask(self, inputs, mask=None):
        return tf.math.not_equal(inputs, 0)


class TransformerDecoder(tf.keras.layers.Layer):
    def __init__(self, embed_dim, latent_dim, num_heads, **kwargs):
        super(TransformerDecoder, self).__init__(**kwargs)
        self.embed_dim = embed_dim
        self.latent_dim = latent_dim
        self.num_heads = num_heads
        self.attention_1 = tf.keras.layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim
        )
        self.attention_2 = tf.keras.layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim
        )
        self.dense_proj = tf.keras.Sequential(
            [Dense(latent_dim, activation="relu"), Dense(embed_dim),]
        )
        self.layernorm_1 = tf.keras.layers.LayerNormalization()
        self.layernorm_2 = tf.keras.layers.LayerNormalization()
        self.layernorm_3 = tf.keras.layers.LayerNormalization()
        self.supports_masking = True

    def call(self, inputs, encoder_outputs, mask=None):
        causal_mask = self.get_causal_attention_mask(inputs)
        padding_mask = None
        if mask is not None:
            padding_mask = tf.cast(mask[:, tf.newaxis, :], dtype="int32")
            padding_mask = tf.minimum(padding_mask, causal_mask)

        attention_output_1 = self.attention_1(
            query=inputs, value=inputs, key=inputs, attention_mask=causal_mask
        )
        out_1 = self.layernorm_1(inputs + attention_output_1)

        attention_output_2 = self.attention_2(
            query=out_1,
            value=encoder_outputs,
            key=encoder_outputs,
            attention_mask=padding_mask,
        )
        out_2 = self.layernorm_2(out_1 + attention_output_2)

        proj_output = self.dense_proj(out_2)
        return self.layernorm_3(out_2 + proj_output)

    def get_causal_attention_mask(self, inputs):
        input_shape = tf.shape(inputs)
        batch_size, sequence_length = input_shape[0], input_shape[1]
        i = tf.range(sequence_length)[:, tf.newaxis]
        j = tf.range(sequence_length)
        mask = tf.cast(i >= j, dtype="int32")
        mask = tf.reshape(mask, (1, input_shape[1], input_shape[1]))
        mult = tf.concat(
            [tf.expand_dims(batch_size, -1), tf.constant([1, 1], dtype=tf.int32)],
            axis=0,
        )
        return tf.tile(mask, mult)
    
    def get_config(self):
        config = super(TransformerDecoder, self).get_config()
        config.update({
            "embed_dim": self.embed_dim,
            "latent_dim": self.latent_dim,
            "num_heads": self.num_heads
            })
        return config

def TransformerEncoder_LSTM_model(time2vec_dim=1, num_heads=8, head_size=128, ff_dim=None, num_layers=1, dropout=0):
    inputs = Input(shape=(train.shape[-2:]))
    x = do_TransformerEncoder_LSTM(inputs, time2vec_dim, num_heads, head_size, ff_dim, num_layers, dropout)
    x = Dense(1)(x)
    x_output = ScaleLayer()(x)

    model = Model(inputs=inputs, outputs=x_output, 
                  name='TransformerEncoder_LSTM_model')
    return model    

def ExternalTransformerEncoder_LSTM_model(time2vec_dim=1, num_heads=8, head_size=128, ff_dim=None, num_layers=1, dropout=0):
    inputs = Input(shape=(train.shape[-2:]))
    x = do_ExternalTransformerEncoder_LSTM(inputs, time2vec_dim, num_heads, head_size, ff_dim, num_layers, dropout)
    x = Dense(1)(x)
    in_pressure = ScaleLayer(name = 'in_pressure')(x)
    out_pressure = ScaleLayer(name = 'out_pressure')(x)

    model = Model(inputs=inputs, outputs=[in_pressure, out_pressure], 
                  name='ExternalTransformerEncoder_LSTM_model')
    return model    


TRANSFORM_MAX_LEN = 83

def Transformer_LSTM_model(time2vec_dim=1, num_heads=8, head_size=128, ff_dim=None, num_layers=1, dropout=0):
    encoder_inputs = Input(shape=(train.shape[-2:]))
    encoder_outputs = do_TransformerEncoder_LSTM(encoder_inputs, time2vec_dim, num_heads, head_size, ff_dim, num_layers, dropout)

    encoder_model = Model(inputs=encoder_inputs, outputs=encoder_outputs, 
                  name='encoder_model')
    
    embed_dim = 128
    latent_dim = 1024
    decoder_inputs = Input(shape=(TRANSFORM_MAX_LEN,), name="decoder_inputs")
    encoded_seq_inputs = Input(shape=(80, embed_dim), name="decoder_state_inputs")
    
    time2vec = Time2Vec(kernel_size=1)
    time_embedding = tf.keras.layers.TimeDistributed(time2vec)
    #Expand target and embeding with time. 80x2
    x = K.expand_dims(decoder_inputs, -1)
    x = time_embedding(x)
    #Expand 80x2 to 80xembed_dim
    x = Dense(embed_dim)(x)
    
    x = TransformerDecoder(embed_dim, latent_dim, num_heads)(x, encoded_seq_inputs)
#     x = Dropout(0.5)(x)
    x = Dense(128, activation='selu')(x)
    decoder_outputs = Dense(1)(x)
    decoder = Model([decoder_inputs, encoded_seq_inputs], decoder_outputs, name='decoder_model')
    decoder.summary()
    
    decoder_outputs = decoder([decoder_inputs, encoder_outputs])
    transformer = Model(
        [encoder_inputs, decoder_inputs], decoder_outputs, name="Transformer_LSTM_model"
    )
    
    return transformer

# %% [markdown]
# model=ModelTrunk(ff_dim=256,num_heads=4,num_layers=2,)
# x=tf.random.uniform((64,80,66))
# x=model(x)
# print(x.shape)
# del model

# %% [markdown]
# ## Keras DNN Model

# %%
def dnn_model_v4():
    
    x_input = Input(shape=(train.shape[-2:]))
    
    x1 = Bidirectional(LSTM(units=768, return_sequences=True))(x_input)
    x2 = Bidirectional(LSTM(units=512, return_sequences=True))(x1)
    x3 = Bidirectional(LSTM(units=384, return_sequences=True))(x2)
    x4 = Bidirectional(LSTM(units=256, return_sequences=True))(x3)
    x5 = Bidirectional(LSTM(units=128, return_sequences=True))(x4)
    
    z2 = Bidirectional(GRU(units=384, return_sequences=True))(x2)
    
    z31 = Multiply()([x3, z2])
    z31 = BatchNormalization()(z31)
    z3 = Bidirectional(GRU(units=256, return_sequences=True))(z31)
    
    z41 = Multiply()([x4, z3])
    z41 = BatchNormalization()(z41)
    z4 = Bidirectional(GRU(units=128, return_sequences=True))(z41)
    
    z51 = Multiply()([x5, z4])
    z51 = BatchNormalization()(z51)
    z5 = Bidirectional(GRU(units=64, return_sequences=True))(z51)
    
    x = Concatenate(axis=2)([x5, z2, z3, z4, z5])
    
    x = Dense(units=128, activation='selu')(x)
    
    x_output = Dense(units=1)(x)
    
    x_output = ScaleLayer()(x_output)

    model = Model(inputs=x_input, outputs=x_output, 
                  name='DNN_Model_v4')
    return model

# %%
#refer to https://www.kaggle.com/masato114/vp-wavenet-training-gpu
# def conv_block(x: tf.Tensor, filters: int, kernel_size: int):
#     """
#     Implements convolution block with residual connection.
#     :param x: Input tensor.
#     :param filters: Number of filters in convolution layer.
#     :param kernel_size: Filter size.
#     :return: Output tensor.
#     """
#     x = tf.keras.layers.Conv1D(filters=filters,
#                kernel_size=1,
#                padding='same')(x)
#     res_x = x
#     x = tf.keras.layers.Conv1D(filters=filters,
#                kernel_size=kernel_size,
#                padding='same', activation='relu')(x)
#     x = tf.keras.layers.Conv1D(filters=filters,
#                kernel_size=kernel_size,
#                padding='same', activation='relu')(x)
#     x = tf.keras.layers.Conv1D(filters=filters,
#                kernel_size=kernel_size,
#                padding='same', activation='relu')(x)
#     res_x = tf.keras.layers.Add()([res_x, x])
#     return res_x

# def wave_block(x: tf.Tensor, filters: int, kernel_size: int, n: int):
#     """
#     Implements wavenet block.
#     :param x: Input tensor.
#     :param filters: Number of kernels.
#     :param kernel_size: Filter size.
#     :param n: Number of dilation rates for convolutions.
#     :return: Output tensor.
#     """
#     dilation_rates = [2 ** i for i in range(n)]
#     x = tf.keras.layers.Conv1D(filters=filters,
#                kernel_size=1,
#                padding='same')(x)
#     res_x = x
#     for dilation_rate in dilation_rates:
#         tanh_out = tf.keras.layers.Conv1D(filters=filters,
#                           kernel_size=kernel_size,
#                           padding='same',
#                           activation='tanh',
#                           dilation_rate=dilation_rate)(x)
#         sigm_out = tf.keras.layers.Conv1D(filters=filters,
#                           kernel_size=kernel_size,
#                           padding='same',
#                           activation='sigmoid',
#                           dilation_rate=dilation_rate)(x)
#         x = tf.keras.layers.Multiply()([tanh_out, sigm_out])
#         x = tf.keras.layers.Conv1D(filters=filters,
#                    kernel_size=1,
#                    padding='same')(x)
#         res_x = tf.keras.layers.Add()([res_x, x])
#     return res_x

# def do_wavenet(inp):
#     x = conv_block(inp, 16, 3)
#     x = wave_block(x, 16, 3, 12)
#     x = conv_block(x, 32, 3)
#     x = wave_block(x, 32, 3, 8)
#     x = conv_block(x, 64, 3)
#     x = wave_block(x, 64, 3, 4)
#     x = conv_block(x, 128, 3)
#     x = wave_block(x, 128, 3, 1)
#     return x

#refer to https://www.kaggle.com/meminozturk/into-the-wild-wavenet/
i_wavenet_layer = 0
def wave_block(x, filters, kernel_size, n):
    global i_wavenet_layer
    dilation_rates = [2**i for i in range(n)]
    x = tf.keras.layers.Conv1D(filters = filters,
                kernel_size = 1,
                padding = 'same')(x)
    res_x = x
    for dilation_rate in dilation_rates:
        tanh_out = tf.keras.layers.Conv1D(filters = filters,
                          kernel_size = kernel_size,
                          padding = 'same', 
                          activation = 'tanh', 
                          dilation_rate = dilation_rate)(x)
        sigm_out = tf.keras.layers.Conv1D(filters = filters,
                          kernel_size = kernel_size,
                          padding = 'same',
                          activation = 'sigmoid', 
                          dilation_rate = dilation_rate)(x)
        x = tf.keras.layers.Multiply(name=f'wavenet_Multiply_{i_wavenet_layer}')([tanh_out, sigm_out])
        x = tf.keras.layers.Conv1D(filters = filters,
                    kernel_size = 1,
                    padding = 'same')(x)
        res_x = tf.keras.layers.Add()([res_x, x])
        i_wavenet_layer += 1
    return res_x

def do_wavenet(inp):
  x = wave_block(inp, 16, 3, 8)
  x = wave_block(x, 32, 3, 12)
  x = wave_block(x, 64, 3, 4)
  x = wave_block(x, 128, 3, 1)
  return x

def load_model_until(checkpoint_name, drop_idx=-4, retrain=False):
  print('Load pretrain weight from ', checkpoint_name)
  load_locally = tf.saved_model.LoadOptions(experimental_io_device='/job:localhost')
  try:
    # At loading time, register the custom objects with a `custom_object_scope`:
    custom_objects = {"ScaleLayer": ScaleLayer}
    with tf.keras.utils.custom_object_scope(custom_objects):
        base_model = load_model(checkpoint_name, options=load_locally)
  except (OSError):
    print('Cannot load pretrain weight from ', checkpoint_name)

  # base_model.summary()
  base_output = base_model.layers[drop_idx].output
  # Frozen layers
  for layer in base_model.layers[0:drop_idx]:
    layer.trainable = retrain

  return base_model.inputs, base_output

def load_dnn_model_v4_add_wavenet(drop_idx=-4, retrain=False):
  base_inputs, base_output = load_model_until('/gdrive/MyDrive/ventilator-pressure-prediction/gb-rescaling-eda-v3/Bidirect_LSTM_model_1C.h5', drop_idx, 
                                              drop_idx=drop_idx, retrain=retrain)
  
  wavenet_output = do_wavenet(base_output)

  global i_wavenet_layer
  x_output = Dense(units=1, name=f'wavenet_Dense_{i_wavenet_layer}')(wavenet_output)
  i_wavenet_layer += 1
  x_output = ScaleLayer()(x_output)

  new_model = tf.keras.models.Model(inputs=base_inputs, outputs=x_output)
  # new_model.summary()

  return new_model

def lstm_wavenet_model():
    x_input = Input(shape=(train.shape[-2:]))
    
    x1 = Bidirectional(LSTM(units=768, return_sequences=True))(x_input)
    x2 = Bidirectional(LSTM(units=512, return_sequences=True))(x1)
    x3 = Bidirectional(LSTM(units=384, return_sequences=True))(x2)
    x4 = Bidirectional(LSTM(units=256, return_sequences=True))(x3)
    x5 = Bidirectional(LSTM(units=128, return_sequences=True))(x4)
    
    z2 = Bidirectional(GRU(units=384, return_sequences=True))(x2)
    
    z31 = Multiply()([x3, z2])
    z31 = BatchNormalization()(z31)
    z3 = Bidirectional(GRU(units=256, return_sequences=True))(z31)
    
    z41 = Multiply()([x4, z3])
    z41 = BatchNormalization()(z41)
    z4 = Bidirectional(GRU(units=128, return_sequences=True))(z41)
    
    z51 = Multiply()([x5, z4])
    z51 = BatchNormalization()(z51)
    z5 = Bidirectional(GRU(units=64, return_sequences=True))(z51)
    
    x = Concatenate(axis=2)([x5, z2, z3, z4, z5])
    
    x = do_wavenet(x)
    
    x = Dense(units=128, activation='selu')(x)
    x_output = Dense(units=1)(x)
    
    x_output = ScaleLayer()(x_output)

    model = Model(inputs=x_input, outputs=x_output, 
                  name='lstm_wavenet_model')
    return model

# %%
def dnn_model_aen():
    
    x_input = Input(shape=(train.shape[-2:]))

    x0 = tf.keras.layers.BatchNormalization()(x_input)
    
    #remove noise
    # encoder = tf.keras.layers.GaussianNoise(0.03527936123679956)(x0)
    encoder = tf.keras.layers.Dense(16)(x0)
    encoder = tf.keras.layers.BatchNormalization()(encoder)
    encoder = tf.keras.layers.Activation('swish')(encoder)
    
    decoder = tf.keras.layers.Dropout(0.0)(encoder)
    decoder = tf.keras.layers.Dense(train.shape[-1], name = 'decoder')(decoder)


    # x = tf.keras.layers.Concatenate()([x0, encoder])
    x = encoder
    
    x1 = Bidirectional(LSTM(units=768, return_sequences=True))(x)
    x2 = Bidirectional(LSTM(units=512, return_sequences=True))(x1)
    x3 = Bidirectional(LSTM(units=384, return_sequences=True))(x2)
    x4 = Bidirectional(LSTM(units=256, return_sequences=True))(x3)
    x5 = Bidirectional(LSTM(units=128, return_sequences=True))(x4)

    x_ae = tf.keras.layers.Dense(128, activation='swish')(x5)
    x_ae = tf.keras.layers.Dropout(0.0)(x_ae)

    out_ae = tf.keras.layers.Dense(1, name = 'ae_action')(x_ae)

    z2 = Bidirectional(GRU(units=384, return_sequences=True))(x2)
    
    z31 = Multiply()([x3, z2])
    z31 = BatchNormalization()(z31)
    z3 = Bidirectional(GRU(units=256, return_sequences=True))(z31)
    
    z41 = Multiply()([x4, z3])
    z41 = BatchNormalization()(z41)
    z4 = Bidirectional(GRU(units=128, return_sequences=True))(z41)
    
    z51 = Multiply()([x5, z4])
    z51 = BatchNormalization()(z51)
    z5 = Bidirectional(GRU(units=64, return_sequences=True))(z51)
    
    x = Concatenate(axis=2)([x5, z2, z3, z4, z5])
    
    x = Dense(units=128, activation='swish')(x)
    
    x_output = Dense(units=1)(x)
    
    x_output = ScaleLayer(name = 'output')(x_output)

    model = Model(inputs=x_input, outputs=[decoder, out_ae, x_output], 
                  name='dnn_model_aen')
    return model

# %%
def dnn_model_GaussianNoise():
    
    x_input = Input(shape=(train.shape[-2:]))
    
    x1 = Bidirectional(LSTM(units=768, return_sequences=True))(x_input)
    x2 = Bidirectional(LSTM(units=512, return_sequences=True))(x1)
    x3 = Bidirectional(LSTM(units=384, return_sequences=True))(x2)
    x4 = Bidirectional(LSTM(units=256, return_sequences=True))(x3)
    x5 = Bidirectional(LSTM(units=128, return_sequences=True))(x4)
    
    z2 = Bidirectional(GRU(units=384, return_sequences=True))(x2)
    
    z31 = Multiply()([x3, z2])
    z31 = BatchNormalization()(z31)
    z31 = tf.keras.layers.GaussianNoise(0.035)(z31)
    z3 = Bidirectional(GRU(units=256, return_sequences=True))(z31)
    
    z41 = Multiply()([x4, z3])
    z41 = BatchNormalization()(z41)
    z4 = Bidirectional(GRU(units=128, return_sequences=True))(z41)
    
    z51 = Multiply()([x5, z4])
    z51 = BatchNormalization()(z51)
    z5 = Bidirectional(GRU(units=64, return_sequences=True))(z51)
    
    x = Concatenate(axis=2)([x5, z2, z3, z4, z5])
    
    x = Dense(units=128, activation='selu')(x)
    
    x_output = Dense(units=1)(x)
    
    x_output = ScaleLayer()(x_output)

    model = Model(inputs=x_input, outputs=x_output, 
                  name='dnn_model_GaussianNoise')
    return model

# %%
def dnn_TransformerEncoder_model():
    
    x_input = Input(shape=(train.shape[-2:]))
    
    x1 = Bidirectional(LSTM(units=768, return_sequences=True))(x_input)
    x2 = Bidirectional(LSTM(units=512, return_sequences=True))(x1)
    x3 = Bidirectional(LSTM(units=384, return_sequences=True))(x2)
    x4 = Bidirectional(LSTM(units=256, return_sequences=True))(x3)
    x5 = Bidirectional(LSTM(units=128, return_sequences=True))(x4)
    
    z2 = Bidirectional(GRU(units=384, return_sequences=True))(x2)

    dropout_r = 0.01
    
    z31 = Multiply()([x3, z2])
    z31 = BatchNormalization()(z31)
    z31_transformer = TransformerEncoder(384*2, 512*2, 8, dropout_r, name="transformer_layer_z31")(z31)
    z31 = Multiply()([z31, z31_transformer])
    
    z3 = Bidirectional(GRU(units=256, return_sequences=True))(z31)
    
    z41 = Multiply()([x4, z3])
    z41 = BatchNormalization()(z41)
    z41_transformer = TransformerEncoder(256*2, 384*2, 8, dropout_r, name="transformer_layer_z41")(z41)
    z41 = Multiply()([z41, z41_transformer])
    
    z4 = Bidirectional(GRU(units=128, return_sequences=True))(z41)
    
    z51 = Multiply()([x5, z4])
    z51 = BatchNormalization()(z51)
    z51_transformer = TransformerEncoder(128*2, 256*2, 8, dropout_r, name="transformer_layer_z51")(z51)
    z51 = Multiply()([z51, z51_transformer])
    
    z5 = Bidirectional(GRU(units=64, return_sequences=True))(z51)
    
    x = Concatenate(axis=2)([x5, z2, z3, z4, z5])

    x = Dense(units=128)(x)

    x_transformer = BatchNormalization()(x)
    x_transformer = TransformerEncoder(128, 512, 8, dropout_r, name="transformer_layer_128")(x_transformer)
    x = Multiply()([Dropout(0.01)(x), x_transformer])
    
    x = Dense(units=128, activation='selu')(x)
    
    x_output = Dense(units=1)(x)
    
    x_output = ScaleLayer()(x_output)

    model = Model(inputs=x_input, outputs=x_output, 
                  name='dnn_TransformerEncoder_model')
    return model

# %%
model = ExternalTransformerEncoder_LSTM_model(ff_dim=256,num_heads=8,num_layers=2,)
model.summary()
# Out:
# Model: "ExternalTransformerEncoder_LSTM_model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 80, 66)]     0
# __________________________________________________________________________________________________
# time_distributed (TimeDistribut (None, 80, 132)      264         input_1[0][0]
# __________________________________________________________________________________________________
# tf.concat (TFOpLambda)          (None, 80, 198)      0           input_1[0][0]
#                                                                  time_distributed[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 80, 128)      25472       tf.concat[0][0]
# __________________________________________________________________________________________________
# layer_normalization (LayerNorma (None, 80, 128)      256         dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 80, 512)      66048       layer_normalization[0][0]
# __________________________________________________________________________________________________
# tf.reshape (TFOpLambda)         (None, 80, 32, 16)   0           dense_2[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.transpose (TFOpLam (None, 32, 80, 16)   0           tf.reshape[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 32, 80, 32)   544         tf.compat.v1.transpose[0][0]
# __________________________________________________________________________________________________
# softmax (Softmax)               (None, 32, 80, 32)   0           dense_3[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_sum (TFOpLambda) (None, 32, 80, 1)    0           softmax[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add (TFOpLambd (None, 32, 80, 1)    0           tf.math.reduce_sum[0][0]
# __________________________________________________________________________________________________
# tf.math.truediv (TFOpLambda)    (None, 32, 80, 32)   0           softmax[0][0]
#                                                                  tf.__operators__.add[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 32, 80, 32)   0           tf.math.truediv[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 32, 80, 16)   528         dropout[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.transpose_1 (TFOpL (None, 80, 32, 16)   0           dense_4[0][0]
# __________________________________________________________________________________________________
# tf.reshape_1 (TFOpLambda)       (None, 80, 512)      0           tf.compat.v1.transpose_1[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 80, 128)      65664       tf.reshape_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 80, 128)      0           dense_5[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 80, 128)      0           dropout_1[0][0]
#                                                                  dense_1[0][0]
# __________________________________________________________________________________________________
# layer_normalization_1 (LayerNor (None, 80, 128)      256         add[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 80, 256)      33024       layer_normalization_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 80, 256)      0           dense_6[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 80, 128)      32896       dropout_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 80, 128)      0           dense_7[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 80, 128)      0           dropout_3[0][0]
#                                                                  add[0][0]
# __________________________________________________________________________________________________
# layer_normalization_2 (LayerNor (None, 80, 128)      256         add_1[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 80, 512)      66048       layer_normalization_2[0][0]
# __________________________________________________________________________________________________
# tf.reshape_2 (TFOpLambda)       (None, 80, 32, 16)   0           dense_8[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.transpose_2 (TFOpL (None, 32, 80, 16)   0           tf.reshape_2[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 32, 80, 32)   544         tf.compat.v1.transpose_2[0][0]
# __________________________________________________________________________________________________
# softmax_1 (Softmax)             (None, 32, 80, 32)   0           dense_9[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_sum_1 (TFOpLambd (None, 32, 80, 1)    0           softmax_1[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_1 (TFOpLam (None, 32, 80, 1)    0           tf.math.reduce_sum_1[0][0]
# __________________________________________________________________________________________________
# tf.math.truediv_1 (TFOpLambda)  (None, 32, 80, 32)   0           softmax_1[0][0]
#                                                                  tf.__operators__.add_1[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 32, 80, 32)   0           tf.math.truediv_1[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 32, 80, 16)   528         dropout_4[0][0]
# __________________________________________________________________________________________________
# tf.compat.v1.transpose_3 (TFOpL (None, 80, 32, 16)   0           dense_10[0][0]
# __________________________________________________________________________________________________
# tf.reshape_3 (TFOpLambda)       (None, 80, 512)      0           tf.compat.v1.transpose_3[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 80, 128)      65664       tf.reshape_3[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 80, 128)      0           dense_11[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 80, 128)      0           dropout_5[0][0]
#                                                                  add_1[0][0]
# __________________________________________________________________________________________________
# layer_normalization_3 (LayerNor (None, 80, 128)      256         add_2[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 80, 256)      33024       layer_normalization_3[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 80, 256)      0           dense_12[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 80, 128)      32896       dropout_6[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 80, 128)      0           dense_13[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 80, 128)      0           dropout_7[0][0]
#                                                                  add_2[0][0]
# __________________________________________________________________________________________________
# sequential (Sequential)         (None, 80, 128)      2429056     add_3[0][0]
# __________________________________________________________________________________________________
# dense_14 (Dense)                (None, 80, 1)        129         sequential[0][0]
# __________________________________________________________________________________________________
# in_pressure (ScaleLayer)        (None, 80, 1)        0           dense_14[0][0]
# __________________________________________________________________________________________________
# out_pressure (ScaleLayer)       (None, 80, 1)        0           dense_14[0][0]
# ==================================================================================================
# Total params: 2,853,353
# Trainable params: 2,853,353
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# plot_model(
#     model,
#     to_file='Google_Brain_Keras_Model.png',
#     show_shapes=True,
#     show_layer_names=True
# )

# %%
del model
gc.collect()
# Out:
# 34214

# %%
#reset Keras Session
def reset_keras():
    sess = tf.compat.v1.keras.backend.get_session()
    tf.compat.v1.keras.backend.clear_session()
    sess.close()
    sess = tf.compat.v1.keras.backend.get_session()

    # use the same config as you used to create the session
    config = tf.compat.v1.ConfigProto()
    config.gpu_options.per_process_gpu_memory_fraction = 1
    config.gpu_options.visible_device_list = "0"
    tf.compat.v1.keras.backend.set_session(tf.compat.v1.Session(config=config))
    gc.collect()

reset_keras()

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
import seaborn as sns

def press_diff(series: np.ndarray):
  return series.diff().abs()


def analy_predict(last_test_idx, train_pred):
  train_df = pd.read_csv('../input/ventilator-pressure-prediction/train.csv')
  last_test_breath_ids = train_df['breath_id'].values.reshape(-1, 80)
  last_test_breath_ids = last_test_breath_ids[:, 0]
  last_test_breath_ids = last_test_breath_ids.flatten()
  last_test_breath_ids = last_test_breath_ids[last_test_idx]

  train_pred = train_pred[last_test_idx]
  train_pred = train_pred.flatten()

  train_df = train_df[train_df['breath_id'].isin(last_test_breath_ids)]
  train_df['pred'] = train_pred
  train_df['abs_error'] = np.abs(train_pred-train_df['pressure'])
  train_df['RC'] = train_df["R"].astype(str) + '__' + train_df["C"].astype(str)
  train_df['press_diff'] = train_df.groupby('breath_id')['pressure'].apply(press_diff)

  df_feature = train_df[train_df['u_out']<1].groupby('breath_id').agg({'abs_error': ['mean' , 'max', 'min', 'sum', 'count'], 
                                                                      'RC': ['first'], 
                                                                      'press_diff':['mean', 'max'],
                                                                      'u_in':['first', 'last'],
                                                                      'pressure':['first', 'last', 'mean', 'std']
                                                                      })
  df_feature.columns = ['_'.join(col) for col in df_feature.columns]

  plt.figure(figsize=(16,16))

  plt.title("abs_error distribution by RC")

  for key, grp in df_feature.groupby(['RC_first']):
    print(f'{key} - MAE  {grp.abs_error_mean.mean()}, count: {grp.abs_error_count.sum()}')
    sns.kdeplot(grp['abs_error_mean'], clip=(0.0, 1), 
                label=key)

  plt.axvline(df_feature['abs_error_mean'].mean())
  plt.legend()
  plt.show()

# %% [markdown]
# with tpu_strategy.scope():
#     skip_folds = np.arange(1)
#     VERBOSE = 2
#     EPOCHS = 200
#     FOLDS = 7
#     if DEBUG:
#       EPOCHS = 100
#     test_preds = []
#     kf = KFold(n_splits=FOLDS, shuffle=True, random_state=2021)
#     last_test_idx = []
#
#     for fold, (train_idx, test_idx) in enumerate(kf.split(train, targets)):
#         last_test_idx = test_idx
#         if len(test_preds) > fold:
#           print(f'Ignore corrent fold {fold+1} as we already predicted test data')
#
#         if DEBUG and fold > 0:
#           continue
#         X_train, X_valid = train[train_idx], train[test_idx]
#         y_train, y_valid = targets[train_idx], targets[test_idx]
#
#         model = dnn_model_GaussianNoise()
#         model.compile(optimizer="adam", loss="mae")
#
#         lr = ReduceLROnPlateau(monitor="val_loss", factor=0.75,
#                                patience=10, verbose=VERBOSE)
#         checkpoint_name = f'./model-gpu/Bidirect_LSTM_model_{fold+1}C.h5'
#         chk_point = ModelCheckpoint(checkpoint_name,
#                                     monitor='val_loss', verbose=VERBOSE,
#                                     save_best_only=True, mode='min')
#
#         es = EarlyStopping(monitor="val_loss", patience=50,
#                            verbose=VERBOSE, mode="min",
#                            restore_best_weights=True)
#
#         if fold not in skip_folds:
#           model.fit(X_train, y_train,
#                     validation_data=(X_valid, y_valid),
#                     epochs=EPOCHS,
#                     verbose=VERBOSE,
#                     batch_size=BATCH_SIZE,
#                     callbacks=[lr, chk_point, es])
#         else:
#           print('Load pretrain weight from ', checkpoint_name)
#           load_locally = tf.saved_model.LoadOptions(experimental_io_device='/job:localhost')
#           try:
#             # At loading time, register the custom objects with a `custom_object_scope`:
#             custom_objects = {"ScaleLayer": ScaleLayer}
#             with tf.keras.utils.custom_object_scope(custom_objects):
#                 model = load_model(checkpoint_name, options=load_locally)
#           except (OSError):
#             print('Cannot load pretrain weight from ', checkpoint_name)
#             break
#
#         y_true = y_valid.squeeze().reshape(-1, 1)
#         y_pred = model.predict(X_valid, batch_size=BATCH_SIZE).squeeze().reshape(-1, 1)
#         train_pred[test_idx] = y_pred.reshape(-1, 80)
#         score = mean_absolute_error(y_true, y_pred)
#         test_preds.append(model.predict(test, batch_size=BATCH_SIZE).squeeze().reshape(-1, 1).squeeze())
#
#         print(f"Fold-{fold+1} | OOF Score: {score}")
#
#         del X_train, X_valid, y_train, y_valid, model
#         reset_keras()
#         gc.collect()
#
#         analy_predict(test_idx, train_pred)
#         break

# %% [markdown]
# with tpu_strategy.scope():
#
#     VERBOSE = 2
#     EPOCHS = 200
#     FOLDS = 7
#     if DEBUG:
#       EPOCHS = 100
#     test_preds = []
#     kf = KFold(n_splits=FOLDS, shuffle=True, random_state=2021)
#     last_test_idx = []
#
#     for fold, (train_idx, test_idx) in enumerate(kf.split(train, targets)):
#         last_test_idx = test_idx
#         if len(test_preds) > fold:
#           print(f'Ignore corrent fold {fold+1} as we already predicted test data')
#
#         if DEBUG and fold > 0:
#           continue
#         X_train, X_valid = train[train_idx], train[test_idx]
#         y_train, y_valid = targets[train_idx], targets[test_idx]
#
#         model = dnn_model_aen()
#         model.compile(optimizer = tf.keras.optimizers.Adam(learning_rate = 1e-3),
#               # loss="mae"
#               loss = {
#                   'decoder': tf.keras.losses.MeanSquaredError(),
#                   #'decoder': tf.keras.losses.MeanAbsoluteError(),
#                   'ae_action': tf.keras.losses.MeanAbsoluteError(),
#                   'output': tf.keras.losses.MeanAbsoluteError(),
#                   },
#               loss_weights = [1, 1, 1]
#               )
#
#         lr = ReduceLROnPlateau(monitor="val_output_loss", factor=0.75,
#                                patience=10, verbose=VERBOSE)
#         checkpoint_name = f'./model-gpu/Bidirect_LSTM_model_{fold+1}C.h5'
#         chk_point = ModelCheckpoint(checkpoint_name,
#                                     monitor='val_output_loss',
#                                     verbose=VERBOSE,
#                                     save_best_only=True, mode='min')
#
#         es = EarlyStopping(monitor="val_output_loss", patience=50,
#                            verbose=VERBOSE, mode="min",
#                            restore_best_weights=True)
#
#         if fold not in skip_folds:
#           model.fit(X_train, [X_train, y_train, y_train],
#                     validation_data=(X_valid, [X_valid, y_valid, y_valid]),
#                     epochs=EPOCHS,
#                     verbose=VERBOSE,
#                     batch_size=BATCH_SIZE,
#                     callbacks=[lr, chk_point, es])
#         else:
#           print('Load pretrain weight from ', checkpoint_name)
#           load_locally = tf.saved_model.LoadOptions(experimental_io_device='/job:localhost')
#           try:
#             # At loading time, register the custom objects with a `custom_object_scope`:
#             custom_objects = {"ScaleLayer": ScaleLayer}
#             with tf.keras.utils.custom_object_scope(custom_objects):
#                 model = load_model(checkpoint_name, options=load_locally)
#           except (OSError):
#             print('Cannot load pretrain weight from ', checkpoint_name)
#             break
#
#         y_true = y_valid.squeeze().reshape(-1, 1)
#         y_pred = model.predict(X_valid, batch_size=BATCH_SIZE)[-1].squeeze().reshape(-1, 1)
#         train_pred[test_idx] = y_pred.reshape(-1, 80)
#         score = mean_absolute_error(y_true, y_pred)
#         test_preds.append(model.predict(test, batch_size=BATCH_SIZE)[-1].squeeze().reshape(-1, 1).squeeze())
#
#         print(f"Fold-{fold+1} | OOF Score: {score}")
#
#         del X_train, X_valid, y_train, y_valid, model
#         reset_keras()
#         gc.collect()
#
#         analy_predict(test_idx, train_pred)

# %%
train.shape, targets.shape
# Out:
# ((75450, 80, 66), (75450, 80))

# %% [markdown]
# # Filter only RC==5050 or 5020
# retrain_idx = np.logical_or((train[:, 0, -4] == 1), (train[:, 0, -5] == 1))
# train = train[retrain_idx]
# targets = targets[retrain_idx]
# train.shape, targets.shape

# %%
def RC_loss(y_true, y_pred, weight=50, cols = 80):
    rc = y_true[:, cols: ]
    y = y_true[:, :cols ]

    w = 1 + rc*50
    mae = w * tf.abs(y - y_pred)
    return tf.reduce_sum(mae, axis=-1) / 80

# %%
huber_loss = tf.keras.losses.Huber(reduction=tf.keras.losses.Reduction.NONE, delta=0.1)
def u_out_loss(y_true, y_pred, out_mask):
    y_true = y_true * out_mask
    y_pred = y_pred * out_mask
    # print(y_true, y_pred)

    # loss = tf.abs(y_true-y_pred)
    loss = huber_loss(y_true, y_pred)
    return tf.reduce_sum(loss, axis=-1) / tf.reduce_sum(out_mask, axis=-1)

def out_loss(y_true, y_pred):
    y, out = tf.split(y_true, 2, -1)
    out_mask = out + 1
    return u_out_loss(y, y_pred, out_mask)

def in_loss(y_true, y_pred):
    y, out = tf.split(y_true, 2, -1)
    out_mask = out * (-1)
    return u_out_loss(y, y_pred, out_mask)


# y_true = np.ones((2, 80*2))
# y_true[0, 80:80+40] = -1
# y_true[0, 80+40:] = 0

# y_pred = np.zeros((2, 80))
# y_pred[0] = np.arange(80)


# score_in = in_loss(tf.constant(y_true, tf.float32), tf.constant(y_pred, tf.float32))
# score_out = out_loss(tf.constant(y_true, tf.float32), tf.constant(y_pred, tf.float32))
# print(score_in, score_out)

# %%
#Sometime TF creats model with same weight name and it causes failure of save.
def show_weight_names(model):
  for i in range(len(model.weights)):
    print(i, model.weights[i].name)

# %%
'''
Index(['R', 'C', 'time_step', 'u_in', 'u_out', 'cross', 'cross2', 'area',
       'time_step_cumsum', 'u_in_cumsum', 'u_in_lag1', 'u_out_lag1',
       'u_in_lag_back1', 'u_out_lag_back1', 'u_in_lag2', 'u_out_lag2',
       'u_in_lag_back2', 'u_out_lag_back2', 'u_in_lag3', 'u_out_lag3',
       'u_in_lag_back3', 'u_out_lag_back3', 'u_in_lag4', 'u_out_lag4',
       'u_in_lag_back4', 'u_out_lag_back4', 'breath_id__u_in__max',
       'breath_id__u_out__max', 'breath_id__u_in__diffmax',
       'breath_id__u_in__diffmean', 'u_in_diff1', 'u_out_diff1', 'u_in_diff2',
       'u_out_diff2', 'u_in_diff3', 'u_out_diff3', 'u_in_diff4', 'u_out_diff4',
       'u_in_cummean', 'breath_id__u_in_lag', 'breath_id__u_in_lag2',
       'time_step_diff', 'ewm_u_in_mean', '15_in_sum', '15_in_min',
       '15_in_max', '15_in_mean', 'u_in_lagback_diff1', 'u_out_lagback_diff1',
       'u_in_lagback_diff2', 'u_out_lagback_diff2', 'R_cat_20', 'R_cat_5',
       'R_cat_50', 'C_cat_10', 'C_cat_20', 'C_cat_50', 'R__C_20__10',
       'R__C_20__20', 'R__C_20__50', 'R__C_50__10', 'R__C_50__20',
       'R__C_50__50', 'R__C_5__10', 'R__C_5__20', 'R__C_5__50'],
      dtype='object')
      
u_out: index - 4, 0->-1, 1->0
'''
U_OUT_IDX = 4
TRANSFORMER_START = -2
TRANSFORMER_BLANK = -3
TRANSFORMER_END = -4
# np_data: nx80, np_features: nx80x66
def make_transformer_targets(np_data):
    #insert start
    np_data_wrapped = np.insert(np_data, 0, TRANSFORMER_START, axis=1)
    #append end
    np_data_wrapped = np.insert(np_data_wrapped, np_data_wrapped.shape[1], TRANSFORMER_END, axis=1)
    #append 2 blanks
    np_data_wrapped = np.insert(np_data_wrapped, np_data_wrapped.shape[1], TRANSFORMER_BLANK, axis=1)
    np_data_wrapped = np.insert(np_data_wrapped, np_data_wrapped.shape[1], TRANSFORMER_BLANK, axis=1)
    return np_data_wrapped[:, :-1], np_data_wrapped[:, 1:]

# %% [markdown]
# BATCH_SIZE=512
# IS_WAVENET=False
# USE_RC_LOSS=False
#
# with tpu_strategy.scope():
#     VERBOSE = 2
#     EPOCHS = 300
#     FOLDS = 7
#     if DEBUG:
#       EPOCHS = 100
#     test_preds = []
#     kf = KFold(n_splits=FOLDS, shuffle=True, random_state=2021)
#     last_test_idx = []
#
#     for fold, (train_idx, test_idx) in enumerate(kf.split(train, targets)):
#         last_test_idx = test_idx
#         if len(test_preds) > fold:
#           print(f'Ignore corrent fold {fold+1} as we already predicted test data')
#
#         if DEBUG and fold > 0:
#           continue
#
#         X_train, X_valid = train[train_idx], train[test_idx]
#         y_train, y_valid = targets[train_idx], targets[test_idx]
#         #Align data to batch size and drop remainder. We only need it for TPU not GPU
#         if IS_TPU and IS_WAVENET:
#           fit_batch_size = X_train.shape[0] - (X_train.shape[0]%BATCH_SIZE)
#           print(X_train.shape[0], fit_batch_size)
#           X_train, y_train = X_train[:fit_batch_size, :, :], y_train[:fit_batch_size, :]
#
#           fit_batch_size = X_valid.shape[0] - (X_valid.shape[0]%BATCH_SIZE)
#           print(X_valid.shape[0], fit_batch_size)
#           X_valid, y_valid = X_valid[:fit_batch_size, :, :], y_valid[:fit_batch_size, :]
#
#         checkpoint_name = f'./model-gpu/transform_lstm_gpu_{fold+1}C.h5'
#         custom_objects = {"ScaleLayer": ScaleLayer, "RC_loss": RC_loss,
#                           "Time2Vec": Time2Vec,
#                           "TransformerEncoder": TransformerEncoder,
#                           'TransformerDecoder': TransformerDecoder}
#         load_locally = tf.saved_model.LoadOptions(experimental_io_device='/job:localhost')
#         with tf.keras.utils.custom_object_scope(custom_objects):
#             model = load_model(checkpoint_name, options=load_locally)
#
#         # if not (IS_TPU and IS_WAVENET):
#         #   analy_predict(test_idx, train_pred)
#         break

# %% [markdown]
# def predict_by_transformer_model(X_valid, model, nstep=80):
#   y_decoded = np.zeros(shape=(X_valid.shape[0], nstep+3))
#   # Fill in blank
#   y_decoded += TRANSFORMER_BLANK
#   # Set start as begin
#   y_decoded[:, 0] = TRANSFORMER_START
#   #X_valid[0:1].shape, y_decoded.shape
#   for i in range(80):
#     y_pred = model.predict([X_valid, y_decoded], batch_size=BATCH_SIZE).squeeze()
#     # print(y_decoded.shape, y_pred.shape)
#     #print(i, y_pred.shape)
#     y_decoded[:, i+1] = y_pred[:, i]
#   #remove start
#   return y_decoded[:, 1:81]
# y_pred = predict_by_transformer_model(train[last_test_idx], model)
# scores = []
# for i in range(80):
#   score = mean_absolute_error(targets[last_test_idx][:, i], y_pred[:, i])
#   print(i, score)
#   scores.append(score)
#
# plt.plot(scores)

# %% [markdown]
# # select 50, 50
# rc50_50_idx = X_valid[:, 0, -4]==1
# X_valid_50_50 = X_valid[rc50_50_idx]
# y_valid_50_50 = y_valid[rc50_50_idx]

# %% [markdown]
# with tf.keras.utils.custom_object_scope(custom_objects):
#   lstm_model = load_model('/gdrive/MyDrive/ventilator-pressure-prediction/gb-rescaling-eda-v3/Bidirect_LSTM_model_1C.h5', options=load_locally)

# %% [markdown]
# y_pred = predict_by_transformer_model(X_valid_50_50[0:1], model)
# y_pred_lstm = lstm_model.predict(X_valid_50_50[0:1], batch_size=1).reshape(1, 80)
#
# plt.figure(figsize=(16,16))
# transformer_score = mean_absolute_error(y_valid_50_50[0][:-1], y_pred[0][1:])
# lstm_score = mean_absolute_error(y_valid_50_50[0][:-1], y_pred_lstm[0][:-1])
# print(transformer_score, lstm_score)
# plt.plot(y_valid_50_50[0], label='True')
# plt.plot(y_pred[0][1:], label='Transformer Predit')
# plt.plot(y_pred_lstm[0], label='LSTM Predit')
# plt.legend()
# plt.show()

# %%
skip_folds = []#np.arange(7)
train_pred = np.zeros(targets.shape)

BATCH_SIZE=512
IS_WAVENET=False
USE_RC_LOSS=False

with tpu_strategy.scope():
    
    VERBOSE = 1
    EPOCHS = 300
    FOLDS = 7
    if DEBUG:
      EPOCHS = 100
    test_preds = []
    kf = KFold(n_splits=FOLDS, shuffle=True, random_state=2021)
    last_test_idx = []
    
    for fold, (train_idx, test_idx) in enumerate(kf.split(train, targets)):
        last_test_idx = test_idx
        if len(test_preds) > fold:
          print(f'Ignore corrent fold {fold+1} as we already predicted test data')

        if DEBUG and fold > 0:
          continue

        X_train, X_valid = train[train_idx], train[test_idx]
        y_train, y_valid = targets[train_idx], targets[test_idx]
        #Align data to batch size and drop remainder. We only need it for TPU not GPU
        if IS_TPU and IS_WAVENET:
          fit_batch_size = X_train.shape[0] - (X_train.shape[0]%BATCH_SIZE)
          print(X_train.shape[0], fit_batch_size)
          X_train, y_train = X_train[:fit_batch_size, :, :], y_train[:fit_batch_size, :]
          
          fit_batch_size = X_valid.shape[0] - (X_valid.shape[0]%BATCH_SIZE)
          print(X_valid.shape[0], fit_batch_size)
          X_valid, y_valid = X_valid[:fit_batch_size, :, :], y_valid[:fit_batch_size, :]
        
        
        # model = load_dnn_model_v4_add_wavenet(-3, True)
        # model = lstm_wavenet_model()
        # model = dnn_TransformerEncoder_model()
        model = ExternalTransformerEncoder_LSTM_model(ff_dim=256,num_heads=8,num_layers=2,)
        #show_weight_names(model)
        model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate = 1e-3),
                      # loss=RC_loss
                      # loss=tf.keras.losses.MeanAbsoluteError()
                      loss = {
                          'in_pressure': in_loss,
                          'out_pressure': out_loss
                          }
                      )
        
        

        lr = ReduceLROnPlateau(monitor="val_loss", factor=0.75, 
                               patience=10, verbose=VERBOSE)
        
        # scheduler = tf.keras.optimizers.schedules.ExponentialDecay(1e-3, 5, 0.9)
        # lr = tf.keras.callbacks.LearningRateScheduler(scheduler)
        load_locally = tf.saved_model.LoadOptions(experimental_io_device='/job:localhost')
        custom_objects = {"ScaleLayer": ScaleLayer, 
                          "RC_loss": RC_loss,
                          'in_loss': in_loss,
                          'out_loss': out_loss,
                          "Time2Vec": Time2Vec, 
                          "TransformerEncoder": TransformerEncoder}


        checkpoint_name = f'./model-gpu/transform_encoder_lstm_gpu_{fold+1}C.h5'
        chk_point = ModelCheckpoint(checkpoint_name,
                                    monitor='val_loss', verbose=VERBOSE, 
                                    save_best_only=True, mode='min')

        es = EarlyStopping(monitor="val_loss", patience=50,
                           verbose=VERBOSE, mode="min",
                           restore_best_weights=True)
        
        if fold not in skip_folds:
          # if os.path.isfile(checkpoint_name):
          #     with tf.keras.utils.custom_object_scope(custom_objects):
          #         model = load_model(checkpoint_name, options=load_locally)
          #         print('Resumed previous weight from ', checkpoint_name)

          if USE_RC_LOSS:
            model.fit(X_train, np.append(y_train, X_train[:, :, -4]+X_train[:, :, -5], axis =1),
                      validation_data=(X_valid, np.append(y_valid, X_valid[:, :, -4]+X_valid[:, :, -5], axis =1)), 
                      epochs=EPOCHS,
                      verbose=VERBOSE,
                      batch_size=BATCH_SIZE, 
                      callbacks=[lr, chk_point, es])
          else:
            y_train_comb = np.append(y_train, X_train[:, :, U_OUT_IDX], axis =1)
            y_valid_comb = np.append(y_valid, X_valid[:, :, U_OUT_IDX], axis =1)
            # print(y_train_comb.shape, y_valid_comb.shape)
            model.fit(X_train, [y_train_comb, y_train_comb],
                      validation_data=(X_valid, [y_valid_comb, y_valid_comb]), 
                      epochs=EPOCHS,
                      verbose=VERBOSE,
                      batch_size=BATCH_SIZE, 
                      callbacks=[lr, chk_point, es])
        else:
          print('Load pretrain weight from ', checkpoint_name)

          try:
            # At loading time, register the custom objects with a `custom_object_scope`:
            with tf.keras.utils.custom_object_scope(custom_objects):
                model = load_model(checkpoint_name, options=load_locally)
          except (OSError):
            print('Cannot load pretrain weight from ', checkpoint_name)
            break
                
        y_true = y_valid.squeeze().reshape(-1, 1)
        y_pred = model.predict(X_valid, batch_size=BATCH_SIZE)[0].squeeze().reshape(-1, 1)
        score = mean_absolute_error(y_true, y_pred)
        print(f"Fold-{fold+1} | OOF Score: {score}")

        #Save CV predict
        if not (IS_TPU and IS_WAVENET):
          test_preds.append(model.predict(test, batch_size=BATCH_SIZE)[0].squeeze().reshape(-1, 1).squeeze())

        
        del X_train, X_valid, y_train, y_valid, model
        reset_keras()
        gc.collect()

        if not (IS_TPU and IS_WAVENET):
          train_pred[test_idx] = y_pred.reshape(-1, 80)
          analy_predict(test_idx, train_pred)
# Out:
# Epoch 1/300
# 127/127 [==============================] - 55s 265ms/step - loss: 0.2746 - in_pressure_loss: 0.2093 - out_pressure_loss: 0.0653 - val_loss: 0.1278 - val_in_pressure_loss: 0.0977 - val_out_pressure_loss: 0.0301
#
# Epoch 00001: val_loss improved from inf to 0.12775, saving model to ./model-gpu/transform_encoder_lstm_gpu_1C.h5
# /usr/local/lib/python3.7/dist-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# Epoch 2/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.1112 - in_pressure_loss: 0.0829 - out_pressure_loss: 0.0283 - val_loss: 0.1130 - val_in_pressure_loss: 0.0839 - val_out_pressure_loss: 0.0291
#
# Epoch 00002: val_loss improved from 0.12775 to 0.11299, saving model to ./model-gpu/transform_encoder_lstm_gpu_1C.h5
# Epoch 3/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0898 - in_pressure_loss: 0.0660 - out_pressure_loss: 0.0238 - val_loss: 0.0788 - val_in_pressure_loss: 0.0574 - val_out_pressure_loss: 0.0214
#
# Epoch 00003: val_loss improved from 0.11299 to 0.07881, saving model to ./model-gpu/transform_encoder_lstm_gpu_1C.h5
# Epoch 4/300
# 127/127 [==============================] - 14s 108ms/step - loss: 0.0812 - in_pressure_loss: 0.0594 - out_pressure_loss: 0.0219 - val_loss: 0.0716 - val_in_pressure_loss: 0.0514 - val_out_pressure_loss: 0.0202
#
# Epoch 00004: val_loss improved from 0.07881 to 0.07157, saving model to ./model-gpu/transform_encoder_lstm_gpu_1C.h5
# Epoch 5/300
# 127/127 [==============================] - 14s 107ms/step - loss: 0.0732 - in_pressure_loss: 0.0526 - out_pressure_loss: 0.0206 - val_loss: 0.0711 - val_in_pressure_loss: 0.0516 - val_out_pressure_loss: 0.0196
#
# Epoch 00005: val_loss improved from 0.07157 to 0.07115, saving model to ./model-gpu/transform_encoder_lstm_gpu_1C.h5
# Epoch 6/300
# 127/127 [==============================] - 14s 106ms/step - loss: 0.0698 - in_pressure_loss: 0.0499 - out_pressure_loss: 0.0200 - val_loss: 0.1037 - val_in_pressure_loss: 0.0765 - val_out_pressure_loss: 0.0272
#
# Epoch 00006: val_loss did not improve from 0.07115
# Epoch 7/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0702 - in_pressure_loss: 0.0502 - out_pressure_loss: 0.0199 - val_loss: 0.0862 - val_in_pressure_loss: 0.0657 - val_out_pressure_loss: 0.0204
#
# Epoch 00007: val_loss did not improve from 0.07115
# Epoch 8/300
# 127/127 [==============================] - 13s 105ms/step - loss: 0.0630 - in_pressure_loss: 0.0443 - out_pressure_loss: 0.0187 - val_loss: 0.0630 - val_in_pressure_loss: 0.0447 - val_out_pressure_loss: 0.0183
#
# Epoch 00008: val_loss improved from 0.07115 to 0.06298, saving model to ./model-gpu/transform_encoder_lstm_gpu_1C.h5
# Epoch 9/300
# 127/127 [==============================] - 14s 106ms/step - loss: 0.0613 - in_pressure_loss: 0.0430 - out_pressure_loss: 0.0184 - val_loss: 0.0731 - val_in_pressure_loss: 0.0534 - val_out_pressure_loss: 0.0197
#
# Epoch 00009: val_loss did not improve from 0.06298
# Epoch 10/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0606 - in_pressure_loss: 0.0422 - out_pressure_loss: 0.0184 - val_loss: 0.0588 - val_in_pressure_loss: 0.0410 - val_out_pressure_loss: 0.0178
#
# Epoch 00010: val_loss improved from 0.06298 to 0.05876, saving model to ./model-gpu/transform_encoder_lstm_gpu_1C.h5
# Epoch 11/300
# 127/127 [==============================] - 14s 106ms/step - loss: 0.0569 - in_pressure_loss: 0.0392 - out_pressure_loss: 0.0177 - val_loss: 0.0589 - val_in_pressure_loss: 0.0410 - val_out_pressure_loss: 0.0179
#
# Epoch 00011: val_loss did not improve from 0.05876
# Epoch 12/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0552 - in_pressure_loss: 0.0378 - out_pressure_loss: 0.0175 - val_loss: 0.0535 - val_in_pressure_loss: 0.0364 - val_out_pressure_loss: 0.0171
#
# Epoch 00012: val_loss improved from 0.05876 to 0.05352, saving model to ./model-gpu/transform_encoder_lstm_gpu_1C.h5
# Epoch 13/300
# 127/127 [==============================] - 14s 106ms/step - loss: 0.0548 - in_pressure_loss: 0.0373 - out_pressure_loss: 0.0175 - val_loss: 0.0574 - val_in_pressure_loss: 0.0402 - val_out_pressure_loss: 0.0172
#
# Epoch 00013: val_loss did not improve from 0.05352
# Epoch 14/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0536 - in_pressure_loss: 0.0364 - out_pressure_loss: 0.0172 - val_loss: 0.0622 - val_in_pressure_loss: 0.0407 - val_out_pressure_loss: 0.0215
#
# Epoch 00014: val_loss did not improve from 0.05352
# Epoch 15/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0527 - in_pressure_loss: 0.0355 - out_pressure_loss: 0.0172 - val_loss: 0.0534 - val_in_pressure_loss: 0.0369 - val_out_pressure_loss: 0.0166
#
# Epoch 00015: val_loss improved from 0.05352 to 0.05343, saving model to ./model-gpu/transform_encoder_lstm_gpu_1C.h5
# Epoch 16/300
# 127/127 [==============================] - 14s 108ms/step - loss: 0.0502 - in_pressure_loss: 0.0336 - out_pressure_loss: 0.0166 - val_loss: 0.0569 - val_in_pressure_loss: 0.0399 - val_out_pressure_loss: 0.0170
#
# Epoch 00016: val_loss did not improve from 0.05343
# Epoch 17/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0508 - in_pressure_loss: 0.0341 - out_pressure_loss: 0.0167 - val_loss: 0.0523 - val_in_pressure_loss: 0.0356 - val_out_pressure_loss: 0.0167
#
# Epoch 00017: val_loss improved from 0.05343 to 0.05230, saving model to ./model-gpu/transform_encoder_lstm_gpu_1C.h5
# Epoch 18/300
# 127/127 [==============================] - 14s 107ms/step - loss: 0.0492 - in_pressure_loss: 0.0326 - out_pressure_loss: 0.0166 - val_loss: 0.0548 - val_in_pressure_loss: 0.0371 - val_out_pressure_loss: 0.0177
#
# Epoch 00018: val_loss did not improve from 0.05230
# Epoch 19/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0496 - in_pressure_loss: 0.0329 - out_pressure_loss: 0.0167 - val_loss: 0.0504 - val_in_pressure_loss: 0.0336 - val_out_pressure_loss: 0.0168
#
# Epoch 00019: val_loss improved from 0.05230 to 0.05039, saving model to ./model-gpu/transform_encoder_lstm_gpu_1C.h5
# Epoch 20/300
# 127/127 [==============================] - 14s 107ms/step - loss: 0.0469 - in_pressure_loss: 0.0310 - out_pressure_loss: 0.0159 - val_loss: 0.0489 - val_in_pressure_loss: 0.0328 - val_out_pressure_loss: 0.0161
#
# Epoch 00020: val_loss improved from 0.05039 to 0.04892, saving model to ./model-gpu/transform_encoder_lstm_gpu_1C.h5
# Epoch 21/300
# 127/127 [==============================] - 14s 107ms/step - loss: 0.0452 - in_pressure_loss: 0.0295 - out_pressure_loss: 0.0157 - val_loss: 0.0489 - val_in_pressure_loss: 0.0331 - val_out_pressure_loss: 0.0157
#
# Epoch 00021: val_loss improved from 0.04892 to 0.04887, saving model to ./model-gpu/transform_encoder_lstm_gpu_1C.h5
# Epoch 22/300
# 127/127 [==============================] - 14s 107ms/step - loss: 0.0457 - in_pressure_loss: 0.0300 - out_pressure_loss: 0.0157 - val_loss: 0.0483 - val_in_pressure_loss: 0.0321 - val_out_pressure_loss: 0.0162
#
# Epoch 00022: val_loss improved from 0.04887 to 0.04828, saving model to ./model-gpu/transform_encoder_lstm_gpu_1C.h5
# Epoch 23/300
# 127/127 [==============================] - 14s 107ms/step - loss: 0.0441 - in_pressure_loss: 0.0287 - out_pressure_loss: 0.0153 - val_loss: 0.0455 - val_in_pressure_loss: 0.0306 - val_out_pressure_loss: 0.0150
#
# Epoch 00023: val_loss improved from 0.04828 to 0.04555, saving model to ./model-gpu/transform_encoder_lstm_gpu_1C.h5
# Epoch 24/300
# 127/127 [==============================] - 14s 106ms/step - loss: 0.0429 - in_pressure_loss: 0.0279 - out_pressure_loss: 0.0150 - val_loss: 0.0449 - val_in_pressure_loss: 0.0301 - val_out_pressure_loss: 0.0148
#
# Epoch 00024: val_loss improved from 0.04555 to 0.04491, saving model to ./model-gpu/transform_encoder_lstm_gpu_1C.h5
# Epoch 25/300
# 127/127 [==============================] - 14s 107ms/step - loss: 0.0423 - in_pressure_loss: 0.0273 - out_pressure_loss: 0.0150 - val_loss: 0.0477 - val_in_pressure_loss: 0.0292 - val_out_pressure_loss: 0.0185
#
# Epoch 00025: val_loss did not improve from 0.04491
# Epoch 26/300
# 127/127 [==============================] - 14s 107ms/step - loss: 0.0417 - in_pressure_loss: 0.0269 - out_pressure_loss: 0.0148 - val_loss: 0.0492 - val_in_pressure_loss: 0.0341 - val_out_pressure_loss: 0.0150
#
# Epoch 00026: val_loss did not improve from 0.04491
# Epoch 27/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0414 - in_pressure_loss: 0.0267 - out_pressure_loss: 0.0146 - val_loss: 0.0490 - val_in_pressure_loss: 0.0343 - val_out_pressure_loss: 0.0148
#
# Epoch 00027: val_loss did not improve from 0.04491
# Epoch 28/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0424 - in_pressure_loss: 0.0276 - out_pressure_loss: 0.0147 - val_loss: 0.0448 - val_in_pressure_loss: 0.0301 - val_out_pressure_loss: 0.0146
#
# Epoch 00028: val_loss improved from 0.04491 to 0.04478, saving model to ./model-gpu/transform_encoder_lstm_gpu_1C.h5
# Epoch 29/300
# 127/127 [==============================] - 14s 107ms/step - loss: 0.0410 - in_pressure_loss: 0.0266 - out_pressure_loss: 0.0144 - val_loss: 0.0494 - val_in_pressure_loss: 0.0340 - val_out_pressure_loss: 0.0154
#
# Epoch 00029: val_loss did not improve from 0.04478
# Epoch 30/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0435 - in_pressure_loss: 0.0287 - out_pressure_loss: 0.0147 - val_loss: 0.0461 - val_in_pressure_loss: 0.0312 - val_out_pressure_loss: 0.0149
#
# Epoch 00030: val_loss did not improve from 0.04478
# Epoch 31/300
# 127/127 [==============================] - 14s 106ms/step - loss: 0.0421 - in_pressure_loss: 0.0276 - out_pressure_loss: 0.0145 - val_loss: 0.0466 - val_in_pressure_loss: 0.0294 - val_out_pressure_loss: 0.0171
#
# Epoch 00031: val_loss did not improve from 0.04478
# Epoch 32/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0388 - in_pressure_loss: 0.0247 - out_pressure_loss: 0.0141 - val_loss: 0.0432 - val_in_pressure_loss: 0.0291 - val_out_pressure_loss: 0.0141
#
# Epoch 00032: val_loss improved from 0.04478 to 0.04316, saving model to ./model-gpu/transform_encoder_lstm_gpu_1C.h5
# Epoch 33/300
# 127/127 [==============================] - 14s 106ms/step - loss: 0.0386 - in_pressure_loss: 0.0248 - out_pressure_loss: 0.0138 - val_loss: 0.0481 - val_in_pressure_loss: 0.0333 - val_out_pressure_loss: 0.0147
#
# Epoch 00033: val_loss did not improve from 0.04316
# Epoch 34/300
# 127/127 [==============================] - 13s 105ms/step - loss: 0.0383 - in_pressure_loss: 0.0245 - out_pressure_loss: 0.0138 - val_loss: 0.0408 - val_in_pressure_loss: 0.0264 - val_out_pressure_loss: 0.0144
#
# Epoch 00034: val_loss improved from 0.04316 to 0.04085, saving model to ./model-gpu/transform_encoder_lstm_gpu_1C.h5
# Epoch 35/300
# 127/127 [==============================] - 14s 106ms/step - loss: 0.0371 - in_pressure_loss: 0.0235 - out_pressure_loss: 0.0136 - val_loss: 0.0454 - val_in_pressure_loss: 0.0314 - val_out_pressure_loss: 0.0141
#
# Epoch 00035: val_loss did not improve from 0.04085
# Epoch 36/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0381 - in_pressure_loss: 0.0244 - out_pressure_loss: 0.0137 - val_loss: 0.0511 - val_in_pressure_loss: 0.0364 - val_out_pressure_loss: 0.0147
#
# Epoch 00036: val_loss did not improve from 0.04085
# Epoch 37/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0402 - in_pressure_loss: 0.0262 - out_pressure_loss: 0.0139 - val_loss: 0.0421 - val_in_pressure_loss: 0.0281 - val_out_pressure_loss: 0.0140
#
# Epoch 00037: val_loss did not improve from 0.04085
# Epoch 38/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0354 - in_pressure_loss: 0.0221 - out_pressure_loss: 0.0133 - val_loss: 0.0382 - val_in_pressure_loss: 0.0250 - val_out_pressure_loss: 0.0132
#
# Epoch 00038: val_loss improved from 0.04085 to 0.03824, saving model to ./model-gpu/transform_encoder_lstm_gpu_1C.h5
# Epoch 39/300
# 127/127 [==============================] - 14s 106ms/step - loss: 0.0351 - in_pressure_loss: 0.0219 - out_pressure_loss: 0.0132 - val_loss: 0.0434 - val_in_pressure_loss: 0.0274 - val_out_pressure_loss: 0.0160
#
# Epoch 00039: val_loss did not improve from 0.03824
# Epoch 40/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0374 - in_pressure_loss: 0.0240 - out_pressure_loss: 0.0134 - val_loss: 0.0374 - val_in_pressure_loss: 0.0243 - val_out_pressure_loss: 0.0131
#
# Epoch 00040: val_loss improved from 0.03824 to 0.03741, saving model to ./model-gpu/transform_encoder_lstm_gpu_1C.h5
# Epoch 41/300
# 127/127 [==============================] - 14s 106ms/step - loss: 0.0341 - in_pressure_loss: 0.0213 - out_pressure_loss: 0.0128 - val_loss: 0.0372 - val_in_pressure_loss: 0.0245 - val_out_pressure_loss: 0.0127
#
# Epoch 00041: val_loss improved from 0.03741 to 0.03716, saving model to ./model-gpu/transform_encoder_lstm_gpu_1C.h5
# Epoch 42/300
# 127/127 [==============================] - 14s 107ms/step - loss: 0.0340 - in_pressure_loss: 0.0212 - out_pressure_loss: 0.0128 - val_loss: 0.0387 - val_in_pressure_loss: 0.0254 - val_out_pressure_loss: 0.0133
#
# Epoch 00042: val_loss did not improve from 0.03716
# Epoch 43/300
# 127/127 [==============================] - 14s 110ms/step - loss: 0.0354 - in_pressure_loss: 0.0224 - out_pressure_loss: 0.0130 - val_loss: 0.0366 - val_in_pressure_loss: 0.0240 - val_out_pressure_loss: 0.0126
#
# Epoch 00043: val_loss improved from 0.03716 to 0.03660, saving model to ./model-gpu/transform_encoder_lstm_gpu_1C.h5
# Epoch 44/300
# 127/127 [==============================] - 14s 107ms/step - loss: 0.0332 - in_pressure_loss: 0.0206 - out_pressure_loss: 0.0126 - val_loss: 0.0361 - val_in_pressure_loss: 0.0234 - val_out_pressure_loss: 0.0127
#
# Epoch 00044: val_loss improved from 0.03660 to 0.03610, saving model to ./model-gpu/transform_encoder_lstm_gpu_1C.h5
# Epoch 45/300
# 127/127 [==============================] - 14s 107ms/step - loss: 0.0316 - in_pressure_loss: 0.0193 - out_pressure_loss: 0.0123 - val_loss: 0.0387 - val_in_pressure_loss: 0.0254 - val_out_pressure_loss: 0.0133
#
# Epoch 00045: val_loss did not improve from 0.03610
# Epoch 46/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0330 - in_pressure_loss: 0.0205 - out_pressure_loss: 0.0124 - val_loss: 0.0371 - val_in_pressure_loss: 0.0244 - val_out_pressure_loss: 0.0126
#
# Epoch 00046: val_loss did not improve from 0.03610
# Epoch 47/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0322 - in_pressure_loss: 0.0200 - out_pressure_loss: 0.0122 - val_loss: 0.0402 - val_in_pressure_loss: 0.0278 - val_out_pressure_loss: 0.0125
#
# Epoch 00047: val_loss did not improve from 0.03610
# Epoch 48/300
# 127/127 [==============================] - 14s 108ms/step - loss: 0.0326 - in_pressure_loss: 0.0203 - out_pressure_loss: 0.0123 - val_loss: 0.0398 - val_in_pressure_loss: 0.0273 - val_out_pressure_loss: 0.0125
#
# Epoch 00048: val_loss did not improve from 0.03610
# Epoch 49/300
# 127/127 [==============================] - 14s 106ms/step - loss: 0.0342 - in_pressure_loss: 0.0218 - out_pressure_loss: 0.0124 - val_loss: 0.0499 - val_in_pressure_loss: 0.0365 - val_out_pressure_loss: 0.0134
#
# Epoch 00049: val_loss did not improve from 0.03610
# Epoch 50/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0347 - in_pressure_loss: 0.0220 - out_pressure_loss: 0.0126 - val_loss: 0.0367 - val_in_pressure_loss: 0.0236 - val_out_pressure_loss: 0.0132
#
# Epoch 00050: val_loss did not improve from 0.03610
# Epoch 51/300
# 127/127 [==============================] - 14s 106ms/step - loss: 0.0328 - in_pressure_loss: 0.0207 - out_pressure_loss: 0.0121 - val_loss: 0.0370 - val_in_pressure_loss: 0.0247 - val_out_pressure_loss: 0.0122
#
# Epoch 00051: val_loss did not improve from 0.03610
# Epoch 52/300
# 127/127 [==============================] - 14s 106ms/step - loss: 0.0337 - in_pressure_loss: 0.0214 - out_pressure_loss: 0.0123 - val_loss: 0.0363 - val_in_pressure_loss: 0.0242 - val_out_pressure_loss: 0.0121
#
# Epoch 00052: val_loss did not improve from 0.03610
# Epoch 53/300
# 127/127 [==============================] - 14s 106ms/step - loss: 0.0303 - in_pressure_loss: 0.0183 - out_pressure_loss: 0.0120 - val_loss: 0.0327 - val_in_pressure_loss: 0.0208 - val_out_pressure_loss: 0.0120
#
# Epoch 00053: val_loss improved from 0.03610 to 0.03272, saving model to ./model-gpu/transform_encoder_lstm_gpu_1C.h5
# Epoch 54/300
# 127/127 [==============================] - 14s 107ms/step - loss: 0.0290 - in_pressure_loss: 0.0174 - out_pressure_loss: 0.0116 - val_loss: 0.0323 - val_in_pressure_loss: 0.0206 - val_out_pressure_loss: 0.0117
#
# Epoch 00054: val_loss improved from 0.03272 to 0.03232, saving model to ./model-gpu/transform_encoder_lstm_gpu_1C.h5
# Epoch 55/300
# 127/127 [==============================] - 14s 107ms/step - loss: 0.0301 - in_pressure_loss: 0.0184 - out_pressure_loss: 0.0117 - val_loss: 0.0330 - val_in_pressure_loss: 0.0210 - val_out_pressure_loss: 0.0120
#
# Epoch 00055: val_loss did not improve from 0.03232
# Epoch 56/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0289 - in_pressure_loss: 0.0174 - out_pressure_loss: 0.0115 - val_loss: 0.0312 - val_in_pressure_loss: 0.0196 - val_out_pressure_loss: 0.0116
#
# Epoch 00056: val_loss improved from 0.03232 to 0.03117, saving model to ./model-gpu/transform_encoder_lstm_gpu_1C.h5
# Epoch 57/300
# 127/127 [==============================] - 14s 107ms/step - loss: 0.0280 - in_pressure_loss: 0.0166 - out_pressure_loss: 0.0114 - val_loss: 0.0371 - val_in_pressure_loss: 0.0250 - val_out_pressure_loss: 0.0121
#
# Epoch 00057: val_loss did not improve from 0.03117
# Epoch 58/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0321 - in_pressure_loss: 0.0201 - out_pressure_loss: 0.0119 - val_loss: 0.0376 - val_in_pressure_loss: 0.0252 - val_out_pressure_loss: 0.0124
#
# Epoch 00058: val_loss did not improve from 0.03117
# Epoch 59/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0326 - in_pressure_loss: 0.0205 - out_pressure_loss: 0.0122 - val_loss: 0.0344 - val_in_pressure_loss: 0.0222 - val_out_pressure_loss: 0.0122
#
# Epoch 00059: val_loss did not improve from 0.03117
# Epoch 60/300
# 127/127 [==============================] - 14s 106ms/step - loss: 0.0309 - in_pressure_loss: 0.0191 - out_pressure_loss: 0.0117 - val_loss: 0.0336 - val_in_pressure_loss: 0.0219 - val_out_pressure_loss: 0.0118
#
# Epoch 00060: val_loss did not improve from 0.03117
# Epoch 61/300
# 127/127 [==============================] - 14s 106ms/step - loss: 0.0283 - in_pressure_loss: 0.0169 - out_pressure_loss: 0.0114 - val_loss: 0.0360 - val_in_pressure_loss: 0.0242 - val_out_pressure_loss: 0.0118
#
# Epoch 00061: val_loss did not improve from 0.03117
# Epoch 62/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0287 - in_pressure_loss: 0.0172 - out_pressure_loss: 0.0114 - val_loss: 0.0318 - val_in_pressure_loss: 0.0204 - val_out_pressure_loss: 0.0114
#
# Epoch 00062: val_loss did not improve from 0.03117
# Epoch 63/300
# 127/127 [==============================] - 14s 106ms/step - loss: 0.0292 - in_pressure_loss: 0.0177 - out_pressure_loss: 0.0114 - val_loss: 0.0350 - val_in_pressure_loss: 0.0226 - val_out_pressure_loss: 0.0124
#
# Epoch 00063: val_loss did not improve from 0.03117
# Epoch 64/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0292 - in_pressure_loss: 0.0177 - out_pressure_loss: 0.0115 - val_loss: 0.0326 - val_in_pressure_loss: 0.0210 - val_out_pressure_loss: 0.0115
#
# Epoch 00064: val_loss did not improve from 0.03117
# Epoch 65/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0279 - in_pressure_loss: 0.0166 - out_pressure_loss: 0.0112 - val_loss: 0.0361 - val_in_pressure_loss: 0.0240 - val_out_pressure_loss: 0.0121
#
# Epoch 00065: val_loss did not improve from 0.03117
# Epoch 66/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0298 - in_pressure_loss: 0.0184 - out_pressure_loss: 0.0114 - val_loss: 0.0413 - val_in_pressure_loss: 0.0285 - val_out_pressure_loss: 0.0128
#
# Epoch 00066: ReduceLROnPlateau reducing learning rate to 0.0007500000356230885.
#
# Epoch 00066: val_loss did not improve from 0.03117
# Epoch 67/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0269 - in_pressure_loss: 0.0159 - out_pressure_loss: 0.0110 - val_loss: 0.0304 - val_in_pressure_loss: 0.0193 - val_out_pressure_loss: 0.0112
#
# Epoch 00067: val_loss improved from 0.03117 to 0.03044, saving model to ./model-gpu/transform_encoder_lstm_gpu_1C.h5
# Epoch 68/300
# 127/127 [==============================] - 14s 107ms/step - loss: 0.0254 - in_pressure_loss: 0.0147 - out_pressure_loss: 0.0108 - val_loss: 0.0307 - val_in_pressure_loss: 0.0194 - val_out_pressure_loss: 0.0114
#
# Epoch 00068: val_loss did not improve from 0.03044
# Epoch 69/300
# 127/127 [==============================] - 14s 106ms/step - loss: 0.0253 - in_pressure_loss: 0.0146 - out_pressure_loss: 0.0107 - val_loss: 0.0293 - val_in_pressure_loss: 0.0182 - val_out_pressure_loss: 0.0111
#
# Epoch 00069: val_loss improved from 0.03044 to 0.02926, saving model to ./model-gpu/transform_encoder_lstm_gpu_1C.h5
# Epoch 70/300
# 127/127 [==============================] - 14s 108ms/step - loss: 0.0234 - in_pressure_loss: 0.0129 - out_pressure_loss: 0.0104 - val_loss: 0.0288 - val_in_pressure_loss: 0.0177 - val_out_pressure_loss: 0.0110
#
# Epoch 00070: val_loss improved from 0.02926 to 0.02877, saving model to ./model-gpu/transform_encoder_lstm_gpu_1C.h5
# Epoch 71/300
# 127/127 [==============================] - 14s 107ms/step - loss: 0.0244 - in_pressure_loss: 0.0138 - out_pressure_loss: 0.0106 - val_loss: 0.0297 - val_in_pressure_loss: 0.0187 - val_out_pressure_loss: 0.0110
#
# Epoch 00071: val_loss did not improve from 0.02877
# Epoch 72/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0242 - in_pressure_loss: 0.0137 - out_pressure_loss: 0.0105 - val_loss: 0.0293 - val_in_pressure_loss: 0.0183 - val_out_pressure_loss: 0.0110
#
# Epoch 00072: val_loss did not improve from 0.02877
# Epoch 73/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0231 - in_pressure_loss: 0.0127 - out_pressure_loss: 0.0104 - val_loss: 0.0280 - val_in_pressure_loss: 0.0172 - val_out_pressure_loss: 0.0108
#
# Epoch 00073: val_loss improved from 0.02877 to 0.02799, saving model to ./model-gpu/transform_encoder_lstm_gpu_1C.h5
# Epoch 74/300
# 127/127 [==============================] - 14s 106ms/step - loss: 0.0227 - in_pressure_loss: 0.0124 - out_pressure_loss: 0.0103 - val_loss: 0.0294 - val_in_pressure_loss: 0.0178 - val_out_pressure_loss: 0.0116
#
# Epoch 00074: val_loss did not improve from 0.02799
# Epoch 75/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0234 - in_pressure_loss: 0.0131 - out_pressure_loss: 0.0104 - val_loss: 0.0299 - val_in_pressure_loss: 0.0185 - val_out_pressure_loss: 0.0114
#
# Epoch 00075: val_loss did not improve from 0.02799
# Epoch 76/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0229 - in_pressure_loss: 0.0126 - out_pressure_loss: 0.0103 - val_loss: 0.0284 - val_in_pressure_loss: 0.0174 - val_out_pressure_loss: 0.0110
#
# Epoch 00076: val_loss did not improve from 0.02799
# Epoch 77/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0239 - in_pressure_loss: 0.0135 - out_pressure_loss: 0.0104 - val_loss: 0.0299 - val_in_pressure_loss: 0.0190 - val_out_pressure_loss: 0.0109
#
# Epoch 00077: val_loss did not improve from 0.02799
# Epoch 78/300
# 127/127 [==============================] - 14s 106ms/step - loss: 0.0239 - in_pressure_loss: 0.0136 - out_pressure_loss: 0.0104 - val_loss: 0.0302 - val_in_pressure_loss: 0.0189 - val_out_pressure_loss: 0.0113
#
# Epoch 00078: val_loss did not improve from 0.02799
# Epoch 79/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0228 - in_pressure_loss: 0.0127 - out_pressure_loss: 0.0102 - val_loss: 0.0291 - val_in_pressure_loss: 0.0180 - val_out_pressure_loss: 0.0112
#
# Epoch 00079: val_loss did not improve from 0.02799
# Epoch 80/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0223 - in_pressure_loss: 0.0122 - out_pressure_loss: 0.0101 - val_loss: 0.0280 - val_in_pressure_loss: 0.0173 - val_out_pressure_loss: 0.0108
#
# Epoch 00080: val_loss did not improve from 0.02799
# Epoch 81/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0215 - in_pressure_loss: 0.0115 - out_pressure_loss: 0.0100 - val_loss: 0.0266 - val_in_pressure_loss: 0.0161 - val_out_pressure_loss: 0.0106
#
# Epoch 00081: val_loss improved from 0.02799 to 0.02664, saving model to ./model-gpu/transform_encoder_lstm_gpu_1C.h5
# Epoch 82/300
# 127/127 [==============================] - 14s 106ms/step - loss: 0.0212 - in_pressure_loss: 0.0112 - out_pressure_loss: 0.0099 - val_loss: 0.0270 - val_in_pressure_loss: 0.0163 - val_out_pressure_loss: 0.0107
#
# Epoch 00082: val_loss did not improve from 0.02664
# Epoch 83/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0214 - in_pressure_loss: 0.0114 - out_pressure_loss: 0.0100 - val_loss: 0.0291 - val_in_pressure_loss: 0.0179 - val_out_pressure_loss: 0.0112
#
# Epoch 00083: val_loss did not improve from 0.02664
# Epoch 84/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0217 - in_pressure_loss: 0.0117 - out_pressure_loss: 0.0100 - val_loss: 0.0281 - val_in_pressure_loss: 0.0172 - val_out_pressure_loss: 0.0109
#
# Epoch 00084: val_loss did not improve from 0.02664
# Epoch 85/300
# 127/127 [==============================] - 14s 110ms/step - loss: 0.0210 - in_pressure_loss: 0.0111 - out_pressure_loss: 0.0099 - val_loss: 0.0267 - val_in_pressure_loss: 0.0162 - val_out_pressure_loss: 0.0105
#
# Epoch 00085: val_loss did not improve from 0.02664
# Epoch 86/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0238 - in_pressure_loss: 0.0135 - out_pressure_loss: 0.0102 - val_loss: 0.0349 - val_in_pressure_loss: 0.0230 - val_out_pressure_loss: 0.0119
#
# Epoch 00086: val_loss did not improve from 0.02664
# Epoch 87/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0298 - in_pressure_loss: 0.0188 - out_pressure_loss: 0.0110 - val_loss: 0.0447 - val_in_pressure_loss: 0.0306 - val_out_pressure_loss: 0.0141
#
# Epoch 00087: val_loss did not improve from 0.02664
# Epoch 88/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0294 - in_pressure_loss: 0.0184 - out_pressure_loss: 0.0110 - val_loss: 0.0305 - val_in_pressure_loss: 0.0197 - val_out_pressure_loss: 0.0109
#
# Epoch 00088: val_loss did not improve from 0.02664
# Epoch 89/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0234 - in_pressure_loss: 0.0133 - out_pressure_loss: 0.0101 - val_loss: 0.0308 - val_in_pressure_loss: 0.0199 - val_out_pressure_loss: 0.0109
#
# Epoch 00089: val_loss did not improve from 0.02664
# Epoch 90/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0232 - in_pressure_loss: 0.0131 - out_pressure_loss: 0.0101 - val_loss: 0.0274 - val_in_pressure_loss: 0.0169 - val_out_pressure_loss: 0.0105
#
# Epoch 00090: val_loss did not improve from 0.02664
# Epoch 91/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0222 - in_pressure_loss: 0.0122 - out_pressure_loss: 0.0100 - val_loss: 0.0284 - val_in_pressure_loss: 0.0179 - val_out_pressure_loss: 0.0105
#
# Epoch 00091: ReduceLROnPlateau reducing learning rate to 0.0005625000048894435.
#
# Epoch 00091: val_loss did not improve from 0.02664
# Epoch 92/300
# 127/127 [==============================] - 14s 106ms/step - loss: 0.0201 - in_pressure_loss: 0.0105 - out_pressure_loss: 0.0096 - val_loss: 0.0251 - val_in_pressure_loss: 0.0148 - val_out_pressure_loss: 0.0103
#
# Epoch 00092: val_loss improved from 0.02664 to 0.02506, saving model to ./model-gpu/transform_encoder_lstm_gpu_1C.h5
# Epoch 93/300
# 127/127 [==============================] - 14s 107ms/step - loss: 0.0193 - in_pressure_loss: 0.0098 - out_pressure_loss: 0.0095 - val_loss: 0.0253 - val_in_pressure_loss: 0.0152 - val_out_pressure_loss: 0.0102
#
# Epoch 00093: val_loss did not improve from 0.02506
# Epoch 94/300
# 127/127 [==============================] - 13s 105ms/step - loss: 0.0191 - in_pressure_loss: 0.0096 - out_pressure_loss: 0.0095 - val_loss: 0.0274 - val_in_pressure_loss: 0.0171 - val_out_pressure_loss: 0.0103
#
# Epoch 00094: val_loss did not improve from 0.02506
# Epoch 95/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0196 - in_pressure_loss: 0.0101 - out_pressure_loss: 0.0095 - val_loss: 0.0254 - val_in_pressure_loss: 0.0151 - val_out_pressure_loss: 0.0103
#
# Epoch 00095: val_loss did not improve from 0.02506
# Epoch 96/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0236 - in_pressure_loss: 0.0136 - out_pressure_loss: 0.0100 - val_loss: 0.0270 - val_in_pressure_loss: 0.0166 - val_out_pressure_loss: 0.0104
#
# Epoch 00096: val_loss did not improve from 0.02506
# Epoch 97/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0202 - in_pressure_loss: 0.0106 - out_pressure_loss: 0.0096 - val_loss: 0.0251 - val_in_pressure_loss: 0.0150 - val_out_pressure_loss: 0.0102
#
# Epoch 00097: val_loss did not improve from 0.02506
# Epoch 98/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0192 - in_pressure_loss: 0.0097 - out_pressure_loss: 0.0094 - val_loss: 0.0267 - val_in_pressure_loss: 0.0158 - val_out_pressure_loss: 0.0109
#
# Epoch 00098: val_loss did not improve from 0.02506
# Epoch 99/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0193 - in_pressure_loss: 0.0099 - out_pressure_loss: 0.0094 - val_loss: 0.0260 - val_in_pressure_loss: 0.0158 - val_out_pressure_loss: 0.0103
#
# Epoch 00099: val_loss did not improve from 0.02506
# Epoch 100/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0188 - in_pressure_loss: 0.0095 - out_pressure_loss: 0.0094 - val_loss: 0.0245 - val_in_pressure_loss: 0.0145 - val_out_pressure_loss: 0.0100
#
# Epoch 00100: val_loss improved from 0.02506 to 0.02451, saving model to ./model-gpu/transform_encoder_lstm_gpu_1C.h5
# Epoch 101/300
# 127/127 [==============================] - 14s 106ms/step - loss: 0.0186 - in_pressure_loss: 0.0093 - out_pressure_loss: 0.0093 - val_loss: 0.0288 - val_in_pressure_loss: 0.0180 - val_out_pressure_loss: 0.0107
#
# Epoch 00101: val_loss did not improve from 0.02451
# Epoch 102/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0186 - in_pressure_loss: 0.0093 - out_pressure_loss: 0.0093 - val_loss: 0.0263 - val_in_pressure_loss: 0.0157 - val_out_pressure_loss: 0.0106
#
# Epoch 00102: val_loss did not improve from 0.02451
# Epoch 103/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0181 - in_pressure_loss: 0.0088 - out_pressure_loss: 0.0093 - val_loss: 0.0252 - val_in_pressure_loss: 0.0151 - val_out_pressure_loss: 0.0100
#
# Epoch 00103: val_loss did not improve from 0.02451
# Epoch 104/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0180 - in_pressure_loss: 0.0088 - out_pressure_loss: 0.0092 - val_loss: 0.0247 - val_in_pressure_loss: 0.0147 - val_out_pressure_loss: 0.0101
#
# Epoch 00104: val_loss did not improve from 0.02451
# Epoch 105/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0178 - in_pressure_loss: 0.0086 - out_pressure_loss: 0.0092 - val_loss: 0.0247 - val_in_pressure_loss: 0.0147 - val_out_pressure_loss: 0.0101
#
# Epoch 00105: val_loss did not improve from 0.02451
# Epoch 106/300
# 127/127 [==============================] - 13s 105ms/step - loss: 0.0177 - in_pressure_loss: 0.0086 - out_pressure_loss: 0.0091 - val_loss: 0.0246 - val_in_pressure_loss: 0.0146 - val_out_pressure_loss: 0.0100
#
# Epoch 00106: val_loss did not improve from 0.02451
# Epoch 107/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0178 - in_pressure_loss: 0.0087 - out_pressure_loss: 0.0091 - val_loss: 0.0250 - val_in_pressure_loss: 0.0147 - val_out_pressure_loss: 0.0102
#
# Epoch 00107: val_loss did not improve from 0.02451
# Epoch 108/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0177 - in_pressure_loss: 0.0086 - out_pressure_loss: 0.0091 - val_loss: 0.0241 - val_in_pressure_loss: 0.0141 - val_out_pressure_loss: 0.0100
#
# Epoch 00108: val_loss improved from 0.02451 to 0.02415, saving model to ./model-gpu/transform_encoder_lstm_gpu_1C.h5
# Epoch 109/300
# 127/127 [==============================] - 14s 106ms/step - loss: 0.0177 - in_pressure_loss: 0.0086 - out_pressure_loss: 0.0091 - val_loss: 0.0250 - val_in_pressure_loss: 0.0147 - val_out_pressure_loss: 0.0103
#
# Epoch 00109: val_loss did not improve from 0.02415
# Epoch 110/300
# 127/127 [==============================] - 13s 105ms/step - loss: 0.0177 - in_pressure_loss: 0.0086 - out_pressure_loss: 0.0091 - val_loss: 0.0252 - val_in_pressure_loss: 0.0150 - val_out_pressure_loss: 0.0102
#
# Epoch 00110: val_loss did not improve from 0.02415
# Epoch 111/300
# 127/127 [==============================] - 13s 105ms/step - loss: 0.0177 - in_pressure_loss: 0.0086 - out_pressure_loss: 0.0091 - val_loss: 0.0240 - val_in_pressure_loss: 0.0140 - val_out_pressure_loss: 0.0100
#
# Epoch 00111: val_loss improved from 0.02415 to 0.02399, saving model to ./model-gpu/transform_encoder_lstm_gpu_1C.h5
# Epoch 112/300
# 127/127 [==============================] - 14s 107ms/step - loss: 0.0188 - in_pressure_loss: 0.0096 - out_pressure_loss: 0.0092 - val_loss: 0.0270 - val_in_pressure_loss: 0.0166 - val_out_pressure_loss: 0.0104
#
# Epoch 00112: val_loss did not improve from 0.02399
# Epoch 113/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0272 - in_pressure_loss: 0.0165 - out_pressure_loss: 0.0107 - val_loss: 0.0293 - val_in_pressure_loss: 0.0184 - val_out_pressure_loss: 0.0109
#
# Epoch 00113: val_loss did not improve from 0.02399
# Epoch 114/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0217 - in_pressure_loss: 0.0120 - out_pressure_loss: 0.0097 - val_loss: 0.0295 - val_in_pressure_loss: 0.0187 - val_out_pressure_loss: 0.0108
#
# Epoch 00114: val_loss did not improve from 0.02399
# Epoch 115/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0197 - in_pressure_loss: 0.0104 - out_pressure_loss: 0.0094 - val_loss: 0.0250 - val_in_pressure_loss: 0.0149 - val_out_pressure_loss: 0.0100
#
# Epoch 00115: val_loss did not improve from 0.02399
# Epoch 116/300
# 127/127 [==============================] - 14s 107ms/step - loss: 0.0186 - in_pressure_loss: 0.0095 - out_pressure_loss: 0.0092 - val_loss: 0.0261 - val_in_pressure_loss: 0.0156 - val_out_pressure_loss: 0.0105
#
# Epoch 00116: val_loss did not improve from 0.02399
# Epoch 117/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0180 - in_pressure_loss: 0.0089 - out_pressure_loss: 0.0091 - val_loss: 0.0251 - val_in_pressure_loss: 0.0151 - val_out_pressure_loss: 0.0100
#
# Epoch 00117: val_loss did not improve from 0.02399
# Epoch 118/300
# 127/127 [==============================] - 13s 105ms/step - loss: 0.0175 - in_pressure_loss: 0.0086 - out_pressure_loss: 0.0090 - val_loss: 0.0244 - val_in_pressure_loss: 0.0144 - val_out_pressure_loss: 0.0100
#
# Epoch 00118: val_loss did not improve from 0.02399
# Epoch 119/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0173 - in_pressure_loss: 0.0083 - out_pressure_loss: 0.0090 - val_loss: 0.0244 - val_in_pressure_loss: 0.0144 - val_out_pressure_loss: 0.0100
#
# Epoch 00119: val_loss did not improve from 0.02399
# Epoch 120/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0170 - in_pressure_loss: 0.0081 - out_pressure_loss: 0.0089 - val_loss: 0.0241 - val_in_pressure_loss: 0.0142 - val_out_pressure_loss: 0.0099
#
# Epoch 00120: val_loss did not improve from 0.02399
# Epoch 121/300
# 127/127 [==============================] - 14s 111ms/step - loss: 0.0168 - in_pressure_loss: 0.0080 - out_pressure_loss: 0.0088 - val_loss: 0.0245 - val_in_pressure_loss: 0.0145 - val_out_pressure_loss: 0.0100
#
# Epoch 00121: ReduceLROnPlateau reducing learning rate to 0.0004218749818392098.
#
# Epoch 00121: val_loss did not improve from 0.02399
# Epoch 122/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0161 - in_pressure_loss: 0.0073 - out_pressure_loss: 0.0087 - val_loss: 0.0241 - val_in_pressure_loss: 0.0142 - val_out_pressure_loss: 0.0099
#
# Epoch 00122: val_loss did not improve from 0.02399
# Epoch 123/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0159 - in_pressure_loss: 0.0072 - out_pressure_loss: 0.0087 - val_loss: 0.0236 - val_in_pressure_loss: 0.0138 - val_out_pressure_loss: 0.0098
#
# Epoch 00123: val_loss improved from 0.02399 to 0.02358, saving model to ./model-gpu/transform_encoder_lstm_gpu_1C.h5
# Epoch 124/300
# 127/127 [==============================] - 14s 106ms/step - loss: 0.0158 - in_pressure_loss: 0.0072 - out_pressure_loss: 0.0087 - val_loss: 0.0245 - val_in_pressure_loss: 0.0146 - val_out_pressure_loss: 0.0099
#
# Epoch 00124: val_loss did not improve from 0.02358
# Epoch 125/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0157 - in_pressure_loss: 0.0071 - out_pressure_loss: 0.0086 - val_loss: 0.0234 - val_in_pressure_loss: 0.0136 - val_out_pressure_loss: 0.0097
#
# Epoch 00125: val_loss improved from 0.02358 to 0.02337, saving model to ./model-gpu/transform_encoder_lstm_gpu_1C.h5
# Epoch 126/300
# 127/127 [==============================] - 14s 107ms/step - loss: 0.0156 - in_pressure_loss: 0.0070 - out_pressure_loss: 0.0086 - val_loss: 0.0234 - val_in_pressure_loss: 0.0136 - val_out_pressure_loss: 0.0098
#
# Epoch 00126: val_loss did not improve from 0.02337
# Epoch 127/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0156 - in_pressure_loss: 0.0070 - out_pressure_loss: 0.0086 - val_loss: 0.0236 - val_in_pressure_loss: 0.0137 - val_out_pressure_loss: 0.0100
#
# Epoch 00127: val_loss did not improve from 0.02337
# Epoch 128/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0156 - in_pressure_loss: 0.0070 - out_pressure_loss: 0.0086 - val_loss: 0.0237 - val_in_pressure_loss: 0.0137 - val_out_pressure_loss: 0.0099
#
# Epoch 00128: val_loss did not improve from 0.02337
# Epoch 129/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0157 - in_pressure_loss: 0.0071 - out_pressure_loss: 0.0086 - val_loss: 0.0245 - val_in_pressure_loss: 0.0147 - val_out_pressure_loss: 0.0098
#
# Epoch 00129: val_loss did not improve from 0.02337
# Epoch 130/300
# 127/127 [==============================] - 13s 105ms/step - loss: 0.0156 - in_pressure_loss: 0.0071 - out_pressure_loss: 0.0085 - val_loss: 0.0237 - val_in_pressure_loss: 0.0138 - val_out_pressure_loss: 0.0100
#
# Epoch 00130: val_loss did not improve from 0.02337
# Epoch 131/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0154 - in_pressure_loss: 0.0069 - out_pressure_loss: 0.0085 - val_loss: 0.0234 - val_in_pressure_loss: 0.0135 - val_out_pressure_loss: 0.0099
#
# Epoch 00131: val_loss did not improve from 0.02337
# Epoch 132/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0153 - in_pressure_loss: 0.0068 - out_pressure_loss: 0.0085 - val_loss: 0.0231 - val_in_pressure_loss: 0.0133 - val_out_pressure_loss: 0.0098
#
# Epoch 00132: val_loss improved from 0.02337 to 0.02312, saving model to ./model-gpu/transform_encoder_lstm_gpu_1C.h5
# Epoch 133/300
# 127/127 [==============================] - 14s 107ms/step - loss: 0.0153 - in_pressure_loss: 0.0068 - out_pressure_loss: 0.0085 - val_loss: 0.0247 - val_in_pressure_loss: 0.0143 - val_out_pressure_loss: 0.0104
#
# Epoch 00133: val_loss did not improve from 0.02312
# Epoch 134/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0153 - in_pressure_loss: 0.0068 - out_pressure_loss: 0.0085 - val_loss: 0.0237 - val_in_pressure_loss: 0.0138 - val_out_pressure_loss: 0.0099
#
# Epoch 00134: val_loss did not improve from 0.02312
# Epoch 135/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0153 - in_pressure_loss: 0.0068 - out_pressure_loss: 0.0085 - val_loss: 0.0234 - val_in_pressure_loss: 0.0136 - val_out_pressure_loss: 0.0098
#
# Epoch 00135: val_loss did not improve from 0.02312
# Epoch 136/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0151 - in_pressure_loss: 0.0066 - out_pressure_loss: 0.0084 - val_loss: 0.0239 - val_in_pressure_loss: 0.0138 - val_out_pressure_loss: 0.0101
#
# Epoch 00136: val_loss did not improve from 0.02312
# Epoch 137/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0151 - in_pressure_loss: 0.0067 - out_pressure_loss: 0.0084 - val_loss: 0.0242 - val_in_pressure_loss: 0.0144 - val_out_pressure_loss: 0.0098
#
# Epoch 00137: val_loss did not improve from 0.02312
# Epoch 138/300
# 127/127 [==============================] - 14s 107ms/step - loss: 0.0151 - in_pressure_loss: 0.0067 - out_pressure_loss: 0.0084 - val_loss: 0.0243 - val_in_pressure_loss: 0.0144 - val_out_pressure_loss: 0.0100
#
# Epoch 00138: val_loss did not improve from 0.02312
# Epoch 139/300
# 127/127 [==============================] - 14s 107ms/step - loss: 0.0150 - in_pressure_loss: 0.0066 - out_pressure_loss: 0.0084 - val_loss: 0.0236 - val_in_pressure_loss: 0.0137 - val_out_pressure_loss: 0.0099
#
# Epoch 00139: val_loss did not improve from 0.02312
# Epoch 140/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0151 - in_pressure_loss: 0.0067 - out_pressure_loss: 0.0084 - val_loss: 0.0248 - val_in_pressure_loss: 0.0148 - val_out_pressure_loss: 0.0100
#
# Epoch 00140: val_loss did not improve from 0.02312
# Epoch 141/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0150 - in_pressure_loss: 0.0066 - out_pressure_loss: 0.0084 - val_loss: 0.0234 - val_in_pressure_loss: 0.0136 - val_out_pressure_loss: 0.0098
#
# Epoch 00141: val_loss did not improve from 0.02312
# Epoch 142/300
# 127/127 [==============================] - 13s 105ms/step - loss: 0.0148 - in_pressure_loss: 0.0064 - out_pressure_loss: 0.0083 - val_loss: 0.0230 - val_in_pressure_loss: 0.0133 - val_out_pressure_loss: 0.0097
#
# Epoch 00142: val_loss improved from 0.02312 to 0.02301, saving model to ./model-gpu/transform_encoder_lstm_gpu_1C.h5
# Epoch 143/300
# 127/127 [==============================] - 14s 106ms/step - loss: 0.0148 - in_pressure_loss: 0.0065 - out_pressure_loss: 0.0083 - val_loss: 0.0230 - val_in_pressure_loss: 0.0132 - val_out_pressure_loss: 0.0098
#
# Epoch 00143: val_loss did not improve from 0.02301
# Epoch 144/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0146 - in_pressure_loss: 0.0063 - out_pressure_loss: 0.0083 - val_loss: 0.0228 - val_in_pressure_loss: 0.0130 - val_out_pressure_loss: 0.0098
#
# Epoch 00144: val_loss improved from 0.02301 to 0.02279, saving model to ./model-gpu/transform_encoder_lstm_gpu_1C.h5
# Epoch 145/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0146 - in_pressure_loss: 0.0063 - out_pressure_loss: 0.0083 - val_loss: 0.0231 - val_in_pressure_loss: 0.0133 - val_out_pressure_loss: 0.0098
#
# Epoch 00145: val_loss did not improve from 0.02279
# Epoch 146/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0148 - in_pressure_loss: 0.0065 - out_pressure_loss: 0.0083 - val_loss: 0.0232 - val_in_pressure_loss: 0.0134 - val_out_pressure_loss: 0.0098
#
# Epoch 00146: val_loss did not improve from 0.02279
# Epoch 147/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0145 - in_pressure_loss: 0.0062 - out_pressure_loss: 0.0083 - val_loss: 0.0232 - val_in_pressure_loss: 0.0134 - val_out_pressure_loss: 0.0098
#
# Epoch 00147: val_loss did not improve from 0.02279
# Epoch 148/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0147 - in_pressure_loss: 0.0064 - out_pressure_loss: 0.0083 - val_loss: 0.0229 - val_in_pressure_loss: 0.0132 - val_out_pressure_loss: 0.0097
#
# Epoch 00148: val_loss did not improve from 0.02279
# Epoch 149/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0145 - in_pressure_loss: 0.0063 - out_pressure_loss: 0.0082 - val_loss: 0.0236 - val_in_pressure_loss: 0.0138 - val_out_pressure_loss: 0.0098
#
# Epoch 00149: val_loss did not improve from 0.02279
# Epoch 150/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0146 - in_pressure_loss: 0.0063 - out_pressure_loss: 0.0083 - val_loss: 0.0234 - val_in_pressure_loss: 0.0136 - val_out_pressure_loss: 0.0098
#
# Epoch 00150: val_loss did not improve from 0.02279
# Epoch 151/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0142 - in_pressure_loss: 0.0061 - out_pressure_loss: 0.0082 - val_loss: 0.0230 - val_in_pressure_loss: 0.0132 - val_out_pressure_loss: 0.0097
#
# Epoch 00151: val_loss did not improve from 0.02279
# Epoch 152/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0143 - in_pressure_loss: 0.0061 - out_pressure_loss: 0.0082 - val_loss: 0.0229 - val_in_pressure_loss: 0.0131 - val_out_pressure_loss: 0.0097
#
# Epoch 00152: val_loss did not improve from 0.02279
# Epoch 153/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0141 - in_pressure_loss: 0.0060 - out_pressure_loss: 0.0081 - val_loss: 0.0231 - val_in_pressure_loss: 0.0134 - val_out_pressure_loss: 0.0097
#
# Epoch 00153: val_loss did not improve from 0.02279
# Epoch 154/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0141 - in_pressure_loss: 0.0060 - out_pressure_loss: 0.0081 - val_loss: 0.0230 - val_in_pressure_loss: 0.0133 - val_out_pressure_loss: 0.0097
#
# Epoch 00154: ReduceLROnPlateau reducing learning rate to 0.00031640623637940735.
#
# Epoch 00154: val_loss did not improve from 0.02279
# Epoch 155/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0135 - in_pressure_loss: 0.0056 - out_pressure_loss: 0.0080 - val_loss: 0.0228 - val_in_pressure_loss: 0.0132 - val_out_pressure_loss: 0.0096
#
# Epoch 00155: val_loss did not improve from 0.02279
# Epoch 156/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0133 - in_pressure_loss: 0.0054 - out_pressure_loss: 0.0079 - val_loss: 0.0225 - val_in_pressure_loss: 0.0129 - val_out_pressure_loss: 0.0096
#
# Epoch 00156: val_loss improved from 0.02279 to 0.02250, saving model to ./model-gpu/transform_encoder_lstm_gpu_1C.h5
# Epoch 157/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0133 - in_pressure_loss: 0.0054 - out_pressure_loss: 0.0079 - val_loss: 0.0226 - val_in_pressure_loss: 0.0130 - val_out_pressure_loss: 0.0096
#
# Epoch 00157: val_loss did not improve from 0.02250
# Epoch 158/300
# 127/127 [==============================] - 13s 105ms/step - loss: 0.0133 - in_pressure_loss: 0.0054 - out_pressure_loss: 0.0079 - val_loss: 0.0226 - val_in_pressure_loss: 0.0129 - val_out_pressure_loss: 0.0096
#
# Epoch 00158: val_loss did not improve from 0.02250
# Epoch 159/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0133 - in_pressure_loss: 0.0054 - out_pressure_loss: 0.0079 - val_loss: 0.0233 - val_in_pressure_loss: 0.0136 - val_out_pressure_loss: 0.0098
#
# Epoch 00159: val_loss did not improve from 0.02250
# Epoch 160/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0136 - in_pressure_loss: 0.0056 - out_pressure_loss: 0.0080 - val_loss: 0.0225 - val_in_pressure_loss: 0.0129 - val_out_pressure_loss: 0.0096
#
# Epoch 00160: val_loss did not improve from 0.02250
# Epoch 161/300
# 127/127 [==============================] - 14s 107ms/step - loss: 0.0134 - in_pressure_loss: 0.0055 - out_pressure_loss: 0.0079 - val_loss: 0.0229 - val_in_pressure_loss: 0.0132 - val_out_pressure_loss: 0.0097
#
# Epoch 00161: val_loss did not improve from 0.02250
# Epoch 162/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0133 - in_pressure_loss: 0.0054 - out_pressure_loss: 0.0079 - val_loss: 0.0229 - val_in_pressure_loss: 0.0132 - val_out_pressure_loss: 0.0096
#
# Epoch 00162: val_loss did not improve from 0.02250
# Epoch 163/300
# 127/127 [==============================] - 14s 110ms/step - loss: 0.0133 - in_pressure_loss: 0.0054 - out_pressure_loss: 0.0079 - val_loss: 0.0228 - val_in_pressure_loss: 0.0132 - val_out_pressure_loss: 0.0096
#
# Epoch 00163: val_loss did not improve from 0.02250
# Epoch 164/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0131 - in_pressure_loss: 0.0053 - out_pressure_loss: 0.0078 - val_loss: 0.0233 - val_in_pressure_loss: 0.0136 - val_out_pressure_loss: 0.0097
#
# Epoch 00164: val_loss did not improve from 0.02250
# Epoch 165/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0131 - in_pressure_loss: 0.0052 - out_pressure_loss: 0.0078 - val_loss: 0.0227 - val_in_pressure_loss: 0.0130 - val_out_pressure_loss: 0.0097
#
# Epoch 00165: val_loss did not improve from 0.02250
# Epoch 166/300
# 127/127 [==============================] - 13s 105ms/step - loss: 0.0131 - in_pressure_loss: 0.0053 - out_pressure_loss: 0.0078 - val_loss: 0.0228 - val_in_pressure_loss: 0.0131 - val_out_pressure_loss: 0.0096
#
# Epoch 00166: ReduceLROnPlateau reducing learning rate to 0.00023730468819849193.
#
# Epoch 00166: val_loss did not improve from 0.02250
# Epoch 167/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0125 - in_pressure_loss: 0.0049 - out_pressure_loss: 0.0077 - val_loss: 0.0222 - val_in_pressure_loss: 0.0126 - val_out_pressure_loss: 0.0096
#
# Epoch 00167: val_loss improved from 0.02250 to 0.02220, saving model to ./model-gpu/transform_encoder_lstm_gpu_1C.h5
# Epoch 168/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0125 - in_pressure_loss: 0.0048 - out_pressure_loss: 0.0077 - val_loss: 0.0229 - val_in_pressure_loss: 0.0131 - val_out_pressure_loss: 0.0098
#
# Epoch 00168: val_loss did not improve from 0.02220
# Epoch 169/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0124 - in_pressure_loss: 0.0048 - out_pressure_loss: 0.0076 - val_loss: 0.0224 - val_in_pressure_loss: 0.0128 - val_out_pressure_loss: 0.0096
#
# Epoch 00169: val_loss did not improve from 0.02220
# Epoch 170/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0124 - in_pressure_loss: 0.0047 - out_pressure_loss: 0.0076 - val_loss: 0.0223 - val_in_pressure_loss: 0.0127 - val_out_pressure_loss: 0.0096
#
# Epoch 00170: val_loss did not improve from 0.02220
# Epoch 171/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0124 - in_pressure_loss: 0.0048 - out_pressure_loss: 0.0076 - val_loss: 0.0223 - val_in_pressure_loss: 0.0127 - val_out_pressure_loss: 0.0095
#
# Epoch 00171: val_loss did not improve from 0.02220
# Epoch 172/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0123 - in_pressure_loss: 0.0047 - out_pressure_loss: 0.0076 - val_loss: 0.0223 - val_in_pressure_loss: 0.0127 - val_out_pressure_loss: 0.0096
#
# Epoch 00172: val_loss did not improve from 0.02220
# Epoch 173/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0124 - in_pressure_loss: 0.0048 - out_pressure_loss: 0.0076 - val_loss: 0.0225 - val_in_pressure_loss: 0.0129 - val_out_pressure_loss: 0.0096
#
# Epoch 00173: val_loss did not improve from 0.02220
# Epoch 174/300
# 127/127 [==============================] - 14s 106ms/step - loss: 0.0125 - in_pressure_loss: 0.0048 - out_pressure_loss: 0.0077 - val_loss: 0.0222 - val_in_pressure_loss: 0.0126 - val_out_pressure_loss: 0.0096
#
# Epoch 00174: val_loss did not improve from 0.02220
# Epoch 175/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0124 - in_pressure_loss: 0.0048 - out_pressure_loss: 0.0076 - val_loss: 0.0223 - val_in_pressure_loss: 0.0128 - val_out_pressure_loss: 0.0096
#
# Epoch 00175: val_loss did not improve from 0.02220
# Epoch 176/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0122 - in_pressure_loss: 0.0046 - out_pressure_loss: 0.0076 - val_loss: 0.0222 - val_in_pressure_loss: 0.0126 - val_out_pressure_loss: 0.0096
#
# Epoch 00176: val_loss improved from 0.02220 to 0.02216, saving model to ./model-gpu/transform_encoder_lstm_gpu_1C.h5
# Epoch 177/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0122 - in_pressure_loss: 0.0047 - out_pressure_loss: 0.0076 - val_loss: 0.0224 - val_in_pressure_loss: 0.0128 - val_out_pressure_loss: 0.0096
#
# Epoch 00177: ReduceLROnPlateau reducing learning rate to 0.00017797851614886895.
#
# Epoch 00177: val_loss did not improve from 0.02216
# Epoch 178/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0119 - in_pressure_loss: 0.0044 - out_pressure_loss: 0.0075 - val_loss: 0.0221 - val_in_pressure_loss: 0.0126 - val_out_pressure_loss: 0.0095
#
# Epoch 00178: val_loss improved from 0.02216 to 0.02210, saving model to ./model-gpu/transform_encoder_lstm_gpu_1C.h5
# Epoch 179/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0118 - in_pressure_loss: 0.0044 - out_pressure_loss: 0.0074 - val_loss: 0.0222 - val_in_pressure_loss: 0.0126 - val_out_pressure_loss: 0.0095
#
# Epoch 00179: val_loss did not improve from 0.02210
# Epoch 180/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0117 - in_pressure_loss: 0.0043 - out_pressure_loss: 0.0074 - val_loss: 0.0221 - val_in_pressure_loss: 0.0126 - val_out_pressure_loss: 0.0095
#
# Epoch 00180: val_loss did not improve from 0.02210
# Epoch 181/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0118 - in_pressure_loss: 0.0043 - out_pressure_loss: 0.0074 - val_loss: 0.0221 - val_in_pressure_loss: 0.0126 - val_out_pressure_loss: 0.0095
#
# Epoch 00181: val_loss improved from 0.02210 to 0.02207, saving model to ./model-gpu/transform_encoder_lstm_gpu_1C.h5
# Epoch 182/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0117 - in_pressure_loss: 0.0043 - out_pressure_loss: 0.0074 - val_loss: 0.0222 - val_in_pressure_loss: 0.0126 - val_out_pressure_loss: 0.0096
#
# Epoch 00182: val_loss did not improve from 0.02207
# Epoch 183/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0117 - in_pressure_loss: 0.0043 - out_pressure_loss: 0.0074 - val_loss: 0.0221 - val_in_pressure_loss: 0.0126 - val_out_pressure_loss: 0.0095
#
# Epoch 00183: val_loss did not improve from 0.02207
# Epoch 184/300
# 127/127 [==============================] - 14s 107ms/step - loss: 0.0118 - in_pressure_loss: 0.0044 - out_pressure_loss: 0.0074 - val_loss: 0.0221 - val_in_pressure_loss: 0.0126 - val_out_pressure_loss: 0.0095
#
# Epoch 00184: val_loss did not improve from 0.02207
# Epoch 185/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0117 - in_pressure_loss: 0.0043 - out_pressure_loss: 0.0074 - val_loss: 0.0221 - val_in_pressure_loss: 0.0126 - val_out_pressure_loss: 0.0095
#
# Epoch 00185: val_loss did not improve from 0.02207
# Epoch 186/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0116 - in_pressure_loss: 0.0043 - out_pressure_loss: 0.0074 - val_loss: 0.0221 - val_in_pressure_loss: 0.0126 - val_out_pressure_loss: 0.0096
#
# Epoch 00186: val_loss did not improve from 0.02207
# Epoch 187/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0116 - in_pressure_loss: 0.0042 - out_pressure_loss: 0.0074 - val_loss: 0.0221 - val_in_pressure_loss: 0.0126 - val_out_pressure_loss: 0.0096
#
# Epoch 00187: val_loss did not improve from 0.02207
# Epoch 188/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0116 - in_pressure_loss: 0.0042 - out_pressure_loss: 0.0073 - val_loss: 0.0222 - val_in_pressure_loss: 0.0126 - val_out_pressure_loss: 0.0096
#
# Epoch 00188: ReduceLROnPlateau reducing learning rate to 0.0001334838816546835.
#
# Epoch 00188: val_loss did not improve from 0.02207
# Epoch 189/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0113 - in_pressure_loss: 0.0040 - out_pressure_loss: 0.0073 - val_loss: 0.0220 - val_in_pressure_loss: 0.0125 - val_out_pressure_loss: 0.0095
#
# Epoch 00189: val_loss improved from 0.02207 to 0.02196, saving model to ./model-gpu/transform_encoder_lstm_gpu_1C.h5
# Epoch 190/300
# 127/127 [==============================] - 14s 106ms/step - loss: 0.0113 - in_pressure_loss: 0.0040 - out_pressure_loss: 0.0073 - val_loss: 0.0220 - val_in_pressure_loss: 0.0125 - val_out_pressure_loss: 0.0095
#
# Epoch 00190: val_loss improved from 0.02196 to 0.02195, saving model to ./model-gpu/transform_encoder_lstm_gpu_1C.h5
# Epoch 191/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0112 - in_pressure_loss: 0.0040 - out_pressure_loss: 0.0073 - val_loss: 0.0220 - val_in_pressure_loss: 0.0124 - val_out_pressure_loss: 0.0095
#
# Epoch 00191: val_loss did not improve from 0.02195
# Epoch 192/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0112 - in_pressure_loss: 0.0040 - out_pressure_loss: 0.0072 - val_loss: 0.0220 - val_in_pressure_loss: 0.0125 - val_out_pressure_loss: 0.0095
#
# Epoch 00192: val_loss did not improve from 0.02195
# Epoch 193/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0112 - in_pressure_loss: 0.0040 - out_pressure_loss: 0.0072 - val_loss: 0.0220 - val_in_pressure_loss: 0.0125 - val_out_pressure_loss: 0.0095
#
# Epoch 00193: val_loss did not improve from 0.02195
# Epoch 194/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0112 - in_pressure_loss: 0.0040 - out_pressure_loss: 0.0072 - val_loss: 0.0223 - val_in_pressure_loss: 0.0127 - val_out_pressure_loss: 0.0096
#
# Epoch 00194: val_loss did not improve from 0.02195
# Epoch 195/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0113 - in_pressure_loss: 0.0040 - out_pressure_loss: 0.0072 - val_loss: 0.0220 - val_in_pressure_loss: 0.0125 - val_out_pressure_loss: 0.0095
#
# Epoch 00195: val_loss did not improve from 0.02195
# Epoch 196/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0112 - in_pressure_loss: 0.0040 - out_pressure_loss: 0.0072 - val_loss: 0.0221 - val_in_pressure_loss: 0.0125 - val_out_pressure_loss: 0.0096
#
# Epoch 00196: val_loss did not improve from 0.02195
# Epoch 197/300
# 127/127 [==============================] - 13s 105ms/step - loss: 0.0112 - in_pressure_loss: 0.0040 - out_pressure_loss: 0.0072 - val_loss: 0.0220 - val_in_pressure_loss: 0.0125 - val_out_pressure_loss: 0.0096
#
# Epoch 00197: val_loss did not improve from 0.02195
# Epoch 198/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0112 - in_pressure_loss: 0.0040 - out_pressure_loss: 0.0072 - val_loss: 0.0220 - val_in_pressure_loss: 0.0125 - val_out_pressure_loss: 0.0095
#
# Epoch 00198: val_loss did not improve from 0.02195
# Epoch 199/300
# 127/127 [==============================] - 13s 105ms/step - loss: 0.0111 - in_pressure_loss: 0.0039 - out_pressure_loss: 0.0072 - val_loss: 0.0221 - val_in_pressure_loss: 0.0126 - val_out_pressure_loss: 0.0095
#
# Epoch 00199: ReduceLROnPlateau reducing learning rate to 0.00010011290578404441.
#
# Epoch 00199: val_loss did not improve from 0.02195
# Epoch 200/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0110 - in_pressure_loss: 0.0038 - out_pressure_loss: 0.0071 - val_loss: 0.0221 - val_in_pressure_loss: 0.0125 - val_out_pressure_loss: 0.0095
#
# Epoch 00200: val_loss did not improve from 0.02195
# Epoch 201/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0109 - in_pressure_loss: 0.0038 - out_pressure_loss: 0.0071 - val_loss: 0.0219 - val_in_pressure_loss: 0.0124 - val_out_pressure_loss: 0.0095
#
# Epoch 00201: val_loss improved from 0.02195 to 0.02188, saving model to ./model-gpu/transform_encoder_lstm_gpu_1C.h5
# Epoch 202/300
# 127/127 [==============================] - 14s 111ms/step - loss: 0.0109 - in_pressure_loss: 0.0038 - out_pressure_loss: 0.0071 - val_loss: 0.0219 - val_in_pressure_loss: 0.0124 - val_out_pressure_loss: 0.0095
#
# Epoch 00202: val_loss did not improve from 0.02188
# Epoch 203/300
# 127/127 [==============================] - 14s 106ms/step - loss: 0.0109 - in_pressure_loss: 0.0038 - out_pressure_loss: 0.0071 - val_loss: 0.0219 - val_in_pressure_loss: 0.0124 - val_out_pressure_loss: 0.0095
#
# Epoch 00203: val_loss improved from 0.02188 to 0.02185, saving model to ./model-gpu/transform_encoder_lstm_gpu_1C.h5
# Epoch 204/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0109 - in_pressure_loss: 0.0038 - out_pressure_loss: 0.0071 - val_loss: 0.0220 - val_in_pressure_loss: 0.0125 - val_out_pressure_loss: 0.0095
#
# Epoch 00204: val_loss did not improve from 0.02185
# Epoch 205/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0108 - in_pressure_loss: 0.0037 - out_pressure_loss: 0.0071 - val_loss: 0.0219 - val_in_pressure_loss: 0.0124 - val_out_pressure_loss: 0.0095
#
# Epoch 00205: val_loss did not improve from 0.02185
# Epoch 206/300
# 127/127 [==============================] - 14s 106ms/step - loss: 0.0108 - in_pressure_loss: 0.0037 - out_pressure_loss: 0.0071 - val_loss: 0.0219 - val_in_pressure_loss: 0.0124 - val_out_pressure_loss: 0.0095
#
# Epoch 00206: val_loss did not improve from 0.02185
# Epoch 207/300
# 127/127 [==============================] - 14s 106ms/step - loss: 0.0108 - in_pressure_loss: 0.0037 - out_pressure_loss: 0.0071 - val_loss: 0.0219 - val_in_pressure_loss: 0.0124 - val_out_pressure_loss: 0.0095
#
# Epoch 00207: val_loss did not improve from 0.02185
# Epoch 208/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0108 - in_pressure_loss: 0.0037 - out_pressure_loss: 0.0071 - val_loss: 0.0219 - val_in_pressure_loss: 0.0124 - val_out_pressure_loss: 0.0095
#
# Epoch 00208: val_loss did not improve from 0.02185
# Epoch 209/300
# 127/127 [==============================] - 13s 106ms/step - loss: 0.0108 - in_pressure_loss: 0.0038 - out_pressure_loss: 0.0071 - val_loss: 0.0219 - val_in_pressure_loss: 0.0124 - val_out_pressure_loss: 0.0095
#
# Epoch 00209: val_loss did not improve from 0.02185
# Epoch 210/300
#   5/127 [>.............................] - ETA: 11s - loss: 0.0107 - in_pressure_loss: 0.0037 - out_pressure_loss: 0.0071

# %%
np.unique(train[:, :, U_OUT_IDX])
# Out:
# array([-1.,  0.])

# %% [markdown]
# # skip_folds = np.arange(6)
# # train_pred = np.zeros(targets.shape)
#
# BATCH_SIZE=128
# IS_WAVENET=False
# USE_RC_LOSS=False
#
# with tpu_strategy.scope():
#
#     VERBOSE = 2
#     EPOCHS = 600
#     FOLDS = 7
#     if DEBUG:
#       EPOCHS = 100
#     test_preds = []
#     kf = KFold(n_splits=FOLDS, shuffle=True, random_state=2021)
#     last_test_idx = []
#
#     for fold, (train_idx, test_idx) in enumerate(kf.split(train, targets)):
#         last_test_idx = test_idx
#         if len(test_preds) > fold:
#           print(f'Ignore corrent fold {fold+1} as we already predicted test data')
#
#         if DEBUG and fold > 0:
#           continue
#
#         X_train, X_valid = train[train_idx], train[test_idx]
#         y_train, y_valid = targets[train_idx], targets[test_idx]
#         #Align data to batch size and drop remainder. We only need it for TPU not GPU
#         if IS_TPU and IS_WAVENET:
#           fit_batch_size = X_train.shape[0] - (X_train.shape[0]%BATCH_SIZE)
#           print(X_train.shape[0], fit_batch_size)
#           X_train, y_train = X_train[:fit_batch_size, :, :], y_train[:fit_batch_size, :]
#
#           fit_batch_size = X_valid.shape[0] - (X_valid.shape[0]%BATCH_SIZE)
#           print(X_valid.shape[0], fit_batch_size)
#           X_valid, y_valid = X_valid[:fit_batch_size, :, :], y_valid[:fit_batch_size, :]
#
#         checkpoint_name = f'./model-gpu/transform_lstm_gpu_{fold+1}C.h5'
#         custom_objects = {"ScaleLayer": ScaleLayer, "RC_loss": RC_loss,
#                           "Time2Vec": Time2Vec,
#                           "TransformerEncoder": TransformerEncoder,
#                           'TransformerDecoder': TransformerDecoder}
#         load_locally = tf.saved_model.LoadOptions(experimental_io_device='/job:localhost')
#
#         if fold not in skip_folds:
#           # model = load_dnn_model_v4_add_wavenet(-3, True)
#           # model = lstm_wavenet_model()
#           # model = dnn_TransformerEncoder_model()
#           model = Transformer_LSTM_model(ff_dim=256,num_heads=8,num_layers=2,)
#           #show_weight_names(model)
#           model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate = 1e-3),
#                         # loss=RC_loss
#                         loss=tf.keras.losses.MeanAbsoluteError()
#                         )
#
#
#
#           lr = ReduceLROnPlateau(monitor="val_loss", factor=0.75,
#                                 patience=10, verbose=VERBOSE)
#
#           # scheduler = tf.keras.optimizers.schedules.ExponentialDecay(1e-3, 5, 0.9)
#           # lr = tf.keras.callbacks.LearningRateScheduler(scheduler)
#
#
#           chk_point = ModelCheckpoint(checkpoint_name,
#                                       monitor='val_loss', verbose=VERBOSE,
#                                       save_best_only=True, mode='min')
#
#           es = EarlyStopping(monitor="val_loss", patience=50,
#                             verbose=VERBOSE, mode="min",
#                             restore_best_weights=True)
#
#
#           if os.path.isfile(checkpoint_name):
#             model.load_weights(checkpoint_name)
#             print('Resumed previous weight from ', checkpoint_name)
#
#           if USE_RC_LOSS:
#             model.fit(X_train, np.append(y_train, X_train[:, :, -4]+X_train[:, :, -5], axis =1),
#                       validation_data=(X_valid, np.append(y_valid, X_valid[:, :, -4]+X_valid[:, :, -5], axis =1)),
#                       epochs=EPOCHS,
#                       verbose=VERBOSE,
#                       batch_size=BATCH_SIZE,
#                       callbacks=[lr, chk_point, es])
#           else:
#             train_decoder_inputs, train_decoder_outputs = make_transformer_targets(y_train)
#             valid_decoder_inputs, valid_decoder_outputs = make_transformer_targets(y_valid)
#
#             # print(train_decoder_inputs[0], train_decoder_outputs[0], valid_decoder_inputs[0], valid_decoder_outputs[0])
#
#             model.fit([X_train, train_decoder_inputs], train_decoder_outputs,
#                       validation_data=([X_valid, valid_decoder_inputs], valid_decoder_outputs),
#                       epochs=EPOCHS,
#                       verbose=VERBOSE,
#                       batch_size=BATCH_SIZE,
#                       callbacks=[lr, chk_point, es])
#         else:
#           print('Load pretrain weight from ', checkpoint_name)
#           try:
#             # At loading time, register the custom objects with a `custom_object_scope`:
#             with tf.keras.utils.custom_object_scope(custom_objects):
#                 model = load_model(checkpoint_name, options=load_locally)
#                 print('Loaded pretrain weight from ', checkpoint_name)
#           except (OSError):
#             print('Cannot load pretrain weight from ', checkpoint_name)
#             break
#
#         # y_true = y_valid.squeeze().reshape(-1, 1)
#         # y_pred = model.predict(X_valid, batch_size=BATCH_SIZE).squeeze().reshape(-1, 1)
#         # score = mean_absolute_error(y_true, y_pred)
#         # print(f"Fold-{fold+1} | OOF Score: {score}")
#
#         # #Save CV predict
#         # if not (IS_TPU and IS_WAVENET):
#         #   train_pred[test_idx] = y_pred.reshape(-1, 80)
#         #   test_preds.append(model.predict(test, batch_size=1).squeeze().reshape(-1, 1).squeeze())
#
#
#         del X_train, X_valid, y_train, y_valid, model
#         reset_keras()
#         gc.collect()
#
#         # if not (IS_TPU and IS_WAVENET):
#         #   analy_predict(test_idx, train_pred)

# %% [markdown]
# if not DEBUG:
#   train_pred = train_pred.flatten()
#   targets = targets.flatten()
#   score = mean_absolute_error(targets, train_pred)
#   print(f"Train Score: {score}")

# %% [markdown]
# ## Create submission file

# %%
if not DEBUG:
  submission = pd.read_csv('../input/ventilator-pressure-prediction/sample_submission.csv')
  submission["pressure"] = sum(test_preds)/len(test_preds)
  submission.to_csv('model-gpu/submission.csv', index=False)

  # ENSEMBLE FOLDS WITH MEDIAN
  #取中位数
  submission["pressure"] = np.median(np.vstack(test_preds),axis=0)
  submission.to_csv('model-gpu/submission_median.csv', index=False)


  # ENSEMBLE FOLDS WITH MEDIAN AND ROUND PREDICTIONS
  submission["pressure"] =\
      np.round( (submission.pressure - pressure_min)/pressure_step ) * pressure_step + pressure_min
  submission.pressure = np.clip(submission.pressure, pressure_min, pressure_max)
  submission.to_csv('model-gpu/submission_median_round.csv', index=False)

# %% [markdown]
# # Analyze predict data

# %%
#analy_predict(last_test_idx, train_pred)
