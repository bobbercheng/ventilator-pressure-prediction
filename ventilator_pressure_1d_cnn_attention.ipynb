# %% [markdown]
# <a href="https://colab.research.google.com/github/bobbercheng/ventilator-pressure-prediction/blob/master/ventilator_pressure_1d_cnn_attention.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-330c3a2a-955e-4837-95f1-c8ebda0705f3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-330c3a2a-955e-4837-95f1-c8ebda0705f3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# User uploaded file "kaggle.json" with length 62 bytes

# %%
#!pip install pandas==1.3.2

# %%
# !pip install kaggle
# !mkdir /root/.kaggle
# !cp kaggle.json /root/.kaggle
# !kaggle competitions download -c ventilator-pressure-prediction
# !mkdir -p /kaggle/input/ventilator-pressure-prediction
# !unzip '*.zip' -d /kaggle/input/ventilator-pressure-prediction
# !ls /kaggle/input/ventilator-pressure-prediction
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.7/dist-packages (1.5.12)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.15.0)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.24.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from kaggle) (2021.5.30)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.7/dist-packages (from kaggle) (5.0.2)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from kaggle) (4.62.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.23.0)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.7/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (2.10)
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /root/.kaggle/kaggle.json'
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.5.12 / client 1.5.4)
# Downloading train.csv.zip to /content
#  98% 137M/139M [00:01<00:00, 112MB/s]
# 100% 139M/139M [00:01<00:00, 137MB/s]
# Downloading test.csv.zip to /content
#  76% 57.0M/75.4M [00:00<00:00, 149MB/s]
# 100% 75.4M/75.4M [00:00<00:00, 191MB/s]
# Downloading sample_submission.csv.zip to /content
#  71% 6.00M/8.50M [00:00<00:00, 60.8MB/s]
# 100% 8.50M/8.50M [00:00<00:00, 78.2MB/s]
# Archive:  train.csv.zip
#   inflating: /kaggle/input/ventilator-pressure-prediction/train.csv
#
# Archive:  sample_submission.csv.zip
#   inflating: /kaggle/input/ventilator-pressure-prediction/sample_submission.csv
#
# Archive:  test.csv.zip
#   inflating: /kaggle/input/ventilator-pressure-prediction/test.csv
#
# 3 archives were successfully processed.
# sample_submission.csv  test.csv  train.csv

# %%
import numpy as np
import pandas as pd

# import optuna

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.callbacks import LearningRateScheduler, ReduceLROnPlateau
from tensorflow.keras.optimizers.schedules import ExponentialDecay

from sklearn.metrics import mean_absolute_error as mae
from sklearn.preprocessing import RobustScaler, normalize
from sklearn.model_selection import train_test_split, GroupKFold, KFold

from IPython.display import display

# %%
DEBUG = False

train = pd.read_csv('/kaggle/input/ventilator-pressure-prediction/train.csv')
test = pd.read_csv('/kaggle/input/ventilator-pressure-prediction/test.csv')
submission = pd.read_csv('/kaggle/input/ventilator-pressure-prediction/sample_submission.csv')

if DEBUG:
    train = train[:80*1000]

# %%
def add_feats(train):
    # # rewritten calculation of lag features from this notebook: https://www.kaggle.com/patrick0302/add-lag-u-in-as-new-feat
# # some of ideas from this notebook: https://www.kaggle.com/mst8823/google-brain-lightgbm-baseline
    # train[["15_out_mean"]] = train.groupby('breath_id')['u_out'].rolling(window=15,min_periods=1).agg({"15_out_mean":"mean"}).reset_index(level=0,drop=True)
    train['last_value_u_in'] = train.groupby('breath_id')['u_in'].transform('last')
    train['u_in_lag1'] = train.groupby('breath_id')['u_in'].shift(1)
    train['u_out_lag1'] = train.groupby('breath_id')['u_out'].shift(1)
    train['u_in_lag_back1'] = train.groupby('breath_id')['u_in'].shift(-1)
    train['u_out_lag_back1'] = train.groupby('breath_id')['u_out'].shift(-1)
    train['u_in_lag2'] = train.groupby('breath_id')['u_in'].shift(2)
    train['u_out_lag2'] = train.groupby('breath_id')['u_out'].shift(2)
    train['u_in_lag3'] = train.groupby('breath_id')['u_in'].shift(3)
    train['u_out_lag3'] = train.groupby('breath_id')['u_out'].shift(3)
    train['u_in_lag_back2'] = train.groupby('breath_id')['u_in'].shift(-2)
    train['u_out_lag_back2'] = train.groupby('breath_id')['u_out'].shift(-2)
    train['u_in_lag_back3'] = train.groupby('breath_id')['u_in'].shift(-3)
    train['u_out_lag_back3'] = train.groupby('breath_id')['u_out'].shift(-3)
    train['u_in_lag_back10'] = train.groupby('breath_id')['u_in'].shift(-10)
    train['u_out_lag_back10'] = train.groupby('breath_id')['u_out'].shift(-10)

    train['u_in_first'] = train.groupby('breath_id')['u_in'].first()
    train['u_out_first'] = train.groupby('breath_id')['u_out'].first()

    ## time since last step
    train['time_step_diff'] = train.groupby('breath_id')['time_step'].diff().fillna(0)
    ### rolling window ts feats
    train['ewm_u_in_mean'] = train.groupby('breath_id')['u_in'].ewm(halflife=9).mean().reset_index(level=0,drop=True)
    train['ewm_u_in_std'] = train.groupby('breath_id')['u_in'].ewm(halflife=10).std().reset_index(level=0,drop=True) ## could add covar?
    train['ewm_u_in_corr'] = train.groupby('breath_id')['u_in'].ewm(halflife=15).corr().reset_index(level=0,drop=True) # self umin corr
    # train['ewm_u_in_corr'] = train.groupby('breath_id')['u_in'].ewm(halflife=6).corr(train.groupby('breath_id')["u_out"]).reset_index(level=0,drop=True) # corr with u_out # error
    ## rolling window of 15 periods
    train[["15_in_sum","15_in_min","15_in_max","15_in_mean","15_out_std"]] = train.groupby('breath_id')['u_in'].rolling(window=15,min_periods=1).agg({"15_in_sum":"sum","15_in_min":"min","15_in_max":"max","15_in_mean":"mean","15_in_std":"std"}).reset_index(level=0,drop=True)
#     train[["45_in_sum","45_in_min","45_in_max","45_in_mean","45_out_std"]] = train.groupby('breath_id')['u_in'].rolling(window=45,min_periods=1).agg({"45_in_sum":"sum","45_in_min":"min","45_in_max":"max","45_in_mean":"mean","45_in_std":"std"}).reset_index(level=0,drop=True)
    train[["45_in_sum","45_in_min","45_in_max","45_in_mean","45_out_std"]] = train.groupby('breath_id')['u_in'].rolling(window=45,min_periods=1).agg({"45_in_sum":"sum","45_in_min":"min","45_in_max":"max","45_in_mean":"mean","45_in_std":"std"}).reset_index(level=0,drop=True)

    train[["15_out_mean"]] = train.groupby('breath_id')['u_out'].rolling(window=15,min_periods=1).agg({"15_out_mean":"mean"}).reset_index(level=0,drop=True)

    print(train.shape[0])
    display(train)
    train = train.fillna(0) # ORIG

    # max, min, mean value of u_in and u_out for each breath
    train['breath_id__u_in__max'] = train.groupby(['breath_id'])['u_in'].transform('max')
    train['breath_id__u_out__max'] = train.groupby(['breath_id'])['u_out'].transform('max')

    train['breath_id__u_out__mean'] =train.groupby(['breath_id'])['u_out'].mean()
    train['breath_id__u_in__mean'] =train.groupby(['breath_id'])['u_in'].mean()

    train['breath_id__u_in__min'] = train.groupby(['breath_id'])['u_in'].transform('min')
    train['breath_id__u_out__min'] = train.groupby(['breath_id'])['u_out'].transform('min')

    train['u_in_first'] = train.groupby(['breath_id'])['u_in'].transform('first')
    train['u_in_last'] = train.groupby(['breath_id'])['u_in'].transform('last')

    train['R_div_C'] = train["R"].div(train["C"])

    # difference between consequitive values
    train['R__C'] = train["R"].astype(str) + '__' + train["C"].astype(str)
    train['u_in_diff1'] = train['u_in'] - train['u_in_lag1']
    train['u_out_diff1'] = train['u_out'] - train['u_out_lag1']
    train['u_in_diff2'] = train['u_in'] - train['u_in_lag2']
    train['u_out_diff2'] = train['u_out'] - train['u_out_lag2']
    train['u_in_diff3'] = train['u_in'] - train['u_in_lag3']
    train['u_out_diff3'] = train['u_out'] - train['u_out_lag3']
    ## diff between last 2 steps
    train['u_in_diff_1_2'] = train['u_in_lag1'] - train['u_in_lag2']
    train['u_out_diff_1_2'] = train['u_out_lag1'] - train['u_out_lag2']
    train['u_in_lagback_diff_1_2'] = train['u_in_lag_back1'] - train['u_in_lag_back2']
    train['u_out_lagback_diff_1_2'] = train['u_out_lag_back1'] - train['u_out_lag_back2']

    train['u_in_lagback_diff1'] = train['u_in'] - train['u_in_lag_back1']
    train['u_out_lagback_diff1'] = train['u_out'] - train['u_out_lag_back1']
    train['u_in_lagback_diff2'] = train['u_in'] - train['u_in_lag_back2']
    train['u_out_lagback_diff2'] = train['u_out'] - train['u_out_lag_back2']

    # from here: https://www.kaggle.com/yasufuminakama/ventilator-pressure-lstm-starter
    train.loc[train['time_step'] == 0, 'u_in_diff'] = 0
    train.loc[train['time_step'] == 0, 'u_out_diff'] = 0

    # difference between the current value of u_in and the max value within the breath
    train['breath_id__u_in__diffmax'] = train.groupby(['breath_id'])['u_in'].transform('max') - train['u_in']
    train['breath_id__u_in__diffmean'] = train.groupby(['breath_id'])['u_in'].transform('mean') - train['u_in']

    print("before OHE")
    display(train)

    # OHE
    train = train.merge(pd.get_dummies(train['R'], prefix='R'), left_index=True, right_index=True).drop(['R'], axis=1)
    train = train.merge(pd.get_dummies(train['C'], prefix='C'), left_index=True, right_index=True).drop(['C'], axis=1)
    train = train.merge(pd.get_dummies(train['R__C'], prefix='R__C'), left_index=True, right_index=True).drop(['R__C'], axis=1)

    # https://www.kaggle.com/c/ventilator-pressure-prediction/discussion/273974
    train['u_in_cumsum'] = train.groupby(['breath_id'])['u_in'].cumsum()
    train['time_step_cumsum'] = train.groupby(['breath_id'])['time_step'].cumsum()

    # feature by u in or out (ideally - make 2 sep columns for each state) # dan
    train['u_in_partition_out_sum'] = train.groupby(['breath_id',"u_out"])['u_in'].transform("sum")

    train = train.fillna(0) # add for consistency with how test is done - dan

    return train

train = add_feats(train)
test = add_feats(test)
# Out:
# 6036000
#               id  breath_id   R  ...  45_in_mean  45_out_std  15_out_mean
# 0              1          1  20  ...    0.083334         NaN          0.0
# 1              2          1  20  ...    9.233188   12.939847          0.0
# 2              3          1  20  ...   13.658551   11.936136          0.0
# 3              4          1  20  ...   15.946119   10.766279          0.0
# 4              5          1  20  ...   17.828065   10.229525          0.0
# ...          ...        ...  ..  ...         ...         ...          ...
# 6035995  6035996     125749  50  ...    3.132079    4.277354          1.0
# 6035996  6035997     125749  50  ...    3.165156    4.258295          1.0
# 6035997  6035998     125749  50  ...    2.890898    3.936430          1.0
# 6035998  6035999     125749  50  ...    2.607671    3.557961          1.0
# 6035999  6036000     125749  50  ...    2.361694    3.221585          1.0
#
# [6036000 rows x 40 columns]
# before OHE
#               id  ...  breath_id__u_in__diffmean
# 0              1  ...                  10.062673
# 1              2  ...                  -8.237035
# 2              3  ...                 -12.363271
# 3              4  ...                 -12.662816
# 4              5  ...                 -15.209844
# ...          ...  ...                        ...
# 6035995  6035996  ...                   3.421689
# 6035996  6035997  ...                   3.422905
# 6035997  6035998  ...                   3.352424
# 6035998  6035999  ...                   3.638739
# 6035999  6036000  ...                   3.428663
#
# [6036000 rows x 67 columns]
# 4024000
#               id  breath_id   R  ...  45_in_mean  45_out_std  15_out_mean
# 0              1          0   5  ...    0.000000         NaN          0.0
# 1              2          0   5  ...    3.757523    5.313940          0.0
# 2              3          0   5  ...    7.388907    7.326652          0.0
# 3              4          0   5  ...   10.849333    9.147936          0.0
# 4              5          0   5  ...   13.943657   10.518450          0.0
# ...          ...        ...  ..  ...         ...         ...          ...
# 4023995  4023996     125748  20  ...    2.794529    2.152980          1.0
# 4023996  4023997     125748  20  ...    2.905101    2.133884          1.0
# 4023997  4023998     125748  20  ...    3.015755    2.108773          1.0
# 4023998  4023999     125748  20  ...    3.126481    2.077404          1.0
# 4023999  4024000     125748  20  ...    3.237267    2.039469          1.0
#
# [4024000 rows x 39 columns]
# before OHE
#               id  ...  breath_id__u_in__diffmean
# 0              1  ...                   9.327338
# 1              2  ...                   1.812292
# 2              3  ...                  -5.324338
# 3              4  ...                 -11.903272
# 4              5  ...                 -16.993619
# ...          ...  ...                        ...
# 4023995  4023996  ...                  -2.288270
# 4023996  4023997  ...                  -2.292733
# 4023997  4023998  ...                  -2.296492
# 4023998  4023999  ...                  -2.299672
# 4023999  4024000  ...                  -2.302397
#
# [4024000 rows x 66 columns]

# %%
train.head()
# Out:
#    id  breath_id  ...  time_step_cumsum  u_in_partition_out_sum
# 0   1          1  ...          0.000000              663.594727
# 1   2          1  ...          0.033652              663.594727
# 2   3          1  ...          0.101167              663.594727
# 3   4          1  ...          0.202709              663.594727
# 4   5          1  ...          0.338464              663.594727
#
# [5 rows x 82 columns]

# %%
train.shape
# Out:
# (6036000, 82)

# %%
targets = train[['pressure']].to_numpy().reshape(-1, 80)
u_outs = train[['u_out']].to_numpy().reshape(-1, 80)
train.drop(['pressure', 'id', 'breath_id'], axis=1, inplace=True)
test = test.drop(['id', 'breath_id'], axis=1)

# %%
RS = RobustScaler()
train = RS.fit_transform(train)
test = RS.transform(test)

# %%
train = train.reshape(-1, 80, train.shape[-1])
test = test.reshape(-1, 80, train.shape[-1])

# %%
def GBVPP_loss(y_true, y_pred, cols = 80):
    u_out = y_true[:, cols: ]
    y = y_true[:, :cols ]

    w = 1 - u_out
    mae = w * tf.abs(y - y_pred)
    return tf.reduce_sum(mae, axis=-1) / tf.reduce_sum(w, axis=-1)

# %%
from google.colab import drive
drive.mount("/gdrive", force_remount=True)
# Out:
# Mounted at /gdrive

# %%
from tensorflow.keras.layers import Layer
from tensorflow.keras import backend as K

class Attention(Layer):
    
    def __init__(self, return_sequences=True):
        self.return_sequences = return_sequences
        super(Attention,self).__init__()
        
    def build(self, input_shape):
        
        self.W=self.add_weight(name="att_weight", shape=(input_shape[-1],1),
                               initializer="normal")
        self.b=self.add_weight(name="att_bias", shape=(input_shape[1],1),
                               initializer="zeros")
        
        super(Attention,self).build(input_shape)
        
    def call(self, x):
        
        e = K.tanh(K.dot(x,self.W)+self.b)
        a = K.softmax(e, axis=1)
        output = x*a
        
        if self.return_sequences:
            return output
        
        return K.sum(output, axis=1)

    def get_config(self):
        return super(Attention, self).get_config()

# %%
def get_cnn_model(train):
  inputs = keras.layers.Input(shape=train.shape[-2:])
  X = inputs
  X = keras.layers.Conv1D(filters=1024, kernel_size=3, activation='relu')(X)
  X = keras.layers.BatchNormalization()(X)
  X = keras.layers.Conv1D(filters=512, kernel_size=3, activation='relu')(X)

  # attend1_x = Attention(return_sequences=True)(X)
  X = keras.layers.AveragePooling1D(pool_size=2)(X)

  X = Attention(return_sequences=True)(X)
  X = keras.layers.BatchNormalization()(X)

  X = keras.layers.Conv1D(filters=256, kernel_size=3, activation='relu')(X)
  X = keras.layers.BatchNormalization()(X)
  X = keras.layers.Conv1D(filters=128, kernel_size=3, activation='relu')(X)

  # attend2_x = Attention(return_sequences=True)(X)
  X = keras.layers.AveragePooling1D(pool_size=2)(X)

  X = Attention(return_sequences=True)(X)
  X = keras.layers.BatchNormalization()(X)

  X = keras.layers.Flatten()(X)
  X = keras.layers.Dense(512, activation='selu', kernel_initializer='lecun_normal')(X)
  X = keras.layers.BatchNormalization()(X)
  X = keras.layers.Dense(256, activation='selu', kernel_initializer='lecun_normal')(X)
  X = keras.layers.BatchNormalization()(X)
  outputs = keras.layers.Dense(80)(X)
  model  = keras.Model(inputs=inputs, outputs=outputs)
  model.summary()
  return model

# %%
EPOCH = 1000
BATCH_SIZE = 1024
NUM_FOLDS = 10

# detect and init the TPU
tpu = tf.distribute.cluster_resolver.TPUClusterResolver.connect()

# instantiate a distribution strategy
tpu_strategy = tf.distribute.experimental.TPUStrategy(tpu)

with tpu_strategy.scope():
    kf = KFold(n_splits=NUM_FOLDS, shuffle=True, random_state=2021)
    test_preds = []
    for fold, (train_idx, test_idx) in enumerate(kf.split(train, targets)):
        print('-'*15, '>', f'Fold {fold+1}', '<', '-'*15)
        X_train, X_valid = train[train_idx], train[test_idx]
        y_train, y_valid = targets[train_idx], targets[test_idx]
        u_out_train, u_out_valid = u_outs[train_idx], u_outs[test_idx]
        
        model = get_cnn_model(train)
        model.compile(optimizer='adam', 
                      # loss=GBVPP_loss,
                      loss="mae"
                      )

        lr = ReduceLROnPlateau(monitor="val_loss", factor=0.75, patience=10, verbose=1)
        es = EarlyStopping(monitor="val_loss", patience=50, verbose=1, mode="min", restore_best_weights=True)
        checkpoint_filepath = f"folds{fold}.hdf5"
        sv = keras.callbacks.ModelCheckpoint(
            checkpoint_filepath, monitor='val_loss', verbose=1, save_best_only=True,
            save_weights_only=False, mode='auto', save_freq='epoch',
            options=None)

        history = model.fit(X_train,
                            y_train,
                            # validation_data=(X_valid, np.append(y_valid, u_out_valid, axis =1)), 
                            validation_data=(X_valid, y_valid), 
                            epochs=EPOCH, 
                            batch_size=1024, 
                            callbacks=[lr,es,sv])
    
        test_preds.append(model.predict(test).squeeze().reshape(-1, 1).squeeze())
# Out:
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Clearing out eager caches
# WARNING:tensorflow:TPU system grpc://10.114.74.178:8470 has already been initialized. Reinitializing the TPU can cause previously created variables on TPU to be lost.
# WARNING:tensorflow:TPU system grpc://10.114.74.178:8470 has already been initialized. Reinitializing the TPU can cause previously created variables on TPU to be lost.
# INFO:tensorflow:Initializing the TPU system: grpc://10.114.74.178:8470
# INFO:tensorflow:Initializing the TPU system: grpc://10.114.74.178:8470
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Finished initializing TPU system.
# WARNING:absl:`tf.distribute.experimental.TPUStrategy` is deprecated, please use  the non experimental symbol `tf.distribute.TPUStrategy` instead.
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:2, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:2, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:3, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:3, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:4, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:4, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:5, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:5, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:6, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:6, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:7, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:7, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)
# Streaming output truncated to the last 5000 lines.
#
# Epoch 00260: val_loss did not improve from 0.27341
# Epoch 261/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3896 - val_loss: 0.2801
#
# Epoch 00261: val_loss did not improve from 0.27341
# Epoch 262/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3886 - val_loss: 0.2791
#
# Epoch 00262: val_loss did not improve from 0.27341
# Epoch 263/1000
# 67/67 [==============================] - 3s 39ms/step - loss: 0.3931 - val_loss: 0.2753
#
# Epoch 00263: val_loss did not improve from 0.27341
# Epoch 264/1000
# 67/67 [==============================] - 2s 30ms/step - loss: 0.3951 - val_loss: 0.2761
#
# Epoch 00264: ReduceLROnPlateau reducing learning rate to 0.00010011290578404441.
#
# Epoch 00264: val_loss did not improve from 0.27341
# Epoch 265/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3905 - val_loss: 0.2718
#
# Epoch 00265: val_loss improved from 0.27341 to 0.27181, saving model to folds7.hdf5
# Epoch 266/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3950 - val_loss: 0.2776
#
# Epoch 00266: val_loss did not improve from 0.27181
# Epoch 267/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3846 - val_loss: 0.2751
#
# Epoch 00267: val_loss did not improve from 0.27181
# Epoch 268/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3864 - val_loss: 0.2738
#
# Epoch 00268: val_loss did not improve from 0.27181
# Epoch 269/1000
# 67/67 [==============================] - 2s 30ms/step - loss: 0.3911 - val_loss: 0.2758
#
# Epoch 00269: val_loss did not improve from 0.27181
# Epoch 270/1000
# 67/67 [==============================] - 2s 30ms/step - loss: 0.3938 - val_loss: 0.2731
#
# Epoch 00270: val_loss did not improve from 0.27181
# Epoch 271/1000
# 67/67 [==============================] - 2s 30ms/step - loss: 0.3900 - val_loss: 0.2780
#
# Epoch 00271: val_loss did not improve from 0.27181
# Epoch 272/1000
# 67/67 [==============================] - 2s 30ms/step - loss: 0.3837 - val_loss: 0.2756
#
# Epoch 00272: val_loss did not improve from 0.27181
# Epoch 273/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3943 - val_loss: 0.2728
#
# Epoch 00273: val_loss did not improve from 0.27181
# Epoch 274/1000
# 67/67 [==============================] - 2s 30ms/step - loss: 0.3854 - val_loss: 0.2748
#
# Epoch 00274: val_loss did not improve from 0.27181
# Epoch 275/1000
# 67/67 [==============================] - 2s 30ms/step - loss: 0.3903 - val_loss: 0.2785
#
# Epoch 00275: ReduceLROnPlateau reducing learning rate to 7.508467933803331e-05.
#
# Epoch 00275: val_loss did not improve from 0.27181
# Epoch 276/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3876 - val_loss: 0.2707
#
# Epoch 00276: val_loss improved from 0.27181 to 0.27066, saving model to folds7.hdf5
# Epoch 277/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3900 - val_loss: 0.2708
#
# Epoch 00277: val_loss did not improve from 0.27066
# Epoch 278/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3848 - val_loss: 0.2723
#
# Epoch 00278: val_loss did not improve from 0.27066
# Epoch 279/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3993 - val_loss: 0.2700
#
# Epoch 00279: val_loss improved from 0.27066 to 0.26997, saving model to folds7.hdf5
# Epoch 280/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3864 - val_loss: 0.2726
#
# Epoch 00280: val_loss did not improve from 0.26997
# Epoch 281/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3783 - val_loss: 0.2723
#
# Epoch 00281: val_loss did not improve from 0.26997
# Epoch 282/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3931 - val_loss: 0.2738
#
# Epoch 00282: val_loss did not improve from 0.26997
# Epoch 283/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3931 - val_loss: 0.2749
#
# Epoch 00283: val_loss did not improve from 0.26997
# Epoch 284/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3928 - val_loss: 0.2697
#
# Epoch 00284: val_loss improved from 0.26997 to 0.26971, saving model to folds7.hdf5
# Epoch 285/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3904 - val_loss: 0.2703
#
# Epoch 00285: val_loss did not improve from 0.26971
# Epoch 286/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3970 - val_loss: 0.2714
#
# Epoch 00286: val_loss did not improve from 0.26971
# Epoch 287/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3933 - val_loss: 0.2766
#
# Epoch 00287: val_loss did not improve from 0.26971
# Epoch 288/1000
# 67/67 [==============================] - 2s 28ms/step - loss: 0.4023 - val_loss: 0.2719
#
# Epoch 00288: val_loss did not improve from 0.26971
# Epoch 289/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3896 - val_loss: 0.2718
#
# Epoch 00289: val_loss did not improve from 0.26971
# Epoch 290/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3877 - val_loss: 0.2702
#
# Epoch 00290: val_loss did not improve from 0.26971
# Epoch 291/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3929 - val_loss: 0.2738
#
# Epoch 00291: val_loss did not improve from 0.26971
# Epoch 292/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3930 - val_loss: 0.2717
#
# Epoch 00292: val_loss did not improve from 0.26971
# Epoch 293/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3935 - val_loss: 0.2727
#
# Epoch 00293: val_loss did not improve from 0.26971
# Epoch 294/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3800 - val_loss: 0.2715
#
# Epoch 00294: ReduceLROnPlateau reducing learning rate to 5.6313510867767036e-05.
#
# Epoch 00294: val_loss did not improve from 0.26971
# Epoch 295/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3821 - val_loss: 0.2709
#
# Epoch 00295: val_loss did not improve from 0.26971
# Epoch 296/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3905 - val_loss: 0.2731
#
# Epoch 00296: val_loss did not improve from 0.26971
# Epoch 297/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3894 - val_loss: 0.2701
#
# Epoch 00297: val_loss did not improve from 0.26971
# Epoch 298/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.4000 - val_loss: 0.2689
#
# Epoch 00298: val_loss improved from 0.26971 to 0.26891, saving model to folds7.hdf5
# Epoch 299/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.4012 - val_loss: 0.2702
#
# Epoch 00299: val_loss did not improve from 0.26891
# Epoch 300/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3833 - val_loss: 0.2706
#
# Epoch 00300: val_loss did not improve from 0.26891
# Epoch 301/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3868 - val_loss: 0.2701
#
# Epoch 00301: val_loss did not improve from 0.26891
# Epoch 302/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3866 - val_loss: 0.2702
#
# Epoch 00302: val_loss did not improve from 0.26891
# Epoch 303/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3984 - val_loss: 0.2697
#
# Epoch 00303: val_loss did not improve from 0.26891
# Epoch 304/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3796 - val_loss: 0.2695
#
# Epoch 00304: val_loss did not improve from 0.26891
# Epoch 305/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3899 - val_loss: 0.2710
#
# Epoch 00305: val_loss did not improve from 0.26891
# Epoch 306/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3920 - val_loss: 0.2720
#
# Epoch 00306: val_loss did not improve from 0.26891
# Epoch 307/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3905 - val_loss: 0.2713
#
# Epoch 00307: val_loss did not improve from 0.26891
# Epoch 308/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3906 - val_loss: 0.2731
#
# Epoch 00308: ReduceLROnPlateau reducing learning rate to 4.223513315082528e-05.
#
# Epoch 00308: val_loss did not improve from 0.26891
# Epoch 309/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3858 - val_loss: 0.2698
#
# Epoch 00309: val_loss did not improve from 0.26891
# Epoch 310/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3930 - val_loss: 0.2705
#
# Epoch 00310: val_loss did not improve from 0.26891
# Epoch 311/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3891 - val_loss: 0.2735
#
# Epoch 00311: val_loss did not improve from 0.26891
# Epoch 312/1000
# 67/67 [==============================] - 2s 37ms/step - loss: 0.3907 - val_loss: 0.2708
#
# Epoch 00312: val_loss did not improve from 0.26891
# Epoch 313/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3878 - val_loss: 0.2718
#
# Epoch 00313: val_loss did not improve from 0.26891
# Epoch 314/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3854 - val_loss: 0.2709
#
# Epoch 00314: val_loss did not improve from 0.26891
# Epoch 315/1000
# 67/67 [==============================] - 2s 30ms/step - loss: 0.3926 - val_loss: 0.2715
#
# Epoch 00315: val_loss did not improve from 0.26891
# Epoch 316/1000
# 67/67 [==============================] - 2s 30ms/step - loss: 0.3862 - val_loss: 0.2692
#
# Epoch 00316: val_loss did not improve from 0.26891
# Epoch 317/1000
# 67/67 [==============================] - 2s 30ms/step - loss: 0.3882 - val_loss: 0.2739
#
# Epoch 00317: val_loss did not improve from 0.26891
# Epoch 318/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3900 - val_loss: 0.2711
#
# Epoch 00318: ReduceLROnPlateau reducing learning rate to 3.167634986311896e-05.
#
# Epoch 00318: val_loss did not improve from 0.26891
# Epoch 319/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3901 - val_loss: 0.2693
#
# Epoch 00319: val_loss did not improve from 0.26891
# Epoch 320/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3901 - val_loss: 0.2684
#
# Epoch 00320: val_loss improved from 0.26891 to 0.26840, saving model to folds7.hdf5
# Epoch 321/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3829 - val_loss: 0.2668
#
# Epoch 00321: val_loss improved from 0.26840 to 0.26684, saving model to folds7.hdf5
# Epoch 322/1000
# 67/67 [==============================] - 2s 30ms/step - loss: 0.3944 - val_loss: 0.2686
#
# Epoch 00322: val_loss did not improve from 0.26684
# Epoch 323/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3867 - val_loss: 0.2682
#
# Epoch 00323: val_loss did not improve from 0.26684
# Epoch 324/1000
# 67/67 [==============================] - 2s 30ms/step - loss: 0.3904 - val_loss: 0.2703
#
# Epoch 00324: val_loss did not improve from 0.26684
# Epoch 325/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3818 - val_loss: 0.2678
#
# Epoch 00325: val_loss did not improve from 0.26684
# Epoch 326/1000
# 67/67 [==============================] - 2s 30ms/step - loss: 0.3785 - val_loss: 0.2684
#
# Epoch 00326: val_loss did not improve from 0.26684
# Epoch 327/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3910 - val_loss: 0.2679
#
# Epoch 00327: val_loss did not improve from 0.26684
# Epoch 328/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3844 - val_loss: 0.2678
#
# Epoch 00328: val_loss did not improve from 0.26684
# Epoch 329/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3932 - val_loss: 0.2684
#
# Epoch 00329: val_loss did not improve from 0.26684
# Epoch 330/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3813 - val_loss: 0.2690
#
# Epoch 00330: val_loss did not improve from 0.26684
# Epoch 331/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3811 - val_loss: 0.2694
#
# Epoch 00331: ReduceLROnPlateau reducing learning rate to 2.3757263079460245e-05.
#
# Epoch 00331: val_loss did not improve from 0.26684
# Epoch 332/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3786 - val_loss: 0.2687
#
# Epoch 00332: val_loss did not improve from 0.26684
# Epoch 333/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3828 - val_loss: 0.2690
#
# Epoch 00333: val_loss did not improve from 0.26684
# Epoch 334/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3849 - val_loss: 0.2698
#
# Epoch 00334: val_loss did not improve from 0.26684
# Epoch 335/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3767 - val_loss: 0.2682
#
# Epoch 00335: val_loss did not improve from 0.26684
# Epoch 336/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3852 - val_loss: 0.2670
#
# Epoch 00336: val_loss did not improve from 0.26684
# Epoch 337/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3833 - val_loss: 0.2682
#
# Epoch 00337: val_loss did not improve from 0.26684
# Epoch 338/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3829 - val_loss: 0.2670
#
# Epoch 00338: val_loss did not improve from 0.26684
# Epoch 339/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3878 - val_loss: 0.2668
#
# Epoch 00339: val_loss improved from 0.26684 to 0.26679, saving model to folds7.hdf5
# Epoch 340/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3782 - val_loss: 0.2676
#
# Epoch 00340: val_loss did not improve from 0.26679
# Epoch 341/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3869 - val_loss: 0.2683
#
# Epoch 00341: ReduceLROnPlateau reducing learning rate to 1.781794799171621e-05.
#
# Epoch 00341: val_loss did not improve from 0.26679
# Epoch 342/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3817 - val_loss: 0.2683
#
# Epoch 00342: val_loss did not improve from 0.26679
# Epoch 343/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3851 - val_loss: 0.2676
#
# Epoch 00343: val_loss did not improve from 0.26679
# Epoch 344/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3884 - val_loss: 0.2711
#
# Epoch 00344: val_loss did not improve from 0.26679
# Epoch 345/1000
# 67/67 [==============================] - 2s 30ms/step - loss: 0.3971 - val_loss: 0.2666
#
# Epoch 00345: val_loss improved from 0.26679 to 0.26659, saving model to folds7.hdf5
# Epoch 346/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3867 - val_loss: 0.2676
#
# Epoch 00346: val_loss did not improve from 0.26659
# Epoch 347/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3894 - val_loss: 0.2693
#
# Epoch 00347: val_loss did not improve from 0.26659
# Epoch 348/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3797 - val_loss: 0.2678
#
# Epoch 00348: val_loss did not improve from 0.26659
# Epoch 349/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3896 - val_loss: 0.2670
#
# Epoch 00349: val_loss did not improve from 0.26659
# Epoch 350/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3847 - val_loss: 0.2671
#
# Epoch 00350: val_loss did not improve from 0.26659
# Epoch 351/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3872 - val_loss: 0.2672
#
# Epoch 00351: val_loss did not improve from 0.26659
# Epoch 352/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3791 - val_loss: 0.2685
#
# Epoch 00352: val_loss did not improve from 0.26659
# Epoch 353/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3965 - val_loss: 0.2688
#
# Epoch 00353: val_loss did not improve from 0.26659
# Epoch 354/1000
# 67/67 [==============================] - 2s 30ms/step - loss: 0.3897 - val_loss: 0.2679
#
# Epoch 00354: val_loss did not improve from 0.26659
# Epoch 355/1000
# 67/67 [==============================] - 2s 30ms/step - loss: 0.3870 - val_loss: 0.2697
#
# Epoch 00355: ReduceLROnPlateau reducing learning rate to 1.3363460311666131e-05.
#
# Epoch 00355: val_loss did not improve from 0.26659
# Epoch 356/1000
# 67/67 [==============================] - 2s 30ms/step - loss: 0.3884 - val_loss: 0.2664
#
# Epoch 00356: val_loss improved from 0.26659 to 0.26640, saving model to folds7.hdf5
# Epoch 357/1000
# 67/67 [==============================] - 2s 30ms/step - loss: 0.3941 - val_loss: 0.2675
#
# Epoch 00357: val_loss did not improve from 0.26640
# Epoch 358/1000
# 67/67 [==============================] - 2s 30ms/step - loss: 0.3869 - val_loss: 0.2673
#
# Epoch 00358: val_loss did not improve from 0.26640
# Epoch 359/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3904 - val_loss: 0.2680
#
# Epoch 00359: val_loss did not improve from 0.26640
# Epoch 360/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3846 - val_loss: 0.2664
#
# Epoch 00360: val_loss improved from 0.26640 to 0.26639, saving model to folds7.hdf5
# Epoch 361/1000
# 67/67 [==============================] - 3s 38ms/step - loss: 0.3816 - val_loss: 0.2666
#
# Epoch 00361: val_loss did not improve from 0.26639
# Epoch 362/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3766 - val_loss: 0.2657
#
# Epoch 00362: val_loss improved from 0.26639 to 0.26565, saving model to folds7.hdf5
# Epoch 363/1000
# 67/67 [==============================] - 2s 30ms/step - loss: 0.3834 - val_loss: 0.2676
#
# Epoch 00363: val_loss did not improve from 0.26565
# Epoch 364/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3821 - val_loss: 0.2671
#
# Epoch 00364: val_loss did not improve from 0.26565
# Epoch 365/1000
# 67/67 [==============================] - 2s 30ms/step - loss: 0.3867 - val_loss: 0.2682
#
# Epoch 00365: val_loss did not improve from 0.26565
# Epoch 366/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3882 - val_loss: 0.2683
#
# Epoch 00366: val_loss did not improve from 0.26565
# Epoch 367/1000
# 67/67 [==============================] - 2s 30ms/step - loss: 0.3900 - val_loss: 0.2678
#
# Epoch 00367: val_loss did not improve from 0.26565
# Epoch 368/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3844 - val_loss: 0.2682
#
# Epoch 00368: val_loss did not improve from 0.26565
# Epoch 369/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.4003 - val_loss: 0.2675
#
# Epoch 00369: val_loss did not improve from 0.26565
# Epoch 370/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3790 - val_loss: 0.2674
#
# Epoch 00370: val_loss did not improve from 0.26565
# Epoch 371/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3895 - val_loss: 0.2660
#
# Epoch 00371: val_loss did not improve from 0.26565
# Epoch 372/1000
# 67/67 [==============================] - 2s 30ms/step - loss: 0.3818 - val_loss: 0.2665
#
# Epoch 00372: ReduceLROnPlateau reducing learning rate to 1.0022595233749598e-05.
#
# Epoch 00372: val_loss did not improve from 0.26565
# Epoch 373/1000
# 67/67 [==============================] - 2s 30ms/step - loss: 0.3754 - val_loss: 0.2658
#
# Epoch 00373: val_loss did not improve from 0.26565
# Epoch 374/1000
# 67/67 [==============================] - 2s 30ms/step - loss: 0.3815 - val_loss: 0.2665
#
# Epoch 00374: val_loss did not improve from 0.26565
# Epoch 375/1000
# 67/67 [==============================] - 2s 30ms/step - loss: 0.3804 - val_loss: 0.2667
#
# Epoch 00375: val_loss did not improve from 0.26565
# Epoch 376/1000
# 67/67 [==============================] - 2s 30ms/step - loss: 0.3867 - val_loss: 0.2671
#
# Epoch 00376: val_loss did not improve from 0.26565
# Epoch 377/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3845 - val_loss: 0.2680
#
# Epoch 00377: val_loss did not improve from 0.26565
# Epoch 378/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3820 - val_loss: 0.2666
#
# Epoch 00378: val_loss did not improve from 0.26565
# Epoch 379/1000
# 67/67 [==============================] - 2s 30ms/step - loss: 0.3805 - val_loss: 0.2673
#
# Epoch 00379: val_loss did not improve from 0.26565
# Epoch 380/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3804 - val_loss: 0.2670
#
# Epoch 00380: val_loss did not improve from 0.26565
# Epoch 381/1000
# 67/67 [==============================] - 2s 30ms/step - loss: 0.3808 - val_loss: 0.2673
#
# Epoch 00381: val_loss did not improve from 0.26565
# Epoch 382/1000
# 67/67 [==============================] - 2s 30ms/step - loss: 0.3876 - val_loss: 0.2676
#
# Epoch 00382: ReduceLROnPlateau reducing learning rate to 7.516946425312199e-06.
#
# Epoch 00382: val_loss did not improve from 0.26565
# Epoch 383/1000
# 67/67 [==============================] - 2s 30ms/step - loss: 0.3891 - val_loss: 0.2665
#
# Epoch 00383: val_loss did not improve from 0.26565
# Epoch 384/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3961 - val_loss: 0.2666
#
# Epoch 00384: val_loss did not improve from 0.26565
# Epoch 385/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3812 - val_loss: 0.2669
#
# Epoch 00385: val_loss did not improve from 0.26565
# Epoch 386/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3830 - val_loss: 0.2665
#
# Epoch 00386: val_loss did not improve from 0.26565
# Epoch 387/1000
# 67/67 [==============================] - 2s 30ms/step - loss: 0.3852 - val_loss: 0.2679
#
# Epoch 00387: val_loss did not improve from 0.26565
# Epoch 388/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3875 - val_loss: 0.2667
#
# Epoch 00388: val_loss did not improve from 0.26565
# Epoch 389/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3889 - val_loss: 0.2671
#
# Epoch 00389: val_loss did not improve from 0.26565
# Epoch 390/1000
# 67/67 [==============================] - 2s 30ms/step - loss: 0.3907 - val_loss: 0.2661
#
# Epoch 00390: val_loss did not improve from 0.26565
# Epoch 391/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3960 - val_loss: 0.2681
#
# Epoch 00391: val_loss did not improve from 0.26565
# Epoch 392/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3953 - val_loss: 0.2666
#
# Epoch 00392: ReduceLROnPlateau reducing learning rate to 5.637709818984149e-06.
#
# Epoch 00392: val_loss did not improve from 0.26565
# Epoch 393/1000
# 67/67 [==============================] - 2s 30ms/step - loss: 0.3762 - val_loss: 0.2649
#
# Epoch 00393: val_loss improved from 0.26565 to 0.26494, saving model to folds7.hdf5
# Epoch 394/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3800 - val_loss: 0.2661
#
# Epoch 00394: val_loss did not improve from 0.26494
# Epoch 395/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3872 - val_loss: 0.2662
#
# Epoch 00395: val_loss did not improve from 0.26494
# Epoch 396/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3941 - val_loss: 0.2675
#
# Epoch 00396: val_loss did not improve from 0.26494
# Epoch 397/1000
# 67/67 [==============================] - 2s 30ms/step - loss: 0.3877 - val_loss: 0.2667
#
# Epoch 00397: val_loss did not improve from 0.26494
# Epoch 398/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3786 - val_loss: 0.2667
#
# Epoch 00398: val_loss did not improve from 0.26494
# Epoch 399/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3932 - val_loss: 0.2662
#
# Epoch 00399: val_loss did not improve from 0.26494
# Epoch 400/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3820 - val_loss: 0.2681
#
# Epoch 00400: val_loss did not improve from 0.26494
# Epoch 401/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3935 - val_loss: 0.2673
#
# Epoch 00401: val_loss did not improve from 0.26494
# Epoch 402/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3909 - val_loss: 0.2667
#
# Epoch 00402: val_loss did not improve from 0.26494
# Epoch 403/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3777 - val_loss: 0.2666
#
# Epoch 00403: ReduceLROnPlateau reducing learning rate to 4.228282364238112e-06.
#
# Epoch 00403: val_loss did not improve from 0.26494
# Epoch 404/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3873 - val_loss: 0.2665
#
# Epoch 00404: val_loss did not improve from 0.26494
# Epoch 405/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3893 - val_loss: 0.2672
#
# Epoch 00405: val_loss did not improve from 0.26494
# Epoch 406/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3967 - val_loss: 0.2673
#
# Epoch 00406: val_loss did not improve from 0.26494
# Epoch 407/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3823 - val_loss: 0.2664
#
# Epoch 00407: val_loss did not improve from 0.26494
# Epoch 408/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3815 - val_loss: 0.2661
#
# Epoch 00408: val_loss did not improve from 0.26494
# Epoch 409/1000
# 67/67 [==============================] - 2s 37ms/step - loss: 0.3849 - val_loss: 0.2664
#
# Epoch 00409: val_loss did not improve from 0.26494
# Epoch 410/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3889 - val_loss: 0.2659
#
# Epoch 00410: val_loss did not improve from 0.26494
# Epoch 411/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3805 - val_loss: 0.2664
#
# Epoch 00411: val_loss did not improve from 0.26494
# Epoch 412/1000
# 67/67 [==============================] - 2s 30ms/step - loss: 0.3863 - val_loss: 0.2665
#
# Epoch 00412: val_loss did not improve from 0.26494
# Epoch 413/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3862 - val_loss: 0.2666
#
# Epoch 00413: ReduceLROnPlateau reducing learning rate to 3.1712116879134555e-06.
#
# Epoch 00413: val_loss did not improve from 0.26494
# Epoch 414/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3806 - val_loss: 0.2674
#
# Epoch 00414: val_loss did not improve from 0.26494
# Epoch 415/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3856 - val_loss: 0.2659
#
# Epoch 00415: val_loss did not improve from 0.26494
# Epoch 416/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3889 - val_loss: 0.2665
#
# Epoch 00416: val_loss did not improve from 0.26494
# Epoch 417/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3881 - val_loss: 0.2668
#
# Epoch 00417: val_loss did not improve from 0.26494
# Epoch 418/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3879 - val_loss: 0.2677
#
# Epoch 00418: val_loss did not improve from 0.26494
# Epoch 419/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3816 - val_loss: 0.2664
#
# Epoch 00419: val_loss did not improve from 0.26494
# Epoch 420/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3767 - val_loss: 0.2664
#
# Epoch 00420: val_loss did not improve from 0.26494
# Epoch 421/1000
# 67/67 [==============================] - 2s 30ms/step - loss: 0.3869 - val_loss: 0.2661
#
# Epoch 00421: val_loss did not improve from 0.26494
# Epoch 422/1000
# 67/67 [==============================] - 2s 30ms/step - loss: 0.3876 - val_loss: 0.2667
#
# Epoch 00422: val_loss did not improve from 0.26494
# Epoch 423/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3799 - val_loss: 0.2674
#
# Epoch 00423: ReduceLROnPlateau reducing learning rate to 2.3784086806699634e-06.
#
# Epoch 00423: val_loss did not improve from 0.26494
# Epoch 424/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3825 - val_loss: 0.2666
#
# Epoch 00424: val_loss did not improve from 0.26494
# Epoch 425/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3898 - val_loss: 0.2666
#
# Epoch 00425: val_loss did not improve from 0.26494
# Epoch 426/1000
# 67/67 [==============================] - 2s 30ms/step - loss: 0.3890 - val_loss: 0.2658
#
# Epoch 00426: val_loss did not improve from 0.26494
# Epoch 427/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3915 - val_loss: 0.2669
#
# Epoch 00427: val_loss did not improve from 0.26494
# Epoch 428/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3812 - val_loss: 0.2667
#
# Epoch 00428: val_loss did not improve from 0.26494
# Epoch 429/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3826 - val_loss: 0.2664
#
# Epoch 00429: val_loss did not improve from 0.26494
# Epoch 430/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3838 - val_loss: 0.2657
#
# Epoch 00430: val_loss did not improve from 0.26494
# Epoch 431/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3762 - val_loss: 0.2655
#
# Epoch 00431: val_loss did not improve from 0.26494
# Epoch 432/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3817 - val_loss: 0.2669
#
# Epoch 00432: val_loss did not improve from 0.26494
# Epoch 433/1000
# 67/67 [==============================] - 2s 30ms/step - loss: 0.3814 - val_loss: 0.2684
#
# Epoch 00433: ReduceLROnPlateau reducing learning rate to 1.7838065105024725e-06.
#
# Epoch 00433: val_loss did not improve from 0.26494
# Epoch 434/1000
# 67/67 [==============================] - 2s 30ms/step - loss: 0.3743 - val_loss: 0.2672
#
# Epoch 00434: val_loss did not improve from 0.26494
# Epoch 435/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3859 - val_loss: 0.2666
#
# Epoch 00435: val_loss did not improve from 0.26494
# Epoch 436/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3914 - val_loss: 0.2657
#
# Epoch 00436: val_loss did not improve from 0.26494
# Epoch 437/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3771 - val_loss: 0.2661
#
# Epoch 00437: val_loss did not improve from 0.26494
# Epoch 438/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3830 - val_loss: 0.2660
#
# Epoch 00438: val_loss did not improve from 0.26494
# Epoch 439/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3863 - val_loss: 0.2669
#
# Epoch 00439: val_loss did not improve from 0.26494
# Epoch 440/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3830 - val_loss: 0.2662
#
# Epoch 00440: val_loss did not improve from 0.26494
# Epoch 441/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3767 - val_loss: 0.2662
#
# Epoch 00441: val_loss did not improve from 0.26494
# Epoch 442/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3754 - val_loss: 0.2656
#
# Epoch 00442: val_loss did not improve from 0.26494
# Epoch 443/1000
# 67/67 [==============================] - 2s 30ms/step - loss: 0.3873 - val_loss: 0.2658
#
# Epoch 00443: ReduceLROnPlateau reducing learning rate to 1.3378548828768544e-06.
# Restoring model weights from the end of the best epoch.
#
# Epoch 00443: val_loss did not improve from 0.26494
# Epoch 00443: early stopping
# --------------- > Fold 9 < ---------------
# Model: "model_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_15 (InputLayer)        [(None, 80, 79)]          0
# _________________________________________________________________
# conv1d_52 (Conv1D)           (None, 78, 1024)          243712
# _________________________________________________________________
# batch_normalization_74 (Batc (None, 78, 1024)          4096
# _________________________________________________________________
# conv1d_53 (Conv1D)           (None, 76, 512)           1573376
# _________________________________________________________________
# average_pooling1d_25 (Averag (None, 38, 512)           0
# _________________________________________________________________
# attention_26 (Attention)     (None, 38, 512)           550
# _________________________________________________________________
# batch_normalization_75 (Batc (None, 38, 512)           2048
# _________________________________________________________________
# conv1d_54 (Conv1D)           (None, 36, 256)           393472
# _________________________________________________________________
# batch_normalization_76 (Batc (None, 36, 256)           1024
# _________________________________________________________________
# conv1d_55 (Conv1D)           (None, 34, 128)           98432
# _________________________________________________________________
# average_pooling1d_26 (Averag (None, 17, 128)           0
# _________________________________________________________________
# attention_27 (Attention)     (None, 17, 128)           145
# _________________________________________________________________
# batch_normalization_77 (Batc (None, 17, 128)           512
# _________________________________________________________________
# flatten_12 (Flatten)         (None, 2176)              0
# _________________________________________________________________
# dense_36 (Dense)             (None, 512)               1114624
# _________________________________________________________________
# batch_normalization_78 (Batc (None, 512)               2048
# _________________________________________________________________
# dense_37 (Dense)             (None, 256)               131328
# _________________________________________________________________
# batch_normalization_79 (Batc (None, 256)               1024
# _________________________________________________________________
# dense_38 (Dense)             (None, 80)                20560
# =================================================================
# Total params: 3,586,951
# Trainable params: 3,581,575
# Non-trainable params: 5,376
# _________________________________________________________________
# Epoch 1/1000
# 67/67 [==============================] - 27s 224ms/step - loss: 10.6410 - val_loss: 9.5716
#
# Epoch 00001: val_loss improved from inf to 9.57165, saving model to folds8.hdf5
# Epoch 2/1000
# 67/67 [==============================] - 2s 30ms/step - loss: 6.4950 - val_loss: 4.3975
#
# Epoch 00002: val_loss improved from 9.57165 to 4.39747, saving model to folds8.hdf5
# Epoch 3/1000
# 67/67 [==============================] - 2s 30ms/step - loss: 2.9854 - val_loss: 3.0497
#
# Epoch 00003: val_loss improved from 4.39747 to 3.04969, saving model to folds8.hdf5
# Epoch 4/1000
# 67/67 [==============================] - 2s 30ms/step - loss: 1.2414 - val_loss: 2.5533
#
# Epoch 00004: val_loss improved from 3.04969 to 2.55328, saving model to folds8.hdf5
# Epoch 5/1000
# 67/67 [==============================] - 2s 30ms/step - loss: 0.9098 - val_loss: 2.2360
#
# Epoch 00005: val_loss improved from 2.55328 to 2.23603, saving model to folds8.hdf5
# Epoch 6/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.8382 - val_loss: 1.9124
#
# Epoch 00006: val_loss improved from 2.23603 to 1.91238, saving model to folds8.hdf5
# Epoch 7/1000
# 67/67 [==============================] - 2s 30ms/step - loss: 0.7775 - val_loss: 1.6500
#
# Epoch 00007: val_loss improved from 1.91238 to 1.64996, saving model to folds8.hdf5
# Epoch 8/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.7541 - val_loss: 1.2565
#
# Epoch 00008: val_loss improved from 1.64996 to 1.25650, saving model to folds8.hdf5
# Epoch 9/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.7170 - val_loss: 1.0502
#
# Epoch 00009: val_loss improved from 1.25650 to 1.05016, saving model to folds8.hdf5
# Epoch 10/1000
# 67/67 [==============================] - 2s 30ms/step - loss: 0.7116 - val_loss: 0.8023
#
# Epoch 00010: val_loss improved from 1.05016 to 0.80226, saving model to folds8.hdf5
# Epoch 11/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.6936 - val_loss: 0.6652
#
# Epoch 00011: val_loss improved from 0.80226 to 0.66517, saving model to folds8.hdf5
# Epoch 12/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.6636 - val_loss: 0.5953
#
# Epoch 00012: val_loss improved from 0.66517 to 0.59533, saving model to folds8.hdf5
# Epoch 13/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.6438 - val_loss: 0.5793
#
# Epoch 00013: val_loss improved from 0.59533 to 0.57933, saving model to folds8.hdf5
# Epoch 14/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.6263 - val_loss: 0.5432
#
# Epoch 00014: val_loss improved from 0.57933 to 0.54324, saving model to folds8.hdf5
# Epoch 15/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.6236 - val_loss: 0.5331
#
# Epoch 00015: val_loss improved from 0.54324 to 0.53310, saving model to folds8.hdf5
# Epoch 16/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.6117 - val_loss: 0.5427
#
# Epoch 00016: val_loss did not improve from 0.53310
# Epoch 17/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.6114 - val_loss: 0.4903
#
# Epoch 00017: val_loss improved from 0.53310 to 0.49035, saving model to folds8.hdf5
# Epoch 18/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.5952 - val_loss: 0.5924
#
# Epoch 00018: val_loss did not improve from 0.49035
# Epoch 19/1000
# 67/67 [==============================] - 2s 30ms/step - loss: 0.5805 - val_loss: 0.4952
#
# Epoch 00019: val_loss did not improve from 0.49035
# Epoch 20/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.5718 - val_loss: 0.4832
#
# Epoch 00020: val_loss improved from 0.49035 to 0.48322, saving model to folds8.hdf5
# Epoch 21/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.5734 - val_loss: 0.5002
#
# Epoch 00021: val_loss did not improve from 0.48322
# Epoch 22/1000
# 67/67 [==============================] - 2s 35ms/step - loss: 0.5639 - val_loss: 0.5102
#
# Epoch 00022: val_loss did not improve from 0.48322
# Epoch 23/1000
# 67/67 [==============================] - 2s 30ms/step - loss: 0.5579 - val_loss: 0.4740
#
# Epoch 00023: val_loss improved from 0.48322 to 0.47396, saving model to folds8.hdf5
# Epoch 24/1000
# 67/67 [==============================] - 2s 30ms/step - loss: 0.5621 - val_loss: 0.4846
#
# Epoch 00024: val_loss did not improve from 0.47396
# Epoch 25/1000
# 67/67 [==============================] - 2s 30ms/step - loss: 0.5519 - val_loss: 0.4649
#
# Epoch 00025: val_loss improved from 0.47396 to 0.46488, saving model to folds8.hdf5
# Epoch 26/1000
# 67/67 [==============================] - 2s 30ms/step - loss: 0.5455 - val_loss: 0.4719
#
# Epoch 00026: val_loss did not improve from 0.46488
# Epoch 27/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.5459 - val_loss: 0.4582
#
# Epoch 00027: val_loss improved from 0.46488 to 0.45822, saving model to folds8.hdf5
# Epoch 28/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.5410 - val_loss: 0.4517
#
# Epoch 00028: val_loss improved from 0.45822 to 0.45172, saving model to folds8.hdf5
# Epoch 29/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.5369 - val_loss: 0.4590
#
# Epoch 00029: val_loss did not improve from 0.45172
# Epoch 30/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.5287 - val_loss: 0.4506
#
# Epoch 00030: val_loss improved from 0.45172 to 0.45060, saving model to folds8.hdf5
# Epoch 31/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.5322 - val_loss: 0.4344
#
# Epoch 00031: val_loss improved from 0.45060 to 0.43438, saving model to folds8.hdf5
# Epoch 32/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.5358 - val_loss: 0.4474
#
# Epoch 00032: val_loss did not improve from 0.43438
# Epoch 33/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.5151 - val_loss: 0.4333
#
# Epoch 00033: val_loss improved from 0.43438 to 0.43325, saving model to folds8.hdf5
# Epoch 34/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.5257 - val_loss: 0.4282
#
# Epoch 00034: val_loss improved from 0.43325 to 0.42821, saving model to folds8.hdf5
# Epoch 35/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.5170 - val_loss: 0.4252
#
# Epoch 00035: val_loss improved from 0.42821 to 0.42515, saving model to folds8.hdf5
# Epoch 36/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.5168 - val_loss: 0.4224
#
# Epoch 00036: val_loss improved from 0.42515 to 0.42243, saving model to folds8.hdf5
# Epoch 37/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.5096 - val_loss: 0.4165
#
# Epoch 00037: val_loss improved from 0.42243 to 0.41650, saving model to folds8.hdf5
# Epoch 38/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.5028 - val_loss: 0.4842
#
# Epoch 00038: val_loss did not improve from 0.41650
# Epoch 39/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.5185 - val_loss: 0.4145
#
# Epoch 00039: val_loss improved from 0.41650 to 0.41447, saving model to folds8.hdf5
# Epoch 40/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.4995 - val_loss: 0.4227
#
# Epoch 00040: val_loss did not improve from 0.41447
# Epoch 41/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.5010 - val_loss: 0.4176
#
# Epoch 00041: val_loss did not improve from 0.41447
# Epoch 42/1000
# 67/67 [==============================] - 2s 28ms/step - loss: 0.5010 - val_loss: 0.3885
#
# Epoch 00042: val_loss improved from 0.41447 to 0.38854, saving model to folds8.hdf5
# Epoch 43/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.5026 - val_loss: 0.4189
#
# Epoch 00043: val_loss did not improve from 0.38854
# Epoch 44/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.4962 - val_loss: 0.3912
#
# Epoch 00044: val_loss did not improve from 0.38854
# Epoch 45/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.4975 - val_loss: 0.4176
#
# Epoch 00045: val_loss did not improve from 0.38854
# Epoch 46/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.5069 - val_loss: 0.4089
#
# Epoch 00046: val_loss did not improve from 0.38854
# Epoch 47/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.4885 - val_loss: 0.4194
#
# Epoch 00047: val_loss did not improve from 0.38854
# Epoch 48/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.4997 - val_loss: 0.4144
#
# Epoch 00048: val_loss did not improve from 0.38854
# Epoch 49/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.4919 - val_loss: 0.3770
#
# Epoch 00049: val_loss improved from 0.38854 to 0.37699, saving model to folds8.hdf5
# Epoch 50/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.4903 - val_loss: 0.4183
#
# Epoch 00050: val_loss did not improve from 0.37699
# Epoch 51/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.4881 - val_loss: 0.3788
#
# Epoch 00051: val_loss did not improve from 0.37699
# Epoch 52/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.4843 - val_loss: 0.3909
#
# Epoch 00052: val_loss did not improve from 0.37699
# Epoch 53/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.4883 - val_loss: 0.4030
#
# Epoch 00053: val_loss did not improve from 0.37699
# Epoch 54/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.4906 - val_loss: 0.4470
#
# Epoch 00054: val_loss did not improve from 0.37699
# Epoch 55/1000
# 67/67 [==============================] - 2s 30ms/step - loss: 0.4848 - val_loss: 0.3927
#
# Epoch 00055: val_loss did not improve from 0.37699
# Epoch 56/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.4815 - val_loss: 0.3671
#
# Epoch 00056: val_loss improved from 0.37699 to 0.36706, saving model to folds8.hdf5
# Epoch 57/1000
# 67/67 [==============================] - 2s 30ms/step - loss: 0.4782 - val_loss: 0.4111
#
# Epoch 00057: val_loss did not improve from 0.36706
# Epoch 58/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.4798 - val_loss: 0.3791
#
# Epoch 00058: val_loss did not improve from 0.36706
# Epoch 59/1000
# 67/67 [==============================] - 2s 30ms/step - loss: 0.4833 - val_loss: 0.3767
#
# Epoch 00059: val_loss did not improve from 0.36706
# Epoch 60/1000
# 67/67 [==============================] - 2s 30ms/step - loss: 0.4765 - val_loss: 0.4061
#
# Epoch 00060: val_loss did not improve from 0.36706
# Epoch 61/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.4814 - val_loss: 0.4257
#
# Epoch 00061: val_loss did not improve from 0.36706
# Epoch 62/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.4753 - val_loss: 0.3741
#
# Epoch 00062: val_loss did not improve from 0.36706
# Epoch 63/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.4731 - val_loss: 0.3900
#
# Epoch 00063: val_loss did not improve from 0.36706
# Epoch 64/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.4773 - val_loss: 0.3674
#
# Epoch 00064: val_loss did not improve from 0.36706
# Epoch 65/1000
# ...
#
# Epoch 00447: val_loss did not improve from 0.27856
# Epoch 448/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3904 - val_loss: 0.2797
#
# Epoch 00448: val_loss did not improve from 0.27856
# Epoch 449/1000
# 67/67 [==============================] - 2s 30ms/step - loss: 0.3989 - val_loss: 0.2794
#
# Epoch 00449: val_loss did not improve from 0.27856
# Epoch 450/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.4021 - val_loss: 0.2803
#
# Epoch 00450: val_loss did not improve from 0.27856
# Epoch 451/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3903 - val_loss: 0.2794
#
# Epoch 00451: val_loss did not improve from 0.27856
# Epoch 452/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.4009 - val_loss: 0.2796
#
# Epoch 00452: val_loss did not improve from 0.27856
# Epoch 453/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.4003 - val_loss: 0.2789
#
# Epoch 00453: val_loss did not improve from 0.27856
# Epoch 454/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3903 - val_loss: 0.2789
#
# Epoch 00454: val_loss did not improve from 0.27856
# Epoch 455/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3939 - val_loss: 0.2789
#
# Epoch 00455: val_loss did not improve from 0.27856
# Epoch 456/1000
# 67/67 [==============================] - 2s 37ms/step - loss: 0.4040 - val_loss: 0.2790
#
# Epoch 00456: ReduceLROnPlateau reducing learning rate to 3.1747922690783525e-07.
#
# Epoch 00456: val_loss did not improve from 0.27856
# Epoch 457/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3888 - val_loss: 0.2787
#
# Epoch 00457: val_loss did not improve from 0.27856
# Epoch 458/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3982 - val_loss: 0.2793
#
# Epoch 00458: val_loss did not improve from 0.27856
# Epoch 459/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3992 - val_loss: 0.2791
#
# Epoch 00459: val_loss did not improve from 0.27856
# Epoch 460/1000
# 67/67 [==============================] - 2s 30ms/step - loss: 0.3888 - val_loss: 0.2791
#
# Epoch 00460: val_loss did not improve from 0.27856
# Epoch 461/1000
# 67/67 [==============================] - 2s 30ms/step - loss: 0.3950 - val_loss: 0.2785
#
# Epoch 00461: val_loss improved from 0.27856 to 0.27853, saving model to folds9.hdf5
# Epoch 462/1000
# 67/67 [==============================] - 2s 30ms/step - loss: 0.3974 - val_loss: 0.2789
#
# Epoch 00462: val_loss did not improve from 0.27853
# Epoch 463/1000
# 67/67 [==============================] - 2s 30ms/step - loss: 0.3995 - val_loss: 0.2790
#
# Epoch 00463: val_loss did not improve from 0.27853
# Epoch 464/1000
# 67/67 [==============================] - 2s 30ms/step - loss: 0.3922 - val_loss: 0.2794
#
# Epoch 00464: val_loss did not improve from 0.27853
# Epoch 465/1000
# 67/67 [==============================] - 2s 30ms/step - loss: 0.3931 - val_loss: 0.2792
#
# Epoch 00465: val_loss did not improve from 0.27853
# Epoch 466/1000
# 67/67 [==============================] - 2s 30ms/step - loss: 0.3900 - val_loss: 0.2800
#
# Epoch 00466: ReduceLROnPlateau reducing learning rate to 2.3810941485180592e-07.
#
# Epoch 00466: val_loss did not improve from 0.27853
# Epoch 467/1000
# 67/67 [==============================] - 2s 30ms/step - loss: 0.3879 - val_loss: 0.2800
#
# Epoch 00467: val_loss did not improve from 0.27853
# Epoch 468/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3926 - val_loss: 0.2786
#
# Epoch 00468: val_loss did not improve from 0.27853
# Epoch 469/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3881 - val_loss: 0.2790
#
# Epoch 00469: val_loss did not improve from 0.27853
# Epoch 470/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3987 - val_loss: 0.2793
#
# Epoch 00470: val_loss did not improve from 0.27853
# Epoch 471/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3937 - val_loss: 0.2790
#
# Epoch 00471: val_loss did not improve from 0.27853
# Epoch 472/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3991 - val_loss: 0.2793
#
# Epoch 00472: val_loss did not improve from 0.27853
# Epoch 473/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3954 - val_loss: 0.2789
#
# Epoch 00473: val_loss did not improve from 0.27853
# Epoch 474/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3949 - val_loss: 0.2794
#
# Epoch 00474: val_loss did not improve from 0.27853
# Epoch 475/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.4021 - val_loss: 0.2791
#
# Epoch 00475: val_loss did not improve from 0.27853
# Epoch 476/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3908 - val_loss: 0.2788
#
# Epoch 00476: ReduceLROnPlateau reducing learning rate to 1.7858205580978392e-07.
#
# Epoch 00476: val_loss did not improve from 0.27853
# Epoch 477/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3956 - val_loss: 0.2797
#
# Epoch 00477: val_loss did not improve from 0.27853
# Epoch 478/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3864 - val_loss: 0.2786
#
# Epoch 00478: val_loss did not improve from 0.27853
# Epoch 479/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3950 - val_loss: 0.2796
#
# Epoch 00479: val_loss did not improve from 0.27853
# Epoch 480/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3884 - val_loss: 0.2791
#
# Epoch 00480: val_loss did not improve from 0.27853
# Epoch 481/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3971 - val_loss: 0.2792
#
# Epoch 00481: val_loss did not improve from 0.27853
# Epoch 482/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.4059 - val_loss: 0.2793
#
# Epoch 00482: val_loss did not improve from 0.27853
# Epoch 483/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3888 - val_loss: 0.2787
#
# Epoch 00483: val_loss did not improve from 0.27853
# Epoch 484/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3950 - val_loss: 0.2790
#
# Epoch 00484: val_loss did not improve from 0.27853
# Epoch 485/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3995 - val_loss: 0.2787
#
# Epoch 00485: val_loss did not improve from 0.27853
# Epoch 486/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3879 - val_loss: 0.2789
#
# Epoch 00486: ReduceLROnPlateau reducing learning rate to 1.3393654185733794e-07.
#
# Epoch 00486: val_loss did not improve from 0.27853
# Epoch 487/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3913 - val_loss: 0.2787
#
# Epoch 00487: val_loss did not improve from 0.27853
# Epoch 488/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3870 - val_loss: 0.2789
#
# Epoch 00488: val_loss did not improve from 0.27853
# Epoch 489/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3945 - val_loss: 0.2805
#
# Epoch 00489: val_loss did not improve from 0.27853
# Epoch 490/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3948 - val_loss: 0.2789
#
# Epoch 00490: val_loss did not improve from 0.27853
# Epoch 491/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3913 - val_loss: 0.2792
#
# Epoch 00491: val_loss did not improve from 0.27853
# Epoch 492/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3822 - val_loss: 0.2791
#
# Epoch 00492: val_loss did not improve from 0.27853
# Epoch 493/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3888 - val_loss: 0.2789
#
# Epoch 00493: val_loss did not improve from 0.27853
# Epoch 494/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3938 - val_loss: 0.2785
#
# Epoch 00494: val_loss improved from 0.27853 to 0.27853, saving model to folds9.hdf5
# Epoch 495/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3940 - val_loss: 0.2794
#
# Epoch 00495: val_loss did not improve from 0.27853
# Epoch 496/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3954 - val_loss: 0.2797
#
# Epoch 00496: ReduceLROnPlateau reducing learning rate to 1.004524037284682e-07.
#
# Epoch 00496: val_loss did not improve from 0.27853
# Epoch 497/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3931 - val_loss: 0.2797
#
# Epoch 00497: val_loss did not improve from 0.27853
# Epoch 498/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3932 - val_loss: 0.2789
#
# Epoch 00498: val_loss did not improve from 0.27853
# Epoch 499/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3945 - val_loss: 0.2788
#
# Epoch 00499: val_loss did not improve from 0.27853
# Epoch 500/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3941 - val_loss: 0.2792
#
# Epoch 00500: val_loss did not improve from 0.27853
# Epoch 501/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3959 - val_loss: 0.2792
#
# Epoch 00501: val_loss did not improve from 0.27853
# Epoch 502/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3959 - val_loss: 0.2790
#
# Epoch 00502: val_loss did not improve from 0.27853
# Epoch 503/1000
# 67/67 [==============================] - 2s 37ms/step - loss: 0.3913 - val_loss: 0.2793
#
# Epoch 00503: val_loss did not improve from 0.27853
# Epoch 504/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3953 - val_loss: 0.2790
#
# Epoch 00504: val_loss did not improve from 0.27853
# Epoch 505/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.4043 - val_loss: 0.2788
#
# Epoch 00505: val_loss did not improve from 0.27853
# Epoch 506/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3894 - val_loss: 0.2789
#
# Epoch 00506: ReduceLROnPlateau reducing learning rate to 7.533930279635115e-08.
#
# Epoch 00506: val_loss did not improve from 0.27853
# Epoch 507/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3943 - val_loss: 0.2793
#
# Epoch 00507: val_loss did not improve from 0.27853
# Epoch 508/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3950 - val_loss: 0.2788
#
# Epoch 00508: val_loss did not improve from 0.27853
# Epoch 509/1000
# 67/67 [==============================] - 2s 30ms/step - loss: 0.4018 - val_loss: 0.2794
#
# Epoch 00509: val_loss did not improve from 0.27853
# Epoch 510/1000
# 67/67 [==============================] - 2s 30ms/step - loss: 0.3874 - val_loss: 0.2789
#
# Epoch 00510: val_loss did not improve from 0.27853
# Epoch 511/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3967 - val_loss: 0.2786
#
# Epoch 00511: val_loss did not improve from 0.27853
# Epoch 512/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3991 - val_loss: 0.2792
#
# Epoch 00512: val_loss did not improve from 0.27853
# Epoch 513/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3872 - val_loss: 0.2789
#
# Epoch 00513: val_loss did not improve from 0.27853
# Epoch 514/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3916 - val_loss: 0.2790
#
# Epoch 00514: val_loss did not improve from 0.27853
# Epoch 515/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3915 - val_loss: 0.2788
#
# Epoch 00515: val_loss did not improve from 0.27853
# Epoch 516/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3879 - val_loss: 0.2786
#
# Epoch 00516: ReduceLROnPlateau reducing learning rate to 5.650447576499573e-08.
#
# Epoch 00516: val_loss did not improve from 0.27853
# Epoch 517/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.4002 - val_loss: 0.2788
#
# Epoch 00517: val_loss did not improve from 0.27853
# Epoch 518/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3984 - val_loss: 0.2788
#
# Epoch 00518: val_loss did not improve from 0.27853
# Epoch 519/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.4027 - val_loss: 0.2787
#
# Epoch 00519: val_loss did not improve from 0.27853
# Epoch 520/1000
# 67/67 [==============================] - 2s 30ms/step - loss: 0.3891 - val_loss: 0.2791
#
# Epoch 00520: val_loss did not improve from 0.27853
# Epoch 521/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3910 - val_loss: 0.2787
#
# Epoch 00521: val_loss did not improve from 0.27853
# Epoch 522/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3921 - val_loss: 0.2788
#
# Epoch 00522: val_loss did not improve from 0.27853
# Epoch 523/1000
# 67/67 [==============================] - 2s 30ms/step - loss: 0.3964 - val_loss: 0.2797
#
# Epoch 00523: val_loss did not improve from 0.27853
# Epoch 524/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.4103 - val_loss: 0.2788
#
# Epoch 00524: val_loss did not improve from 0.27853
# Epoch 525/1000
# 67/67 [==============================] - 2s 30ms/step - loss: 0.3913 - val_loss: 0.2789
#
# Epoch 00525: val_loss did not improve from 0.27853
# Epoch 526/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3993 - val_loss: 0.2791
#
# Epoch 00526: ReduceLROnPlateau reducing learning rate to 4.23783568237468e-08.
#
# Epoch 00526: val_loss did not improve from 0.27853
# Epoch 527/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3958 - val_loss: 0.2803
#
# Epoch 00527: val_loss did not improve from 0.27853
# Epoch 528/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3897 - val_loss: 0.2795
#
# Epoch 00528: val_loss did not improve from 0.27853
# Epoch 529/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3994 - val_loss: 0.2793
#
# Epoch 00529: val_loss did not improve from 0.27853
# Epoch 530/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.4010 - val_loss: 0.2788
#
# Epoch 00530: val_loss did not improve from 0.27853
# Epoch 531/1000
# 67/67 [==============================] - 2s 30ms/step - loss: 0.3938 - val_loss: 0.2790
#
# Epoch 00531: val_loss did not improve from 0.27853
# Epoch 532/1000
# 67/67 [==============================] - 2s 30ms/step - loss: 0.3952 - val_loss: 0.2791
#
# Epoch 00532: val_loss did not improve from 0.27853
# Epoch 533/1000
# 67/67 [==============================] - 2s 30ms/step - loss: 0.3922 - val_loss: 0.2786
#
# Epoch 00533: val_loss did not improve from 0.27853
# Epoch 534/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3946 - val_loss: 0.2785
#
# Epoch 00534: val_loss did not improve from 0.27853
# Epoch 535/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3996 - val_loss: 0.2786
#
# Epoch 00535: val_loss did not improve from 0.27853
# Epoch 536/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3974 - val_loss: 0.2788
#
# Epoch 00536: ReduceLROnPlateau reducing learning rate to 3.17837676178101e-08.
#
# Epoch 00536: val_loss did not improve from 0.27853
# Epoch 537/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3924 - val_loss: 0.2793
#
# Epoch 00537: val_loss did not improve from 0.27853
# Epoch 538/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3932 - val_loss: 0.2798
#
# Epoch 00538: val_loss did not improve from 0.27853
# Epoch 539/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.4054 - val_loss: 0.2796
#
# Epoch 00539: val_loss did not improve from 0.27853
# Epoch 540/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3947 - val_loss: 0.2795
#
# Epoch 00540: val_loss did not improve from 0.27853
# Epoch 541/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3870 - val_loss: 0.2792
#
# Epoch 00541: val_loss did not improve from 0.27853
# Epoch 542/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3943 - val_loss: 0.2796
#
# Epoch 00542: val_loss did not improve from 0.27853
# Epoch 543/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3975 - val_loss: 0.2797
#
# Epoch 00543: val_loss did not improve from 0.27853
# Epoch 544/1000
# 67/67 [==============================] - 2s 29ms/step - loss: 0.3926 - val_loss: 0.2794
# Restoring model weights from the end of the best epoch.
#
# Epoch 00544: val_loss did not improve from 0.27853
# Epoch 00544: early stopping

# %%
PRESSURE_STEP = 0.07030214545120961
PRESSURE_MIN = -1.8957442945646408
PRESSURE_MAX = 64.82099173863948

# %%
# ENSEMBLE FOLDS WITH MEAN
submission["pressure"] = sum(test_preds)/NUM_FOLDS
submission.to_csv('submission_mean.csv', index=False)

# %%
# ENSEMBLE FOLDS WITH MEDIAN
submission["pressure"] = np.median(np.vstack(test_preds),axis=0)
submission.to_csv('submission_median.csv', index=False)

# %%
# ENSEMBLE FOLDS WITH MEDIAN AND ROUND PREDICTIONS
submission["pressure"] =\
    np.round( (submission.pressure - PRESSURE_MIN)/PRESSURE_STEP ) * PRESSURE_STEP + PRESSURE_MIN
submission.pressure = np.clip(submission.pressure, PRESSURE_MIN, PRESSURE_MAX)
submission.to_csv('submission_median_round.csv', index=False)

# %%
# !zip cnn_models.zip *.hdf5
# Out:
#   adding: folds0.hdf5 (deflated 8%)
#   adding: folds1.hdf5 (deflated 8%)
#   adding: folds2.hdf5 (deflated 8%)
#   adding: folds3.hdf5 (deflated 8%)
#   adding: folds4.hdf5 (deflated 8%)
#   adding: folds5.hdf5 (deflated 8%)
#   adding: folds6.hdf5 (deflated 8%)
#   adding: folds7.hdf5 (deflated 8%)
#   adding: folds8.hdf5 (deflated 8%)
#   adding: folds9.hdf5 (deflated 8%)

# %%
# !zip submission.zip *.csv
# Out:
#   adding: submission_mean.csv (deflated 60%)
#   adding: submission_median.csv (deflated 60%)
#   adding: submission_median_round.csv (deflated 80%)

# %%
with open('/gdrive/MyDrive/ventilator-pressure-prediction/submission.zip', 'wb') as f:
  f.write(open('submission.zip', 'rb').read())

# %%
with open('/gdrive/MyDrive/ventilator-pressure-prediction/cnn_models.zip', 'wb') as f:
  f.write(open('cnn_models.zip', 'rb').read())

# %%
# !unzip -t /gdrive/MyDrive/ventilator-pressure-prediction/cnn_models.zip
# Out:
# Archive:  /gdrive/MyDrive/ventilator-pressure-prediction/cnn_models.zip
#     testing: folds0.hdf5              OK
#     testing: folds1.hdf5              OK
#     testing: folds2.hdf5              OK
#     testing: folds3.hdf5              OK
#     testing: folds4.hdf5              OK
#     testing: folds5.hdf5              OK
#     testing: folds6.hdf5              OK
#     testing: folds7.hdf5              OK
#     testing: folds8.hdf5              OK
#     testing: folds9.hdf5              OK
# No errors detected in compressed data of /gdrive/MyDrive/ventilator-pressure-prediction/cnn_models.zip.
