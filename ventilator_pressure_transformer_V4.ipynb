# %% [markdown]
# <a href="https://colab.research.google.com/github/bobbercheng/ventilator-pressure-prediction/blob/master/ventilator_pressure_transformer_V4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# V1: Add PositionalEncoding
#
# V2: Adjust Transformer parameters
#
# V3: Use Transformer class instead of Tensorflow version
#
# V4: Without EDA and only use 400 features that is very similar to Keras time serial transformer sample if features and time serial are flatten. TPU v2 supports 16 heads, 512 key_dim, 512 batch size. But converge is not good
#
# V5: Max TPU V2 config, 128 heads, 512 key_dim, 512 batch size

# %%
# Update pandas version for Colab TPU
#!pip install pandas==1.3.2

# %%
try:
  import google.colab
  IN_COLAB = True
except:
  IN_COLAB = False

# %%
if IN_COLAB:
  from google.colab import drive
  drive.mount("/gdrive", force_remount=True)
# Out:
# Mounted at /gdrive

# %%
if IN_COLAB:
  # !pip install kaggle
  # !mkdir /root/.kaggle
  # !cp /gdrive/MyDrive/ventilator-pressure-prediction/kaggle.json /root/.kaggle
  # !kaggle competitions download -c ventilator-pressure-prediction
  # !mkdir -p /kaggle/input/ventilator-pressure-prediction
  # !unzip '*.zip' -d /kaggle/input/ventilator-pressure-prediction
  # !ls /kaggle/input/ventilator-pressure-prediction
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.7/dist-packages (1.5.12)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.7/dist-packages (from kaggle) (5.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.23.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from kaggle) (2021.5.30)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from kaggle) (4.62.3)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.24.3)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.7/dist-packages (from kaggle) (1.15.0)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.7/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle) (3.0.4)
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.5.12 / client 1.5.4)
# Downloading test.csv.zip to /content
#  95% 72.0M/75.4M [00:00<00:00, 230MB/s]
# 100% 75.4M/75.4M [00:00<00:00, 217MB/s]
# Downloading sample_submission.csv.zip to /content
#   0% 0.00/8.50M [00:00<?, ?B/s]
# 100% 8.50M/8.50M [00:00<00:00, 78.2MB/s]
# Downloading train.csv.zip to /content
#  91% 126M/139M [00:00<00:00, 93.6MB/s]
# 100% 139M/139M [00:01<00:00, 131MB/s]
# Archive:  sample_submission.csv.zip
#   inflating: /kaggle/input/ventilator-pressure-prediction/sample_submission.csv
#
# Archive:  train.csv.zip
#   inflating: /kaggle/input/ventilator-pressure-prediction/train.csv
#
# Archive:  test.csv.zip
#   inflating: /kaggle/input/ventilator-pressure-prediction/test.csv
#
# 3 archives were successfully processed.
# sample_submission.csv  test.csv  train.csv

# %%
import numpy as np
import pandas as pd

# import optuna

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.callbacks import LearningRateScheduler, ReduceLROnPlateau
from tensorflow.keras.optimizers.schedules import ExponentialDecay

from sklearn.metrics import mean_absolute_error as mae
from sklearn.preprocessing import RobustScaler, normalize
from sklearn.model_selection import train_test_split, GroupKFold, KFold

from IPython.display import display

model_folder = '/gdrive/MyDrive/ventilator-pressure-prediction/transformer/'

EPOCH = 300
BATCH_SIZE = 512
NUM_FOLDS = 10

TRANSFORMER_NUM_TRANSFORMER_BLOCKS=8
TRANSFORMER_HEAD_SIZES=[
                        # 768, 512, 
                      768, 512, 256, 128]

TRANSFORMER_NUM_HEADS=[32]*4

TRANSFORMER_OUTPUT_DIMS=[768, 512, 256, 128]

TRANSFORMER_FF_DIMS=[768, 512, 256, 128]

TRANSFORMER_MLP_UNITS=[128, 1]
TRANSFORMER_DROPOUT=0.0
TRANSFORMER_MLP_DROPOUT=0.0

# %%
import os
import random
# Deep Learning
import tensorflow as tf
from tensorflow import keras
# Metrics
from sklearn.metrics import mean_absolute_error

# Random Seed Initialize
RANDOM_SEED = 42

def seed_everything(seed=RANDOM_SEED):
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    random.seed(seed)
    tf.random.set_seed(seed)
    
seed_everything()

# %%
DEBUG = False

train = pd.read_csv('/kaggle/input/ventilator-pressure-prediction/train.csv')
test = pd.read_csv('/kaggle/input/ventilator-pressure-prediction/test.csv')
submission = pd.read_csv('/kaggle/input/ventilator-pressure-prediction/sample_submission.csv')

if DEBUG:
    train = train[:80*1000]

# %%
def add_features(df):
    df['cross']= df['u_in'] * df['u_out']
    df['cross2']= df['time_step'] * df['u_out']
    df['area'] = df['time_step'] * df['u_in']
    df['area'] = df.groupby('breath_id')['area'].cumsum()
    df['u_in_cumsum'] = (df['u_in']).groupby(df['breath_id']).cumsum()
    print("Step-1...Completed")
    
    df['u_in_lag1'] = df.groupby('breath_id')['u_in'].shift(1)
    df['u_out_lag1'] = df.groupby('breath_id')['u_out'].shift(1)
    df['u_in_lag_back1'] = df.groupby('breath_id')['u_in'].shift(-1)
    df['u_out_lag_back1'] = df.groupby('breath_id')['u_out'].shift(-1)
    df['u_in_lag2'] = df.groupby('breath_id')['u_in'].shift(2)
    df['u_out_lag2'] = df.groupby('breath_id')['u_out'].shift(2)
    df['u_in_lag_back2'] = df.groupby('breath_id')['u_in'].shift(-2)
    df['u_out_lag_back2'] = df.groupby('breath_id')['u_out'].shift(-2)
    df['u_in_lag3'] = df.groupby('breath_id')['u_in'].shift(3)
    df['u_out_lag3'] = df.groupby('breath_id')['u_out'].shift(3)
    df['u_in_lag_back3'] = df.groupby('breath_id')['u_in'].shift(-3)
    df['u_out_lag_back3'] = df.groupby('breath_id')['u_out'].shift(-3)
    df['u_in_lag4'] = df.groupby('breath_id')['u_in'].shift(4)
    df['u_out_lag4'] = df.groupby('breath_id')['u_out'].shift(4)
    df['u_in_lag_back4'] = df.groupby('breath_id')['u_in'].shift(-4)
    df['u_out_lag_back4'] = df.groupby('breath_id')['u_out'].shift(-4)
    df = df.fillna(0)
    print("Step-2...Completed")
    
    df['breath_id__u_in__max'] = df.groupby(['breath_id'])['u_in'].transform('max')
    df['breath_id__u_out__max'] = df.groupby(['breath_id'])['u_out'].transform('max')
    df['breath_id__u_in__diffmax'] = df.groupby(['breath_id'])['u_in'].transform('max') - df['u_in']
    df['breath_id__u_in__diffmean'] = df.groupby(['breath_id'])['u_in'].transform('mean') - df['u_in']
    df['breath_id__u_in__diffmax'] = df.groupby(['breath_id'])['u_in'].transform('max') - df['u_in']
    df['breath_id__u_in__diffmean'] = df.groupby(['breath_id'])['u_in'].transform('mean') - df['u_in']
    print("Step-3...Completed")
    
    df['u_in_diff1'] = df['u_in'] - df['u_in_lag1']
    df['u_out_diff1'] = df['u_out'] - df['u_out_lag1']
    df['u_in_diff2'] = df['u_in'] - df['u_in_lag2']
    df['u_out_diff2'] = df['u_out'] - df['u_out_lag2']
    df['u_in_diff3'] = df['u_in'] - df['u_in_lag3']
    df['u_out_diff3'] = df['u_out'] - df['u_out_lag3']
    df['u_in_diff4'] = df['u_in'] - df['u_in_lag4']
    df['u_out_diff4'] = df['u_out'] - df['u_out_lag4']
    print("Step-4...Completed")
    
    df['one'] = 1
    df['count'] = (df['one']).groupby(df['breath_id']).cumsum()
    df['u_in_cummean'] =df['u_in_cumsum'] /df['count']
    
    df['breath_id_lag']=df['breath_id'].shift(1).fillna(0)
    df['breath_id_lag2']=df['breath_id'].shift(2).fillna(0)
    df['breath_id_lagsame']=np.select([df['breath_id_lag']==df['breath_id']],[1],0)
    df['breath_id_lag2same']=np.select([df['breath_id_lag2']==df['breath_id']],[1],0)
    df['breath_id__u_in_lag'] = df['u_in'].shift(1).fillna(0)
    df['breath_id__u_in_lag'] = df['breath_id__u_in_lag'] * df['breath_id_lagsame']
    df['breath_id__u_in_lag2'] = df['u_in'].shift(2).fillna(0)
    df['breath_id__u_in_lag2'] = df['breath_id__u_in_lag2'] * df['breath_id_lag2same']
    
    df['R'] = df['R'].astype(str)
    df['C'] = df['C'].astype(str)
    df['R__C'] = df["R"].astype(str) + '__' + df["C"].astype(str)
    df = pd.get_dummies(df)
    print("Step-5...Completed")
    
    return df

print("Train data...\n")
train = add_features(train)

print("\nTest data...\n")
test = add_features(test)
# Out:
# Train data...
#
# Step-1...Completed
# Step-2...Completed
# Step-3...Completed
# Step-4...Completed
# Step-5...Completed
#
# Test data...
#
# Step-1...Completed
# Step-2...Completed
# Step-3...Completed
# Step-4...Completed
# Step-5...Completed

# %%
targets = train[['pressure']].to_numpy().reshape(-1, 80)

train.drop(['pressure','id', 'breath_id'], axis=1, inplace=True)

test = test.drop(['id', 'breath_id'], axis=1)

train.head(), train.shape
# Out:
# (   time_step       u_in  u_out  ...  R__C_5__10  R__C_5__20  R__C_5__50
#  0   0.000000   0.083334      0  ...           0           0           0
#  1   0.033652  18.383041      0  ...           0           0           0
#  2   0.067514  22.509278      0  ...           0           0           0
#  3   0.101542  22.808822      0  ...           0           0           0
#  4   0.135756  25.355850      0  ...           0           0           0
#
#  [5 rows x 59 columns], (6036000, 59))

# %%
train.drop(['one','count',
            'breath_id_lag','breath_id_lag2','breath_id_lagsame',
            'breath_id_lag2same'], axis=1, inplace=True)

test = test.drop(['one','count','breath_id_lag',
                  'breath_id_lag2','breath_id_lagsame',
                  'breath_id_lag2same'], axis=1)

# %%
RS = RobustScaler()
train = RS.fit_transform(train)
test = RS.transform(test)

# %%
train = train.reshape(-1, 80, train.shape[-1])
test = test.reshape(-1, 80, train.shape[-1])

# %%
from tensorflow.keras import layers
from tensorflow import keras

# %%
# refer to https://www.tensorflow.org/text/tutorials/transformer#encoder
def get_angles(pos, i, d_model):
  angle_rates = 1 / np.power(10000, (2 * (i//2)) / np.float32(d_model))
  return pos * angle_rates

def get_positional_encoding(position, d_model):
  angle_rads = get_angles(np.arange(position)[:, np.newaxis],
                          np.arange(d_model)[np.newaxis, :],
                          d_model)

  # apply sin to even indices in the array; 2i
  angle_rads[:, 0::2] = np.sin(angle_rads[:, 0::2])

  # apply cos to odd indices in the array; 2i+1
  angle_rads[:, 1::2] = np.cos(angle_rads[:, 1::2])

  pos_encoding = angle_rads[np.newaxis, ...]

  return tf.cast(pos_encoding, dtype=tf.float32)
def scaled_dot_product_attention(q, k, v, mask):
  """Calculate the attention weights.
  q, k, v must have matching leading dimensions.
  k, v must have matching penultimate dimension, i.e.: seq_len_k = seq_len_v.
  The mask has different shapes depending on its type(padding or look ahead)
  but it must be broadcastable for addition.

  Args:
    q: query shape == (..., seq_len_q, depth)
    k: key shape == (..., seq_len_k, depth)
    v: value shape == (..., seq_len_v, depth_v)
    mask: Float tensor with shape broadcastable
          to (..., seq_len_q, seq_len_k). Defaults to None.

  Returns:
    output, attention_weights
  """

  matmul_qk = tf.matmul(q, k, transpose_b=True)  # (..., seq_len_q, seq_len_k)

  # scale matmul_qk
  dk = tf.cast(tf.shape(k)[-1], tf.float32)
  scaled_attention_logits = matmul_qk / tf.math.sqrt(dk)

  # add the mask to the scaled tensor.
  if mask is not None:
    scaled_attention_logits += (mask * -1e9)

  # softmax is normalized on the last axis (seq_len_k) so that the scores
  # add up to 1.
  attention_weights = tf.nn.softmax(scaled_attention_logits, axis=-1)  # (..., seq_len_q, seq_len_k)

  output = tf.matmul(attention_weights, v)  # (..., seq_len_q, depth_v)

  return output, attention_weights

class MultiHeadAttention(tf.keras.layers.Layer):
  def __init__(self, d_model, num_heads):
    super(MultiHeadAttention, self).__init__()
    self.num_heads = num_heads
    self.d_model = d_model


    assert d_model % self.num_heads == 0

    self.depth = d_model // self.num_heads

    self.wq = tf.keras.layers.Dense(d_model)
    self.wk = tf.keras.layers.Dense(d_model)
    self.wv = tf.keras.layers.Dense(d_model)

    self.dense = tf.keras.layers.Dense(d_model)

  def split_heads(self, x, batch_size):
    """Split the last dimension into (num_heads, depth).
    Transpose the result such that the shape is (batch_size, num_heads, seq_len, depth)
    """
    x = tf.reshape(x, (batch_size, -1, self.num_heads, self.depth))
    return tf.transpose(x, perm=[0, 2, 1, 3])

  def call(self, v, k, q, mask):
    batch_size = tf.shape(q)[0]

    q = self.wq(q)  # (batch_size, seq_len, d_model)
    k = self.wk(k)  # (batch_size, seq_len, d_model)
    v = self.wv(v)  # (batch_size, seq_len, d_model)

    q = self.split_heads(q, batch_size)  # (batch_size, num_heads, seq_len_q, depth)
    k = self.split_heads(k, batch_size)  # (batch_size, num_heads, seq_len_k, depth)
    v = self.split_heads(v, batch_size)  # (batch_size, num_heads, seq_len_v, depth)

    # scaled_attention.shape == (batch_size, num_heads, seq_len_q, depth)
    # attention_weights.shape == (batch_size, num_heads, seq_len_q, seq_len_k)
    scaled_attention, attention_weights = scaled_dot_product_attention(
        q, k, v, mask)

    scaled_attention = tf.transpose(scaled_attention, perm=[0, 2, 1, 3])  # (batch_size, seq_len_q, num_heads, depth)

    concat_attention = tf.reshape(scaled_attention,
                                  (batch_size, -1, self.d_model))  # (batch_size, seq_len_q, d_model)

    output = self.dense(concat_attention)  # (batch_size, seq_len_q, d_model)

    return output, attention_weights

  def get_config(self):
    config = super(MultiHeadAttention, self).get_config()
    config.update({"num_heads": self.num_heads,
            "d_model": self.d_model})
    return config

def create_look_ahead_mask(size):
  mask = 1 - tf.linalg.band_part(tf.ones((size, size)), -1, 0)
  return mask  # (seq_len, seq_len)

def home_transformer_encoder(inputs, head_size, num_heads, ff_dims, dropout=0):
    # Normalization and Attention
    x = layers.LayerNormalization(epsilon=1e-6)(inputs)

    x, _ = MultiHeadAttention(d_model=inputs.shape[-1], num_heads=num_heads)(x, k=x, q=x, mask=None)
    x = layers.Dropout(dropout)(x)
    res = x + inputs

    # Feed Forward Part
    # Feed forward can be Den lay or RNN as long as it keep final dimension
    x = layers.LayerNormalization(epsilon=1e-6)(res)
    x = layers.Conv1D(filters=ff_dims, kernel_size=1, activation="relu")(x)
    x = layers.Dropout(dropout)(x)
    x = layers.Conv1D(filters=inputs.shape[-1], kernel_size=1)(x)

    return x + res

# %%
#refer to https://keras.io/examples/timeseries/timeseries_classification_transformer/
def transformer_encoder(inputs, value, head_size, num_heads, ff_dims, dropout=0, output_dim=None):
    # print('transformer_encoder:', inputs.shape, head_size, num_heads, ff_dims, output_dim)
    # Normalization and Attention
    x = layers.LayerNormalization(epsilon=1e-6)(inputs)

    #print(head_size, num_heads, output_dim, ff_dims, dropout)
    x = layers.MultiHeadAttention(
        key_dim=head_size, num_heads=num_heads, dropout=dropout
        # , output_shape=output_dim
    )(x, x)
    x = layers.Dropout(dropout)(x)
    res = x + inputs

    # Feed Forward Part
    # Feed forward can be Den lay or CNN as long as it keep final dimension
    x = layers.LayerNormalization(epsilon=1e-6)(res)
    x = layers.Conv1D(filters=ff_dims, kernel_size=1, activation="selu")(x)
    x = layers.Dropout(dropout)(x)
    x = layers.Conv1D(filters=inputs.shape[-1], kernel_size=1)(x)

    return x + res

# %%
# refer to https://www.tensorflow.org/text/tutorials/transformer#encoder
# https://rubikscode.net/2019/08/19/transformer-with-python-and-tensorflow-2-0-encoder-decoder/
# https://trungtran.io/2019/04/29/create-the-transformer-with-tensorflow-2-0/
# https://github.com/ChunML/NLP/blob/master/chatbot/model.py
def build_transfer_model(
    input_shape,
    head_sizes=TRANSFORMER_HEAD_SIZES,
    num_heads=TRANSFORMER_NUM_HEADS,
    output_dims=TRANSFORMER_OUTPUT_DIMS,
    ff_dims=TRANSFORMER_FF_DIMS,
    num_transformer_blocks=TRANSFORMER_NUM_TRANSFORMER_BLOCKS,
    mlp_units=TRANSFORMER_MLP_UNITS,
    dropout=TRANSFORMER_DROPOUT,
    mlp_dropout=TRANSFORMER_MLP_DROPOUT,
):

    inputs = keras.Input(shape=input_shape)
    time_lenght = input_shape[0]
    positional_encoding = get_positional_encoding(time_lenght, input_shape[-1])
    # print('positional_encoding:', positional_encoding)

    x = inputs

    # increase x then add position encoding.
    '''
    The reason we increase the embedding values before the addition is to make 
    the positional encoding relatively smaller. This means the original meaning 
    in the embedding vector won’t be lost when we add them together.
    '''
    x *= tf.math.sqrt(tf.cast(input_shape[-1], tf.float32))
    x += positional_encoding[:, :time_lenght, :]

    #add x dimension to [batch, 80, 53+11=64] for home transformer encoder
    #x = tf.concat([x, tf.zeros_like(x[:,:,0:11])], -1)

    #Reshape x to (batch size, sequence length * features, 1)
    #x = tf.reshape(x, [-1, x.shape[1]*x.shape[-1], 1])

    # for head_size, num_head, ff_dim, output_dim in zip(head_sizes, num_heads, ff_dims, output_dims):
    #     x = transformer_encoder(x, head_size, num_head, ff_dim, dropout, output_dim)
    i = 0
    # print(head_sizes, num_heads, ff_dims, dropout, output_dims)
    x1 = transformer_encoder(x, x, head_sizes[i], num_heads[i], ff_dims[i], dropout, output_dims[i])
    i = 1
    x2 = transformer_encoder(x1, x, head_sizes[i], num_heads[i], ff_dims[i], dropout, output_dims[i])
    i = 2
    x3 = transformer_encoder(x2, x, head_sizes[i], num_heads[i], ff_dims[i], dropout, output_dims[i])
    i = 3
    x4 = transformer_encoder(x3, x, head_sizes[i], num_heads[i], ff_dims[i], dropout, output_dims[i])

    nDim = 256
    z2 = transformer_encoder(x2, x, nDim, num_heads[i], nDim, dropout, nDim)
    nDim = 128
    z3 = transformer_encoder(layers.Add()([x3, z2]), x, nDim, num_heads[i], nDim, dropout, nDim)
    nDim = 64
    z4 = transformer_encoder(layers.Add()([x4, z3]), x, nDim, num_heads[i], nDim, dropout, nDim)

    x = layers.Concatenate(axis=2)([x4, z2, z3, z4])

    for dim in mlp_units[:-1]:
        x = layers.Dense(dim, activation="selu")(x)
        x = layers.Dropout(mlp_dropout)(x)
    
    outputs = layers.Dense(mlp_units[-1])(x)

    model = keras.Model(inputs, outputs)
    model.summary()
    return model

# %%
from tensorflow.keras.utils import plot_model
model = build_transfer_model(train.shape[1:])
plot_model(
    model, 
    to_file='Google_Brain_Keras_Model.png', 
    show_shapes=True,
    show_layer_names=True
)
# Out:
# Model: "model_8"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_12 (InputLayer)           [(None, 80, 53)]     0
# __________________________________________________________________________________________________
# tf.math.multiply_11 (TFOpLambda (None, 80, 53)       0           input_12[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_91 (TFOpLa (None, 80, 53)       0           tf.math.multiply_11[0][0]
# __________________________________________________________________________________________________
# layer_normalization_129 (LayerN (None, 80, 53)       106         tf.__operators__.add_91[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_73 (MultiH (None, 80, 53)       5283893     layer_normalization_129[0][0]
#                                                                  layer_normalization_129[0][0]
# __________________________________________________________________________________________________
# dropout_81 (Dropout)            (None, 80, 53)       0           multi_head_attention_73[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_92 (TFOpLa (None, 80, 53)       0           dropout_81[0][0]
#                                                                  tf.__operators__.add_91[0][0]
# __________________________________________________________________________________________________
# layer_normalization_130 (LayerN (None, 80, 53)       106         tf.__operators__.add_92[0][0]
# __________________________________________________________________________________________________
# conv1d_59 (Conv1D)              (None, 80, 768)      41472       layer_normalization_130[0][0]
# __________________________________________________________________________________________________
# dropout_82 (Dropout)            (None, 80, 768)      0           conv1d_59[0][0]
# __________________________________________________________________________________________________
# conv1d_60 (Conv1D)              (None, 80, 53)       40757       dropout_82[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_93 (TFOpLa (None, 80, 53)       0           conv1d_60[0][0]
#                                                                  tf.__operators__.add_92[0][0]
# __________________________________________________________________________________________________
# layer_normalization_131 (LayerN (None, 80, 53)       106         tf.__operators__.add_93[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_74 (MultiH (None, 80, 53)       3522613     layer_normalization_131[0][0]
#                                                                  layer_normalization_131[0][0]
# __________________________________________________________________________________________________
# dropout_83 (Dropout)            (None, 80, 53)       0           multi_head_attention_74[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_94 (TFOpLa (None, 80, 53)       0           dropout_83[0][0]
#                                                                  tf.__operators__.add_93[0][0]
# __________________________________________________________________________________________________
# layer_normalization_132 (LayerN (None, 80, 53)       106         tf.__operators__.add_94[0][0]
# __________________________________________________________________________________________________
# conv1d_61 (Conv1D)              (None, 80, 512)      27648       layer_normalization_132[0][0]
# __________________________________________________________________________________________________
# dropout_84 (Dropout)            (None, 80, 512)      0           conv1d_61[0][0]
# __________________________________________________________________________________________________
# conv1d_62 (Conv1D)              (None, 80, 53)       27189       dropout_84[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_95 (TFOpLa (None, 80, 53)       0           conv1d_62[0][0]
#                                                                  tf.__operators__.add_94[0][0]
# __________________________________________________________________________________________________
# layer_normalization_133 (LayerN (None, 80, 53)       106         tf.__operators__.add_95[0][0]
# __________________________________________________________________________________________________
# layer_normalization_137 (LayerN (None, 80, 53)       106         tf.__operators__.add_95[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_75 (MultiH (None, 80, 53)       1761333     layer_normalization_133[0][0]
#                                                                  layer_normalization_133[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_77 (MultiH (None, 80, 53)       1761333     layer_normalization_137[0][0]
#                                                                  layer_normalization_137[0][0]
# __________________________________________________________________________________________________
# dropout_85 (Dropout)            (None, 80, 53)       0           multi_head_attention_75[0][0]
# __________________________________________________________________________________________________
# dropout_89 (Dropout)            (None, 80, 53)       0           multi_head_attention_77[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_96 (TFOpLa (None, 80, 53)       0           dropout_85[0][0]
#                                                                  tf.__operators__.add_95[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_100 (TFOpL (None, 80, 53)       0           dropout_89[0][0]
#                                                                  tf.__operators__.add_95[0][0]
# __________________________________________________________________________________________________
# layer_normalization_134 (LayerN (None, 80, 53)       106         tf.__operators__.add_96[0][0]
# __________________________________________________________________________________________________
# layer_normalization_138 (LayerN (None, 80, 53)       106         tf.__operators__.add_100[0][0]
# __________________________________________________________________________________________________
# conv1d_63 (Conv1D)              (None, 80, 256)      13824       layer_normalization_134[0][0]
# __________________________________________________________________________________________________
# conv1d_67 (Conv1D)              (None, 80, 256)      13824       layer_normalization_138[0][0]
# __________________________________________________________________________________________________
# dropout_86 (Dropout)            (None, 80, 256)      0           conv1d_63[0][0]
# __________________________________________________________________________________________________
# dropout_90 (Dropout)            (None, 80, 256)      0           conv1d_67[0][0]
# __________________________________________________________________________________________________
# conv1d_64 (Conv1D)              (None, 80, 53)       13621       dropout_86[0][0]
# __________________________________________________________________________________________________
# conv1d_68 (Conv1D)              (None, 80, 53)       13621       dropout_90[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_97 (TFOpLa (None, 80, 53)       0           conv1d_64[0][0]
#                                                                  tf.__operators__.add_96[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_101 (TFOpL (None, 80, 53)       0           conv1d_68[0][0]
#                                                                  tf.__operators__.add_100[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 80, 53)       0           tf.__operators__.add_97[0][0]
#                                                                  tf.__operators__.add_101[0][0]
# __________________________________________________________________________________________________
# layer_normalization_135 (LayerN (None, 80, 53)       106         tf.__operators__.add_97[0][0]
# __________________________________________________________________________________________________
# layer_normalization_139 (LayerN (None, 80, 53)       106         add_18[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_76 (MultiH (None, 80, 53)       880693      layer_normalization_135[0][0]
#                                                                  layer_normalization_135[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_78 (MultiH (None, 80, 53)       880693      layer_normalization_139[0][0]
#                                                                  layer_normalization_139[0][0]
# __________________________________________________________________________________________________
# dropout_87 (Dropout)            (None, 80, 53)       0           multi_head_attention_76[0][0]
# __________________________________________________________________________________________________
# dropout_91 (Dropout)            (None, 80, 53)       0           multi_head_attention_78[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_98 (TFOpLa (None, 80, 53)       0           dropout_87[0][0]
#                                                                  tf.__operators__.add_97[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_102 (TFOpL (None, 80, 53)       0           dropout_91[0][0]
#                                                                  add_18[0][0]
# __________________________________________________________________________________________________
# layer_normalization_136 (LayerN (None, 80, 53)       106         tf.__operators__.add_98[0][0]
# __________________________________________________________________________________________________
# layer_normalization_140 (LayerN (None, 80, 53)       106         tf.__operators__.add_102[0][0]
# __________________________________________________________________________________________________
# conv1d_65 (Conv1D)              (None, 80, 128)      6912        layer_normalization_136[0][0]
# __________________________________________________________________________________________________
# conv1d_69 (Conv1D)              (None, 80, 128)      6912        layer_normalization_140[0][0]
# __________________________________________________________________________________________________
# dropout_88 (Dropout)            (None, 80, 128)      0           conv1d_65[0][0]
# __________________________________________________________________________________________________
# dropout_92 (Dropout)            (None, 80, 128)      0           conv1d_69[0][0]
# __________________________________________________________________________________________________
# conv1d_66 (Conv1D)              (None, 80, 53)       6837        dropout_88[0][0]
# __________________________________________________________________________________________________
# conv1d_70 (Conv1D)              (None, 80, 53)       6837        dropout_92[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_99 (TFOpLa (None, 80, 53)       0           conv1d_66[0][0]
#                                                                  tf.__operators__.add_98[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_103 (TFOpL (None, 80, 53)       0           conv1d_70[0][0]
#                                                                  tf.__operators__.add_102[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, 80, 53)       0           tf.__operators__.add_99[0][0]
#                                                                  tf.__operators__.add_103[0][0]
# __________________________________________________________________________________________________
# layer_normalization_141 (LayerN (None, 80, 53)       106         add_19[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_79 (MultiH (None, 80, 53)       440373      layer_normalization_141[0][0]
#                                                                  layer_normalization_141[0][0]
# __________________________________________________________________________________________________
# dropout_93 (Dropout)            (None, 80, 53)       0           multi_head_attention_79[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_104 (TFOpL (None, 80, 53)       0           dropout_93[0][0]
#                                                                  add_19[0][0]
# __________________________________________________________________________________________________
# layer_normalization_142 (LayerN (None, 80, 53)       106         tf.__operators__.add_104[0][0]
# __________________________________________________________________________________________________
# conv1d_71 (Conv1D)              (None, 80, 64)       3456        layer_normalization_142[0][0]
# __________________________________________________________________________________________________
# dropout_94 (Dropout)            (None, 80, 64)       0           conv1d_71[0][0]
# __________________________________________________________________________________________________
# conv1d_72 (Conv1D)              (None, 80, 53)       3445        dropout_94[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_105 (TFOpL (None, 80, 53)       0           conv1d_72[0][0]
#                                                                  tf.__operators__.add_104[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 80, 212)      0           tf.__operators__.add_99[0][0]
#                                                                  tf.__operators__.add_101[0][0]
#                                                                  tf.__operators__.add_103[0][0]
#                                                                  tf.__operators__.add_105[0][0]
# __________________________________________________________________________________________________
# dense_16 (Dense)                (None, 80, 128)      27264       concatenate_8[0][0]
# __________________________________________________________________________________________________
# dropout_95 (Dropout)            (None, 80, 128)      0           dense_16[0][0]
# __________________________________________________________________________________________________
# dense_17 (Dense)                (None, 80, 1)        129         dropout_95[0][0]
# ==================================================================================================
# Total params: 14,786,163
# Trainable params: 14,786,163
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Function to get hardware strategy
def get_hardware_strategy():
    try:
        # TPU detection. No parameters necessary if TPU_NAME environment variable is
        # set: this is always the case on Kaggle.
        tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
        print('Running on TPU ', tpu.master())
    except ValueError:
        tpu = None

    if tpu:
        tf.config.experimental_connect_to_cluster(tpu)
        tf.tpu.experimental.initialize_tpu_system(tpu)
        strategy = tf.distribute.experimental.TPUStrategy(tpu)
        tf.config.optimizer.set_jit(True)
    else:
        # Default distribution strategy in Tensorflow. Works on CPU and single GPU.
        strategy = tf.distribute.get_strategy()

    return tpu, strategy

tpu, strategy = get_hardware_strategy()
# Out:
# Running on TPU  grpc://10.69.244.10:8470
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Clearing out eager caches
# INFO:tensorflow:Initializing the TPU system: grpc://10.69.244.10:8470
# INFO:tensorflow:Initializing the TPU system: grpc://10.69.244.10:8470
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Finished initializing TPU system.
# WARNING:absl:`tf.distribute.experimental.TPUStrategy` is deprecated, please use  the non experimental symbol `tf.distribute.TPUStrategy` instead.
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:2, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:2, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:3, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:3, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:4, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:4, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:5, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:5, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:6, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:6, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:7, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:7, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)

# %%
from tensorflow.keras.optimizers.schedules import ExponentialDecay

with strategy.scope():
    kf = KFold(n_splits=NUM_FOLDS, shuffle=True, random_state=2021)
    test_preds = []
    train_preds = []
    for fold, (train_idx, test_idx) in enumerate(kf.split(train, targets)):
        print('-'*15, '>', f'Fold {fold+1}', '<', '-'*15)
        X_train, X_valid = train[train_idx], train[test_idx]
        y_train, y_valid = targets[train_idx], targets[test_idx]
        #u_out_train, u_out_valid = u_outs[train_idx], u_outs[test_idx]
        
        #model = get_cnn_model(train)
        model = build_transfer_model(train.shape[1:])
        model.compile(optimizer='adam', 
                      # loss=GBVPP_loss,
                      loss="mae"
                      )

        #scheduler = ExponentialDecay(1e-3, 40*((len(train)*0.8)/BATCH_SIZE), 1e-5)
        #lr = LearningRateScheduler(scheduler, verbose=1)
        lr = ReduceLROnPlateau(monitor="val_loss", factor=0.75, patience=10, verbose=1)
        es = EarlyStopping(monitor="val_loss", patience=50, verbose=1, mode="min", restore_best_weights=True)
        checkpoint_filepath = f"folds{fold}.hdf5"
        sv = keras.callbacks.ModelCheckpoint(
            checkpoint_filepath, monitor='val_loss', verbose=1, save_best_only=True,
            save_weights_only=False, mode='auto', save_freq='epoch',
            options=None)

        history = model.fit(X_train,
                            y_train,
                            # validation_data=(X_valid, np.append(y_valid, u_out_valid, axis =1)), 
                            validation_data=(X_valid, y_valid), 
                            epochs=EPOCH, 
                            batch_size=512, #GPU only can use 64 as batch size
                            callbacks=[lr,
                                       es,
                                       sv])
        
        if IN_COLAB:
          with open(model_folder+checkpoint_filepath, 'wb') as f:
            f.write(open(checkpoint_filepath, 'rb').read())
    
        test_preds.append(model.predict(test).squeeze().reshape(-1, 1).squeeze())
        train_preds.append(model.predict(train).squeeze().reshape(-1, 1).squeeze())
# Out:
# --------------- > Fold 1 < ---------------
# Model: "model_9"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_13 (InputLayer)           [(None, 80, 53)]     0
# __________________________________________________________________________________________________
# tf.math.multiply_12 (TFOpLambda (None, 80, 53)       0           input_13[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_106 (TFOpL (None, 80, 53)       0           tf.math.multiply_12[0][0]
# __________________________________________________________________________________________________
# layer_normalization_143 (LayerN (None, 80, 53)       106         tf.__operators__.add_106[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_80 (MultiH (None, 80, 53)       5283893     layer_normalization_143[0][0]
#                                                                  layer_normalization_143[0][0]
# __________________________________________________________________________________________________
# dropout_96 (Dropout)            (None, 80, 53)       0           multi_head_attention_80[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_107 (TFOpL (None, 80, 53)       0           dropout_96[0][0]
#                                                                  tf.__operators__.add_106[0][0]
# __________________________________________________________________________________________________
# layer_normalization_144 (LayerN (None, 80, 53)       106         tf.__operators__.add_107[0][0]
# __________________________________________________________________________________________________
# conv1d_73 (Conv1D)              (None, 80, 768)      41472       layer_normalization_144[0][0]
# __________________________________________________________________________________________________
# dropout_97 (Dropout)            (None, 80, 768)      0           conv1d_73[0][0]
# __________________________________________________________________________________________________
# conv1d_74 (Conv1D)              (None, 80, 53)       40757       dropout_97[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_108 (TFOpL (None, 80, 53)       0           conv1d_74[0][0]
#                                                                  tf.__operators__.add_107[0][0]
# __________________________________________________________________________________________________
# layer_normalization_145 (LayerN (None, 80, 53)       106         tf.__operators__.add_108[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_81 (MultiH (None, 80, 53)       3522613     layer_normalization_145[0][0]
#                                                                  layer_normalization_145[0][0]
# __________________________________________________________________________________________________
# dropout_98 (Dropout)            (None, 80, 53)       0           multi_head_attention_81[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_109 (TFOpL (None, 80, 53)       0           dropout_98[0][0]
#                                                                  tf.__operators__.add_108[0][0]
# __________________________________________________________________________________________________
# layer_normalization_146 (LayerN (None, 80, 53)       106         tf.__operators__.add_109[0][0]
# __________________________________________________________________________________________________
# conv1d_75 (Conv1D)              (None, 80, 512)      27648       layer_normalization_146[0][0]
# __________________________________________________________________________________________________
# dropout_99 (Dropout)            (None, 80, 512)      0           conv1d_75[0][0]
# __________________________________________________________________________________________________
# conv1d_76 (Conv1D)              (None, 80, 53)       27189       dropout_99[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_110 (TFOpL (None, 80, 53)       0           conv1d_76[0][0]
#                                                                  tf.__operators__.add_109[0][0]
# __________________________________________________________________________________________________
# layer_normalization_147 (LayerN (None, 80, 53)       106         tf.__operators__.add_110[0][0]
# __________________________________________________________________________________________________
# layer_normalization_151 (LayerN (None, 80, 53)       106         tf.__operators__.add_110[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_82 (MultiH (None, 80, 53)       1761333     layer_normalization_147[0][0]
#                                                                  layer_normalization_147[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_84 (MultiH (None, 80, 53)       1761333     layer_normalization_151[0][0]
#                                                                  layer_normalization_151[0][0]
# __________________________________________________________________________________________________
# dropout_100 (Dropout)           (None, 80, 53)       0           multi_head_attention_82[0][0]
# __________________________________________________________________________________________________
# dropout_104 (Dropout)           (None, 80, 53)       0           multi_head_attention_84[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_111 (TFOpL (None, 80, 53)       0           dropout_100[0][0]
#                                                                  tf.__operators__.add_110[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_115 (TFOpL (None, 80, 53)       0           dropout_104[0][0]
#                                                                  tf.__operators__.add_110[0][0]
# __________________________________________________________________________________________________
# layer_normalization_148 (LayerN (None, 80, 53)       106         tf.__operators__.add_111[0][0]
# __________________________________________________________________________________________________
# layer_normalization_152 (LayerN (None, 80, 53)       106         tf.__operators__.add_115[0][0]
# __________________________________________________________________________________________________
# conv1d_77 (Conv1D)              (None, 80, 256)      13824       layer_normalization_148[0][0]
# __________________________________________________________________________________________________
# conv1d_81 (Conv1D)              (None, 80, 256)      13824       layer_normalization_152[0][0]
# __________________________________________________________________________________________________
# dropout_101 (Dropout)           (None, 80, 256)      0           conv1d_77[0][0]
# __________________________________________________________________________________________________
# dropout_105 (Dropout)           (None, 80, 256)      0           conv1d_81[0][0]
# __________________________________________________________________________________________________
# conv1d_78 (Conv1D)              (None, 80, 53)       13621       dropout_101[0][0]
# __________________________________________________________________________________________________
# conv1d_82 (Conv1D)              (None, 80, 53)       13621       dropout_105[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_112 (TFOpL (None, 80, 53)       0           conv1d_78[0][0]
#                                                                  tf.__operators__.add_111[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_116 (TFOpL (None, 80, 53)       0           conv1d_82[0][0]
#                                                                  tf.__operators__.add_115[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, 80, 53)       0           tf.__operators__.add_112[0][0]
#                                                                  tf.__operators__.add_116[0][0]
# __________________________________________________________________________________________________
# layer_normalization_149 (LayerN (None, 80, 53)       106         tf.__operators__.add_112[0][0]
# __________________________________________________________________________________________________
# layer_normalization_153 (LayerN (None, 80, 53)       106         add_20[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_83 (MultiH (None, 80, 53)       880693      layer_normalization_149[0][0]
#                                                                  layer_normalization_149[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_85 (MultiH (None, 80, 53)       880693      layer_normalization_153[0][0]
#                                                                  layer_normalization_153[0][0]
# __________________________________________________________________________________________________
# dropout_102 (Dropout)           (None, 80, 53)       0           multi_head_attention_83[0][0]
# __________________________________________________________________________________________________
# dropout_106 (Dropout)           (None, 80, 53)       0           multi_head_attention_85[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_113 (TFOpL (None, 80, 53)       0           dropout_102[0][0]
#                                                                  tf.__operators__.add_112[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_117 (TFOpL (None, 80, 53)       0           dropout_106[0][0]
#                                                                  add_20[0][0]
# __________________________________________________________________________________________________
# layer_normalization_150 (LayerN (None, 80, 53)       106         tf.__operators__.add_113[0][0]
# __________________________________________________________________________________________________
# layer_normalization_154 (LayerN (None, 80, 53)       106         tf.__operators__.add_117[0][0]
# __________________________________________________________________________________________________
# conv1d_79 (Conv1D)              (None, 80, 128)      6912        layer_normalization_150[0][0]
# __________________________________________________________________________________________________
# conv1d_83 (Conv1D)              (None, 80, 128)      6912        layer_normalization_154[0][0]
# __________________________________________________________________________________________________
# dropout_103 (Dropout)           (None, 80, 128)      0           conv1d_79[0][0]
# __________________________________________________________________________________________________
# dropout_107 (Dropout)           (None, 80, 128)      0           conv1d_83[0][0]
# __________________________________________________________________________________________________
# conv1d_80 (Conv1D)              (None, 80, 53)       6837        dropout_103[0][0]
# __________________________________________________________________________________________________
# conv1d_84 (Conv1D)              (None, 80, 53)       6837        dropout_107[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_114 (TFOpL (None, 80, 53)       0           conv1d_80[0][0]
#                                                                  tf.__operators__.add_113[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_118 (TFOpL (None, 80, 53)       0           conv1d_84[0][0]
#                                                                  tf.__operators__.add_117[0][0]
# __________________________________________________________________________________________________
# add_21 (Add)                    (None, 80, 53)       0           tf.__operators__.add_114[0][0]
#                                                                  tf.__operators__.add_118[0][0]
# __________________________________________________________________________________________________
# layer_normalization_155 (LayerN (None, 80, 53)       106         add_21[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_86 (MultiH (None, 80, 53)       440373      layer_normalization_155[0][0]
#                                                                  layer_normalization_155[0][0]
# __________________________________________________________________________________________________
# dropout_108 (Dropout)           (None, 80, 53)       0           multi_head_attention_86[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_119 (TFOpL (None, 80, 53)       0           dropout_108[0][0]
#                                                                  add_21[0][0]
# __________________________________________________________________________________________________
# layer_normalization_156 (LayerN (None, 80, 53)       106         tf.__operators__.add_119[0][0]
# __________________________________________________________________________________________________
# conv1d_85 (Conv1D)              (None, 80, 64)       3456        layer_normalization_156[0][0]
# __________________________________________________________________________________________________
# dropout_109 (Dropout)           (None, 80, 64)       0           conv1d_85[0][0]
# __________________________________________________________________________________________________
# conv1d_86 (Conv1D)              (None, 80, 53)       3445        dropout_109[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_120 (TFOpL (None, 80, 53)       0           conv1d_86[0][0]
#                                                                  tf.__operators__.add_119[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 80, 212)      0           tf.__operators__.add_114[0][0]
#                                                                  tf.__operators__.add_116[0][0]
#                                                                  tf.__operators__.add_118[0][0]
#                                                                  tf.__operators__.add_120[0][0]
# __________________________________________________________________________________________________
# dense_18 (Dense)                (None, 80, 128)      27264       concatenate_9[0][0]
# __________________________________________________________________________________________________
# dropout_110 (Dropout)           (None, 80, 128)      0           dense_18[0][0]
# __________________________________________________________________________________________________
# dense_19 (Dense)                (None, 80, 1)        129         dropout_110[0][0]
# ==================================================================================================
# Total params: 14,786,163
# Trainable params: 14,786,163
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/300
# 133/133 [==============================] - 92s 412ms/step - loss: 5.2086 - val_loss: 1.9758
#
# Epoch 00001: val_loss improved from inf to 1.97577, saving model to folds0.hdf5
# /usr/local/lib/python3.7/dist-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# Epoch 2/300
# 133/133 [==============================] - 19s 143ms/step - loss: 1.8124 - val_loss: 1.5475
#
# Epoch 00002: val_loss improved from 1.97577 to 1.54750, saving model to folds0.hdf5
# Epoch 3/300
# 133/133 [==============================] - 19s 143ms/step - loss: 1.7534 - val_loss: 1.7332
#
# Epoch 00003: val_loss did not improve from 1.54750
# Epoch 4/300
# 133/133 [==============================] - 19s 143ms/step - loss: 1.5479 - val_loss: 1.3492
#
# Epoch 00004: val_loss improved from 1.54750 to 1.34918, saving model to folds0.hdf5
# Epoch 5/300
# 133/133 [==============================] - 19s 143ms/step - loss: 1.2628 - val_loss: 1.3282
#
# Epoch 00005: val_loss improved from 1.34918 to 1.32822, saving model to folds0.hdf5
# Epoch 6/300
# 133/133 [==============================] - 19s 143ms/step - loss: 1.3644 - val_loss: 1.8320
#
# Epoch 00006: val_loss did not improve from 1.32822
# Epoch 7/300
# 133/133 [==============================] - 19s 143ms/step - loss: 1.1699 - val_loss: 1.1462
#
# Epoch 00007: val_loss improved from 1.32822 to 1.14619, saving model to folds0.hdf5
# Epoch 8/300
# 133/133 [==============================] - 19s 143ms/step - loss: 1.1801 - val_loss: 1.1627
#
# Epoch 00008: val_loss did not improve from 1.14619
# Epoch 9/300
# 133/133 [==============================] - 19s 143ms/step - loss: 1.2007 - val_loss: 0.9242
#
# Epoch 00009: val_loss improved from 1.14619 to 0.92420, saving model to folds0.hdf5
# Epoch 10/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.9876 - val_loss: 1.1721
#
# Epoch 00010: val_loss did not improve from 0.92420
# Epoch 11/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.9674 - val_loss: 0.8948
#
# Epoch 00011: val_loss improved from 0.92420 to 0.89476, saving model to folds0.hdf5
# Epoch 12/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.8898 - val_loss: 0.7590
#
# Epoch 00012: val_loss improved from 0.89476 to 0.75900, saving model to folds0.hdf5
# Epoch 13/300
# 133/133 [==============================] - 19s 144ms/step - loss: 0.9636 - val_loss: 0.7854
#
# Epoch 00013: val_loss did not improve from 0.75900
# Epoch 14/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.9041 - val_loss: 0.7144
#
# Epoch 00014: val_loss improved from 0.75900 to 0.71444, saving model to folds0.hdf5
# Epoch 15/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.8447 - val_loss: 0.7701
#
# Epoch 00015: val_loss did not improve from 0.71444
# Epoch 16/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.8270 - val_loss: 0.9714
#
# Epoch 00016: val_loss did not improve from 0.71444
# Epoch 17/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.8146 - val_loss: 0.7061
#
# Epoch 00017: val_loss improved from 0.71444 to 0.70613, saving model to folds0.hdf5
# Epoch 18/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.7788 - val_loss: 0.5748
#
# Epoch 00018: val_loss improved from 0.70613 to 0.57476, saving model to folds0.hdf5
# Epoch 19/300
# 133/133 [==============================] - 19s 144ms/step - loss: 0.7137 - val_loss: 0.7693
#
# Epoch 00019: val_loss did not improve from 0.57476
# Epoch 20/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.6674 - val_loss: 0.7478
#
# Epoch 00020: val_loss did not improve from 0.57476
# Epoch 21/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.6785 - val_loss: 0.7103
#
# Epoch 00021: val_loss did not improve from 0.57476
# Epoch 22/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.6713 - val_loss: 0.8030
#
# Epoch 00022: val_loss did not improve from 0.57476
# Epoch 23/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.6425 - val_loss: 0.5931
#
# Epoch 00023: val_loss did not improve from 0.57476
# Epoch 24/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.6005 - val_loss: 0.6186
#
# Epoch 00024: val_loss did not improve from 0.57476
# Epoch 25/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.6189 - val_loss: 0.5353
#
# Epoch 00025: val_loss improved from 0.57476 to 0.53528, saving model to folds0.hdf5
# Epoch 26/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.5606 - val_loss: 0.5096
#
# Epoch 00026: val_loss improved from 0.53528 to 0.50962, saving model to folds0.hdf5
# Epoch 27/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.5450 - val_loss: 0.4798
#
# Epoch 00027: val_loss improved from 0.50962 to 0.47981, saving model to folds0.hdf5
# Epoch 28/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.5579 - val_loss: 0.4673
#
# Epoch 00028: val_loss improved from 0.47981 to 0.46729, saving model to folds0.hdf5
# Epoch 29/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.5550 - val_loss: 0.5298
#
# Epoch 00029: val_loss did not improve from 0.46729
# Epoch 30/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.5390 - val_loss: 0.5204
#
# Epoch 00030: val_loss did not improve from 0.46729
# Epoch 31/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.5410 - val_loss: 0.4898
#
# Epoch 00031: val_loss did not improve from 0.46729
# Epoch 32/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.5139 - val_loss: 0.4783
#
# Epoch 00032: val_loss did not improve from 0.46729
# Epoch 33/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.4933 - val_loss: 0.5232
#
# Epoch 00033: val_loss did not improve from 0.46729
# Epoch 34/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.5046 - val_loss: 0.5007
#
# Epoch 00034: val_loss did not improve from 0.46729
# Epoch 35/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.4660 - val_loss: 0.4547
#
# Epoch 00035: val_loss improved from 0.46729 to 0.45471, saving model to folds0.hdf5
# Epoch 36/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.4505 - val_loss: 0.4493
#
# Epoch 00036: val_loss improved from 0.45471 to 0.44931, saving model to folds0.hdf5
# Epoch 37/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.4517 - val_loss: 0.4755
#
# Epoch 00037: val_loss did not improve from 0.44931
# Epoch 38/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.4537 - val_loss: 0.4426
#
# Epoch 00038: val_loss improved from 0.44931 to 0.44259, saving model to folds0.hdf5
# Epoch 39/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.4355 - val_loss: 0.4678
#
# Epoch 00039: val_loss did not improve from 0.44259
# Epoch 40/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.4314 - val_loss: 0.4333
#
# Epoch 00040: val_loss improved from 0.44259 to 0.43332, saving model to folds0.hdf5
# Epoch 41/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.4207 - val_loss: 0.4194
#
# Epoch 00041: val_loss improved from 0.43332 to 0.41945, saving model to folds0.hdf5
# Epoch 42/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.4162 - val_loss: 0.4054
#
# Epoch 00042: val_loss improved from 0.41945 to 0.40541, saving model to folds0.hdf5
# Epoch 43/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.4081 - val_loss: 0.4449
#
# Epoch 00043: val_loss did not improve from 0.40541
# Epoch 44/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.4074 - val_loss: 0.4071
#
# Epoch 00044: val_loss did not improve from 0.40541
# Epoch 45/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.4139 - val_loss: 0.4229
#
# Epoch 00045: val_loss did not improve from 0.40541
# Epoch 46/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.3919 - val_loss: 0.3901
#
# Epoch 00046: val_loss improved from 0.40541 to 0.39008, saving model to folds0.hdf5
# Epoch 47/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.3849 - val_loss: 0.4206
#
# Epoch 00047: val_loss did not improve from 0.39008
# Epoch 48/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.3862 - val_loss: 0.3977
#
# Epoch 00048: val_loss did not improve from 0.39008
# Epoch 49/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.3785 - val_loss: 0.3772
#
# Epoch 00049: val_loss improved from 0.39008 to 0.37716, saving model to folds0.hdf5
# Epoch 50/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.3763 - val_loss: 0.3976
#
# Epoch 00050: val_loss did not improve from 0.37716
# Epoch 51/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.3784 - val_loss: 0.3776
#
# Epoch 00051: val_loss did not improve from 0.37716
# Epoch 52/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.3778 - val_loss: 0.3719
#
# Epoch 00052: val_loss improved from 0.37716 to 0.37186, saving model to folds0.hdf5
# Epoch 53/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.3646 - val_loss: 0.3729
#
# Epoch 00053: val_loss did not improve from 0.37186
# Epoch 54/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.3649 - val_loss: 0.3683
#
# Epoch 00054: val_loss improved from 0.37186 to 0.36829, saving model to folds0.hdf5
# Epoch 55/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.3588 - val_loss: 0.3677
#
# Epoch 00055: val_loss improved from 0.36829 to 0.36767, saving model to folds0.hdf5
# Epoch 56/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.3522 - val_loss: 0.3618
#
# Epoch 00056: val_loss improved from 0.36767 to 0.36176, saving model to folds0.hdf5
# Epoch 57/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.3493 - val_loss: 0.3513
#
# Epoch 00057: val_loss improved from 0.36176 to 0.35130, saving model to folds0.hdf5
# Epoch 58/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.3572 - val_loss: 0.3629
#
# Epoch 00058: val_loss did not improve from 0.35130
# Epoch 59/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.3465 - val_loss: 0.3669
#
# Epoch 00059: val_loss did not improve from 0.35130
# Epoch 60/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.3516 - val_loss: 0.3624
#
# Epoch 00060: val_loss did not improve from 0.35130
# Epoch 61/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.3460 - val_loss: 0.3406
#
# Epoch 00061: val_loss improved from 0.35130 to 0.34057, saving model to folds0.hdf5
# Epoch 62/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.3450 - val_loss: 0.3415
#
# Epoch 00062: val_loss did not improve from 0.34057
# Epoch 63/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.3352 - val_loss: 0.3557
#
# Epoch 00063: val_loss did not improve from 0.34057
# Epoch 64/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.3346 - val_loss: 0.3428
#
# Epoch 00064: val_loss did not improve from 0.34057
# Epoch 65/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.3337 - val_loss: 0.3425
#
# Epoch 00065: val_loss did not improve from 0.34057
# Epoch 66/300
# 133/133 [==============================] - 20s 147ms/step - loss: 0.3376 - val_loss: 0.3481
#
# Epoch 00066: val_loss did not improve from 0.34057
# Epoch 67/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.3273 - val_loss: 0.3323
#
# Epoch 00067: val_loss improved from 0.34057 to 0.33234, saving model to folds0.hdf5
# Epoch 68/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.3237 - val_loss: 0.3337
#
# Epoch 00068: val_loss did not improve from 0.33234
# Epoch 69/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.3231 - val_loss: 0.3310
#
# Epoch 00069: val_loss improved from 0.33234 to 0.33103, saving model to folds0.hdf5
# Epoch 70/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.3188 - val_loss: 0.3239
#
# Epoch 00070: val_loss improved from 0.33103 to 0.32390, saving model to folds0.hdf5
# Epoch 71/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.3244 - val_loss: 0.3301
#
# Epoch 00071: val_loss did not improve from 0.32390
# Epoch 72/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.3211 - val_loss: 0.3598
#
# Epoch 00072: val_loss did not improve from 0.32390
# Epoch 73/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.3222 - val_loss: 0.3206
#
# Epoch 00073: val_loss improved from 0.32390 to 0.32058, saving model to folds0.hdf5
# Epoch 74/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.3108 - val_loss: 0.3142
#
# Epoch 00074: val_loss improved from 0.32058 to 0.31417, saving model to folds0.hdf5
# Epoch 75/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.3085 - val_loss: 0.3444
#
# Epoch 00075: val_loss did not improve from 0.31417
# Epoch 76/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.3102 - val_loss: 0.3539
#
# Epoch 00076: val_loss did not improve from 0.31417
# Epoch 77/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.3151 - val_loss: 0.3299
#
# Epoch 00077: val_loss did not improve from 0.31417
# Epoch 78/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.3084 - val_loss: 0.3321
#
# Epoch 00078: val_loss did not improve from 0.31417
# Epoch 79/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.3050 - val_loss: 0.3089
#
# Epoch 00079: val_loss improved from 0.31417 to 0.30894, saving model to folds0.hdf5
# Epoch 80/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.3080 - val_loss: 0.3260
#
# Epoch 00080: val_loss did not improve from 0.30894
# Epoch 81/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.3004 - val_loss: 0.3083
#
# Epoch 00081: val_loss improved from 0.30894 to 0.30829, saving model to folds0.hdf5
# Epoch 82/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.3007 - val_loss: 0.3148
#
# Epoch 00082: val_loss did not improve from 0.30829
# Epoch 83/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.3000 - val_loss: 0.3252
#
# Epoch 00083: val_loss did not improve from 0.30829
# Epoch 84/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.2970 - val_loss: 0.3163
#
# Epoch 00084: val_loss did not improve from 0.30829
# Epoch 85/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.2930 - val_loss: 0.2958
#
# Epoch 00085: val_loss improved from 0.30829 to 0.29576, saving model to folds0.hdf5
# Epoch 86/300
# 133/133 [==============================] - 19s 143ms/step - loss: 3.5458 - val_loss: 2.0128
#
# Epoch 00086: val_loss did not improve from 0.29576
# Epoch 87/300
# 133/133 [==============================] - 19s 143ms/step - loss: 1.1938 - val_loss: 0.8313
#
# Epoch 00087: val_loss did not improve from 0.29576
# Epoch 88/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.7887 - val_loss: 0.7160
#
# Epoch 00088: val_loss did not improve from 0.29576
# Epoch 89/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.6881 - val_loss: 0.6307
#
# Epoch 00089: val_loss did not improve from 0.29576
# Epoch 90/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.6156 - val_loss: 0.6681
#
# Epoch 00090: val_loss did not improve from 0.29576
# Epoch 91/300
# 133/133 [==============================] - 19s 144ms/step - loss: 0.5942 - val_loss: 0.6321
#
# Epoch 00091: val_loss did not improve from 0.29576
# Epoch 92/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.5440 - val_loss: 0.5590
#
# Epoch 00092: val_loss did not improve from 0.29576
# Epoch 93/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.5260 - val_loss: 0.5185
#
# Epoch 00093: val_loss did not improve from 0.29576
# Epoch 94/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.5198 - val_loss: 0.5623
#
# Epoch 00094: val_loss did not improve from 0.29576
# Epoch 95/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.5023 - val_loss: 0.4920
#
# Epoch 00095: ReduceLROnPlateau reducing learning rate to 0.0007500000356230885.
#
# Epoch 00095: val_loss did not improve from 0.29576
# Epoch 96/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.4602 - val_loss: 0.4614
#
# Epoch 00096: val_loss did not improve from 0.29576
# Epoch 97/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.4549 - val_loss: 0.4582
#
# Epoch 00097: val_loss did not improve from 0.29576
# Epoch 98/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.4476 - val_loss: 0.4449
#
# Epoch 00098: val_loss did not improve from 0.29576
# Epoch 99/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.4386 - val_loss: 0.4361
#
# Epoch 00099: val_loss did not improve from 0.29576
# Epoch 100/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.4355 - val_loss: 0.4501
#
# Epoch 00100: val_loss did not improve from 0.29576
# Epoch 101/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.4316 - val_loss: 0.4317
#
# Epoch 00101: val_loss did not improve from 0.29576
# Epoch 102/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.4283 - val_loss: 0.4210
#
# Epoch 00102: val_loss did not improve from 0.29576
# Epoch 103/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.4177 - val_loss: 0.4108
#
# Epoch 00103: val_loss did not improve from 0.29576
# Epoch 104/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.4183 - val_loss: 0.4204
#
# Epoch 00104: val_loss did not improve from 0.29576
# Epoch 105/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.4113 - val_loss: 0.4334
#
# Epoch 00105: ReduceLROnPlateau reducing learning rate to 0.0005625000048894435.
#
# Epoch 00105: val_loss did not improve from 0.29576
# Epoch 106/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.3907 - val_loss: 0.3914
#
# Epoch 00106: val_loss did not improve from 0.29576
# Epoch 107/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.3860 - val_loss: 0.4113
#
# Epoch 00107: val_loss did not improve from 0.29576
# Epoch 108/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.3907 - val_loss: 0.4009
#
# Epoch 00108: val_loss did not improve from 0.29576
# Epoch 109/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.3835 - val_loss: 0.3873
#
# Epoch 00109: val_loss did not improve from 0.29576
# Epoch 110/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.3816 - val_loss: 0.3815
#
# Epoch 00110: val_loss did not improve from 0.29576
# Epoch 111/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.3810 - val_loss: 0.4279
#
# Epoch 00111: val_loss did not improve from 0.29576
# Epoch 112/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.3814 - val_loss: 0.3910
#
# Epoch 00112: val_loss did not improve from 0.29576
# Epoch 113/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.3741 - val_loss: 0.3836
#
# Epoch 00113: val_loss did not improve from 0.29576
# Epoch 114/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.3750 - val_loss: 0.3894
#
# Epoch 00114: val_loss did not improve from 0.29576
# Epoch 115/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.3719 - val_loss: 0.3722
#
# Epoch 00115: ReduceLROnPlateau reducing learning rate to 0.0004218749818392098.
#
# Epoch 00115: val_loss did not improve from 0.29576
# Epoch 116/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.3593 - val_loss: 0.3689
#
# Epoch 00116: val_loss did not improve from 0.29576
# Epoch 117/300
# 133/133 [==============================] - 20s 148ms/step - loss: 0.3560 - val_loss: 0.3774
#
# Epoch 00117: val_loss did not improve from 0.29576
# Epoch 118/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.3544 - val_loss: 0.3630
#
# Epoch 00118: val_loss did not improve from 0.29576
# Epoch 119/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.3519 - val_loss: 0.3596
#
# Epoch 00119: val_loss did not improve from 0.29576
# Epoch 120/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.3544 - val_loss: 0.3845
#
# Epoch 00120: val_loss did not improve from 0.29576
# Epoch 121/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.3511 - val_loss: 0.3620
#
# Epoch 00121: val_loss did not improve from 0.29576
# Epoch 122/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.3503 - val_loss: 0.3661
#
# Epoch 00122: val_loss did not improve from 0.29576
# Epoch 123/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.3474 - val_loss: 0.3571
#
# Epoch 00123: val_loss did not improve from 0.29576
# Epoch 124/300
# 133/133 [==============================] - 19s 144ms/step - loss: 0.3474 - val_loss: 0.3537
#
# Epoch 00124: val_loss did not improve from 0.29576
# Epoch 125/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.3470 - val_loss: 0.3618
#
# Epoch 00125: ReduceLROnPlateau reducing learning rate to 0.00031640623637940735.
#
# Epoch 00125: val_loss did not improve from 0.29576
# Epoch 126/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.3343 - val_loss: 0.3523
#
# Epoch 00126: val_loss did not improve from 0.29576
# Epoch 127/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.3321 - val_loss: 0.3486
#
# Epoch 00127: val_loss did not improve from 0.29576
# Epoch 128/300
# 133/133 [==============================] - 19s 144ms/step - loss: 0.3324 - val_loss: 0.3462
#
# Epoch 00128: val_loss did not improve from 0.29576
# Epoch 129/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.3314 - val_loss: 0.3472
#
# Epoch 00129: val_loss did not improve from 0.29576
# Epoch 130/300
# 133/133 [==============================] - 19s 144ms/step - loss: 0.3306 - val_loss: 0.3449
#
# Epoch 00130: val_loss did not improve from 0.29576
# Epoch 131/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.3313 - val_loss: 0.3565
#
# Epoch 00131: val_loss did not improve from 0.29576
# Epoch 132/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.3299 - val_loss: 0.3433
#
# Epoch 00132: val_loss did not improve from 0.29576
# Epoch 133/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.3277 - val_loss: 0.3528
#
# Epoch 00133: val_loss did not improve from 0.29576
# Epoch 134/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.3278 - val_loss: 0.3443
#
# Epoch 00134: val_loss did not improve from 0.29576
# Epoch 135/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.3246 - val_loss: 0.3413
#
# Epoch 00135: ReduceLROnPlateau reducing learning rate to 0.00023730468819849193.
# Restoring model weights from the end of the best epoch.
#
# Epoch 00135: val_loss did not improve from 0.29576
# Epoch 00135: early stopping
# --------------- > Fold 2 < ---------------
# Model: "model_10"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_14 (InputLayer)           [(None, 80, 53)]     0
# __________________________________________________________________________________________________
# tf.math.multiply_13 (TFOpLambda (None, 80, 53)       0           input_14[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_121 (TFOpL (None, 80, 53)       0           tf.math.multiply_13[0][0]
# __________________________________________________________________________________________________
# layer_normalization_157 (LayerN (None, 80, 53)       106         tf.__operators__.add_121[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_87 (MultiH (None, 80, 53)       5283893     layer_normalization_157[0][0]
#                                                                  layer_normalization_157[0][0]
# __________________________________________________________________________________________________
# dropout_111 (Dropout)           (None, 80, 53)       0           multi_head_attention_87[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_122 (TFOpL (None, 80, 53)       0           dropout_111[0][0]
#                                                                  tf.__operators__.add_121[0][0]
# __________________________________________________________________________________________________
# layer_normalization_158 (LayerN (None, 80, 53)       106         tf.__operators__.add_122[0][0]
# __________________________________________________________________________________________________
# conv1d_87 (Conv1D)              (None, 80, 768)      41472       layer_normalization_158[0][0]
# __________________________________________________________________________________________________
# dropout_112 (Dropout)           (None, 80, 768)      0           conv1d_87[0][0]
# __________________________________________________________________________________________________
# conv1d_88 (Conv1D)              (None, 80, 53)       40757       dropout_112[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_123 (TFOpL (None, 80, 53)       0           conv1d_88[0][0]
#                                                                  tf.__operators__.add_122[0][0]
# __________________________________________________________________________________________________
# layer_normalization_159 (LayerN (None, 80, 53)       106         tf.__operators__.add_123[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_88 (MultiH (None, 80, 53)       3522613     layer_normalization_159[0][0]
#                                                                  layer_normalization_159[0][0]
# __________________________________________________________________________________________________
# dropout_113 (Dropout)           (None, 80, 53)       0           multi_head_attention_88[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_124 (TFOpL (None, 80, 53)       0           dropout_113[0][0]
#                                                                  tf.__operators__.add_123[0][0]
# __________________________________________________________________________________________________
# layer_normalization_160 (LayerN (None, 80, 53)       106         tf.__operators__.add_124[0][0]
# __________________________________________________________________________________________________
# conv1d_89 (Conv1D)              (None, 80, 512)      27648       layer_normalization_160[0][0]
# __________________________________________________________________________________________________
# dropout_114 (Dropout)           (None, 80, 512)      0           conv1d_89[0][0]
# __________________________________________________________________________________________________
# conv1d_90 (Conv1D)              (None, 80, 53)       27189       dropout_114[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_125 (TFOpL (None, 80, 53)       0           conv1d_90[0][0]
#                                                                  tf.__operators__.add_124[0][0]
# __________________________________________________________________________________________________
# layer_normalization_161 (LayerN (None, 80, 53)       106         tf.__operators__.add_125[0][0]
# __________________________________________________________________________________________________
# layer_normalization_165 (LayerN (None, 80, 53)       106         tf.__operators__.add_125[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_89 (MultiH (None, 80, 53)       1761333     layer_normalization_161[0][0]
#                                                                  layer_normalization_161[0][0]
# __________________________________________________________________________________________________
# multi_head_attention_91 (MultiH (None, 80, 53)       1761333     layer_normalization_165[0][0]
#                                                                  layer_normalization_165[0][0]
# __________________________________________________________________________________________________
# dropout_115 (Dropout)           (None, 80, 53)       0           multi_head_attention_89[0][0]
# __________________________________________________________________________________________________
# dropout_119 (Dropout)           (None, 80, 53)       0           multi_head_attention_91[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_126 (TFOpL (None, 80, 53)       0           dropout_115[0][0]
#                                                                  tf.__operators__.add_125[0][0]
# __________________________________________________________________________________________________
# tf.__operators__.add_130 (TFOpL (None, 80, 53)       0           dropout_119[0][0]
#                                                                  tf.__operators__.add_125[0][0]
# __________________________________________________________________________________________________
# layer_normalization_162 (LayerN (None, 80, 53)       106         tf.__operators__.add_126[0][0]
# __________________________________________________________________________________________________
# layer_normalization_166 (LayerN (None, 80, 53)       106         tf.__operators__.add_130[0][0]
# ...
#
# Epoch 00071: val_loss did not improve from 0.32782
# Epoch 72/300
# 133/133 [==============================] - 19s 144ms/step - loss: 0.3164 - val_loss: 0.3247
#
# Epoch 00072: val_loss improved from 0.32782 to 0.32466, saving model to folds3.hdf5
# Epoch 73/300
# 133/133 [==============================] - 19s 144ms/step - loss: 0.3027 - val_loss: 0.3304
#
# Epoch 00073: val_loss did not improve from 0.32466
# Epoch 74/300
# 133/133 [==============================] - 19s 144ms/step - loss: 0.3089 - val_loss: 0.3281
#
# Epoch 00074: val_loss did not improve from 0.32466
# Epoch 75/300
# 133/133 [==============================] - 19s 144ms/step - loss: 0.3059 - val_loss: 0.3347
#
# Epoch 00075: val_loss did not improve from 0.32466
# Epoch 76/300
# 133/133 [==============================] - 19s 144ms/step - loss: 0.2952 - val_loss: 0.3403
#
# Epoch 00076: val_loss did not improve from 0.32466
# Epoch 77/300
# 133/133 [==============================] - 19s 145ms/step - loss: 0.3035 - val_loss: 0.3304
#
# Epoch 00077: val_loss did not improve from 0.32466
# Epoch 78/300
# 133/133 [==============================] - 19s 144ms/step - loss: 0.3010 - val_loss: 0.3153
#
# Epoch 00078: val_loss improved from 0.32466 to 0.31534, saving model to folds3.hdf5
# Epoch 79/300
# 133/133 [==============================] - 19s 144ms/step - loss: 0.2987 - val_loss: 0.3314
#
# Epoch 00079: val_loss did not improve from 0.31534
# Epoch 80/300
# 133/133 [==============================] - 20s 150ms/step - loss: 0.2960 - val_loss: 0.3180
#
# Epoch 00080: val_loss did not improve from 0.31534
# Epoch 81/300
# 133/133 [==============================] - 19s 144ms/step - loss: 0.2910 - val_loss: 0.3266
#
# Epoch 00081: val_loss did not improve from 0.31534
# Epoch 82/300
# 133/133 [==============================] - 19s 144ms/step - loss: 0.2908 - val_loss: 0.3037
#
# Epoch 00082: val_loss improved from 0.31534 to 0.30375, saving model to folds3.hdf5
# Epoch 83/300
# 133/133 [==============================] - 19s 144ms/step - loss: 0.2887 - val_loss: 0.3023
#
# Epoch 00083: val_loss improved from 0.30375 to 0.30230, saving model to folds3.hdf5
# Epoch 84/300
# 133/133 [==============================] - 19s 144ms/step - loss: 0.2921 - val_loss: 0.3231
#
# Epoch 00084: val_loss did not improve from 0.30230
# Epoch 85/300
# 133/133 [==============================] - 19s 144ms/step - loss: 0.2936 - val_loss: 0.3135
#
# Epoch 00085: val_loss did not improve from 0.30230
# Epoch 86/300
# 133/133 [==============================] - 19s 144ms/step - loss: 0.2914 - val_loss: 0.3123
#
# Epoch 00086: val_loss did not improve from 0.30230
# Epoch 87/300
# 133/133 [==============================] - 19s 144ms/step - loss: 0.2837 - val_loss: 0.3017
#
# Epoch 00087: val_loss improved from 0.30230 to 0.30171, saving model to folds3.hdf5
# Epoch 88/300
# 133/133 [==============================] - 19s 144ms/step - loss: 0.2831 - val_loss: 0.3005
#
# Epoch 00088: val_loss improved from 0.30171 to 0.30045, saving model to folds3.hdf5
# Epoch 89/300
# 133/133 [==============================] - 19s 144ms/step - loss: 0.2861 - val_loss: 0.3045
#
# Epoch 00089: val_loss did not improve from 0.30045
# Epoch 90/300
# 133/133 [==============================] - 19s 144ms/step - loss: 0.2860 - val_loss: 0.3049
#
# Epoch 00090: val_loss did not improve from 0.30045
# Epoch 91/300
# 133/133 [==============================] - 19s 144ms/step - loss: 0.2807 - val_loss: 0.3437
#
# Epoch 00091: val_loss did not improve from 0.30045
# Epoch 92/300
# 133/133 [==============================] - 19s 144ms/step - loss: 0.2807 - val_loss: 0.3034
#
# Epoch 00092: val_loss did not improve from 0.30045
# Epoch 93/300
# 133/133 [==============================] - 19s 144ms/step - loss: 0.2825 - val_loss: 0.3181
#
# Epoch 00093: val_loss did not improve from 0.30045
# Epoch 94/300
# 133/133 [==============================] - 19s 144ms/step - loss: 0.2793 - val_loss: 0.2980
#
# Epoch 00094: val_loss improved from 0.30045 to 0.29803, saving model to folds3.hdf5
# Epoch 95/300
# 133/133 [==============================] - 19s 144ms/step - loss: 0.2745 - val_loss: 0.3015
#
# Epoch 00095: val_loss did not improve from 0.29803
# Epoch 96/300
# 133/133 [==============================] - 19s 144ms/step - loss: 0.2729 - val_loss: 0.2956
#
# Epoch 00096: val_loss improved from 0.29803 to 0.29562, saving model to folds3.hdf5
# Epoch 97/300
# 133/133 [==============================] - 19s 144ms/step - loss: 0.2746 - val_loss: 0.2993
#
# Epoch 00097: val_loss did not improve from 0.29562
# Epoch 98/300
# 133/133 [==============================] - 19s 144ms/step - loss: 0.2777 - val_loss: 0.3069
#
# Epoch 00098: val_loss did not improve from 0.29562
# Epoch 99/300
# 133/133 [==============================] - 19s 144ms/step - loss: 0.2680 - val_loss: 0.2868
#
# Epoch 00099: val_loss improved from 0.29562 to 0.28682, saving model to folds3.hdf5
# Epoch 100/300
# 133/133 [==============================] - 19s 144ms/step - loss: 0.2748 - val_loss: 0.2916
#
# Epoch 00100: val_loss did not improve from 0.28682
# Epoch 101/300
# 133/133 [==============================] - 19s 144ms/step - loss: 0.2622 - val_loss: 0.2856
#
# Epoch 00101: val_loss improved from 0.28682 to 0.28559, saving model to folds3.hdf5
# Epoch 102/300
# 133/133 [==============================] - 19s 144ms/step - loss: 0.2667 - val_loss: 0.2879
#
# Epoch 00102: val_loss did not improve from 0.28559
# Epoch 103/300
# 133/133 [==============================] - 19s 144ms/step - loss: 0.2701 - val_loss: 0.2800
#
# Epoch 00103: val_loss improved from 0.28559 to 0.28004, saving model to folds3.hdf5
# Epoch 104/300
# 133/133 [==============================] - 19s 144ms/step - loss: 0.2622 - val_loss: 0.2851
#
# Epoch 00104: val_loss did not improve from 0.28004
# Epoch 105/300
# 133/133 [==============================] - 19s 144ms/step - loss: 0.2620 - val_loss: 0.2838
#
# Epoch 00105: val_loss did not improve from 0.28004
# Epoch 106/300
# 133/133 [==============================] - 19s 144ms/step - loss: 0.2629 - val_loss: 0.2822
#
# Epoch 00106: val_loss did not improve from 0.28004
# Epoch 107/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.2593 - val_loss: 0.3009
#
# Epoch 00107: val_loss did not improve from 0.28004
# Epoch 108/300
# 133/133 [==============================] - 19s 144ms/step - loss: 0.2639 - val_loss: 0.2855
#
# Epoch 00108: val_loss did not improve from 0.28004
# Epoch 109/300
# 133/133 [==============================] - 19s 144ms/step - loss: 0.2599 - val_loss: 0.2920
#
# Epoch 00109: val_loss did not improve from 0.28004
# Epoch 110/300
# 133/133 [==============================] - 19s 144ms/step - loss: 0.2564 - val_loss: 0.2814
#
# Epoch 00110: val_loss did not improve from 0.28004
# Epoch 111/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.2614 - val_loss: 0.2895
#
# Epoch 00111: val_loss did not improve from 0.28004
# Epoch 112/300
# 133/133 [==============================] - 19s 144ms/step - loss: 0.2555 - val_loss: 0.2782
#
# Epoch 00112: val_loss improved from 0.28004 to 0.27825, saving model to folds3.hdf5
# Epoch 113/300
# 133/133 [==============================] - 19s 144ms/step - loss: 0.2539 - val_loss: 0.2758
#
# Epoch 00113: val_loss improved from 0.27825 to 0.27579, saving model to folds3.hdf5
# Epoch 114/300
# 133/133 [==============================] - 19s 144ms/step - loss: 0.2548 - val_loss: 0.2994
#
# Epoch 00114: val_loss did not improve from 0.27579
# Epoch 115/300
# 133/133 [==============================] - 19s 144ms/step - loss: 0.2548 - val_loss: 0.2751
#
# Epoch 00115: val_loss improved from 0.27579 to 0.27510, saving model to folds3.hdf5
# Epoch 116/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.2543 - val_loss: 0.2834
#
# Epoch 00116: val_loss did not improve from 0.27510
# Epoch 117/300
# 133/133 [==============================] - 19s 144ms/step - loss: 0.2566 - val_loss: 0.2851
#
# Epoch 00117: val_loss did not improve from 0.27510
# Epoch 118/300
# 133/133 [==============================] - 19s 144ms/step - loss: 0.2504 - val_loss: 0.2720
#
# Epoch 00118: val_loss improved from 0.27510 to 0.27203, saving model to folds3.hdf5
# Epoch 119/300
# 133/133 [==============================] - 19s 144ms/step - loss: 0.2498 - val_loss: 0.2812
#
# Epoch 00119: val_loss did not improve from 0.27203
# Epoch 120/300
# 133/133 [==============================] - 19s 144ms/step - loss: 0.2468 - val_loss: 0.2696
#
# Epoch 00120: val_loss improved from 0.27203 to 0.26956, saving model to folds3.hdf5
# Epoch 121/300
# 133/133 [==============================] - 19s 144ms/step - loss: 0.2402 - val_loss: 0.2671
#
# Epoch 00121: val_loss improved from 0.26956 to 0.26708, saving model to folds3.hdf5
# Epoch 122/300
# 133/133 [==============================] - 19s 144ms/step - loss: 0.2463 - val_loss: 0.2748
#
# Epoch 00122: val_loss did not improve from 0.26708
# Epoch 123/300
# 133/133 [==============================] - 19s 144ms/step - loss: 0.2486 - val_loss: 0.2801
#
# Epoch 00123: val_loss did not improve from 0.26708
# Epoch 124/300
# 133/133 [==============================] - 19s 144ms/step - loss: 0.2475 - val_loss: 0.2725
#
# Epoch 00124: val_loss did not improve from 0.26708
# Epoch 125/300
# 133/133 [==============================] - 19s 144ms/step - loss: 0.2455 - val_loss: 0.2882
#
# Epoch 00125: val_loss did not improve from 0.26708
# Epoch 126/300
# 133/133 [==============================] - 19s 144ms/step - loss: 0.2393 - val_loss: 0.2646
#
# Epoch 00126: val_loss improved from 0.26708 to 0.26456, saving model to folds3.hdf5
# Epoch 127/300
# 133/133 [==============================] - 19s 144ms/step - loss: 0.2392 - val_loss: 0.2681
#
# Epoch 00127: val_loss did not improve from 0.26456
# Epoch 128/300
# 133/133 [==============================] - 19s 144ms/step - loss: 0.2394 - val_loss: 0.2601
#
# Epoch 00128: val_loss improved from 0.26456 to 0.26008, saving model to folds3.hdf5
# Epoch 129/300
# 133/133 [==============================] - 19s 144ms/step - loss: 0.2421 - val_loss: 0.2753
#
# Epoch 00129: val_loss did not improve from 0.26008
# Epoch 130/300
# 133/133 [==============================] - 19s 144ms/step - loss: 0.2467 - val_loss: 0.2693
#
# Epoch 00130: val_loss did not improve from 0.26008
# Epoch 131/300
# 133/133 [==============================] - 19s 144ms/step - loss: 0.2404 - val_loss: 0.2756
#
# Epoch 00131: val_loss did not improve from 0.26008
# Epoch 132/300
# 133/133 [==============================] - 19s 144ms/step - loss: 0.2393 - val_loss: 0.2628
#
# Epoch 00132: val_loss did not improve from 0.26008
# Epoch 133/300
# 133/133 [==============================] - 19s 144ms/step - loss: 0.2387 - val_loss: 0.2633
#
# Epoch 00133: val_loss did not improve from 0.26008
# Epoch 134/300
# 133/133 [==============================] - 19s 144ms/step - loss: 0.2319 - val_loss: 0.2651
#
# Epoch 00134: val_loss did not improve from 0.26008
# Epoch 135/300
# 133/133 [==============================] - 19s 144ms/step - loss: 0.2387 - val_loss: 0.2748
#
# Epoch 00135: val_loss did not improve from 0.26008
# Epoch 136/300
# 133/133 [==============================] - 19s 144ms/step - loss: 0.2334 - val_loss: 0.2740
#
# Epoch 00136: val_loss did not improve from 0.26008
# Epoch 137/300
# 133/133 [==============================] - 19s 144ms/step - loss: 0.2379 - val_loss: 0.2884
#
# Epoch 00137: val_loss did not improve from 0.26008
# Epoch 138/300
# 133/133 [==============================] - 19s 144ms/step - loss: 0.2366 - val_loss: 0.2633
#
# Epoch 00138: ReduceLROnPlateau reducing learning rate to 0.0007500000356230885.
#
# Epoch 00138: val_loss did not improve from 0.26008
# Epoch 139/300
# 133/133 [==============================] - 19s 144ms/step - loss: 0.2183 - val_loss: 0.2460
#
# Epoch 00139: val_loss improved from 0.26008 to 0.24603, saving model to folds3.hdf5
# Epoch 140/300
# 133/133 [==============================] - 19s 144ms/step - loss: 0.2115 - val_loss: 0.2461
#
# Epoch 00140: val_loss did not improve from 0.24603
# Epoch 141/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.2111 - val_loss: 0.2431
#
# Epoch 00141: val_loss improved from 0.24603 to 0.24310, saving model to folds3.hdf5
# Epoch 142/300
# 133/133 [==============================] - 19s 143ms/step - loss: 0.2112 - val_loss: 0.2457
#
# Epoch 00142: val_loss did not improve from 0.24310
# Epoch 143/300
# 133/133 [==============================] - 19s 144ms/step - loss: 0.2139 - val_loss: 0.2529
#
# Epoch 00143: val_loss did not improve from 0.24310
# Epoch 144/300
# 133/133 [==============================] - 19s 144ms/step - loss: 0.2141 - val_loss: 0.2568
#
# Epoch 00144: val_loss did not improve from 0.24310
# Epoch 145/300
# 133/133 [==============================] - 19s 144ms/step - loss: 0.2128 - val_loss: 0.2453
#
# Epoch 00145: val_loss did not improve from 0.24310
# Epoch 146/300
# 133/133 [==============================] - 19s 144ms/step - loss: 0.2106 - val_loss: 0.2444
#
# Epoch 00146: val_loss did not improve from 0.24310
# Epoch 147/300
# 133/133 [==============================] - 19s 144ms/step - loss: 0.2107 - val_loss: 0.2456
#
# Epoch 00147: val_loss did not improve from 0.24310
# Epoch 148/300
# 133/133 [==============================] - 19s 144ms/step - loss: 0.2105 - val_loss: 0.2413
#
# Epoch 00148: val_loss improved from 0.24310 to 0.24129, saving model to folds3.hdf5
# Epoch 149/300
# 133/133 [==============================] - 19s 144ms/step - loss: 0.2110 - val_loss: 0.2419
#
# Epoch 00149: val_loss did not improve from 0.24129
# Epoch 150/300
# 133/133 [==============================] - 19s 144ms/step - loss: 0.2089 - val_loss: 0.2411
#
# Epoch 00150: val_loss improved from 0.24129 to 0.24113, saving model to folds3.hdf5
# Epoch 151/300
# 133/133 [==============================] - 19s 144ms/step - loss: 0.2072 - val_loss: 0.2441
#
# Epoch 00151: val_loss did not improve from 0.24113
# Epoch 152/300
# 133/133 [==============================] - 19s 144ms/step - loss: 0.2087 - val_loss: 0.2407
#
# Epoch 00152: val_loss improved from 0.24113 to 0.24066, saving model to folds3.hdf5
# Epoch 153/300
# 133/133 [==============================] - 19s 144ms/step - loss: 0.2119 - val_loss: 0.2503
#
# Epoch 00153: val_loss did not improve from 0.24066
# Epoch 154/300
# 133/133 [==============================] - 19s 144ms/step - loss: 0.2143 - val_loss: 0.2402
#
# Epoch 00154: val_loss improved from 0.24066 to 0.24022, saving model to folds3.hdf5
# Epoch 155/300
# 133/133 [==============================] - 19s 144ms/step - loss: 0.2088 - val_loss: 0.2469
#
# Epoch 00155: val_loss did not improve from 0.24022
# Epoch 156/300
# 133/133 [==============================] - 19s 145ms/step - loss: 0.2074 - val_loss: 0.2504
#
# Epoch 00156: val_loss did not improve from 0.24022
# Epoch 157/300
# 133/133 [==============================] - 19s 144ms/step - loss: 0.2050 - val_loss: 0.2401
#
# Epoch 00157: val_loss improved from 0.24022 to 0.24005, saving model to folds3.hdf5
# Epoch 158/300
# 133/133 [==============================] - 19s 144ms/step - loss: 0.2057 - val_loss: 0.2362
#
# Epoch 00158: val_loss improved from 0.24005 to 0.23618, saving model to folds3.hdf5
# Epoch 159/300
# 133/133 [==============================] - 19s 144ms/step - loss: 0.2047 - val_loss: 0.2362
#
# Epoch 00159: val_loss did not improve from 0.23618
# Epoch 160/300
# 133/133 [==============================] - 19s 144ms/step - loss: 0.2078 - val_loss: 0.2389
#
# Epoch 00160: val_loss did not improve from 0.23618
# Epoch 161/300
# 133/133 [==============================] - 19s 144ms/step - loss: 0.2067 - val_loss: 0.2480
#
# Epoch 00161: val_loss did not improve from 0.23618
# Epoch 162/300
# 133/133 [==============================] - 19s 144ms/step - loss: 0.2065 - val_loss: 0.2434
#
# Epoch 00162: val_loss did not improve from 0.23618
# Epoch 163/300
# 133/133 [==============================] - 20s 149ms/step - loss: 0.2058 - val_loss: 0.2443
#
# Epoch 00163: val_loss did not improve from 0.23618
# Epoch 164/300
# 133/133 [==============================] - 19s 144ms/step - loss: 0.2061 - val_loss: 0.2409
#
# Epoch 00164: val_loss did not improve from 0.23618
# Epoch 165/300
# 133/133 [==============================] - 19s 144ms/step - loss: 0.2011 - val_loss: 0.2358
#
# Epoch 00165: val_loss improved from 0.23618 to 0.23575, saving model to folds3.hdf5
# Epoch 166/300
#   2/133 [..............................] - ETA: 17s - loss: 0.2046

# %%
mae(targets.flatten(), np.median(np.vstack(train_preds),axis=0))

# %%
PRESSURE_STEP = 0.07030214545120961
PRESSURE_MIN = -1.8957442945646408
PRESSURE_MAX = 64.82099173863948

# %%
# ENSEMBLE FOLDS WITH MEAN
submission["pressure"] = sum(test_preds)/len(test_preds)
submission.to_csv('submission_mean.csv', index=False)

# %%
# ENSEMBLE FOLDS WITH MEDIAN
submission["pressure"] = np.median(np.vstack(test_preds),axis=0)
submission.to_csv('submission_median.csv', index=False)

# %%
# ENSEMBLE FOLDS WITH MEDIAN AND ROUND PREDICTIONS
submission["pressure"] =\
    np.round( (submission.pressure - PRESSURE_MIN)/PRESSURE_STEP ) * PRESSURE_STEP + PRESSURE_MIN
submission.pressure = np.clip(submission.pressure, PRESSURE_MIN, PRESSURE_MAX)
submission.to_csv('submission_median_round.csv', index=False)

# %%
if IN_COLAB:
  # !zip cnn_models.zip *.hdf5
  # !zip submission.zip *.csv
  with open(model_folder + 'submission.zip', 'wb') as f:
    f.write(open('submission.zip', 'rb').read())
  with open(model_folder + 'cnn_models.zip', 'wb') as f:
    f.write(open('cnn_models.zip', 'rb').read())
